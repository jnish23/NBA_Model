# %% [markdown]
# # Team Based Model

# %% [markdown]
# ## Imports

# %%
import pep8
import autopep8
import sqlite3
import joblib
import optuna
import plotly.graph_objects as go
import plotly.express as px
import parfit.parfit as pf
from sklearn.model_selection import ParameterGrid
import pickle
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import learning_curve, validation_curve
import sklearn.model_selection
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import VarianceThreshold, RFE, RFECV
from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn.model_selection import cross_val_score
from skopt.space import Real, Categorical, Integer
from skopt import BayesSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import StackingClassifier
import xgboost as xgb
from sklearn.svm import LinearSVC, SVC
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import ElasticNetCV, LogisticRegression, SGDClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split, TimeSeriesSplit
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import pointbiserialr

from tqdm import tqdm
from nba_api.stats.static import players, teams

import sys

# %load_ext autoreload
# %autoreload 2

sys.path.append("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.options.display.max_columns=230
pd.options.display.max_rows=120

# %% [markdown]
# ## Gather Team Level Basic, Advanced, and Scoring Data

# %%
def load_team_data(conn):
    """Loads basic, advanced, and scoring boxscores 
    from sqlite db and merges them into one dataframe"""

    basic = pd.read_sql("SELECT * FROM team_basic_boxscores", connection)
    adv = pd.read_sql("SELECT * FROM team_advanced_boxscores", connection)
    scoring = pd.read_sql("SELECT * FROM team_scoring_boxscores", connection)

    temp = pd.merge(basic, adv, how='left', on=[
                    'GAME_ID', 'TEAM_ID'], suffixes=['', '_y'])
    df = pd.merge(temp, scoring, how='left', on=[
                  'GAME_ID', 'TEAM_ID'], suffixes=['', '_y'])

    df = df.drop(columns=['TEAM_NAME_y', 'TEAM_CITY',
                          'TEAM_ABBREVIATION_y',
                          'TEAM_CITY_y', 'MIN_y'])
    return df


connection = sqlite3.connect('../data/nba.db')
df = load_team_data(connection)
connection.close()

# %%
df.loc[df['GAME_ID'] == '0022000098']
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  \
# 51534  2020-21  1610612745               HOU   Houston Rockets  0022000098
# 51535  2020-21  1610612742               DAL  Dallas Mavericks  0022000098
#
#         GAME_DATE      MATCHUP WL  MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 51534  2021-01-04  HOU vs. DAL  L  240   30   77   0.390    11    40    0.275
# 51535  2021-01-04    DAL @ HOU  W  240   39   82   0.476    16    39    0.410
#
#        FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS  \
# 51534   29   36   0.806     7    28   35   17    5    4   12  19  100
# 51535   19   20   0.950    10    41   51   24    4    3   18  31  113
#
#        PLUS_MINUS  E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  \
# 51534         -13         102.2       105.3         114.4       118.9
# 51535          13         114.4       118.9         102.2       105.3
#
#        E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  OREB_PCT  \
# 51534         -12.2       -13.7    0.567     1.42       14.0     0.176
# 51535          12.2        13.7    0.615     1.33       18.1     0.326
#
#        DREB_PCT  REB_PCT  E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  \
# 51534     0.674    0.404        12.265        12.6    0.461   0.539      1.0
# 51535     0.824    0.596        18.219        18.9    0.573   0.622      1.0
#
#        E_USG_PCT  E_PACE  PACE  PACE_PER40  POSS    PIE  PCT_FGA_2PT  \
# 51534      0.196   98.32  95.0       79.17  95.0  0.425        0.481
# 51535      0.191   98.32  95.0       79.17  95.0  0.575        0.524
#
#        PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  PCT_PTS_FB  \
# 51534        0.519        0.380           0.020        0.330        0.04
# 51535        0.476        0.407           0.071        0.425        0.08
#
#        PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  PCT_UAST_2PM  \
# 51534       0.290            0.230          0.360        0.579         0.421
# 51535       0.168            0.088          0.336        0.478         0.522
#
#        PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM
# 51534        0.545         0.455        0.567         0.433
# 51535        0.813         0.188        0.615         0.385

# %%
def clean_team_data(df):
    """This function cleans the team_data
    1) Changes W/L to 1/0 
    2) Changes franchise abbreviations to their most 
    recent abbreviation for consistency
    3) Converts GAME_DATE to datetime object
    4) Creates a binary column 'HOME_GAME'
    5) Removes 3 games where advanced stats were not collected
    """
    df = df.copy()
    df['WL'] = (df['WL'] == 'W').astype(int)

    abbr_mapping = {'NJN': 'BKN',
                    'CHH': 'CHA',
                    'VAN': 'MEM',
                    'NOH': 'NOP',
                    'NOK': 'NOP',
                    'SEA': 'OKC'}

    df['TEAM_ABBREVIATION'] = df['TEAM_ABBREVIATION'].replace(abbr_mapping)
    df['MATCHUP'] = df['MATCHUP'].str.replace('NJN', 'BKN')
    df['MATCHUP'] = df['MATCHUP'].str.replace('CHH', 'CHA')
    df['MATCHUP'] = df['MATCHUP'].str.replace('VAN', 'MEM')
    df['MATCHUP'] = df['MATCHUP'].str.replace('NOH', 'NOP')
    df['MATCHUP'] = df['MATCHUP'].str.replace('NOK', 'NOP')
    df['MATCHUP'] = df['MATCHUP'].str.replace('SEA', 'OKC')

    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])

    df['HOME_GAME'] = df['MATCHUP'].str.contains('vs').astype(int)

    df = df.dropna(subset=['E_OFF_RATING'])

    return df


clean_df = clean_team_data(df)
clean_df
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      2000-01  1610612739               CLE     Cleveland Cavaliers
# 1      2000-01  1610612751               BKN         New Jersey Nets
# 2      2000-01  1610612745               HOU         Houston Rockets
# 3      2000-01  1610612750               MIN  Minnesota Timberwolves
# 4      2000-01  1610612759               SAS       San Antonio Spurs
# ...        ...         ...               ...                     ...
# 53671  2020-21  1610612749               MIL         Milwaukee Bucks
# 53672  2020-21  1610612756               PHX            Phoenix Suns
# 53673  2020-21  1610612749               MIL         Milwaukee Bucks
# 53674  2020-21  1610612749               MIL         Milwaukee Bucks
# 53675  2020-21  1610612756               PHX            Phoenix Suns
#
#           GAME_ID  GAME_DATE      MATCHUP  WL  MIN  FGM  FGA  FG_PCT  FG3M  \
# 0      0020000002 2000-10-31    CLE @ BKN   1  240   32   78   0.410     2
# 1      0020000002 2000-10-31  BKN vs. CLE   0  240   31   85   0.365     3
# 2      0020000008 2000-10-31  HOU vs. MIN   0  240   34   74   0.459     2
# 3      0020000008 2000-10-31    MIN @ HOU   1  240   43   88   0.489     6
# 4      0020000009 2000-10-31  SAS vs. IND   1  240   33   64   0.516     4
# ...           ...        ...          ...  ..  ...  ...  ...     ...   ...
# 53671  0042000404 2021-07-14  MIL vs. PHX   1  240   39   97   0.402     7
# 53672  0042000405 2021-07-17  PHX vs. MIL   0  240   48   87   0.552    13
# 53673  0042000405 2021-07-17    MIL @ PHX   1  240   50   87   0.575    14
# 53674  0042000406 2021-07-20  MIL vs. PHX   1  240   37   82   0.451     6
# 53675  0042000406 2021-07-20    PHX @ MIL   0  240   38   86   0.442     6
#
#        FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  \
# 0         7    0.286   20   32   0.625    11    41   52   16    5    8   19
# 1        10    0.300   17   26   0.654    12    35   47   24    9    8   15
# 2         9    0.222   28   40   0.700    11    27   38   18    9    7   18
# 3        11    0.545   14   16   0.875    13    31   44   29    7    1   16
# 4         8    0.500   28   35   0.800     5    32   37   17    6    4   18
# ...     ...      ...  ...  ...     ...   ...   ...  ...  ...  ...  ...  ...
# 53671    29    0.241   24   29   0.828    17    31   48   22   11    3    5
# 53672    19    0.684   10   11   0.909     8    27   35   23    9    5    9
# 53673    28    0.500    9   17   0.529    11    26   37   26    7    1   12
# 53674    27    0.222   25   29   0.862    11    42   53   20   10    6   19
# 53675    25    0.240   16   19   0.842     6    31   37   14   11    4   15
#
#        PF  PTS  PLUS_MINUS  E_OFF_RATING  OFF_RATING  E_DEF_RATING  \
# 0      27   86           4          85.9        87.8          82.5
# 1      31   82          -4          82.5        83.7          85.9
# 2      17   98          -8          99.4       103.2         108.1
# 3      25  106           8         108.1       110.4          99.4
# 4      22   98          13         106.1       104.3          90.7
# ...    ..  ...         ...           ...         ...           ...
# 53671  18  109           6         111.5       112.4         104.7
# 53672  20  119          -4         128.2       129.3         128.8
# 53673  17  123           4         128.8       135.2         128.2
# 53674  17  105           7         102.2       101.9          94.8
# 53675  21   98          -7          94.8        96.1         102.2
#
#        DEF_RATING  E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  \
# 0            83.7           3.5         4.1    0.500     0.84       12.6
# 1            87.8          -3.5        -4.1    0.774     1.60       17.7
# 2           110.4          -8.7        -7.3    0.529     1.00       14.1
# 3           103.2           8.7         7.3    0.674     1.81       20.7
# 4            90.4          15.4        13.8    0.515     0.94       14.9
# ...           ...           ...         ...      ...      ...        ...
# 53671       106.2           6.8         6.2    0.564     4.40       16.1
# 53672       135.2          -0.6        -5.8    0.479     2.56       18.6
# 53673       129.3           0.6         5.8    0.520     2.17       19.6
# 53674        96.1           7.4         5.9    0.541     1.05       15.0
# 53675       101.9          -7.4        -5.9    0.368     0.93       11.3
#
#        OREB_PCT  DREB_PCT  REB_PCT  E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  \
# 0         0.302     0.724    0.523        18.985        19.4    0.423   0.467
# 1         0.276     0.698    0.477        15.084        15.3    0.382   0.425
# 2         0.289     0.667    0.478        18.256        18.9    0.473   0.535
# 3         0.333     0.711    0.522        16.320        16.7    0.523   0.558
# 4           NaN     0.761      NaN        19.481        19.1    0.547   0.617
# ...         ...       ...      ...           ...         ...      ...     ...
# 53671     0.344     0.795    0.520         5.115         5.2    0.438   0.497
# 53672     0.300     0.643    0.476         9.694         9.8    0.626   0.648
# 53673     0.357     0.700    0.524        12.568        13.2    0.655   0.651
# 53674     0.319     0.857    0.594        18.490        18.4    0.488   0.554
# 53675     0.143     0.681    0.406        14.512        14.7    0.477   0.519
#
#        USG_PCT  E_USG_PCT  E_PACE   PACE  PACE_PER40   POSS    PIE  \
# 0          1.0      0.202   99.76   98.0       81.67   98.0  0.512
# 1          1.0      0.196   99.76   98.0       81.67   98.0  0.488
# 2          1.0      0.197   98.32   95.5       79.58   95.0  0.446
# 3          1.0      0.195   98.32   95.5       79.58   96.0  0.554
# 4          1.0      0.203   93.06   94.0       78.33   94.0  0.641
# ...        ...        ...     ...    ...         ...    ...    ...
# 53671      1.0      0.202   98.06   97.0       80.83   97.0  0.536
# 53672      1.0      0.198   94.16   91.5       76.25   92.0  0.503
# 53673      1.0      0.195   94.16   91.5       76.25   91.0  0.497
# 53674      1.0      0.200  103.06  102.5       85.42  103.0  0.583
# 53675      1.0      0.196  103.06  102.5       85.42  102.0  0.417
#
#        PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  \
# 0            0.910        0.090        0.698           0.279        0.070
# 1            0.882        0.118        0.683           0.171        0.110
# 2            0.878        0.122        0.653           0.163        0.061
# 3            0.875        0.125        0.698           0.396        0.170
# 4            0.875        0.125        0.592           0.429        0.122
# ...            ...          ...          ...             ...          ...
# 53671        0.701        0.299        0.587           0.147        0.193
# 53672        0.782        0.218        0.588           0.151        0.328
# 53673        0.678        0.322        0.585           0.211        0.341
# 53674        0.671        0.329        0.590           0.114        0.171
# 53675        0.709        0.291        0.653           0.204        0.184
#
#        PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  \
# 0           0.163       0.233            0.140          0.419        0.467
# 1           0.110       0.207            0.256          0.512        0.750
# 2           0.102       0.286            0.204          0.490        0.563
# 3           0.085       0.132            0.208          0.302        0.622
# 4           0.061       0.286            0.153          0.163        0.448
# ...           ...         ...              ...            ...          ...
# 53671       0.138       0.220            0.220          0.440        0.500
# 53672       0.101       0.084            0.143          0.437        0.400
# 53673       0.171       0.073            0.130          0.374        0.389
# 53674       0.105       0.238            0.095          0.476        0.548
# 53675       0.112       0.163            0.163          0.449        0.313
#
#        PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM  \
# 0             0.533        1.000         0.000        0.500         0.500
# 1             0.250        1.000         0.000        0.774         0.226
# 2             0.438        0.000         1.000        0.529         0.471
# 3             0.378        1.000         0.000        0.674         0.326
# 4             0.552        1.000         0.000        0.515         0.485
# ...             ...          ...           ...          ...           ...
# 53671         0.500        0.857         0.143        0.564         0.436
# 53672         0.600        0.692         0.308        0.479         0.521
# 53673         0.611        0.857         0.143        0.520         0.480
# 53674         0.452        0.500         0.500        0.541         0.459
# 53675         0.688        0.667         0.333        0.368         0.632
#
#        HOME_GAME
# 0              0
# 1              1
# 2              1
# 3              0
# 4              1
# ...          ...
# 53671          1
# 53672          1
# 53673          0
# 53674          1
# 53675          0
#
# [53674 rows x 67 columns]

# %%
from src.data.make_team_dataset import prep_for_aggregation


def prep_for_aggregation(df):
    """This function...
    1) Removes categories that are percentages,
    as we will be averaging them and do not want to average 
    percentages. 
    2) Converts shooting percentage stats into raw values"""
    df = df.copy()

    df = df.drop(columns=['FT_PCT', 'FG_PCT', 'FG3_PCT', 'DREB_PCT',
                          'OREB_PCT', 'REB_PCT', 'AST_PCT', 'AST_TOV',
                          'AST_RATIO', 'E_TM_TOV_PCT', 'TM_TOV_PCT',
                          'EFG_PCT', 'TS_PCT', 'USG_PCT', 'E_USG_PCT',
                          'PACE', 'PACE_PER40', 'MIN'])

    df['FG2M'] = df['FGM'] - df['FG3M']
    df['FG2A'] = df['FGA'] - df['FG3A']
    df['PTS_2PT_MR'] = (df['PTS'] * df['PCT_PTS_2PT_MR']).astype('int8')
    df['PTS_FB'] = (df['PTS'] * df['PCT_PTS_FB']).astype('int8')
    df['PTS_OFF_TOV'] = (df['PTS'] * df['PCT_PTS_OFF_TOV']).astype('int8')
    df['PTS_PAINT'] = (df['PTS'] * df['PCT_PTS_PAINT']).astype('int8')
    df['AST_2PM'] = (df['FG2M'] * df['PCT_AST_2PM']).astype('int8')
    df['AST_3PM'] = (df['FG3M'] * df['PCT_AST_3PM']).astype('int8')
    df['UAST_2PM'] = (df['FG2M'] * df['PCT_UAST_2PM']).astype('int8')
    df['UAST_3PM'] = (df['FG3M'] * df['PCT_UAST_3PM']).astype('int8')

#     df = df.drop(columns = ['PCT_PTS_2PT', 'PCT_PTS_2PT_MR',
#                             'PCT_PTS_3PT', 'PCT_PTS_FB',
#                             'PCT_PTS_OFF_TOV', 'PCT_PTS_PAINT',
#                             'PCT_AST_2PM', 'PCT_UAST_2PM',
#                             'PCT_AST_3PM', 'PCT_UAST_3PM',
#                             'PCT_AST_FGM', 'PCT_UAST_FGM',
#                             'FGM', 'FGA'])

    df['POINT_DIFF'] = df['PLUS_MINUS']
    df['RECORD'] = df['WL']
    df['TEAM_SCORE'] = df['PTS']

    df = df[['SEASON', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
             'GAME_DATE', 'MATCHUP', 'HOME_GAME', 'TEAM_SCORE', 'POINT_DIFF', 'WL',
             'RECORD', 'FG2M', 'FG2A', 'FG3M', 'FG3A', 'FTM', 'FTA', 'OREB', 'DREB',
             'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS',
             'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
             'E_NET_RATING', 'NET_RATING', 'POSS', 'PIE', 'PTS_2PT_MR',
             'PTS_FB', 'PTS_OFF_TOV', 'PTS_PAINT', 'AST_2PM', 'AST_3PM',
             'UAST_2PM', 'UAST_3PM']]

    return df


clean_df2 = prep_for_aggregation(clean_df)

clean_df2
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      2000-01  1610612739               CLE     Cleveland Cavaliers
# 1      2000-01  1610612751               BKN         New Jersey Nets
# 2      2000-01  1610612745               HOU         Houston Rockets
# 3      2000-01  1610612750               MIN  Minnesota Timberwolves
# 4      2000-01  1610612759               SAS       San Antonio Spurs
# ...        ...         ...               ...                     ...
# 53671  2020-21  1610612749               MIL         Milwaukee Bucks
# 53672  2020-21  1610612756               PHX            Phoenix Suns
# 53673  2020-21  1610612749               MIL         Milwaukee Bucks
# 53674  2020-21  1610612749               MIL         Milwaukee Bucks
# 53675  2020-21  1610612756               PHX            Phoenix Suns
#
#           GAME_ID  GAME_DATE      MATCHUP  HOME_GAME  TEAM_SCORE  POINT_DIFF  \
# 0      0020000002 2000-10-31    CLE @ BKN          0          86           4
# 1      0020000002 2000-10-31  BKN vs. CLE          1          82          -4
# 2      0020000008 2000-10-31  HOU vs. MIN          1          98          -8
# 3      0020000008 2000-10-31    MIN @ HOU          0         106           8
# 4      0020000009 2000-10-31  SAS vs. IND          1          98          13
# ...           ...        ...          ...        ...         ...         ...
# 53671  0042000404 2021-07-14  MIL vs. PHX          1         109           6
# 53672  0042000405 2021-07-17  PHX vs. MIL          1         119          -4
# 53673  0042000405 2021-07-17    MIL @ PHX          0         123           4
# 53674  0042000406 2021-07-20  MIL vs. PHX          1         105           7
# 53675  0042000406 2021-07-20    PHX @ MIL          0          98          -7
#
#        WL  RECORD  FG2M  FG2A  FG3M  FG3A  FTM  FTA  OREB  DREB  REB  AST  \
# 0       1       1    30    71     2     7   20   32    11    41   52   16
# 1       0       0    28    75     3    10   17   26    12    35   47   24
# 2       0       0    32    65     2     9   28   40    11    27   38   18
# 3       1       1    37    77     6    11   14   16    13    31   44   29
# 4       1       1    29    56     4     8   28   35     5    32   37   17
# ...    ..     ...   ...   ...   ...   ...  ...  ...   ...   ...  ...  ...
# 53671   1       1    32    68     7    29   24   29    17    31   48   22
# 53672   0       0    35    68    13    19   10   11     8    27   35   23
# 53673   1       1    36    59    14    28    9   17    11    26   37   26
# 53674   1       1    31    55     6    27   25   29    11    42   53   20
# 53675   0       0    32    61     6    25   16   19     6    31   37   14
#
#        STL  BLK  TOV  PF  PTS  PLUS_MINUS  E_OFF_RATING  OFF_RATING  \
# 0        5    8   19  27   86           4          85.9        87.8
# 1        9    8   15  31   82          -4          82.5        83.7
# 2        9    7   18  17   98          -8          99.4       103.2
# 3        7    1   16  25  106           8         108.1       110.4
# 4        6    4   18  22   98          13         106.1       104.3
# ...    ...  ...  ...  ..  ...         ...           ...         ...
# 53671   11    3    5  18  109           6         111.5       112.4
# 53672    9    5    9  20  119          -4         128.2       129.3
# 53673    7    1   12  17  123           4         128.8       135.2
# 53674   10    6   19  17  105           7         102.2       101.9
# 53675   11    4   15  21   98          -7          94.8        96.1
#
#        E_DEF_RATING  DEF_RATING  E_NET_RATING  NET_RATING   POSS    PIE  \
# 0              82.5        83.7           3.5         4.1   98.0  0.512
# 1              85.9        87.8          -3.5        -4.1   98.0  0.488
# 2             108.1       110.4          -8.7        -7.3   95.0  0.446
# 3              99.4       103.2           8.7         7.3   96.0  0.554
# 4              90.7        90.4          15.4        13.8   94.0  0.641
# ...             ...         ...           ...         ...    ...    ...
# 53671         104.7       106.2           6.8         6.2   97.0  0.536
# 53672         128.8       135.2          -0.6        -5.8   92.0  0.503
# 53673         128.2       129.3           0.6         5.8   91.0  0.497
# 53674          94.8        96.1           7.4         5.9  103.0  0.583
# 53675         102.2       101.9          -7.4        -5.9  102.0  0.417
#
#        PTS_2PT_MR  PTS_FB  PTS_OFF_TOV  PTS_PAINT  AST_2PM  AST_3PM  UAST_2PM  \
# 0              23      14           12         36       14        2        15
# 1              14       9           20         41       21        3         7
# 2              15       9           19         48       18        0        14
# 3              41       9           22         32       23        6        13
# 4              42       5           14         15       12        4        16
# ...           ...     ...          ...        ...      ...      ...       ...
# 53671          16      15           23         47       16        5        16
# 53672          17      12           17         52       14        8        21
# 53673          25      21           15         46       14       11        21
# 53674          11      11            9         49       16        3        14
# 53675          19      10           15         44       10        4        22
#
#        UAST_3PM
# 0             0
# 1             0
# 2             2
# 3             0
# 4             0
# ...         ...
# 53671         1
# 53672         4
# 53673         2
# 53674         3
# 53675         1
#
# [53674 rows x 44 columns]

# %% [markdown]
# ## Add Betting Data

# %%
def load_betting_data(conn):
    spreads = pd.read_sql("SELECT * FROM spreads", conn)
    moneylines = pd.read_sql("SELECT * FROM moneylines", conn)

    return spreads, moneylines


connection = sqlite3.connect("../data/nba.db")
spreads, moneylines = load_betting_data(connection)
connection.close()

# %%
spreads
# Out:
#         SEASON     GM_DATE      HOME_TEAM     AWAY_TEAM  AWAY_SCOREBOARD  \
# 0      2006-07  2006-10-31          Miami       Chicago  22,37,21,28,108
# 1      2006-07  2006-10-31    L.A. Lakers       Phoenix  41,17,21,27,106
# 2      2006-07  2006-11-02         Dallas   San Antonio   26,19,27,25,97
# 3      2006-07  2006-11-02  L.A. Clippers        Denver   24,24,22,25,95
# 4      2006-07  2006-11-03        Memphis     Charlotte   21,26,23,13,83
# ...        ...         ...            ...           ...              ...
# 18776  2007-08  2008-04-29        Detroit  Philadelphia   21,21,17,22,81
# 18777  2007-08  2008-04-29    New Orleans        Dallas   22,17,24,31,94
# 18778  2007-08  2008-04-29        Houston          Utah   16,16,23,14,69
# 18779  2007-08  2008-04-29    San Antonio       Phoenix   26,19,27,15,87
# 18780  2016-17  2017-05-14   Golden State   San Antonio  30,32,28,21,111
#
#        HOME_SCOREBOARD                 AWAY_SPREAD                 HOME_SPREAD
# 0       16,14,21,15,66               -,-,+4½-110,-               -,-,-4½-110,-
# 1      26,27,34,27,114               -,-,-8½-110,-               -,-,+8½-110,-
# 2       27,24,24,16,91                -,-,+3-110,-                -,-,-3-110,-
# 3       18,31,16,31,96               -,-,+4½-110,-               -,-,-4½-110,-
# 4       24,20,16,36,96                -,-,+5-110,-                -,-,-5-110,-
# ...                ...                         ...                         ...
# 18776   35,19,25,19,98         -,+10-110,+9½-110,-         -,-10-110,-9½-110,-
# 18777   28,26,17,28,99           -,+7-110,+7-105,-           -,-7-110,-7-115,-
# 18778   18,25,31,21,95           -,+1-110,+1-110,-           -,-1-110,-1-110,-
# 18779   30,24,15,23,92                -,+5-110,-,-                -,-5-110,-,-
# 18780  16,26,39,32,113  +10½-105,+10-110,+10-110,-  -10½-105,-10-110,-10-110,-
#
# [18781 rows x 8 columns]

# %%
moneylines
# Out:
#         SEASON     GM_DATE    HOME_TEAM      AWAY_TEAM           AWAY_ML  \
# 0      2020-21  2020-12-22     Brooklyn   Golden State  +290,+275,+275,-
# 1      2020-21  2020-12-22  L.A. Lakers  L.A. Clippers  +110,+110,+120,-
# 2      2020-21  2020-12-23    Cleveland      Charlotte  -155,-156,-155,-
# 3      2020-21  2020-12-23      Indiana       New York  +270,+300,+265,-
# 4      2020-21  2020-12-23      Orlando          Miami  -195,-195,-210,-
# ...        ...         ...          ...            ...               ...
# 16234  2020-21  2021-06-17    Milwaukee       Brooklyn  +185,+163,+155,-
# 16235  2020-21  2021-06-27      Atlanta      Milwaukee  -210,-190,-200,-
# 16236  2020-21  2021-07-03      Atlanta      Milwaukee  +150,+135,+130,-
# 16237  2020-21  2021-07-06      Phoenix      Milwaukee  +185,+190,+190,-
# 16238  2020-21  2021-07-11    Milwaukee        Phoenix  +165,+175,+170,-
#
#                 HOME_ML
# 0      -360,-330,-350,-
# 1      -130,-130,-140,-
# 2      +135,+136,+135,-
# 3      -330,-370,-330,-
# 4      +170,+170,+175,-
# ...                 ...
# 16234  -220,-183,-175,-
# 16235  +180,+165,+170,-
# 16236  -170,-155,-150,-
# 16237  -215,-220,-230,-
# 16238  -190,-205,-200,-
#
# [16239 rows x 6 columns]

# %%
def convert_american_to_decimal(x):
    return np.where(x>0, (100+x)/100, 1+(100.0/-x))

# %%
def clean_moneyline_df(df=moneylines):
    abbr_mapping = {'Boston': 'BOS', 'Portland': 'POR',
                    'L.A. Lakers': 'LAL', 'Brooklyn': 'BKN',
                    'Cleveland': 'CLE', 'Toronto': 'TOR',
                    'Philadelphia': 'PHI', 'Memphis': 'MEM',
                    'Minnesota': 'MIN', 'New Orleans': 'NOP',
                    'Oklahoma City': 'OKC', 'Dallas': 'DAL',
                    'San Antonio': 'SAS', 'Denver': 'DEN',
                    'Golden State': 'GSW', 'L.A. Clippers': 'LAC',
                    'Orlando': 'ORL', 'Utah': 'UTA',
                    'Charlotte': 'CHA', 'Detroit': 'DET',
                    'Miami': 'MIA', 'Phoenix': 'PHX',
                    'Atlanta': 'ATL', 'New York': 'NYK',
                    'Indiana': 'IND', 'Chicago': 'CHI',
                    'Houston': 'HOU', 'Milwaukee': 'MIL',
                    'Sacramento': 'SAC', 'Washington': 'WAS'}

    df['HOME_TEAM'] = df['HOME_TEAM'].replace(abbr_mapping)
    df['AWAY_TEAM'] = df['AWAY_TEAM'].replace(abbr_mapping)

    away_mls = df['AWAY_ML'].str.split(",", expand=True)
    home_mls = df['HOME_ML'].str.split(",", expand=True)

    away_mls = away_mls.replace('-', np.nan).replace('', np.nan)
    away_mls = away_mls.fillna(value=np.nan)
    away_mls = away_mls.astype(float)

    home_mls = home_mls.replace('-', np.nan).replace('', np.nan)
    home_mls = home_mls.fillna(value=np.nan)
    home_mls = home_mls.astype(float)

    highest_away_ml = away_mls.apply(lambda row: np.nanmax(
        abs(row)) if np.nanmax(row) > 0 else -np.nanmax(abs(row)), axis=1)
    highest_away_ml = convert_american_to_decimal(highest_away_ml)
    highest_away_ml = pd.DataFrame(
        highest_away_ml, columns=['HIGHEST_AWAY_ML'])

    highest_home_ml = home_mls.apply(lambda row: np.nanmax(
        abs(row)) if np.nanmax(row) > 0 else -np.nanmax(abs(row)), axis=1)
    highest_home_ml = convert_american_to_decimal(highest_home_ml)
    highest_home_ml = pd.DataFrame(
        highest_home_ml, columns=['HIGHEST_HOME_ML'])

    moneylines = pd.concat(
        [df.iloc[:, :4], highest_home_ml, highest_away_ml], axis=1)

    return moneylines

# %%
clean_mls = clean_moneyline_df(df=moneylines)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: All-NaN axis encountered
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: RuntimeWarning: All-NaN axis encountered

# %%
def clean_spreads_df(df=spreads):
    abbr_mapping = {'Boston': 'BOS', 'Portland': 'POR',
                    'L.A. Lakers': 'LAL', 'Brooklyn': 'BKN',
                    'Cleveland': 'CLE', 'Toronto': 'TOR',
                    'Philadelphia': 'PHI', 'Memphis': 'MEM',
                    'Minnesota': 'MIN', 'New Orleans': 'NOP',
                    'Oklahoma City': 'OKC', 'Dallas': 'DAL',
                    'San Antonio': 'SAS', 'Denver': 'DEN',
                    'Golden State': 'GSW', 'L.A. Clippers': 'LAC',
                    'Orlando': 'ORL', 'Utah': 'UTA',
                    'Charlotte': 'CHA', 'Detroit': 'DET',
                    'Miami': 'MIA', 'Phoenix': 'PHX',
                    'Atlanta': 'ATL', 'New York': 'NYK',
                    'Indiana': 'IND', 'Chicago': 'CHI',
                    'Houston': 'HOU', 'Milwaukee': 'MIL',
                    'Sacramento': 'SAC', 'Washington': 'WAS'}

    df['HOME_TEAM'] = df['HOME_TEAM'].replace(abbr_mapping)
    df['AWAY_TEAM'] = df['AWAY_TEAM'].replace(abbr_mapping)

    away_spreads = df['AWAY_SPREAD'].str.split(",", expand=True)
    home_spreads = df['HOME_SPREAD'].str.split(",", expand=True)

    for col in away_spreads.columns:
        away_spreads[col] = away_spreads[col].str[:-4]
        away_spreads[col] = away_spreads[col].str.replace('½', '.5')
        away_spreads[col] = away_spreads[col].str.replace('PK', '0')
        away_spreads[col] = away_spreads[col].astype(str).apply(
            lambda x: x if x == '' else (x[:-1] if x[-1] == '-' else x))

    away_spreads = away_spreads.replace('-', np.nan)
    away_spreads = away_spreads.replace('', np.nan)
    away_spreads = away_spreads.fillna(value=np.nan)

    away_spreads = away_spreads.astype(float)

    for col in home_spreads.columns:
        home_spreads[col] = home_spreads[col].str[:-4]
        home_spreads[col] = home_spreads[col].str.replace('½', '.5')
        home_spreads[col] = home_spreads[col].str.replace('PK', '0')
        home_spreads[col] = home_spreads[col].astype(str).apply(
            lambda x: x if x == '' else (x[:-1] if x[-1] == '-' else x))

    home_spreads = home_spreads.replace('-', np.nan).replace('', np.nan)
    home_spreads = home_spreads.fillna(value=np.nan)

    home_spreads = home_spreads.astype(float)

    highest_away_spread = away_spreads.apply(
        lambda row: -np.nanmax(abs(row)) if np.nanmax(row) < 0 else np.nanmax(abs(row)), axis=1)
    highest_away_spread = pd.DataFrame(
        highest_away_spread, columns=['HIGHEST_AWAY_SPREAD'])

    highest_home_spread = home_spreads.apply(
        lambda row: -np.nanmax(abs(row)) if np.nanmax(row) < 0 else np.nanmax(abs(row)), axis=1)
    highest_home_spread = pd.DataFrame(
        highest_home_spread, columns=['HIGHEST_HOME_SPREAD'])

    spreads = pd.concat(
        [df.iloc[:, :4], highest_home_spread, highest_away_spread], axis=1)

    return spreads

# %%
clean_spreads = clean_spreads_df(df = spreads)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: All-NaN axis encountered

# %%
# clean_spreads = clean_spreads_df(spreads)

clean_spreads

# %%
clean_mls

# %%
def merge_betting_and_boxscore_data(clean_spreads, clean_mls, clean_boxscores):
    clean_boxscores['HOME_TEAM'] = clean_boxscores['MATCHUP'].apply(
        lambda x: x[:3] if 'vs' in x else x[-3:])
    clean_boxscores['AWAY_TEAM'] = clean_boxscores['MATCHUP'].apply(
        lambda x: x[:3] if '@' in x else x[-3:])

    temp = pd.merge(clean_mls, clean_spreads, on=[
                    'SEASON', 'GM_DATE', 'HOME_TEAM', 'AWAY_TEAM'])
    temp['GM_DATE'] = pd.to_datetime(temp['GM_DATE'])

    merged_df = pd.merge(clean_boxscores, temp, how='left', 
                         left_on=['SEASON', 'HOME_TEAM', 'AWAY_TEAM', 'GAME_DATE'],
                         right_on=['SEASON', 'HOME_TEAM', 'AWAY_TEAM', 'GM_DATE'])

    merged_df['ML'] = merged_df.apply(lambda row: row['HIGHEST_HOME_ML'] if row['HOME_GAME'] == 1
                                      else row['HIGHEST_AWAY_ML'], axis=1)

    merged_df['SPREAD'] = merged_df.apply(lambda row: row['HIGHEST_HOME_SPREAD'] if row['HOME_GAME'] == 1
                                          else -row['HIGHEST_HOME_SPREAD'], axis=1)

    merged_df = merged_df.drop(columns=['HOME_TEAM', 'AWAY_TEAM', 'GM_DATE',
                                        'HIGHEST_HOME_ML', 'HIGHEST_AWAY_ML',
                                        'HIGHEST_HOME_SPREAD', 'HIGHEST_AWAY_SPREAD'])

    merged_df['ATS_DIFF'] = merged_df['POINT_DIFF'] + merged_df['SPREAD']

    merged_df['TEAM_COVERED'] = (merged_df['ATS_DIFF'] > 0).astype(int)

    return merged_df


merged_df = merge_betting_and_boxscore_data(
    clean_spreads, clean_mls, clean_boxscores=clean_df2)

# %%
merged_df

# %%
def create_matchups(df):
    """This function makes each row a matchup between 
    team and opp"""
    df = df.copy()
    

    matchups = pd.merge(df, df, on=['GAME_ID'], suffixes=['_team', '_opp'])
    matchups = matchups.loc[matchups['TEAM_ABBREVIATION_team'] != matchups['TEAM_ABBREVIATION_opp']]

    matchups = matchups.drop(columns = ['SEASON_opp', 'TEAM_ID_opp',
                             'TEAM_ABBREVIATION_opp', 'TEAM_NAME_opp', 'GAME_DATE_opp',
                             'MATCHUP_opp', 'HOME_GAME_opp', 'TEAM_SCORE_opp', 
                             'POINT_DIFF_opp', 'WL_opp',
                             'ML_opp', 'SPREAD_opp', 'OFF_RATING_team',
                             'DEF_RATING_team', 'NET_RATING_team', 'OFF_RATING_opp',
                             'DEF_RATING_opp', 'NET_RATING_opp']
                 )
    
    return matchups


matchups = create_matchups(merged_df)

# %%
matchups

# %%
def get_team_and_opp_ewm(df, min_periods=5, alpha=0.1, adjust=True):
    df = df.copy()

    df = df[['SEASON_team', 'TEAM_ID_team', 'TEAM_ABBREVIATION_team',
             'TEAM_NAME_team', 'GAME_ID', 'GAME_DATE_team', 'MATCHUP_team',
             'HOME_GAME_team', 'TEAM_SCORE_team', 'POINT_DIFF_team', 'WL_team',
             'ML_team', 'SPREAD_team', 'TEAM_COVERED_team', 'RECORD_team',
             'FG2M_team', 'FG2A_team',
             'FG3M_team', 'FG3A_team', 'FTM_team', 'FTA_team', 'OREB_team',
             'DREB_team', 'REB_team',
             'AST_team', 'STL_team', 'BLK_team', 'TOV_team', 'PF_team', 'PTS_team',
             'PLUS_MINUS_team', 'E_OFF_RATING_team', 'E_DEF_RATING_team',
             'E_NET_RATING_team', 'POSS_team', 'PIE_team', 'PTS_2PT_MR_team',
             'PTS_FB_team', 'PTS_OFF_TOV_team', 'PTS_PAINT_team', 'AST_2PM_team',
             'AST_3PM_team', 'UAST_2PM_team', 'UAST_3PM_team', 'ATS_DIFF_team',
             'RECORD_opp', 'FG2M_opp', 'FG2A_opp', 'FG3M_opp',
             'FG3A_opp', 'FTM_opp', 'FTA_opp', 'OREB_opp', 'DREB_opp', 'REB_opp',
             'AST_opp', 'STL_opp', 'BLK_opp',
             'TOV_opp', 'PF_opp', 'PTS_opp', 'PLUS_MINUS_opp', 'E_OFF_RATING_opp',
             'E_DEF_RATING_opp', 'E_NET_RATING_opp', 'POSS_opp', 'PIE_opp',
             'PTS_2PT_MR_opp', 'PTS_FB_opp', 'PTS_OFF_TOV_opp', 'PTS_PAINT_opp',
             'AST_2PM_opp', 'AST_3PM_opp', 'UAST_2PM_opp', 'UAST_3PM_opp',
             'ATS_DIFF_opp', 'TEAM_COVERED_opp']]

    team_dfs = []
    for season in tqdm(df['SEASON_team'].unique(), desc='Progress'):
        season_df = df.loc[df['SEASON_team'] == season]
        for team in df['TEAM_ABBREVIATION_team'].unique():
            team_df = season_df.loc[season_df['TEAM_ABBREVIATION_team'] == team].sort_values(
                'GAME_DATE_team')

            avg_spread = team_df['SPREAD_team'].shift(1).expanding().mean()

            avg_ml = team_df['ML_team'].shift(1).expanding().mean()

            record = team_df['RECORD_team'].shift(1).expanding().mean()

            ATS_rec = team_df['TEAM_COVERED_team'].shift(
                1).expanding().mean()

            ATS_avg_diff = team_df['ATS_DIFF_team'].shift(
                1).expanding().mean()

            records = pd.DataFrame({'WL_PCT': record,
                                   'ATS_PCT': ATS_rec,
                                    'AVG_SPREAD': avg_spread,
                                    'AVG_ML': avg_ml,
                                    'AVG_ATS_DIFF': ATS_avg_diff
                                    })

            team_df.iloc[:, 14:] = team_df.iloc[:, 14:].shift(
                1).ewm(alpha=alpha, min_periods=min_periods).mean()

            team_df = pd.concat([team_df, records], axis=1)

            team_dfs.append(team_df)

    new_df = pd.concat(team_dfs)
    new_df = new_df.reset_index(drop=True)

    return new_df


avg_data_ewm_19 = get_team_and_opp_ewm(matchups, min_periods=5, alpha=0.1)

# %%
avg_data_ewm_19

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We will calculate OREB_PCT, DREB_PCT, TS_PCT,
# <br>EFG_PCT, AST_RATIO, TOV_PCT for both team and opp
# <br>which we removed earlier, from the averaged raw numbers.

# %%
def add_percentage_features(df):
    """Add the following features for both team and opp:
    OREB_PCT, DREB_PCT, REB_PCT, TS_PCT, EFG_PCT, AST_RATIO, TOV_PCT.
    """
    
    df = df.copy()
    
    df['OREB_PCT_team'] = df['OREB_team'] / (df['OREB_team'] + df['DREB_opp'])
    df['OREB_PCT_opp'] = df['OREB_opp'] / (df['OREB_opp'] + df['DREB_team'])

    df['DREB_PCT_team'] = df['DREB_team'] / (df['DREB_team'] + df['OREB_opp'])
    df['DREB_PCT_opp'] = df['DREB_opp'] / (df['DREB_opp'] + df['OREB_team'])

    df['REB_PCT_team'] = df['REB_team'] / (df['REB_team'] + df['REB_opp'])
    df['REB_PCT_opp'] = df['REB_opp'] / (df['REB_opp'] + df['REB_team'])

    df['TS_PCT_team'] = df['PTS_team'] / ((2*(df['FG2A_team'] + df['FG3A_team']) + 0.44*df['FTA_team']))
    
    df['TS_PCT_opp'] = df['PTS_opp'] / ((2*(df['FG2A_opp'] + df['FG3A_opp']) + 0.44*df['FTA_opp']))

    df['EFG_PCT_team'] = (df['FG2M_team'] + 1.5*df['FG3M_team']) / (df['FG2A_team']
                                                                    + df['FG3A_team'])
    df['EFG_PCT_opp'] = (df['FG2M_opp'] + 1.5*df['FG3M_opp']) / (df['FG2A_opp'] 
                                                                 + df['FG3A_opp'])

    df['AST_RATIO_team'] = (df['AST_team'] * 100) / df['POSS_team']
    df['AST_RATIO_opp'] = (df['AST_opp'] * 100) / df['POSS_opp']

    df['TOV_PCT_team'] = 100*df['TOV_team'] / (df['FG2A_team'] 
                                               + df['FG3A_team'] 
                                               + 0.44*df['FTA_team'] 
                                               + df['TOV_team'])
    
    df['TOV_PCT_opp'] = 100*df['TOV_opp'] / (df['FG2A_opp'] 
                                             + df['FG3A_opp'] 
                                             + 0.44*df['FTA_opp'] 
                                             + df['TOV_opp'])

    
    return df


def add_rest_days(df):
    df['REST'] = np.nan

    for season in df['SEASON_team'].unique():
        season_df = df.loc[df['SEASON_team'] == season]
        for team in season_df['TEAM_ABBREVIATION_team'].unique():
            team_df = season_df.loc[season_df['TEAM_ABBREVIATION_team'] == team].sort_values('GAME_DATE_team')
            idx = team_df.index
            team_df['REST'] = (team_df['GAME_DATE_team'] - team_df['GAME_DATE_team'].shift(1)) / np.timedelta64(1, 'D')
            df.loc[idx, 'REST'] = team_df['REST']
            
    df.loc[df['REST'] >= 8, 'REST'] = 8
            
    return df

# %%
avg_data_2_ewm_19 = add_rest_days(avg_data_ewm_19)
full_df_ewm_19 = add_percentage_features(avg_data_2_ewm_19)

# %%
full_df_ewm_19['REST'].value_counts()

# %%
full_df_ewm_19

# %%
full_df_ewm_19.loc[full_df_ewm_19['GAME_ID'] =='0020900329']

# %%
full_df_ewm_19.iloc[:, 14:].head(10)

# %%
def compute_matchup_diffs(avg_data):
    
    avg_data = avg_data.copy(deep=True)
        
    home_teams = avg_data.loc[avg_data['HOME_GAME_team'] == 1].sort_values('GAME_ID').reset_index(drop=True)
    away_teams = avg_data.loc[avg_data['HOME_GAME_team'] == 0].sort_values('GAME_ID').reset_index(drop=True)


    stat_diffs_home = home_teams.iloc[:, 14:] - away_teams.iloc[:, 14:]
    new_cols = [col+"_diff" for col in stat_diffs_home.columns]
    stat_diffs_home.columns = new_cols

    stat_diffs_away = away_teams.iloc[:, 14:] - home_teams.iloc[:, 14:]
    stat_diffs_away.columns = new_cols

    full_df_home = pd.concat([home_teams.iloc[:, :14], stat_diffs_home], axis=1)
    full_df_away = pd.concat([away_teams.iloc[:, :14], stat_diffs_away], axis=1)

    full_df = pd.concat([full_df_home, full_df_away])
    
    full_df = full_df.sort_values(['GAME_DATE_team', 'GAME_ID', 'HOME_GAME_team'])

    full_df.rename(columns={'SEASON_team':'SEASON',
                            'SEASON_ID_team':'SEASON_ID',
                            'TEAM_ID_team': 'TEAM_ID',
                            'TEAM_ABBREVIATION_team': 'TEAM_ABBREVIATION',
                            'TEAM_NAME_team': 'TEAM_NAME',
                            'GAME_DATE_team': 'GAME_DATE',
                            'MATCHUP_team': 'MATCHUP',
                            'HOME_GAME_team': 'HOME_GAME',
                            'TEAM_SCORE_team': 'SCORE_team'}, inplace=True)

    full_df = full_df.reset_index(drop=True)
    
    return full_df

df_ewm_19_diffs = compute_matchup_diffs(full_df_ewm_19)

# %%
df_ewm_19_diffs

# %% [markdown]
# ## Add ELO Rating

# %%
# Helper functions go generate ELO rating

def get_K(MOV, elo_diff):
    """This K multiplier """
    K_0 = 20    

    if MOV > 0:
        multiplier = (MOV+3)**(0.8)/(7.5+0.006*(elo_diff))
    else:
        multiplier = (-MOV+3)**(0.8)/(7.5+0.006*(-elo_diff))
        
    return K_0*multiplier, K_0*multiplier

def get_S(team_score, opp_score):
    """S is the 1 if the team wins, and 0 if the team loses"""
    S_team, S_opp = 0, 0
    if team_score > opp_score:
        S_team = 1
    else:
        S_opp = 1
    return S_team, S_opp


def elo_prediction(team_rating, opp_rating):
    """Generate the probability of a home victory based on the teams' elo ratings"""
    E_team = 1.0/(1 + 10 ** ((opp_rating - team_rating) / (400.0)))
    return E_team


def elo_update(team_score, opp_score, team_rating, opp_rating):
    # Add 100 to the home_rating for home court advantage   
    
    E_team = elo_prediction(team_rating, opp_rating)
    E_opp = 1.0 - E_team
    
    
    MOV = team_score - opp_score
    if MOV > 0:
        elo_diff = team_rating - opp_rating
    else:
        elo_diff = opp_rating - team_rating
    
#     print(MOV)
        
    S_team, S_opp = get_S(team_score, opp_score)
    
    K_team, K_opp = get_K(MOV, elo_diff)
        
#     print("expected_win_prob: ", E_team, E_opp)
#     print("elo_diff:", elo_diff)
#     print("S_team:", S_team, "S_opp:", S_opp)
#     print("K_team:", K_team, "K_opp:", K_opp)
#     print(K_team*(S_team-E_team), K_opp*(S_opp-E_opp))
#     print(elo_diff, K_team*(S_team-E_team), K_opp*(S_opp-E_opp))
    return K_team*(S_team-E_team), K_opp*(S_opp-E_opp)
    



def season_reset(rating):
    new_rating = 0.75*rating + 0.25*1505
    return new_rating

# %%
# full_df_ewm_19.rename(columns={'SEASON_YEAR_team':'SEASON_YEAR',
#                             'SEASON_ID_team':'SEASON_ID',
#                             'TEAM_ID_team': 'TEAM_ID',
#                             'TEAM_ABBREVIATION_team': 'TEAM_ABBREVIATION',
#                             'TEAM_NAME_team': 'TEAM_NAME',
#                             'GAME_DATE_team': 'GAME_DATE',
#                             'MATCHUP_team': 'MATCHUP',
#                             'HOME_GAME_team': 'HOME_GAME',
#                             'TEAM_SCORE_team': 'SCORE_team'}, inplace=True)

# %%
def add_elo_ratings(df):
    """This function will generate elo_ratings in the elo_df
    """
    
    # Initialize the following columns
    df.sort_values(['GAME_DATE', 'GAME_ID'], inplace=True)
    df.reset_index(drop=True, inplace=True)
    df['team_elo_pred'] = np.nan

    df['team_rating_i'] = np.nan
    df['team_rating_n'] = np.nan

    df['opp_rating_i'] = np.nan
    df['opp_rating_n'] = np.nan

    elo_dic = {}
    for idx, row in tqdm(df.iterrows(), desc="progress:"):
        if (idx > 2) and (row['SEASON'] != df.loc[idx-1, 'SEASON']):
            for team in elo_dic:
                elo_dic[team] = season_reset(elo_dic[team])

                
        if (idx >= 1) and (row['GAME_ID'] == df.loc[idx-1, 'GAME_ID']):
            df.loc[idx, 'team_rating_i'] = df.loc[idx-1, 'opp_rating_i']
            df.loc[idx, 'team_rating_n'] = df.loc[idx-1, 'opp_rating_n']
            df.loc[idx, 'opp_rating_i'] = df.loc[idx-1, 'team_rating_i']
            df.loc[idx, 'opp_rating_n'] = df.loc[idx-1, 'team_rating_n']
            df.loc[idx, 'team_elo_pred'] = 1 - df.loc[idx-1, 'team_elo_pred']            
            continue
            
        team_abbr = row['MATCHUP'][:3]
        opp_abbr = row['MATCHUP'][-3:]
            
        if team_abbr not in elo_dic:
            elo_dic[team_abbr] = 1300
            df.loc[idx, 'team_rating_i'] = 1300
        else:
            df.loc[idx, 'team_rating_i'] = elo_dic[team_abbr]            

        if opp_abbr not in elo_dic:
            elo_dic[opp_abbr] = 1300
            df.loc[idx, 'opp_rating_i'] = 1300
        else:
            df.loc[idx, 'opp_rating_i'] = elo_dic[opp_abbr]

        team_score = row['SCORE_team']
        opp_score = row['SCORE_team'] - row['POINT_DIFF_team']
            
        team_rating = elo_dic[team_abbr]
        opp_rating = elo_dic[opp_abbr]

        if row['HOME_GAME'] == 1:
            team_rating_temp = team_rating + 69
            opp_rating_temp = opp_rating
        else:
            opp_rating_temp = opp_rating + 69
            team_rating_temp = team_rating
            
        team_update, opp_update = elo_update(team_score, opp_score, team_rating_temp, opp_rating_temp)

        df.loc[idx, 'team_rating_n'] = team_rating + team_update
        df.loc[idx, 'opp_rating_n'] = opp_rating + opp_update
        

        df.loc[idx, 'team_elo_pred'] = elo_prediction(team_rating_temp, opp_rating_temp)

        elo_dic[team_abbr] = df.loc[idx, 'team_rating_n']
        elo_dic[opp_abbr] = df.loc[idx, 'opp_rating_n']

    df['elo_MOV_pred'] = round((df['team_rating_i'] - df['opp_rating_i'])/28, 2)

    return df

# %%
df_ewm_19_diffs = add_elo_ratings(df_ewm_19_diffs)

# %%
df_ewm_19_diffs

# %%
teams = []
elos = []
for team in df_ewm_19_diffs['TEAM_ABBREVIATION'].unique():
    team_elo = df_ewm_19_diffs.loc[df_ewm_19_diffs['TEAM_ABBREVIATION']==team, 'team_rating_n']
    elos.append(team_elo.values[-1])
    teams.append(team)
    
elo_final_2021 = pd.DataFrame({'TEAM':teams,
                              'ELO':elos})

elo_final_2021.sort_values('ELO', ascending=False)

# %%
df_ewm_19_diffs

# %%
test = df_ewm_19_diffs.dropna()

test = test.loc[test['SPREAD_team'] + test['POINT_DIFF_team'] != 0]

test

# %%
import seaborn as sns
corr = pd.concat([test.iloc[:, 14:], test['POINT_DIFF_team']], axis=1).corr()

mask = np.zeros_like(corr)

mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(40, 40))
    ax = sns.heatmap(corr, mask=mask, vmax=0.3, square=True)

# %%
columns = []
point_biserial_correlations = []
p_values = []

for col in test.columns[14:]:
    cont = test[col]
    cover = test['TEAM_COVERED_team']
    pbc = pointbiserialr(cont, cover)
    columns.append(col)
    point_biserial_correlations.append(pbc[0])
    p_values.append(pbc[1])
    
pbc_df = pd.DataFrame({'feature':columns, 
              'pbc':point_biserial_correlations, 
              'p_value':p_values})

# %%
columns = []
point_biserial_correlations = []
p_values = []

for col in test.columns[14:]:
    cont = test[col]
    cover = test['WL_team']
    pbc = pointbiserialr(cont, cover)
    columns.append(col)
    point_biserial_correlations.append(pbc[0])
    p_values.append(pbc[1])
    
pbc_df = pd.DataFrame({'feature':columns, 
              'pbc':point_biserial_correlations, 
              'p_value':p_values})

pbc_df.sort_values('pbc', ascending=False)

# %%
pbc_df.sort_values(['pbc'])

# %%
home_games = test.loc[test['HOME_GAME'] == 1]
away_games = test.loc[test['HOME_GAME'] == 0]

home_cover_year = home_games.groupby('SEASON').TEAM_COVERED_team.mean().reset_index()
home_cover_year

# %%
home_games = test.loc[test['HOME_GAME'] == 1]
away_games = test.loc[test['HOME_GAME'] == 0]

home_cover_year = home_games.groupby('SEASON').TEAM_COVERED_team.mean().reset_index()

px.line(home_cover_year, x='SEASON', y='TEAM_COVERED_team')

# %% [markdown]
# ## Helper Functions for Bet Simulations

# %%
def simulate_bets_1(selected_bets, unit_size):
    """This function simulates betting unit_size of your bankroll on each bet in the
    selected_bets df"""
    selected_bets = selected_bets.copy()
    selected_bets = selected_bets.reset_index()
    selected_bets.loc[0, 'bankroll_i'] = 100
    for idx in range(selected_bets.shape[0]):
        if np.isnan(selected_bets.loc[idx, 'bankroll_i']):
            selected_bets.loc[idx, 'bankroll_i'] = selected_bets.loc[idx-1, 'bankroll_n']

        selected_bets.loc[idx, 'bet_size'] = unit_size
        if selected_bets.loc[idx, 'bet_won'] == 1:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] + (1/1.1)*selected_bets.loc[idx, 'bet_size']
        elif selected_bets.loc[idx, 'bet_won'] == 0:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] - selected_bets.loc[idx, 'bet_size']
        else:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i']
            
    plt.style.use('fivethirtyeight')

    fig, ax = plt.subplots(figsize=(12, 8))

    ax.plot(range(selected_bets.shape[0]), selected_bets['bankroll_i'], linewidth=1.5)
    ax.set_ylabel("Bankroll")
    ax.set_xlabel("Games Bet")
    plt.show()
    min_balance = selected_bets['bankroll_n'].min()
    max_balance = selected_bets['bankroll_n'].max()
    final_balance = selected_bets['bankroll_n'].iloc[-1]
    win_pct = selected_bets.loc[selected_bets['bet_won'] != 0.5, 'bet_won'].mean()
    
    amt_won = selected_bets.loc[selected_bets['bet_won'] ==1, 'bet_size'].sum() * 1/1.1
    amt_lost = selected_bets.loc[selected_bets['bet_won']==0, 'bet_size'].sum()
    amt_risked = selected_bets['bet_size'].sum()

    profit = amt_won - amt_lost
    roi = profit/amt_risked
    
    print("min balance:", min_balance,
         "\nmax balance:", max_balance,
         "\nfinal balance:", final_balance,
         "\nwin percentage", round(win_pct, 4) * 100,
         "\nprofit:", profit, "risk:", amt_risked,
         "\nROI:", round(roi, 4) * 100)
    return selected_bets, roi, profit, win_pct

def simulate_bets_2(selected_bets, unit_pct=0.03):
    """This function simulates betting unit_size (default 3%) of your bankroll on each bet in the
    selected_bets df"""
    selected_bets = selected_bets.copy()
    selected_bets = selected_bets.reset_index()
    selected_bets.loc[0, 'bankroll_i'] = 100
    for idx in range(selected_bets.shape[0]):
        if np.isnan(selected_bets.loc[idx, 'bankroll_i']):
            selected_bets.loc[idx, 'bankroll_i'] = selected_bets.loc[idx-1, 'bankroll_n']

        selected_bets.loc[idx, 'bet_size'] = selected_bets.loc[idx, 'bankroll_i'] * unit_pct
        if selected_bets.loc[idx, 'bet_won'] == 1:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] + (1/1.1)*selected_bets.loc[idx, 'bet_size']
        elif selected_bets.loc[idx, 'bet_won'] == 0:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] - selected_bets.loc[idx, 'bet_size']
        else:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i']
            
    plt.style.use('fivethirtyeight')

    fig, ax = plt.subplots(figsize=(12, 8))

    ax.plot(range(selected_bets.shape[0]), selected_bets['bankroll_i'], linewidth=1.5)
    ax.set_ylabel("Bankroll")
    ax.set_xlabel("Games Bet")
    plt.show()
    min_balance = selected_bets['bankroll_n'].min()
    max_balance = selected_bets['bankroll_n'].max()
    final_balance = selected_bets['bankroll_n'].iloc[-1]
    win_pct = selected_bets.loc[selected_bets['bet_won'] != 0.5, 'bet_won'].mean()
    
    amt_won = selected_bets.loc[selected_bets['bet_won'] ==1, 'bet_size'].sum() * 1/1.1
    amt_lost = selected_bets.loc[selected_bets['bet_won']==0, 'bet_size'].sum()
    amt_risked = selected_bets['bet_size'].sum()

    profit = amt_won - amt_lost
    roi = profit/amt_risked
    
    print("min balance:", min_balance,
         "\nmax balance:", max_balance,
         "\nfinal balance:", final_balance,
         "\nwin percentage", round(win_pct, 4) * 100,
         "\nprofit:", profit, "risk:", amt_risked,
         "\nROI:", round(roi, 4) * 100)
    return selected_bets, roi, profit, win_pct


def simulate_bets_3(selected_bets):
    """This function simulates betting unit_size (default 3%) of your bankroll on each bet in the
    selected_bets df"""
    selected_bets = selected_bets.copy()
    selected_bets = selected_bets.reset_index()
    selected_bets.loc[0, 'bankroll_i'] = 100
    for idx in range(selected_bets.shape[0]):
        if np.isnan(selected_bets.loc[idx, 'bankroll_i']):
            selected_bets.loc[idx, 'bankroll_i'] = selected_bets.loc[idx-1, 'bankroll_n']

        if abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.04:
            bet_size = 5
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.03:
            bet_size = 4
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.02:
            bet_size = 3
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.01:
            bet_size = 2
        else:
            bet_size = 1
            
        selected_bets.at[idx, 'bet_size'] = bet_size
        if selected_bets.at[idx, 'bet_won'] == 1:
            selected_bets.at[idx, 'bankroll_n'] = selected_bets.at[idx, 'bankroll_i'] + (1/1.1)*selected_bets.loc[idx, 'bet_size']
        elif selected_bets.at[idx, 'bet_won'] == 0:
            selected_bets.at[idx, 'bankroll_n'] = selected_bets.at[idx, 'bankroll_i'] - selected_bets.at[idx, 'bet_size']
        else:
            selected_bets.at[idx, 'bankroll_n'] = selected_bets.at[idx, 'bankroll_i']
            
    plt.style.use('fivethirtyeight')

    fig, ax = plt.subplots(figsize=(12, 8))

    ax.plot(range(selected_bets.shape[0]), selected_bets['bankroll_i'], linewidth=1.5)
    ax.set_ylabel("Bankroll")
    ax.set_xlabel("Games Bet")
    plt.show()
    min_balance = selected_bets['bankroll_n'].min()
    max_balance = selected_bets['bankroll_n'].max()
    final_balance = selected_bets['bankroll_n'].iloc[-1]
    win_pct = selected_bets.loc[selected_bets['bet_won'] != 0.5, 'bet_won'].mean()
    
    amt_won = selected_bets.loc[selected_bets['bet_won'] ==1, 'bet_size'].sum() * 1/1.1
    amt_lost = selected_bets.loc[selected_bets['bet_won']==0, 'bet_size'].sum()
    amt_risked = selected_bets['bet_size'].sum()

    profit = amt_won - amt_lost
    roi = profit/amt_risked
    
    print("min balance:", min_balance,
         "\nmax balance:", max_balance,
         "\nfinal balance:", final_balance,
         "\nwin percentage", round(win_pct, 4) * 100,
         "\nprofit:", profit, "risk:", amt_risked,
         "\nROI:", round(roi, 4) * 100)
    return selected_bets, roi, profit, win_pct

def simulate_bets_4(selected_bets):
    """This function simulates betting unit_size (default 3%) of your bankroll on each bet in the
    selected_bets df"""
    selected_bets = selected_bets.copy()
    selected_bets = selected_bets.reset_index()
    selected_bets.loc[0, 'bankroll_i'] = 100
    for idx in range(selected_bets.shape[0]):
        if np.isnan(selected_bets.loc[idx, 'bankroll_i']):
            selected_bets.loc[idx, 'bankroll_i'] = selected_bets.loc[idx-1, 'bankroll_n']

        if abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.04:
            bet_size = 0.05
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.03:
            bet_size = 0.04
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.02:
            bet_size = 0.03
        elif abs(selected_bets.at[idx, 'prob_avg']-0.5) > 0.01:
            bet_size = 0.02
        else:
            bet_size = 0.01
        
        selected_bets.loc[idx, 'bankroll_i'] = selected_bets.loc[idx-1, 'bankroll_n']

        selected_bets.loc[idx, 'bet_size'] = selected_bets.loc[idx, 'bankroll_i'] * bet_size
        if selected_bets.loc[idx, 'bet_won'] == 1:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] + (1/1.1)*selected_bets.loc[idx, 'bet_size']
        elif selected_bets.loc[idx, 'bet_won'] == 0:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i'] - selected_bets.loc[idx, 'bet_size']
        else:
            selected_bets.loc[idx, 'bankroll_n'] = selected_bets.loc[idx, 'bankroll_i']
            
            
    plt.style.use('fivethirtyeight')

    fig, ax = plt.subplots(figsize=(12, 8))

    ax.plot(range(selected_bets.shape[0]), selected_bets['bankroll_i'], linewidth=1.5)
    ax.set_ylabel("Bankroll")
    ax.set_xlabel("Games Bet")
    plt.show()
    min_balance = selected_bets['bankroll_n'].min()
    max_balance = selected_bets['bankroll_n'].max()
    final_balance = selected_bets['bankroll_n'].iloc[-1]
    win_pct = selected_bets.loc[selected_bets['bet_won'] != 0.5, 'bet_won'].mean()
    
    amt_won = selected_bets.loc[selected_bets['bet_won'] ==1, 'bet_size'].sum() * 1/1.1
    amt_lost = selected_bets.loc[selected_bets['bet_won']==0, 'bet_size'].sum()
    amt_risked = selected_bets['bet_size'].sum()

    profit = amt_won - amt_lost
    roi = profit/amt_risked
    
    print("min balance:", min_balance,
         "\nmax balance:", max_balance,
         "\nfinal balance:", final_balance,
         "\nwin percentage", round(win_pct, 4) * 100,
         "\nprofit:", profit, "risk:", amt_risked,
         "\nROI:", round(roi, 4) * 100)
    return selected_bets, roi, profit, win_pct

# %%
# Find ranges of model probability where the win percentage is higher than 52.8
def find_optimal_threshold(df, test_probs, test_indices):
    """
    INPUTS:
    df:
    test_preds: array of class predictions
    test_indices: indices of full df for the test set 
    OUTPUTS:
    select_bets: df of bets at the optimal thresholds
    confidence_thresholds: df of thresholds, num_games_bet, win_percentage, expected_profits
    best_thresholds: tuple of lower and upper thresholds
    
    """
    df=df.copy(deep=True)
    
    betting_df = create_betting_df(df, test_probs, test_indices)

    confidence_range = []
    win_percentages = []
    num_games_bet = []
    expected_profits = []
#     for num in range(1, 4):
#         strat_types = ['home', 'away', 'avg']
#         strat = strat_types[num-1]
    for i in range(1, 500):
        select_bets = betting_df.loc[~betting_df['prob_avg'].between(0.5-i/1000, 0.5+i/1000)]
        win_pct = select_bets['bet_won'].mean()
        num_games = select_bets.shape[0]
        confidence_range.append((0.5+i/1000))
        win_percentages.append(win_pct)
        num_games_bet.append(num_games)
        bets_won = select_bets['bet_won'].sum()
        bets_lost = num_games - bets_won
        expected_profit = (bets_won*100 + bets_lost*-110)
        expected_profits.append(expected_profit)

    confidence_thresholds = pd.DataFrame({
                                        'confidence_range':confidence_range, 
                                       'num_games_bet':num_games_bet, 
                                       'win_percentage':win_percentages,
                                         'expected_profit':expected_profits})
    
    confidence_thresholds = confidence_thresholds.loc[confidence_thresholds['win_percentage'] > 0.5238]
    confidence_thresholds.sort_values(['expected_profit', 'num_games_bet'], ascending=[False, False], inplace=True)
    confidence_thresholds.reset_index(drop=False, inplace=True) 
    try:
        best_threshold = confidence_thresholds.loc[0, 'confidence_range']
#         print("best_strategy:", confidence_thresholds.loc[0, 'strategy'])
        print("best threshold for testset 1:", best_threshold)
        select_bets =  betting_df.loc[~(betting_df['prob_avg'].between(1-best_threshold, best_threshold))]
        print("num_games_bet at threshold:", select_bets.shape[0])
        print("win percetange at threshold:", select_bets['bet_won'].mean())
    except:
        print("no best threshold")
        select_bets = betting_df
        best_threshold = 0.5
        print("The except block executed")
    
    return select_bets, confidence_thresholds, best_threshold

# %%
# # Find ranges of model probability where the win percentage is higher than 52.8
# def find_optimal_confidence_thresholds(df, diff_preds, test_indices):
#     """
#     INPUTS:
#     test_preds: array of class predictions
#     test_indices: indices of full df for the test set 
#     OUTPUTS:
#     select_bets: df of bets at the optimal thresholds
#     best_thresholds: tuple of lower and upper thresholds
    
#     """
#     betting_df = df.loc[test_indices, ['GAME_ID', 'HOME_GAME_x', 'MATCHUP_x', 
#                                                  'spread_team_x', 'ml_team_x', 'SCORE_team_x', 
#                                                  'point_diff_team_x']]
#     betting_df.rename(columns={'MATCHUP_x':'MATCHUP',
#                                'HOME_GAME_x':'HOME_GAME',
#                                'spread_team_x':'spread', 
#                               'ml_team_x':'ml', 
#                               'SCORE_team_x':'team_score', 
#                               'point_diff_team_x':'point_diff'}, inplace=True)


#     betting_df['cover'] = (betting_df['spread'] + betting_df['point_diff'] > 0).astype(int)

#     betting_df['diff_preds'] = diff_preds

#     home_df = betting_df.loc[betting_df['HOME_GAME']==1]
#     away_df = betting_df.loc[betting_df['HOME_GAME']==0]

#     betting_df = pd.merge(home_df, away_df, on=['GAME_ID'], suffixes=['_home', '_away'])

#     betting_df = betting_df[['GAME_ID', 'MATCHUP_home', 'spread_home', 
#                                  'ml_home', 'ml_away', 'point_diff_home', 
#                                  'cover_home', 'diff_preds_home', 
#                              'diff_preds_away']]

#     betting_df['point_diff_avg'] = (betting_df['diff_preds_home'] - betting_df['diff_preds_away'])/2

#     betting_df['bet_home1'] = ((betting_df['diff_preds_home'] + betting_df['spread_home']) >0).astype(int)
#     betting_df['bet_home2'] = ((-1*betting_df['diff_preds_away'] + betting_df['spread_home']) >0).astype(int)
#     betting_df['bet_home3'] = ((betting_df['point_diff_avg'] + betting_df['spread_home']) >0).astype(int)

#     betting_df = betting_df.loc[betting_df['spread_home'] + betting_df['point_diff_home']!=0]

#     betting_df['confidence_pred1'] = betting_df['diff_preds_home'] + betting_df['spread_home']
#     betting_df['confidence_pred2'] = -betting_df['diff_preds_away'] + betting_df['spread_home']
#     betting_df['confidence_pred3'] = betting_df['point_diff_avg'] + betting_df['spread_home']


#     betting_df['bankroll_i'] = np.nan
#     betting_df['bankroll_n'] = np.nan
#     betting_df['bankroll_i'].iloc[0] = 10000
#     betting_df['bet_size'] = np.nan
        
#     prediction_num = []
#     confidence_threshold = []
#     win_percentages = []
#     num_games_bet = []
#     expected_profits = []
    
#     for num in range(1, 4):
#         betting_df['bet_won'] = (betting_df['bet_home{}'.format(num)] == betting_df['cover_home']).astype(int)

#         for i in range(1, 1001):
#             select_bets = betting_df.loc[abs(betting_df['confidence_pred{}'.format(num)]) > i/100]
#             win_pct = select_bets['bet_won'].mean()
#             num_games = select_bets.shape[0]
#             confidence_threshold.append(i/100)
#             win_percentages.append(win_pct)
#             num_games_bet.append(num_games)
#             bets_won = select_bets['bet_won'].sum()
#             bets_lost = num_games - bets_won
#             expected_profit = (bets_won*100 + bets_lost*-108)
#             expected_profits.append(expected_profit)
#             prediction_num.append(num)
        

#     confidence_thresholds = pd.DataFrame({'prediction_num':prediction_num,
#                                         'confidence_thresholds':confidence_threshold, 
#                                        'num_games_bet':num_games_bet, 
#                                        'win_percentage':win_percentages,
#                                          'expected_profits':expected_profits})
    
#     confidence_thresholds = confidence_thresholds.loc[confidence_thresholds['win_percentage'] > 0.53]
#     confidence_thresholds.sort_values(['expected_profits', 'confidence_thresholds'], 
#                                       ascending=[False, True], inplace=True)
#     confidence_thresholds = confidence_thresholds.reset_index(drop=False) 
#     print('DONE')

#     try:
#         best_threshold = confidence_thresholds.loc[0, 'confidence_thresholds']
#         print("best threshold:", best_threshold)
#         best_num = confidence_thresholds.loc[0, 'prediction_num']
#         print("best prediction strat:", best_num)
#         betting_df['bet_won'] = (betting_df['bet_home{}'.format(best_num)] == betting_df['cover_home']).astype(int)
#         select_bets = betting_df.loc[abs(betting_df['confidence_pred{}'.format(best_num)]) > best_threshold]
#         print("num_games_bet:", select_bets.shape[0])
#         print("win percetange at threshold:", select_bets['bet_won'].mean())
#     except:
#         print("no best threshold")
#         select_bets = betting_df
   
    
#     return select_bets, confidence_thresholds

# %% [markdown]
# #### Test Model Per Season

# %%
def create_betting_df(df, probs, test_indices):
    df=df.copy(deep=True)
    
    df.rename(columns= {'SPREAD_team':'SPREAD', 
                      'SCORE_team':'SCORE', 
                      'POINT_DIFF_team':'POINT_DIFF'}, inplace=True)
    betting_df = df.loc[test_indices, ['GAME_ID', 'HOME_GAME', 'MATCHUP', 
                                                 'SPREAD', 'SCORE', 
                                                 'POINT_DIFF']]

    betting_df['prob'] = probs[:, 1]
    

    home_df = betting_df.loc[betting_df['HOME_GAME']==1]
    away_df = betting_df.loc[betting_df['HOME_GAME']==0]

    betting_df = pd.merge(home_df, away_df, on=['GAME_ID'], suffixes=['_home', '_away'])

      
    betting_df = betting_df[['GAME_ID', 'MATCHUP_home', 'SPREAD_home',
                             'SCORE_home', 'SCORE_away', 'POINT_DIFF_home', 
                                 'cover_home', 'prob_home', 'prob_away']]

    betting_df['prob_avg'] = (betting_df['prob_home'] + (1-betting_df['prob_away']))/2

    betting_df['bet_home'] = (betting_df['prob_avg'] > 0.5).astype(int)
    betting_df['bet_won'] = (betting_df['bet_home'] == betting_df['cover_home']).astype(int)

    betting_df = betting_df.loc[betting_df['spread_home'] + betting_df['point_diff_home']!=0]


    betting_df['bankroll_i'] = np.nan
    betting_df['bankroll_n'] = np.nan
    betting_df.loc[0, 'bankroll_i'] = 100
    betting_df['bet_size'] = np.nan
    
    return betting_df

# %%
def test_model_per_season(df, model, test_seasons_idxs):
    df = df.copy(deep=True)
    
    X = df.iloc[:, 12:]
    X = X.drop(columns=['team_rating_n_x', 'opp_rating_n_x', 'WL_team_y'])
    
    y = (df['point_diff_team_x'] + df['spread_team_x']).astype(int)
    
    result_dfs = []
    print(len(test_season_idxs))
    for i in range(len(test_seasons_idxs)-1):
        print("loop:", i)
        X_train1 = X.loc[:test_seasons_idxs[i][0]-1]
        X_test1 = X.loc[test_seasons_idxs[i][0]:test_seasons_idxs[i][-1]]
        y_train1 = y.loc[:test_seasons_idxs[i][0]-1]
        y_test1 = y.loc[test_seasons_idxs[i][0]:test_seasons_idxs[i][-1]]
        
        X_train2 = X.loc[:test_seasons_idxs[i+1][0]-1]
        X_test2 = X.loc[test_seasons_idxs[i+1][0]:test_seasons_idxs[i+1][-1]]
        y_train2 = y.loc[:test_seasons_idxs[i+1][0]-1]
        y_test2 = y.loc[test_seasons_idxs[i+1][0]:test_seasons_idxs[i+1][-1]]        

        model.fit(X_train1, y_train1)
        probs1 = model.predict_proba(X_test1)
        
        select_bets, confidence_thresholds = find_optimal_threshold(df, probs1, test_seasons_idxs[i])
        
        try:
            best_strat = confidence_thresholds.loc[0, 'strategy']
            best_threshold = confidence_thresholds.loc[0, 'confidence_range'] 
            print("best_strat:", best_strat, "best_threshold:", best_threshold)
            
        except:
            best_strat = 3
            best_threshold = 0.5
            print("no best strategy/threshold for season", select_bets.loc[0, 'SEASON_YEAR_x'])
        
        model.fit(X_train2, y_train2)
        probs2 = model.predict_proba(X_test2)
        
        
        bets = create_betting_df(df, probs2, test_season_idxs[i+1], 3)
        select_bets = bets.loc[~bets['prob_avg'].between(1-best_threshold, best_threshold)]
        print('season ', df.loc[test_season_idxs[i+1][0], 'SEASON_YEAR_x'])
        simulate_bets(select_bets)
        
        result_dfs.append(select_bets)
        
    return result_dfs

# %%
df_ewm_19_diffs
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION            TEAM_NAME     GAME_ID  \
# 0      2000-01  1610612755               PHI   Philadelphia 76ers  0020000001
# 1      2000-01  1610612752               NYK      New York Knicks  0020000001
# 2      2000-01  1610612739               CLE  Cleveland Cavaliers  0020000002
# 3      2000-01  1610612751               BKN      New Jersey Nets  0020000002
# 4      2000-01  1610612764               WAS   Washington Wizards  0020000003
# ...        ...         ...               ...                  ...         ...
# 53669  2020-21  1610612749               MIL      Milwaukee Bucks  0042000404
# 53670  2020-21  1610612749               MIL      Milwaukee Bucks  0042000405
# 53671  2020-21  1610612756               PHX         Phoenix Suns  0042000405
# 53672  2020-21  1610612756               PHX         Phoenix Suns  0042000406
# 53673  2020-21  1610612749               MIL      Milwaukee Bucks  0042000406
#
#        GAME_DATE      MATCHUP  HOME_GAME  SCORE_team  POINT_DIFF_team  \
# 0     2000-10-31    PHI @ NYK          0         101               29
# 1     2000-10-31  NYK vs. PHI          1          72              -29
# 2     2000-10-31    CLE @ BKN          0          86                4
# 3     2000-10-31  BKN vs. CLE          1          82               -4
# 4     2000-10-31    WAS @ ORL          0          86              -11
# ...          ...          ...        ...         ...              ...
# 53669 2021-07-14  MIL vs. PHX          1         109                6
# 53670 2021-07-17    MIL @ PHX          0         123                4
# 53671 2021-07-17  PHX vs. MIL          1         119               -4
# 53672 2021-07-20    PHX @ MIL          0          98               -7
# 53673 2021-07-20  MIL vs. PHX          1         105                7
#
#        WL_team   ML_team  SPREAD_team  TEAM_COVERED_team  RECORD_team_diff  \
# 0            1       NaN          NaN                  0               NaN
# 1            0       NaN          NaN                  0               NaN
# 2            1       NaN          NaN                  0               NaN
# 3            0       NaN          NaN                  0               NaN
# 4            0       NaN          NaN                  0               NaN
# ...        ...       ...          ...                ...               ...
# 53669        1  1.487805         -5.0                  1         -0.094598
# 53670        1  2.600000          4.5                  1          0.014868
# 53671        0  1.540541         -4.5                  0         -0.014868
# 53672        0  2.650000          4.5                  0         -0.113386
# 53673        1  1.526316         -4.5                  1          0.113386
#
#        FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  FG3A_team_diff  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 53669        0.674764        0.181271        0.143275        4.353561
# 53670        0.507277        1.463215        0.128950        4.518219
# 53671       -0.507277       -1.463215       -0.128950       -4.518219
# 53672       -0.556549       -0.416834       -0.216059       -4.966426
# 53673        0.556549        0.416834        0.216059        4.966426
#
#        FTM_team_diff  FTA_team_diff  OREB_team_diff  DREB_team_diff  \
# 0                NaN            NaN             NaN             NaN
# 1                NaN            NaN             NaN             NaN
# 2                NaN            NaN             NaN             NaN
# 3                NaN            NaN             NaN             NaN
# 4                NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 53669      -0.626273       2.676078        4.164678        0.115788
# 53670       0.236402       3.408511        4.948255       -0.295814
# 53671      -0.236402      -3.408511       -4.948255        0.295814
# 53672      -0.112759      -3.667677       -4.753420        0.366231
# 53673       0.112759       3.667677        4.753420       -0.366231
#
#        REB_team_diff  AST_team_diff  STL_team_diff  BLK_team_diff  \
# 0                NaN            NaN            NaN            NaN
# 1                NaN            NaN            NaN            NaN
# 2                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 4                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 53669       4.280466      -0.415827       1.811564       0.769375
# 53670       4.652442       0.025783       2.430444       0.092396
# 53671      -4.652442      -0.025783      -2.430444      -0.092396
# 53672      -4.387189      -0.323220      -1.987376       0.316864
# 53673       4.387189       0.323220       1.987376      -0.316864
#
#        TOV_team_diff  PF_team_diff  PTS_team_diff  PLUS_MINUS_team_diff  \
# 0                NaN           NaN            NaN                   NaN
# 1                NaN           NaN            NaN                   NaN
# 2                NaN           NaN            NaN                   NaN
# 3                NaN           NaN            NaN                   NaN
# 4                NaN           NaN            NaN                   NaN
# ...              ...           ...            ...                   ...
# 53669       0.592062     -1.373597       1.153082             -0.414971
# 53670      -0.667218     -1.836266       1.637806              0.826602
# 53671       0.667218      1.836266      -1.637806             -0.826602
# 53672       0.300476      1.952645      -1.874032             -1.543981
# 53673      -0.300476     -1.952645       1.874032              1.543981
#
#        E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  E_NET_RATING_team_diff  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 53669               -1.191108               -1.288151                0.092439
# 53670               -0.391947               -1.839368                1.443277
# 53671                0.391947                1.839368               -1.443277
# 53672                0.292756                1.715435               -1.418950
# 53673               -0.292756               -1.715435                1.418950
#
#        POSS_team_diff  PIE_team_diff  PTS_2PT_MR_team_diff  PTS_FB_team_diff  \
# 0                 NaN            NaN                   NaN               NaN
# 1                 NaN            NaN                   NaN               NaN
# 2                 NaN            NaN                   NaN               NaN
# 3                 NaN            NaN                   NaN               NaN
# 4                 NaN            NaN                   NaN               NaN
# ...               ...            ...                   ...               ...
# 53669        1.742678      -0.003307             -7.070413          4.061340
# 53670        1.568401       0.004224             -7.263388          5.155273
# 53671       -1.568401      -0.004224              7.263388         -5.155273
# 53672       -1.311550      -0.003202              5.736973         -5.539763
# 53673        1.311550       0.003202             -5.736973          5.539763
#
#        PTS_OFF_TOV_team_diff  PTS_PAINT_team_diff  AST_2PM_team_diff  \
# 0                        NaN                  NaN                NaN
# 1                        NaN                  NaN                NaN
# 2                        NaN                  NaN                NaN
# 3                        NaN                  NaN                NaN
# 4                        NaN                  NaN                NaN
# ...                      ...                  ...                ...
# 53669              -0.997338             8.295705          -0.424502
# 53670               0.902508             8.266135           0.217986
# 53671              -0.902508            -8.266135          -0.217986
# 53672              -0.612241            -6.839445          -0.196186
# 53673               0.612241             6.839445           0.196186
#
#        AST_3PM_team_diff  UAST_2PM_team_diff  UAST_3PM_team_diff  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 53669           0.037132            1.188370            0.062725
# 53670          -0.166591            0.469489            0.156459
# 53671           0.166591           -0.469489           -0.156459
# 53672          -0.150084           -0.422534            0.059198
# 53673           0.150084            0.422534           -0.059198
#
#        ATS_DIFF_team_diff  RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  \
# 0                     NaN              NaN            NaN            NaN
# 1                     NaN              NaN            NaN            NaN
# 2                     NaN              NaN            NaN            NaN
# 3                     NaN              NaN            NaN            NaN
# 4                     NaN              NaN            NaN            NaN
# ...                   ...              ...            ...            ...
# 53669           -0.517751         0.094598       0.344140       0.100805
# 53670           -0.265960        -0.014868       0.409727      -1.209358
# 53671            0.265960         0.014868      -0.409727       1.209358
# 53672           -1.460728         0.113386      -0.268742       0.188374
# 53673            1.460728        -0.113386       0.268742      -0.188374
#
#        FG3M_opp_diff  FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  \
# 0                NaN            NaN           NaN           NaN
# 1                NaN            NaN           NaN           NaN
# 2                NaN            NaN           NaN           NaN
# 3                NaN            NaN           NaN           NaN
# 4                NaN            NaN           NaN           NaN
# ...              ...            ...           ...           ...
# 53669       1.003626       0.930601     -2.131106     -4.268551
# 53670       0.903261       0.237506     -2.718033     -4.841732
# 53671      -0.903261      -0.237506      2.718033      4.841732
# 53672      -0.712924       0.686287      2.346206      4.957561
# 53673       0.712924      -0.686287     -2.346206     -4.957561
#
#        OREB_opp_diff  DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  \
# 0                NaN            NaN           NaN           NaN           NaN
# 1                NaN            NaN           NaN           NaN           NaN
# 2                NaN            NaN           NaN           NaN           NaN
# 3                NaN            NaN           NaN           NaN           NaN
# 4                NaN            NaN           NaN           NaN           NaN
# ...              ...            ...           ...           ...           ...
# 53669      -1.674753      -0.030537     -1.705290      0.351897      1.025443
# 53670      -2.707339       0.372540     -2.334799     -0.083318      0.122846
# 53671       2.707339      -0.372540      2.334799      0.083318     -0.122846
# 53672       2.736606      -0.435293      2.301313      0.375003     -0.310570
# 53673      -2.736606       0.435293     -2.301313     -0.375003      0.310570
#
#        BLK_opp_diff  TOV_opp_diff  PF_opp_diff  PTS_opp_diff  \
# 0               NaN           NaN          NaN           NaN
# 1               NaN           NaN          NaN           NaN
# 2               NaN           NaN          NaN           NaN
# 3               NaN           NaN          NaN           NaN
# 4               NaN           NaN          NaN           NaN
# ...             ...           ...          ...           ...
# 53669     -0.087588      1.847764     1.859030      1.568053
# 53670      0.521205      2.863048     2.273150      0.811204
# 53671     -0.521205     -2.863048    -2.273150     -0.811204
# 53672     -0.869103     -2.276713    -2.345839     -0.330051
# 53673      0.869103      2.276713     2.345839      0.330051
#
#        PLUS_MINUS_opp_diff  E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 53669             0.414971              -1.288151              -1.191108
# 53670            -0.826602              -1.839368              -0.391947
# 53671             0.826602               1.839368               0.391947
# 53672             1.543981               1.715435               0.292756
# 53673            -1.543981              -1.715435              -0.292756
#
#        E_NET_RATING_opp_diff  POSS_opp_diff  PIE_opp_diff  \
# 0                        NaN            NaN           NaN
# 1                        NaN            NaN           NaN
# 2                        NaN            NaN           NaN
# 3                        NaN            NaN           NaN
# 4                        NaN            NaN           NaN
# ...                      ...            ...           ...
# 53669              -0.092439       2.281465      0.003307
# 53670              -1.443277       2.053305     -0.004224
# 53671               1.443277      -2.053305      0.004224
# 53672               1.418950      -1.947972      0.003202
# 53673              -1.418950       1.947972     -0.003202
#
#        PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  PTS_OFF_TOV_opp_diff  \
# 0                      NaN              NaN                   NaN
# 1                      NaN              NaN                   NaN
# 2                      NaN              NaN                   NaN
# 3                      NaN              NaN                   NaN
# 4                      NaN              NaN                   NaN
# ...                    ...              ...                   ...
# 53669             7.043358        -2.477651              1.541514
# 53670             7.239028        -3.729957             -0.412752
# 53671            -7.239028         3.729957              0.412752
# 53672            -5.715040         4.256993              0.171466
# 53673             5.715040        -4.256993             -0.171466
#
#        PTS_PAINT_opp_diff  AST_2PM_opp_diff  AST_3PM_opp_diff  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
# ...                   ...               ...               ...
# 53669           -6.273630          0.496981         -0.067916
# 53670           -6.446278         -0.152756          0.138890
# 53671            6.446278          0.152756         -0.138890
# 53672            5.201588          0.137481          0.175016
# 53673           -5.201588         -0.137481         -0.175016
#
#        UAST_2PM_opp_diff  UAST_3PM_opp_diff  ATS_DIFF_opp_diff  \
# 0                    NaN                NaN                NaN
# 1                    NaN                NaN                NaN
# 2                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 4                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 53669          -0.248892           1.055630           0.517751
# 53670           0.376031           0.850056           0.265960
# 53671          -0.376031          -0.850056          -0.265960
# 53672          -0.338423          -0.965056           1.460728
# 53673           0.338423           0.965056          -1.460728
#
#        TEAM_COVERED_opp_diff  WL_PCT_diff  ATS_PCT_diff  AVG_SPREAD_diff  \
# 0                        NaN          NaN           NaN              NaN
# 1                        NaN          NaN           NaN              NaN
# 2                        NaN          NaN           NaN              NaN
# 3                        NaN          NaN           NaN              NaN
# 4                        NaN          NaN           NaN              NaN
# ...                      ...          ...           ...              ...
# 53669               0.096789    -0.072981     -0.103918        -2.012422
# 53670              -0.012897    -0.061360     -0.091982        -2.099404
# 53671               0.012897     0.061360      0.091982         2.099404
# 53672               0.111612     0.049989      0.080302         1.981297
# 53673              -0.111612    -0.049989     -0.080302        -1.981297
#
#        AVG_ML_diff  AVG_ATS_DIFF_diff  REST_diff  OREB_PCT_team_diff  \
# 0              NaN                NaN        NaN                 NaN
# 1              NaN                NaN        NaN                 NaN
# 2              NaN                NaN        NaN                 NaN
# 3              NaN                NaN        NaN                 NaN
# 4              NaN                NaN        NaN                 NaN
# ...            ...                ...        ...                 ...
# 53669    -0.192671          -2.174032        0.0            0.073099
# 53670    -0.205192          -2.128857        0.0            0.084461
# 53671     0.205192           2.128857        0.0           -0.084461
# 53672     0.189262           1.924216        0.0           -0.081885
# 53673    -0.189262          -1.924216        0.0            0.081885
#
#        OREB_PCT_opp_diff  DREB_PCT_team_diff  DREB_PCT_opp_diff  \
# 0                    NaN                 NaN                NaN
# 1                    NaN                 NaN                NaN
# 2                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 4                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 53669          -0.030023            0.030023          -0.073099
# 53670          -0.046057            0.046057          -0.084461
# 53671           0.046057           -0.046057           0.084461
# 53672           0.046869           -0.046869           0.081885
# 53673          -0.046869            0.046869          -0.081885
#
#        REB_PCT_team_diff  REB_PCT_opp_diff  TS_PCT_team_diff  TS_PCT_opp_diff  \
# 0                    NaN               NaN               NaN              NaN
# 1                    NaN               NaN               NaN              NaN
# 2                    NaN               NaN               NaN              NaN
# 3                    NaN               NaN               NaN              NaN
# 4                    NaN               NaN               NaN              NaN
# ...                  ...               ...               ...              ...
# 53669           0.033571         -0.033571         -0.026773         0.007947
# 53670           0.039358         -0.039358         -0.034348         0.017346
# 53671          -0.039358          0.039358          0.034348        -0.017346
# 53672          -0.038422          0.038422          0.030189        -0.014488
# 53673           0.038422         -0.038422         -0.030189         0.014488
#
#        EFG_PCT_team_diff  EFG_PCT_opp_diff  AST_RATIO_team_diff  \
# 0                    NaN               NaN                  NaN
# 1                    NaN               NaN                  NaN
# 2                    NaN               NaN                  NaN
# 3                    NaN               NaN                  NaN
# 4                    NaN               NaN                  NaN
# ...                  ...               ...                  ...
# 53669          -0.017646          0.014947            -0.859358
# 53670          -0.028321          0.025992            -0.357876
# 53671           0.028321         -0.025992             0.357876
# 53672           0.023329         -0.020661            -0.006428
# 53673          -0.023329          0.020661             0.006428
#
#        AST_RATIO_opp_diff  TOV_PCT_team_diff  TOV_PCT_opp_diff  team_elo_pred  \
# 0                     NaN                NaN               NaN       0.401986
# 1                     NaN                NaN               NaN       0.598014
# 2                     NaN                NaN               NaN       0.401986
# 3                     NaN                NaN               NaN       0.598014
# 4                     NaN                NaN               NaN       0.401986
# ...                   ...                ...               ...            ...
# 53669           -0.159733          -0.085550          1.596979       0.545481
# 53670           -0.550989          -1.283525          2.659991       0.370766
# 53671            0.550989           1.283525         -2.659991       0.629234
# 53672            0.840469           0.937399         -2.185362       0.409904
# 53673           -0.840469          -0.937399          2.185362       0.590096
#
#        team_rating_i  team_rating_n  opp_rating_i  opp_rating_n  elo_MOV_pred
# 0        1300.000000    1327.005984   1300.000000   1272.994016          0.00
# 1        1300.000000    1272.994016   1300.000000   1327.005984          0.00
# 2        1300.000000    1308.006053   1300.000000   1291.993947          0.00
# 3        1300.000000    1291.993947   1300.000000   1308.006053          0.00
# 4        1300.000000    1290.629938   1300.000000   1309.370062          0.00
# ...              ...            ...           ...           ...           ...
# 53669    1705.296008    1712.508201   1742.604936   1735.392744         -1.33
# 53670    1712.508201    1721.098675   1735.392744   1726.802269         -0.82
# 53671    1735.392744    1726.802269   1712.508201   1721.098675          0.82
# 53672    1726.802269    1719.537558   1721.098675   1728.363386          0.20
# 53673    1721.098675    1728.363386   1726.802269   1719.537558         -0.20
#
# [53674 rows x 103 columns]

# %% [markdown]
# ## Create Features Sets

# %% [markdown]
# ### Features EWM

# %%
home_games = df_ewm_19_diffs.loc[df_ewm_19_diffs['HOME_GAME'] == 1]

home_games
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 1      2000-01  1610612752               NYK  New York Knicks  0020000001
# 3      2000-01  1610612751               BKN  New Jersey Nets  0020000002
# 5      2000-01  1610612753               ORL    Orlando Magic  0020000003
# 7      2000-01  1610612737               ATL    Atlanta Hawks  0020000004
# 9      2000-01  1610612761               TOR  Toronto Raptors  0020000005
# ...        ...         ...               ...              ...         ...
# 53665  2020-21  1610612756               PHX     Phoenix Suns  0042000402
# 53667  2020-21  1610612749               MIL  Milwaukee Bucks  0042000403
# 53669  2020-21  1610612749               MIL  Milwaukee Bucks  0042000404
# 53671  2020-21  1610612756               PHX     Phoenix Suns  0042000405
# 53673  2020-21  1610612749               MIL  Milwaukee Bucks  0042000406
#
#        GAME_DATE      MATCHUP  HOME_GAME  SCORE_team  POINT_DIFF_team  \
# 1     2000-10-31  NYK vs. PHI          1          72              -29
# 3     2000-10-31  BKN vs. CLE          1          82               -4
# 5     2000-10-31  ORL vs. WAS          1          97               11
# 7     2000-10-31  ATL vs. CHA          1          82              -24
# 9     2000-10-31  TOR vs. DET          1          95               -9
# ...          ...          ...        ...         ...              ...
# 53665 2021-07-08  PHX vs. MIL          1         118               10
# 53667 2021-07-11  MIL vs. PHX          1         120               20
# 53669 2021-07-14  MIL vs. PHX          1         109                6
# 53671 2021-07-17  PHX vs. MIL          1         119               -4
# 53673 2021-07-20  MIL vs. PHX          1         105                7
#
#        WL_team   ML_team  SPREAD_team  TEAM_COVERED_team  RECORD_team_diff  \
# 1            0       NaN          NaN                  0               NaN
# 3            0       NaN          NaN                  0               NaN
# 5            1       NaN          NaN                  0               NaN
# 7            0       NaN          NaN                  0               NaN
# 9            0       NaN          NaN                  0               NaN
# ...        ...       ...          ...                ...               ...
# 53665        1  1.476190         -4.5                  1          0.129137
# 53667        1       NaN         -5.0                  1         -0.216229
# 53669        1  1.487805         -5.0                  1         -0.094598
# 53671        0  1.540541         -4.5                  0         -0.014868
# 53673        1  1.526316         -4.5                  1          0.113386
#
#        FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  FG3A_team_diff  \
# 1                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 5                 NaN             NaN             NaN             NaN
# 7                 NaN             NaN             NaN             NaN
# 9                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 53665        0.031214        1.578822       -0.781875       -5.757597
# 53667        0.971982       -0.020827       -0.396400        4.281729
# 53669        0.674764        0.181271        0.143275        4.353561
# 53671       -0.507277       -1.463215       -0.128950       -4.518219
# 53673        0.556549        0.416834        0.216059        4.966426
#
#        FTM_team_diff  FTA_team_diff  OREB_team_diff  DREB_team_diff  \
# 1                NaN            NaN             NaN             NaN
# 3                NaN            NaN             NaN             NaN
# 5                NaN            NaN             NaN             NaN
# 7                NaN            NaN             NaN             NaN
# 9                NaN            NaN             NaN             NaN
# ...              ...            ...             ...             ...
# 53665       2.217750      -1.069103       -3.499551       -0.093556
# 53667      -1.695936       1.862251        3.849618       -0.315825
# 53669      -0.626273       2.676078        4.164678        0.115788
# 53671      -0.236402      -3.408511       -4.948255        0.295814
# 53673       0.112759       3.667677        4.753420       -0.366231
#
#        REB_team_diff  AST_team_diff  STL_team_diff  BLK_team_diff  \
# 1                NaN            NaN            NaN            NaN
# 3                NaN            NaN            NaN            NaN
# 5                NaN            NaN            NaN            NaN
# 7                NaN            NaN            NaN            NaN
# 9                NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 53665      -3.593107       0.822041      -1.508079      -0.517725
# 53667       3.533793      -1.239867       1.457267       0.965985
# 53669       4.280466      -0.415827       1.811564       0.769375
# 53671      -4.652442      -0.025783      -2.430444      -0.092396
# 53673       4.387189       0.323220       1.987376      -0.316864
#
#        TOV_team_diff  PF_team_diff  PTS_team_diff  PLUS_MINUS_team_diff  \
# 1                NaN           NaN            NaN                   NaN
# 3                NaN           NaN            NaN                   NaN
# 5                NaN           NaN            NaN                   NaN
# 7                NaN           NaN            NaN                   NaN
# 9                NaN           NaN            NaN                   NaN
# ...              ...           ...            ...                   ...
# 53665      -1.916231      0.732783      -0.065446              3.228594
# 53667       1.324566     -0.859513      -0.941173             -4.905852
# 53669       0.592062     -1.373597       1.153082             -0.414971
# 53671       0.667218      1.836266      -1.637806             -0.826602
# 53673      -0.300476     -1.952645       1.874032              1.543981
#
#        E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  E_NET_RATING_team_diff  \
# 1                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 5                         NaN                     NaN                     NaN
# 7                         NaN                     NaN                     NaN
# 9                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 53665                3.322522               -0.261680                3.589886
# 53667               -3.790308                1.035559               -4.830983
# 53669               -1.191108               -1.288151                0.092439
# 53671                0.391947                1.839368               -1.443277
# 53673               -0.292756               -1.715435                1.418950
#
#        POSS_team_diff  PIE_team_diff  PTS_2PT_MR_team_diff  PTS_FB_team_diff  \
# 1                 NaN            NaN                   NaN               NaN
# 3                 NaN            NaN                   NaN               NaN
# 5                 NaN            NaN                   NaN               NaN
# 7                 NaN            NaN                   NaN               NaN
# 9                 NaN            NaN                   NaN               NaN
# ...               ...            ...                   ...               ...
# 53665       -2.262604       0.024430              5.605329         -2.791674
# 53667        1.936323      -0.030788             -5.744808          3.512559
# 53669        1.742678      -0.003307             -7.070413          4.061340
# 53671       -1.568401      -0.004224              7.263388         -5.155273
# 53673        1.311550       0.003202             -5.736973          5.539763
#
#        PTS_OFF_TOV_team_diff  PTS_PAINT_team_diff  AST_2PM_team_diff  \
# 1                        NaN                  NaN                NaN
# 3                        NaN                  NaN                NaN
# 5                        NaN                  NaN                NaN
# 7                        NaN                  NaN                NaN
# 9                        NaN                  NaN                NaN
# ...                      ...                  ...                ...
# 53665               2.206689            -5.512987           1.104379
# 53667              -1.885997             7.661849          -0.693910
# 53669              -0.997338             8.295705          -0.424502
# 53671              -0.902508            -8.266135          -0.217986
# 53673               0.612241             6.839445           0.196186
#
#        AST_3PM_team_diff  UAST_2PM_team_diff  UAST_3PM_team_diff  \
# 1                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 5                    NaN                 NaN                 NaN
# 7                    NaN                 NaN                 NaN
# 9                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 53665          -0.440939           -1.183171           -0.398452
# 53667          -0.403219            1.764896           -0.041425
# 53669           0.037132            1.188370            0.062725
# 53671           0.166591           -0.469489           -0.156459
# 53673           0.150084            0.422534           -0.059198
#
#        ATS_DIFF_team_diff  RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  \
# 1                     NaN              NaN            NaN            NaN
# 3                     NaN              NaN            NaN            NaN
# 5                     NaN              NaN            NaN            NaN
# 7                     NaN              NaN            NaN            NaN
# 9                     NaN              NaN            NaN            NaN
# ...                   ...              ...            ...            ...
# 53665            3.120893        -0.129137      -1.289141      -1.927070
# 53667           -3.908859         0.216229       0.160145       0.334245
# 53669           -0.517751         0.094598       0.344140       0.100805
# 53671            0.265960         0.014868      -0.409727       1.209358
# 53673            1.460728        -0.113386       0.268742      -0.188374
#
#        FG3M_opp_diff  FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  \
# 1                NaN            NaN           NaN           NaN
# 3                NaN            NaN           NaN           NaN
# 5                NaN            NaN           NaN           NaN
# 7                NaN            NaN           NaN           NaN
# 9                NaN            NaN           NaN           NaN
# ...              ...            ...           ...           ...
# 53665      -0.634078      -0.766159      1.186476      3.035150
# 53667       1.670743       1.589603     -1.367840     -3.631677
# 53669       1.003626       0.930601     -2.131106     -4.268551
# 53671      -0.903261      -0.237506      2.718033      4.841732
# 53673       0.712924      -0.686287     -2.346206     -4.957561
#
#        OREB_opp_diff  DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  \
# 1                NaN            NaN           NaN           NaN           NaN
# 3                NaN            NaN           NaN           NaN           NaN
# 5                NaN            NaN           NaN           NaN           NaN
# 7                NaN            NaN           NaN           NaN           NaN
# 9                NaN            NaN           NaN           NaN           NaN
# ...              ...            ...           ...           ...           ...
# 53665       0.425516      -0.011682      0.413833     -0.743118     -1.994452
# 53667      -1.083016       0.410545     -0.672470      1.168835      1.694984
# 53669      -1.674753      -0.030537     -1.705290      0.351897      1.025443
# 53671       2.707339      -0.372540      2.334799      0.083318     -0.122846
# 53673      -2.736606       0.435293     -2.301313     -0.375003      0.310570
#
#        BLK_opp_diff  TOV_opp_diff  PF_opp_diff  PTS_opp_diff  \
# 1               NaN           NaN          NaN           NaN
# 3               NaN           NaN          NaN           NaN
# 5               NaN           NaN          NaN           NaN
# 7               NaN           NaN          NaN           NaN
# 9               NaN           NaN          NaN           NaN
# ...             ...           ...          ...           ...
# 53665     -0.323998     -1.095943    -1.332095     -3.294039
# 53667     -0.208441      1.386371     1.398891      3.964679
# 53669     -0.087588      1.847764     1.859030      1.568053
# 53671     -0.521205     -2.863048    -2.273150     -0.811204
# 53673      0.869103      2.276713     2.345839      0.330051
#
#        PLUS_MINUS_opp_diff  E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  \
# 1                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 5                      NaN                    NaN                    NaN
# 7                      NaN                    NaN                    NaN
# 9                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 53665            -3.228594              -0.261680               3.322522
# 53667             4.905852               1.035559              -3.790308
# 53669             0.414971              -1.288151              -1.191108
# 53671             0.826602               1.839368               0.391947
# 53673            -1.543981              -1.715435              -0.292756
#
#        E_NET_RATING_opp_diff  POSS_opp_diff  PIE_opp_diff  \
# 1                        NaN            NaN           NaN
# 3                        NaN            NaN           NaN
# 5                        NaN            NaN           NaN
# 7                        NaN            NaN           NaN
# 9                        NaN            NaN           NaN
# ...                      ...            ...           ...
# 53665              -3.589886      -2.705543     -0.024430
# 53667               4.830983       2.534979      0.030788
# 53669              -0.092439       2.281465      0.003307
# 53671               1.443277      -2.053305      0.004224
# 53673              -1.418950       1.947972     -0.003202
#
#        PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  PTS_OFF_TOV_opp_diff  \
# 1                      NaN              NaN                   NaN
# 3                      NaN              NaN                   NaN
# 5                      NaN              NaN                   NaN
# 7                      NaN              NaN                   NaN
# 9                      NaN              NaN                   NaN
# ...                    ...              ...                   ...
# 53665            -5.571932         0.836473             -2.878521
# 53667             5.714747        -1.752892              2.490640
# 53669             7.043358        -2.477651              1.541514
# 53671            -7.239028         3.729957              0.412752
# 53673             5.715040        -4.256993             -0.171466
#
#        PTS_PAINT_opp_diff  AST_2PM_opp_diff  AST_3PM_opp_diff  \
# 1                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 5                     NaN               NaN               NaN
# 7                     NaN               NaN               NaN
# 9                     NaN               NaN               NaN
# ...                   ...               ...               ...
# 53665            3.016562         -1.193864          0.478940
# 53667           -5.415078          0.774447          0.369014
# 53669           -6.273630          0.496981         -0.067916
# 53671            6.446278          0.152756         -0.138890
# 53673           -5.201588         -0.137481         -0.175016
#
#        UAST_2PM_opp_diff  UAST_3PM_opp_diff  ATS_DIFF_opp_diff  \
# 1                    NaN                NaN                NaN
# 3                    NaN                NaN                NaN
# 5                    NaN                NaN                NaN
# 7                    NaN                NaN                NaN
# 9                    NaN                NaN                NaN
# ...                  ...                ...                ...
# 53665           0.023305          -0.982251          -3.120893
# 53667          -0.721026           1.284049           3.908859
# 53669          -0.248892           1.055630           0.517751
# 53671          -0.376031          -0.850056          -0.265960
# 53673           0.338423           0.965056          -1.460728
#
#        TEAM_COVERED_opp_diff  WL_PCT_diff  ATS_PCT_diff  AVG_SPREAD_diff  \
# 1                        NaN          NaN           NaN              NaN
# 3                        NaN          NaN           NaN              NaN
# 5                        NaN          NaN           NaN              NaN
# 7                        NaN          NaN           NaN              NaN
# 9                        NaN          NaN           NaN              NaN
# ...                      ...          ...           ...              ...
# 53665              -0.131841     0.074657      0.106242         2.044881
# 53667               0.218663    -0.084860     -0.116117        -1.923504
# 53669               0.096789    -0.072981     -0.103918        -2.012422
# 53671               0.012897     0.061360      0.091982         2.099404
# 53673              -0.111612    -0.049989     -0.080302        -1.981297
#
#        AVG_ML_diff  AVG_ATS_DIFF_diff  REST_diff  OREB_PCT_team_diff  \
# 1              NaN                NaN        NaN                 NaN
# 3              NaN                NaN        NaN                 NaN
# 5              NaN                NaN        NaN                 NaN
# 7              NaN                NaN        NaN                 NaN
# 9              NaN                NaN        NaN                 NaN
# ...            ...                ...        ...                 ...
# 53665     0.211843           2.435019        0.0           -0.061670
# 53667    -0.192671          -2.529609        0.0            0.064658
# 53669    -0.192671          -2.174032        0.0            0.073099
# 53671     0.205192           2.128857        0.0           -0.084461
# 53673    -0.189262          -1.924216        0.0            0.081885
#
#        OREB_PCT_opp_diff  DREB_PCT_team_diff  DREB_PCT_opp_diff  \
# 1                    NaN                 NaN                NaN
# 3                    NaN                 NaN                NaN
# 5                    NaN                 NaN                NaN
# 7                    NaN                 NaN                NaN
# 9                    NaN                 NaN                NaN
# ...                  ...                 ...                ...
# 53665           0.007970           -0.007970           0.061670
# 53667          -0.017420            0.017420          -0.064658
# 53669          -0.030023            0.030023          -0.073099
# 53671           0.046057           -0.046057           0.084461
# 53673          -0.046869            0.046869          -0.081885
#
#        REB_PCT_team_diff  REB_PCT_opp_diff  TS_PCT_team_diff  TS_PCT_opp_diff  \
# 1                    NaN               NaN               NaN              NaN
# 3                    NaN               NaN               NaN              NaN
# 5                    NaN               NaN               NaN              NaN
# 7                    NaN               NaN               NaN              NaN
# 9                    NaN               NaN               NaN              NaN
# ...                  ...               ...               ...              ...
# 53665          -0.021935          0.021935          0.027993        -0.005120
# 53667           0.023188         -0.023188         -0.034986         0.014428
# 53669           0.033571         -0.033571         -0.026773         0.007947
# 53671          -0.039358          0.039358          0.034348        -0.017346
# 53673           0.038422         -0.038422         -0.030189         0.014488
#
#        EFG_PCT_team_diff  EFG_PCT_opp_diff  AST_RATIO_team_diff  \
# 1                    NaN               NaN                  NaN
# 3                    NaN               NaN                  NaN
# 5                    NaN               NaN                  NaN
# 7                    NaN               NaN                  NaN
# 9                    NaN               NaN                  NaN
# ...                  ...               ...                  ...
# 53665           0.012554         -0.009599             1.394668
# 53667          -0.021653          0.018944            -1.748613
# 53669          -0.017646          0.014947            -0.859358
# 53671           0.028321         -0.025992             0.357876
# 53673          -0.023329          0.020661             0.006428
#
#        AST_RATIO_opp_diff  TOV_PCT_team_diff  TOV_PCT_opp_diff  team_elo_pred  \
# 1                     NaN                NaN               NaN       0.598014
# 3                     NaN                NaN               NaN       0.598014
# 5                     NaN                NaN               NaN       0.598014
# 7                     NaN                NaN               NaN       0.598014
# 9                     NaN                NaN               NaN       0.598014
# ...                   ...                ...               ...            ...
# 53665           -0.162203          -1.093878         -0.749176       0.671238
# 53667            0.628826           0.575005          1.096532       0.498349
# 53669           -0.159733          -0.085550          1.596979       0.545481
# 53671            0.550989           1.283525         -2.659991       0.629234
# 53673           -0.840469          -0.937399          2.185362       0.590096
#
#        team_rating_i  team_rating_n  opp_rating_i  opp_rating_n  elo_MOV_pred
# 1        1300.000000    1272.994016   1300.000000   1327.005984          0.00
# 3        1300.000000    1291.993947   1300.000000   1308.006053          0.00
# 5        1300.000000    1309.370062   1300.000000   1290.629938          0.00
# 7        1300.000000    1276.426122   1300.000000   1323.573878          0.00
# 9        1300.000000    1287.677892   1300.000000   1312.322108          0.00
# ...              ...            ...           ...           ...           ...
# 53665    1751.449345    1759.024232   1696.451599   1688.876712          1.96
# 53667    1688.876712    1705.296008   1759.024232   1742.604936         -2.51
# 53669    1705.296008    1712.508201   1742.604936   1735.392744         -1.33
# 53671    1735.392744    1726.802269   1712.508201   1721.098675          0.82
# 53673    1721.098675    1728.363386   1726.802269   1719.537558         -0.20
#
# [26837 rows x 103 columns]

# %%
cutoff_16 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2015-16'].index[-1]
cutoff_17 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2016-17'].index[-1]
cutoff_18 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2017-18'].index[-1]
cutoff_19 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2018-19'].index[-1]
cutoff_20 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2019-20'].index[-1]
cutoff_21 = df_ewm_19_diffs.loc[df_ewm_19_diffs['SEASON'] == '2020-21'].index[-1]

# %%
df = df_ewm_19_diffs.copy(deep=True)
df = df.loc[df['point_diff_team'] + df['spread_team']!=0]


df = df.sort_values(['GAME_DATE', 'GAME_ID', 'HOME_GAME'])
# df.dropna(inplace=True)


features = df.iloc[:, 13:]

df.loc[df['GAME_ID']==20600076] 
# features['spread'] = df['spread_team']
# features.drop(columns=['team_rating_n', 'opp_rating_n', 'RECORD_team', 'team_covered_team'], inplace=True)

# cover = (df['point_diff_team'] + df['spread_team'] > 0).astype(int)

# cover.value_counts()

# X_train1 = features.loc[:cutoff]
# X_test1 = features.loc[cutoff+1:]

# cover_train1 = cover.loc[:cutoff]
# cover_test1 = cover.loc[cutoff+1:]


# train_idx1 = X_train1.index
# test_idx1 = X_test1.index

# X_train1 = X_train1.astype(float)
# X_test1 = X_test1.astype(float)
# Out:
#       SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME   GAME_ID  \
# 15550     2006-07  1610612753               ORL   Orlando Magic  20600076
# 15551     2006-07  1610612754               IND  Indiana Pacers  20600076
#
#        GAME_DATE      MATCHUP  HOME_GAME  SCORE_team  point_diff_team  \
# 15550 2006-11-10    ORL @ IND          0          83            -10.0
# 15551 2006-11-10  IND vs. ORL          1          93             10.0
#
#        WL_team  spread_team   ml_team  team_covered_team  RECORD_team  \
# 15550        0          5.5  2.900000                  0            0
# 15551        1         -5.5  1.434783                  1            1
#
#          avg_ml  avg_spread  avg_point_spread_diff  points_covered_spread_by  \
# 15550  1.648539        -3.0                  -2.25                       NaN
# 15551  1.968208        -1.3                  -1.90                 -2.599424
#
#        FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  FG3A_team_diff  \
# 15550         0.57581       -7.261337       -1.148934       -6.622988
# 15551        -0.57581        7.261337        1.148934        6.622988
#
#        FTM_team_diff  FTA_team_diff  OREB_team_diff  DREB_team_diff  \
# 15550       0.816903       4.248272       -4.494689       -1.648116
# 15551      -0.816903      -4.248272        4.494689        1.648116
#
#        REB_team_diff  AST_team_diff  STL_team_diff  BLK_team_diff  \
# 15550      -6.142805       -4.42419      -0.493932         -1.449
# 15551       6.142805        4.42419       0.493932          1.449
#
#        TOV_team_diff  PF_team_diff  PTS_team_diff  PLUS_MINUS_team_diff  \
# 15550       3.451833      1.093185      -1.478279              2.022368
# 15551      -3.451833     -1.093185       1.478279             -2.022368
#
#        E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  E_NET_RATING_team_diff  \
# 15550                2.621902                0.945064                1.721037
# 15551               -2.621902               -0.945064               -1.721037
#
#        POSS_team_diff  PIE_team_diff  PTS_2PT_MR_team_diff  PTS_FB_team_diff  \
# 15550       -3.771092       0.004203              7.343752         -1.015506
# 15551        3.771092      -0.004203             -7.343752          1.015506
#
#        PTS_OFF_TOV_team_diff  PTS_PAINT_team_diff  AST_2PM_team_diff  \
# 15550               0.291275            -6.814339          -3.979243
# 15551              -0.291275             6.814339           3.979243
#
#        UAST_2PM_team_diff  AST_3PM_team_diff  UAST_3PM_team_diff  \
# 15550            4.377036          -0.654001           -0.501551
# 15551           -4.377036           0.654001            0.501551
#
#        team_covered_opp_diff  RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  \
# 15550               0.173378        -0.046397      -5.610901      -7.406803
# 15551              -0.173378         0.046397       5.610901       7.406803
#
#        FG3M_opp_diff  FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  \
# 15550       1.867403       0.823912      2.118947      1.581207
# 15551      -1.867403      -0.823912     -2.118947     -1.581207
#
#        OREB_opp_diff  DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  \
# 15550      -0.850773      -7.125809     -7.976582      -1.82882      3.576201
# 15551       0.850773       7.125809      7.976582       1.82882     -3.576201
#
#        BLK_opp_diff  TOV_opp_diff  PF_opp_diff  PTS_opp_diff  \
# 15550     -0.950331       0.89822     2.521355     -3.500647
# 15551      0.950331      -0.89822    -2.521355      3.500647
#
#        PLUS_MINUS_opp_diff  E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  \
# 15550            -2.022368               0.945064               2.621902
# 15551             2.022368              -0.945064              -2.621902
#
#        E_NET_RATING_opp_diff  POSS_opp_diff  PIE_opp_diff  \
# 15550              -1.721037      -3.595272     -0.004203
# 15551               1.721037       3.595272      0.004203
#
#        PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  PTS_OFF_TOV_opp_diff  \
# 15550              1.95038        -1.222461              4.223462
# 15551             -1.95038         1.222461             -4.223462
#
#        PTS_PAINT_opp_diff  AST_2PM_opp_diff  UAST_2PM_opp_diff  \
# 15550          -12.996362         -4.447852          -0.943274
# 15551           12.996362          4.447852           0.943274
#
#        AST_3PM_opp_diff  UAST_3PM_opp_diff  WL_record_diff  ATS_record_diff  \
# 15550          1.922786           0.206613             0.0             -0.4
# 15551         -1.922786          -0.206613             0.0              0.4
#
#        rest_diff  OREB_PCT_team_diff  OREB_PCT_opp_diff  DREB_PCT_team_diff  \
# 15550        0.0           -0.017803          -0.003636            0.003636
# 15551        0.0            0.017803           0.003636           -0.003636
#
#        DREB_PCT_opp_diff  REB_PCT_team_diff  REB_PCT_opp_diff  \
# 15550           0.017803           0.017193         -0.017193
# 15551          -0.017803          -0.017193          0.017193
#
#        TS_PCT_team_diff  TS_PCT_opp_diff  EFG_PCT_team_diff  EFG_PCT_opp_diff  \
# 15550          0.083842         0.021807           0.077382          0.005346
# 15551         -0.083842        -0.021807          -0.077382         -0.005346
#
#        AST_RATIO_team_diff  AST_RATIO_opp_diff  TOV_PCT_team_diff  \
# 15550            -3.823167           -1.197866           4.636984
# 15551             3.823167            1.197866          -4.636984
#
#        TOV_PCT_opp_diff  team_elo_pred  team_rating_i  team_rating_n  \
# 15550          1.547139       0.406054    1462.790293    1453.892355
# 15551         -1.547139       0.593946    1459.855633    1468.753571
#
#        opp_rating_i  opp_rating_n  elo_MOV_pred
# 15550   1459.855633   1468.753571           0.1
# 15551   1462.790293   1453.892355          -0.1

# %%
home_games.isnull().sum()
# Out:
# SEASON                        0
# TEAM_ID                       0
# TEAM_ABBREVIATION             0
# TEAM_NAME                     0
# GAME_ID                       0
# GAME_DATE                     0
# MATCHUP                       0
# HOME_GAME                     0
# SCORE_team                    0
# POINT_DIFF_team               0
# WL_team                       0
# ML_team                   13007
# SPREAD_team                8470
# TEAM_COVERED_team             0
# RECORD_team_diff           1663
# FG2M_team_diff             1663
# FG2A_team_diff             1663
# FG3M_team_diff             1663
# FG3A_team_diff             1663
# FTM_team_diff              1663
# FTA_team_diff              1663
# OREB_team_diff             1663
# DREB_team_diff             1663
# REB_team_diff              1663
# AST_team_diff              1663
# STL_team_diff              1663
# BLK_team_diff              1663
# TOV_team_diff              1663
# PF_team_diff               1663
# PTS_team_diff              1663
# PLUS_MINUS_team_diff       1663
# E_OFF_RATING_team_diff     1663
# E_DEF_RATING_team_diff     1663
# E_NET_RATING_team_diff     1663
# POSS_team_diff             1663
# PIE_team_diff              1663
# PTS_2PT_MR_team_diff       1663
# PTS_FB_team_diff           1663
# PTS_OFF_TOV_team_diff      1663
# PTS_PAINT_team_diff        1663
# AST_2PM_team_diff          1663
# AST_3PM_team_diff          1663
# UAST_2PM_team_diff         1663
# UAST_3PM_team_diff         1663
# ATS_DIFF_team_diff         9090
# RECORD_opp_diff            1663
# FG2M_opp_diff              1663
# FG2A_opp_diff              1663
# FG3M_opp_diff              1663
# FG3A_opp_diff              1663
# FTM_opp_diff               1663
# FTA_opp_diff               1663
# OREB_opp_diff              1663
# DREB_opp_diff              1663
# REB_opp_diff               1663
# AST_opp_diff               1663
# STL_opp_diff               1663
# BLK_opp_diff               1663
# TOV_opp_diff               1663
# PF_opp_diff                1663
# PTS_opp_diff               1663
# PLUS_MINUS_opp_diff        1663
# E_OFF_RATING_opp_diff      1663
# E_DEF_RATING_opp_diff      1663
# E_NET_RATING_opp_diff      1663
# POSS_opp_diff              1663
# PIE_opp_diff               1663
# PTS_2PT_MR_opp_diff        1663
# PTS_FB_opp_diff            1663
# PTS_OFF_TOV_opp_diff       1663
# PTS_PAINT_opp_diff         1663
# AST_2PM_opp_diff           1663
# AST_3PM_opp_diff           1663
# UAST_2PM_opp_diff          1663
# UAST_3PM_opp_diff          1663
# ATS_DIFF_opp_diff          9090
# TEAM_COVERED_opp_diff      1663
# WL_PCT_diff                 360
# ATS_PCT_diff                360
# AVG_SPREAD_diff            8124
# AVG_ML_diff                8410
# AVG_ATS_DIFF_diff          8124
# REST_diff                   360
# OREB_PCT_team_diff         1663
# OREB_PCT_opp_diff          1663
# DREB_PCT_team_diff         1663
# DREB_PCT_opp_diff          1663
# REB_PCT_team_diff          1663
# REB_PCT_opp_diff           1663
# TS_PCT_team_diff           1663
# TS_PCT_opp_diff            1663
# EFG_PCT_team_diff          1663
# EFG_PCT_opp_diff           1663
# AST_RATIO_team_diff        1663
# AST_RATIO_opp_diff         1663
# TOV_PCT_team_diff          1663
# TOV_PCT_opp_diff           1663
# team_elo_pred                 0
# team_rating_i                 0
# team_rating_n                 0
# opp_rating_i                  0
# opp_rating_n                  0
# elo_MOV_pred                  0
# dtype: int64

# %%
df_ewm_19_diffs.loc[df_ewm_19_diffs['FG2M_team_diff'].isnull()]

df_ewm_19_diffs.dropna(subset=['ML_team'])['SEASON'].value_counts()
# Out:
# 2017-18    2444
# 2018-19    2226
# 2016-17    2206
# 2012-13    2142
# 2014-15    2093
# 2020-21    1982
# 2019-20    1932
# 2015-16    1728
# 2007-08    1708
# 2010-11    1702
# 2009-10    1672
# 2011-12    1628
# 2008-09    1600
# 2013-14    1438
# 2006-07    1159
# Name: SEASON, dtype: int64

# %%
df_ewm_19_diffs.dropna(subset=['SPREAD_team'])['SEASON'].value_counts()
# Out:
# 2017-18    2624
# 2018-19    2622
# 2012-13    2616
# 2015-16    2616
# 2016-17    2604
# 2013-14    2594
# 2014-15    2554
# 2009-10    2548
# 2008-09    2496
# 2010-11    2486
# 2020-21    2330
# 2019-20    2264
# 2007-08    2236
# 2006-07    2094
# 2011-12    2050
# Name: SEASON, dtype: int64

# %%
def split_prep_data(df, cutoff):
    df = df.copy(deep=True)
    df = df.loc[df['POINT_DIFF_team'] + df['SPREAD_team'] != 0]

    df = df.sort_values(['GAME_DATE', 'GAME_ID', 'HOME_GAME'])
    df = df.dropna()

    features = df.iloc[:, 14:]
    features['SPREAD'] = df['SPREAD_team']
    features = features.drop(
        columns=['team_rating_n', 'opp_rating_n', 'RECORD_team_diff'])

    y = df['TEAM_COVERED_team']

    X_train = features.loc[:cutoff]
    X_test = features.loc[cutoff+1:]

    y_train = y.loc[:cutoff]
    y_test = y.loc[cutoff+1:]

    train_idx = X_train.index
    test_idx = X_test.index

#     X_train = X_train.astype(float)
#     X_test = X_test.astype(float)

    return X_train, X_test, y_train, y_test, train_idx, test_idx

# %%
X_train, X_test, y_train, y_test, train_idx, test_idx = split_prep_data(home_games, cutoff_16)

# %%
print(X_train.shape[0] / (X_train.shape[0] + X_test.shape[0]))

X_train
# Out:
# 0.6005744833639193
#        FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  FG3A_team_diff  \
# 15577        0.248831       -5.853269        1.502618        5.116500
# 15589       -0.310867       -2.912442       -2.059230       -3.786198
# 15621       -4.151588       -6.939368        2.351356        3.641615
# 15635       -0.520470       -5.976881        3.087585        5.373902
# 15643       -3.687772       -6.606679        3.060266        7.137484
# ...               ...             ...             ...             ...
# 41183        2.054025        4.438997       -0.064319        0.805696
# 41185       -2.448634       -3.195063       -0.942144       -1.725156
# 41187       -0.903728       -0.575488       -0.547921       -2.352658
# 41191        2.308044        1.923904       -1.833843       -4.795702
# 41193       -3.277257       -2.431520        2.150465        5.516144
#
#        FTM_team_diff  FTA_team_diff  OREB_team_diff  DREB_team_diff  \
# 15577       0.741806       4.067155       -2.524098       -4.860218
# 15589       4.815621       7.069610       -1.276218        2.217901
# 15621       2.256933       1.361913       -3.020485        6.015463
# 15635      -2.518998       0.582491       -3.426173       -1.425477
# 15643       2.018421       8.090618        2.972189        2.340917
# ...              ...            ...             ...             ...
# 41183       0.275749       0.564327       -0.055228        0.708355
# 41185       0.651848       0.892143       -0.250303       -1.537547
# 41187       0.086648      -0.097096        0.674753       -0.283763
# 41191      -1.329841      -0.828656        0.226543       -0.379854
# 41193       0.696841       0.445778       -0.103885       -0.758152
#
#        REB_team_diff  AST_team_diff  STL_team_diff  BLK_team_diff  \
# 15577      -7.384317       1.130916       0.828619      -0.143984
# 15589       0.941683      -1.076968       0.047447       0.899699
# 15621       2.994978       1.406835      -2.569380       0.733913
# 15635      -4.851650       4.345695      -2.248074       2.599900
# 15643       5.313106      -2.068726      -2.495105       0.626018
# ...              ...            ...            ...            ...
# 41183       0.653127       2.700311       1.598343       0.887023
# 41185      -1.787850      -3.530306      -0.638479      -1.398334
# 41187       0.390990      -2.977262      -0.274623      -1.358500
# 41191      -0.153312      -3.431598       0.097563      -1.100376
# 41193      -0.862037       2.588423      -0.787820       0.590329
#
#        TOV_team_diff  PF_team_diff  PTS_team_diff  PLUS_MINUS_team_diff  \
# 15577       0.688071      1.640417       5.747321             -4.966068
# 15589      -0.861477     -1.362193      -1.983802              8.393718
# 15621      -0.044282      0.811497       1.007824              4.958086
# 15635      -4.807501      1.483492       5.702818              0.638772
# 15643      -2.349584     -0.197005       3.823674              6.614823
# ...              ...           ...            ...                   ...
# 41183       0.850006      2.241257       4.190840             -3.784626
# 41185      -1.065006     -2.117128      -7.071850             -3.194041
# 41187      -1.358511     -1.705401      -3.364571              3.125519
# 41191      -1.020388     -1.101360      -2.215282              3.551672
# 41193       1.118352      0.991219       0.593722             -5.996547
#
#        E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  E_NET_RATING_team_diff  \
# 15577                1.147953                9.931757               -8.799363
# 15589                1.528530               -9.267668               10.730022
# 15621                0.967314               -8.347689                9.341805
# 15635                7.793916                6.398731                1.381873
# 15643                5.272884               -2.971553                8.241899
# ...                       ...                     ...                     ...
# 41183               -2.920386               -1.811102               -1.094110
# 41185               -1.211782                5.470091               -6.695529
# 41187                2.239484                1.592989                0.634204
# 41191                2.649989                0.454304                2.203729
# 41193               -4.365023                1.571160               -5.923422
#
#        POSS_team_diff  PIE_team_diff  PTS_2PT_MR_team_diff  PTS_FB_team_diff  \
# 15577        3.214400      -0.039563             -7.976541         10.693661
# 15589       -3.185082       0.079243            -10.447319         -3.641969
# 15621        3.154921       0.054438              3.943956          1.928162
# 15635       -2.273843       0.005919             -9.680554         10.249335
# 15643       -0.190253       0.031047             -4.815366          5.543455
# ...               ...            ...                   ...               ...
# 41183        7.045571      -0.015567             -0.894481          4.149071
# 41185       -6.440998      -0.029391              0.605020         -3.934160
# 41187       -5.796882       0.008949              0.944530         -2.840718
# 41191       -4.785457       0.011328              2.615105         -0.580936
# 41193        4.106898      -0.041396             -3.653613         -0.377176
#
#        PTS_OFF_TOV_team_diff  PTS_PAINT_team_diff  AST_2PM_team_diff  \
# 15577               9.831084             8.595020          -1.060535
# 15589               3.948446             9.363916           1.948496
# 15621              -2.559897           -12.595212          -1.055252
# 15635               2.013957             8.564265           2.194065
# 15643              -1.545260            -2.229334          -3.876557
# ...                      ...                  ...                ...
# 41183               1.272228             4.678293           3.390841
# 41185              -1.645011            -5.310477          -3.451759
# 41187               1.019561            -2.579358          -3.106573
# 41191               0.815835             2.420818          -2.426316
# 41193              -0.634247            -3.378752           1.283662
#
#        AST_3PM_team_diff  UAST_2PM_team_diff  UAST_3PM_team_diff  \
# 15577           1.462068            1.309366           -0.277551
# 15589          -2.657958           -2.223960            0.458703
# 15621           2.300340           -3.213733           -0.190989
# 15635           1.847285           -2.867557            0.725003
# 15643           1.927246            0.292464            1.322685
# ...                  ...                 ...                 ...
# 41183          -0.434767           -1.199405            0.329989
# 41185          -0.208731            0.879455           -0.596998
# 41187           0.012147            2.091542           -0.337292
# 41191          -1.090185            4.644206           -0.463209
# 41193           1.381173           -4.479780            0.416886
#
#        ATS_DIFF_team_diff  RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  \
# 15577           -3.224664        -0.017287       1.533418      -0.542578
# 15589           14.859112        -0.442910       0.918317       5.296610
# 15621            3.287805        -0.110441      -1.083515       3.430018
# 15635            2.150464         0.088032       2.479886       4.694578
# 15643            0.073483        -0.374389      -1.566558      -2.561074
# ...                   ...              ...            ...            ...
# 41183           -4.305675        -0.072472       0.845528       8.343577
# 41185           -1.525084         0.165228      -0.160958      -8.309224
# 41187            5.027617         0.048702      -1.444893      -9.778342
# 41191            5.842388         0.029448      -4.210425     -10.310475
# 41193           -7.658188         0.073498       4.989399       9.979427
#
#        FG3M_opp_diff  FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  \
# 15577       2.146127       3.637273      1.208172      1.145158
# 15589      -2.524759      -0.813527     -4.639878     -6.159402
# 15621      -1.123570       2.105314      1.587478      2.093305
# 15635       0.058684       1.770606     -0.071777      1.699913
# 15643       0.877277       1.263678     -2.289863     -1.335505
# ...              ...            ...           ...           ...
# 41183       0.157984       0.181954      5.810458      7.039952
# 41185       0.857845       0.836272     -6.129426     -7.735982
# 41187       0.472051       1.552665     -5.016457     -6.062342
# 41191       1.772392       4.147719     -2.663280     -4.160453
# 41193      -2.095160      -4.932965      2.896953      4.044402
#
#        OREB_opp_diff  DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  \
# 15577       5.271976       1.456937      6.728914      0.035934     -0.313075
# 15589       3.780090      -1.954756      1.825334     -0.631198     -1.406888
# 15621      -0.904976       3.472443      2.567468     -3.175802     -1.587483
# 15635       6.817294       0.984785      7.802079      1.604212     -0.648608
# 15643      -3.392500      -0.796883     -4.189383      0.075905     -1.125931
# ...              ...            ...           ...           ...           ...
# 41183       4.625219       4.100180      8.725399      0.380462      1.270642
# 41185      -3.862676      -2.790127     -6.652802      0.757616     -1.943594
# 41187      -4.376420      -3.611136     -7.987556      0.481849     -2.049238
# 41191      -3.224874      -2.775006     -5.999880      1.410313     -1.979882
# 41193       2.802380       3.597520      6.399901     -0.769271      2.481903
#
#        BLK_opp_diff  TOV_opp_diff  PF_opp_diff  PTS_opp_diff  \
# 15577      0.672521      2.928280     2.308727     10.713389
# 15589      0.672122      0.256923     0.650510    -10.377520
# 15621     -1.155016     -3.028780     0.434871     -3.950262
# 15635     -0.682632     -1.895357     0.361166      5.064045
# 15643     -0.311258     -1.591091     5.233421     -2.791148
# ...             ...           ...          ...           ...
# 41183      1.122194      1.888932     0.241339      7.975465
# 41185     -0.409953     -1.400019    -0.117202     -3.877808
# 41187     -0.268955     -0.860002    -0.305484     -6.490090
# 41191     -0.217849     -0.776601    -0.527445     -5.766953
# 41193      0.596071      0.498936     0.474697      6.590269
#
#        PLUS_MINUS_opp_diff  E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  \
# 15577             4.966068               9.931757               1.147953
# 15589            -8.393718              -9.267668               1.528530
# 15621            -4.958086              -8.347689               0.967314
# 15635            -0.638772               6.398731               7.793916
# 15643            -6.614823              -2.971553               5.272884
# ...                    ...                    ...                    ...
# 41183             3.784626              -1.811102              -2.920386
# 41185             3.194041               5.470091              -1.211782
# 41187            -3.125519               1.592989               2.239484
# 41191            -3.551672               0.454304               2.649989
# 41193             5.996547               1.571160              -4.365023
#
#        E_NET_RATING_opp_diff  POSS_opp_diff  PIE_opp_diff  \
# 15577               8.799363       3.499295      0.039563
# 15589             -10.730022      -2.519261     -0.079243
# 15621              -9.341805       3.101608     -0.054438
# 15635              -1.381873      -1.395200     -0.005919
# 15643              -8.241899      -0.742105     -0.031047
# ...                      ...            ...           ...
# 41183               1.094110       6.994291      0.015567
# 41185               6.695529      -6.194840      0.029391
# 41187              -0.634204      -5.575340     -0.008949
# 41191              -2.203729      -4.426006     -0.011329
# 41193               5.923422       4.183399      0.041396
#
#        PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  PTS_OFF_TOV_opp_diff  \
# 15577            -4.467826         2.210313             -0.891262
# 15589            -4.853021         1.276503             -1.117154
# 15621            -0.547427        -3.014637             -0.914546
# 15635            -3.305902        -5.683425             -3.085844
# 15643             2.637905         2.974783             -1.470963
# ...                    ...              ...                   ...
# 41183             0.219522         5.925093              0.589105
# 41185             0.002429        -5.132561             -0.030172
# 41187            -0.397823        -5.319310             -2.527214
# 41191            -2.172275        -6.028654             -2.037036
# 41193             3.255069         6.325793              1.733327
#
#        PTS_PAINT_opp_diff  AST_2PM_opp_diff  AST_3PM_opp_diff  \
# 15577            7.408640         -2.847430          2.445020
# 15589            6.705730          1.194721         -1.832152
# 15621           -1.395851         -2.214594         -1.919403
# 15635            7.640515          0.142303          1.115957
# 15643           -5.731487         -0.874784          0.546546
# ...                   ...               ...               ...
# 41183            1.567202          0.325705         -0.174422
# 41185           -0.310442          0.106877          0.756996
# 41187           -2.479451          0.096190          0.481291
# 41191           -6.518445         -0.012095          1.489869
# 41193            7.066613          0.910901         -1.740887
#
#        UAST_2PM_opp_diff  UAST_3PM_opp_diff  ATS_DIFF_opp_diff  \
# 15577           4.344354          -0.438918           3.224664
# 15589          -0.276404          -0.640491         -14.859112
# 15621           1.091478           0.359686          -3.287805
# 15635           2.094322          -0.833145          -2.150464
# 15643          -0.533750          -0.054690          -0.073483
# ...                  ...                ...                ...
# 41183           0.506124           0.351626           4.305675
# 41185          -0.255505          -0.016453           1.525084
# 41187          -1.529987          -0.214813          -5.027617
# 41191          -4.189342           0.016007          -5.842388
# 41193           4.070407          -0.014408           7.658188
#
#        TEAM_COVERED_opp_diff  WL_PCT_diff  ATS_PCT_diff  AVG_SPREAD_diff  \
# 15577              -0.036495     0.000000      0.000000         1.833333
# 15589              -0.442910     0.466667      0.300000         7.900000
# 15621              -0.088328     0.125000      0.000000        -2.900000
# 15635              -0.231647    -0.089286      0.178571         0.517857
# 15643              -0.096606     0.321429     -0.196429        -7.678571
# ...                      ...          ...           ...              ...
# 41183              -0.106575     0.148660      0.035773        -3.216383
# 41185               0.195920    -0.157305     -0.045464         3.308247
# 41187               0.076325    -0.145870     -0.035056         3.317791
# 41191               0.051823    -0.143184     -0.034368         3.326311
# 41193               0.053361     0.132213      0.024370        -3.257188
#
#        AVG_ML_diff  AVG_ATS_DIFF_diff  REST_diff  OREB_PCT_team_diff  \
# 15577     0.067786          -3.500000        1.0           -0.055326
# 15589     0.880172          15.700000       -1.0           -0.009183
# 15621    -1.197584           2.157143        1.0           -0.077545
# 15635    -1.098455           0.232143        1.0           -0.064605
# 15643    -0.629276          -1.035714       -1.0            0.062480
# ...            ...                ...        ...                 ...
# 41183    -0.150649          -0.299400        0.0           -0.024815
# 41185     0.174094          -0.251856        0.0            0.011861
# 41187     0.167083           0.394171        0.0            0.033774
# 41191     0.156915           0.534466        0.0            0.021312
# 41193    -0.147027          -0.763566        0.0           -0.024004
#
#        OREB_PCT_opp_diff  DREB_PCT_team_diff  DREB_PCT_opp_diff  \
# 15577           0.119639           -0.119639           0.055326
# 15589           0.056948           -0.056948           0.009183
# 15621          -0.058557            0.058557           0.077545
# 15635           0.126023           -0.126023           0.064605
# 15643          -0.075801            0.075801          -0.062480
# ...                  ...                 ...                ...
# 41183           0.075851           -0.075851           0.024815
# 41185          -0.058512            0.058512          -0.011861
# 41187          -0.074057            0.074057          -0.033774
# 41191          -0.053141            0.053141          -0.021312
# 41193           0.053209           -0.053209           0.024004
#
#        REB_PCT_team_diff  REB_PCT_opp_diff  TS_PCT_team_diff  TS_PCT_opp_diff  \
# 15577          -0.084828          0.084828          0.033309         0.039705
# 15589          -0.005871          0.005871          0.024821        -0.086348
# 15621           0.005677         -0.005677          0.027031        -0.060742
# 15635          -0.075661          0.075661          0.036095        -0.016228
# 15643           0.059145         -0.059145          0.006939        -0.006036
# ...                  ...               ...               ...              ...
# 41183          -0.047860          0.047860         -0.012969        -0.018301
# 41185           0.029233         -0.029233         -0.007935         0.035832
# 41187           0.049737         -0.049737          0.000982         0.023962
# 41191           0.034808         -0.034808          0.008060         0.012586
# 41193          -0.043311          0.043311         -0.018247        -0.001087
#
#        EFG_PCT_team_diff  EFG_PCT_opp_diff  AST_RATIO_team_diff  \
# 15577           0.037237          0.039834             0.443206
# 15589          -0.001416         -0.068187            -0.589664
# 15621           0.013433         -0.066034             0.713936
# 15635           0.054868         -0.007592             5.147102
# 15643           0.008401          0.004723            -2.169407
# ...                  ...               ...                  ...
# 41183          -0.010589         -0.036553             1.012604
# 41185          -0.014395          0.057133            -2.060442
# 41187          -0.001716          0.039872            -1.651894
# 41191           0.013076          0.018175            -2.447681
# 41193          -0.020460         -0.008270             1.724470
#
#        AST_RATIO_opp_diff  TOV_PCT_team_diff  TOV_PCT_opp_diff  team_elo_pred  \
# 15577           -0.902845           0.432949          1.833472       0.341538
# 15589           -0.059615          -0.172998         -0.032534       0.194816
# 15621           -4.066601           0.318576         -3.174742       0.710913
# 15635            2.012683          -3.702134         -2.579865       0.463029
# 15643            0.249958          -2.483331         -1.017763       0.777719
# ...                   ...                ...               ...            ...
# 41183           -1.176661           0.050852          0.199945       0.743215
# 41185            2.193246          -0.310423          0.177814       0.393894
# 41187            1.773985          -0.732142          0.634390       0.464294
# 41191            2.481536          -0.431142          0.335964       0.502679
# 41193           -1.749975           0.509103         -0.415084       0.653888
#
#        team_rating_i  opp_rating_i  elo_MOV_pred  SPREAD
# 15577    1415.020181   1598.056882         -6.54    -3.5
# 15589    1278.319773   1593.828466        -11.27     6.5
# 15621    1511.462374   1424.147011          3.12    -5.0
# 15635    1449.843213   1544.580516         -3.38    -5.5
# 15643    1538.109265   1389.540944          5.31    -6.0
# ...              ...           ...           ...     ...
# 41183    1873.595656   1757.977511          4.13    -6.0
# 41185    1743.852634   1887.720533         -5.14     2.0
# 41187    1768.859894   1862.713273         -3.35    -2.5
# 41191    1782.217423   1849.355743         -2.40    -2.0
# 41193    1836.543894   1795.029273          1.48    -5.0
#
# [7527 rows x 87 columns]

# %%
df_ewm_19_diffs.loc[train_idx]
# Out:
#         SEASON     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 15577  2006-07  1610612744               GSW   Golden State Warriors
# 15589  2006-07  1610612757               POR  Portland Trail Blazers
# 15621  2006-07  1610612751               BKN         New Jersey Nets
# 15635  2006-07  1610612744               GSW   Golden State Warriors
# 15643  2006-07  1610612739               CLE     Cleveland Cavaliers
# ...        ...         ...               ...                     ...
# 41183  2015-16  1610612744               GSW   Golden State Warriors
# 41185  2015-16  1610612739               CLE     Cleveland Cavaliers
# 41187  2015-16  1610612739               CLE     Cleveland Cavaliers
# 41191  2015-16  1610612739               CLE     Cleveland Cavaliers
# 41193  2015-16  1610612744               GSW   Golden State Warriors
#
#           GAME_ID  GAME_DATE      MATCHUP  HOME_GAME  SCORE_team  \
# 15577  0020600089 2006-11-11  GSW vs. DET          1         111
# 15589  0020600095 2006-11-12  POR vs. DAL          1          96
# 15621  0020600111 2006-11-15  BKN vs. MIL          1         100
# 15635  0020600118 2006-11-16  GSW vs. SAC          1         117
# 15643  0020600122 2006-11-17  CLE vs. MIN          1          92
# ...           ...        ...          ...        ...         ...
# 41183  0041500402 2016-06-05  GSW vs. CLE          1         110
# 41185  0041500403 2016-06-08  CLE vs. GSW          1         120
# 41187  0041500404 2016-06-10  CLE vs. GSW          1          97
# 41191  0041500406 2016-06-16  CLE vs. GSW          1         115
# 41193  0041500407 2016-06-19  GSW vs. CLE          1          89
#
#        POINT_DIFF_team  WL_team   ML_team  SPREAD_team  TEAM_COVERED_team  \
# 15577               32        1  1.606061         -3.5                  1
# 15589               -7        0  3.100000          6.5                  0
# 15621               13        1  1.454545         -5.0                  1
# 15635               12        1  1.500000         -5.5                  1
# 15643               16        1  1.370370         -6.0                  1
# ...                ...      ...       ...          ...                ...
# 41183               33        1  1.408163         -6.0                  1
# 41185               30        1  1.769231          2.0                  1
# 41187              -11        0  1.689655         -2.5                  0
# 41191               14        1  1.689655         -2.0                  1
# 41193               -4        0  1.500000         -5.0                  0
#
#        RECORD_team_diff  FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  \
# 15577          0.017287        0.248831       -5.853269        1.502618
# 15589          0.442910       -0.310867       -2.912442       -2.059230
# 15621          0.110441       -4.151588       -6.939368        2.351356
# 15635         -0.088032       -0.520470       -5.976881        3.087585
# 15643          0.374389       -3.687772       -6.606679        3.060266
# ...                 ...             ...             ...             ...
# 41183          0.072472        2.054025        4.438997       -0.064319
# 41185         -0.165228       -2.448634       -3.195063       -0.942144
# 41187         -0.048702       -0.903728       -0.575488       -0.547921
# 41191         -0.029448        2.308044        1.923904       -1.833843
# 41193         -0.073498       -3.277257       -2.431520        2.150465
#
#        FG3A_team_diff  FTM_team_diff  FTA_team_diff  OREB_team_diff  \
# 15577        5.116500       0.741806       4.067155       -2.524098
# 15589       -3.786198       4.815621       7.069610       -1.276218
# 15621        3.641615       2.256933       1.361913       -3.020485
# 15635        5.373902      -2.518998       0.582491       -3.426173
# 15643        7.137484       2.018421       8.090618        2.972189
# ...               ...            ...            ...             ...
# 41183        0.805696       0.275749       0.564327       -0.055228
# 41185       -1.725156       0.651848       0.892143       -0.250303
# 41187       -2.352658       0.086648      -0.097096        0.674753
# 41191       -4.795702      -1.329841      -0.828656        0.226543
# 41193        5.516144       0.696841       0.445778       -0.103885
#
#        DREB_team_diff  REB_team_diff  AST_team_diff  STL_team_diff  \
# 15577       -4.860218      -7.384317       1.130916       0.828619
# 15589        2.217901       0.941683      -1.076968       0.047447
# 15621        6.015463       2.994978       1.406835      -2.569380
# 15635       -1.425477      -4.851650       4.345695      -2.248074
# 15643        2.340917       5.313106      -2.068726      -2.495105
# ...               ...            ...            ...            ...
# 41183        0.708355       0.653127       2.700311       1.598343
# 41185       -1.537547      -1.787850      -3.530306      -0.638479
# 41187       -0.283763       0.390990      -2.977262      -0.274623
# 41191       -0.379854      -0.153312      -3.431598       0.097563
# 41193       -0.758152      -0.862037       2.588423      -0.787820
#
#        BLK_team_diff  TOV_team_diff  PF_team_diff  PTS_team_diff  \
# 15577      -0.143984       0.688071      1.640417       5.747321
# 15589       0.899699      -0.861477     -1.362193      -1.983802
# 15621       0.733913      -0.044282      0.811497       1.007824
# 15635       2.599900      -4.807501      1.483492       5.702818
# 15643       0.626018      -2.349584     -0.197005       3.823674
# ...              ...            ...           ...            ...
# 41183       0.887023       0.850006      2.241257       4.190840
# 41185      -1.398334      -1.065006     -2.117128      -7.071850
# 41187      -1.358500      -1.358511     -1.705401      -3.364571
# 41191      -1.100376      -1.020388     -1.101360      -2.215282
# 41193       0.590329       1.118352      0.991219       0.593722
#
#        PLUS_MINUS_team_diff  E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  \
# 15577             -4.966068                1.147953                9.931757
# 15589              8.393718                1.528530               -9.267668
# 15621              4.958086                0.967314               -8.347689
# 15635              0.638772                7.793916                6.398731
# 15643              6.614823                5.272884               -2.971553
# ...                     ...                     ...                     ...
# 41183             -3.784626               -2.920386               -1.811102
# 41185             -3.194041               -1.211782                5.470091
# 41187              3.125519                2.239484                1.592989
# 41191              3.551672                2.649989                0.454304
# 41193             -5.996547               -4.365023                1.571160
#
#        E_NET_RATING_team_diff  POSS_team_diff  PIE_team_diff  \
# 15577               -8.799363        3.214400      -0.039563
# 15589               10.730022       -3.185082       0.079243
# 15621                9.341805        3.154921       0.054438
# 15635                1.381873       -2.273843       0.005919
# 15643                8.241899       -0.190253       0.031047
# ...                       ...             ...            ...
# 41183               -1.094110        7.045571      -0.015567
# 41185               -6.695529       -6.440998      -0.029391
# 41187                0.634204       -5.796882       0.008949
# 41191                2.203729       -4.785457       0.011328
# 41193               -5.923422        4.106898      -0.041396
#
#        PTS_2PT_MR_team_diff  PTS_FB_team_diff  PTS_OFF_TOV_team_diff  \
# 15577             -7.976541         10.693661               9.831084
# 15589            -10.447319         -3.641969               3.948446
# 15621              3.943956          1.928162              -2.559897
# 15635             -9.680554         10.249335               2.013957
# 15643             -4.815366          5.543455              -1.545260
# ...                     ...               ...                    ...
# 41183             -0.894481          4.149071               1.272228
# 41185              0.605020         -3.934160              -1.645011
# 41187              0.944530         -2.840718               1.019561
# 41191              2.615105         -0.580936               0.815835
# 41193             -3.653613         -0.377176              -0.634247
#
#        PTS_PAINT_team_diff  AST_2PM_team_diff  AST_3PM_team_diff  \
# 15577             8.595020          -1.060535           1.462068
# 15589             9.363916           1.948496          -2.657958
# 15621           -12.595212          -1.055252           2.300340
# 15635             8.564265           2.194065           1.847285
# 15643            -2.229334          -3.876557           1.927246
# ...                    ...                ...                ...
# 41183             4.678293           3.390841          -0.434767
# 41185            -5.310477          -3.451759          -0.208731
# 41187            -2.579358          -3.106573           0.012147
# 41191             2.420818          -2.426316          -1.090185
# 41193            -3.378752           1.283662           1.381173
#
#        UAST_2PM_team_diff  UAST_3PM_team_diff  ATS_DIFF_team_diff  \
# 15577            1.309366           -0.277551           -3.224664
# 15589           -2.223960            0.458703           14.859112
# 15621           -3.213733           -0.190989            3.287805
# 15635           -2.867557            0.725003            2.150464
# 15643            0.292464            1.322685            0.073483
# ...                   ...                 ...                 ...
# 41183           -1.199405            0.329989           -4.305675
# 41185            0.879455           -0.596998           -1.525084
# 41187            2.091542           -0.337292            5.027617
# 41191            4.644206           -0.463209            5.842388
# 41193           -4.479780            0.416886           -7.658188
#
#        RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  FG3M_opp_diff  \
# 15577        -0.017287       1.533418      -0.542578       2.146127
# 15589        -0.442910       0.918317       5.296610      -2.524759
# 15621        -0.110441      -1.083515       3.430018      -1.123570
# 15635         0.088032       2.479886       4.694578       0.058684
# 15643        -0.374389      -1.566558      -2.561074       0.877277
# ...                ...            ...            ...            ...
# 41183        -0.072472       0.845528       8.343577       0.157984
# 41185         0.165228      -0.160958      -8.309224       0.857845
# 41187         0.048702      -1.444893      -9.778342       0.472051
# 41191         0.029448      -4.210425     -10.310475       1.772392
# 41193         0.073498       4.989399       9.979427      -2.095160
#
#        FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  OREB_opp_diff  \
# 15577       3.637273      1.208172      1.145158       5.271976
# 15589      -0.813527     -4.639878     -6.159402       3.780090
# 15621       2.105314      1.587478      2.093305      -0.904976
# 15635       1.770606     -0.071777      1.699913       6.817294
# 15643       1.263678     -2.289863     -1.335505      -3.392500
# ...              ...           ...           ...            ...
# 41183       0.181954      5.810458      7.039952       4.625219
# 41185       0.836272     -6.129426     -7.735982      -3.862676
# 41187       1.552665     -5.016457     -6.062342      -4.376420
# 41191       4.147719     -2.663280     -4.160453      -3.224874
# 41193      -4.932965      2.896953      4.044402       2.802380
#
#        DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  BLK_opp_diff  \
# 15577       1.456937      6.728914      0.035934     -0.313075      0.672521
# 15589      -1.954756      1.825334     -0.631198     -1.406888      0.672122
# 15621       3.472443      2.567468     -3.175802     -1.587483     -1.155016
# 15635       0.984785      7.802079      1.604212     -0.648608     -0.682632
# 15643      -0.796883     -4.189383      0.075905     -1.125931     -0.311258
# ...              ...           ...           ...           ...           ...
# 41183       4.100180      8.725399      0.380462      1.270642      1.122194
# 41185      -2.790127     -6.652802      0.757616     -1.943594     -0.409953
# 41187      -3.611136     -7.987556      0.481849     -2.049238     -0.268955
# 41191      -2.775006     -5.999880      1.410313     -1.979882     -0.217849
# 41193       3.597520      6.399901     -0.769271      2.481903      0.596071
#
#        TOV_opp_diff  PF_opp_diff  PTS_opp_diff  PLUS_MINUS_opp_diff  \
# 15577      2.928280     2.308727     10.713389             4.966068
# 15589      0.256923     0.650510    -10.377520            -8.393718
# 15621     -3.028780     0.434871     -3.950262            -4.958086
# 15635     -1.895357     0.361166      5.064045            -0.638772
# 15643     -1.591091     5.233421     -2.791148            -6.614823
# ...             ...          ...           ...                  ...
# 41183      1.888932     0.241339      7.975465             3.784626
# 41185     -1.400019    -0.117202     -3.877808             3.194041
# 41187     -0.860002    -0.305484     -6.490090            -3.125519
# 41191     -0.776601    -0.527445     -5.766953            -3.551672
# 41193      0.498936     0.474697      6.590269             5.996547
#
#        E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  E_NET_RATING_opp_diff  \
# 15577               9.931757               1.147953               8.799363
# 15589              -9.267668               1.528530             -10.730022
# 15621              -8.347689               0.967314              -9.341805
# 15635               6.398731               7.793916              -1.381873
# 15643              -2.971553               5.272884              -8.241899
# ...                      ...                    ...                    ...
# 41183              -1.811102              -2.920386               1.094110
# 41185               5.470091              -1.211782               6.695529
# 41187               1.592989               2.239484              -0.634204
# 41191               0.454304               2.649989              -2.203729
# 41193               1.571160              -4.365023               5.923422
#
#        POSS_opp_diff  PIE_opp_diff  PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  \
# 15577       3.499295      0.039563            -4.467826         2.210313
# 15589      -2.519261     -0.079243            -4.853021         1.276503
# 15621       3.101608     -0.054438            -0.547427        -3.014637
# 15635      -1.395200     -0.005919            -3.305902        -5.683425
# 15643      -0.742105     -0.031047             2.637905         2.974783
# ...              ...           ...                  ...              ...
# 41183       6.994291      0.015567             0.219522         5.925093
# 41185      -6.194840      0.029391             0.002429        -5.132561
# 41187      -5.575340     -0.008949            -0.397823        -5.319310
# 41191      -4.426006     -0.011329            -2.172275        -6.028654
# 41193       4.183399      0.041396             3.255069         6.325793
#
#        PTS_OFF_TOV_opp_diff  PTS_PAINT_opp_diff  AST_2PM_opp_diff  \
# 15577             -0.891262            7.408640         -2.847430
# 15589             -1.117154            6.705730          1.194721
# 15621             -0.914546           -1.395851         -2.214594
# 15635             -3.085844            7.640515          0.142303
# 15643             -1.470963           -5.731487         -0.874784
# ...                     ...                 ...               ...
# 41183              0.589105            1.567202          0.325705
# 41185             -0.030172           -0.310442          0.106877
# 41187             -2.527214           -2.479451          0.096190
# 41191             -2.037036           -6.518445         -0.012095
# 41193              1.733327            7.066613          0.910901
#
#        AST_3PM_opp_diff  UAST_2PM_opp_diff  UAST_3PM_opp_diff  \
# 15577          2.445020           4.344354          -0.438918
# 15589         -1.832152          -0.276404          -0.640491
# 15621         -1.919403           1.091478           0.359686
# 15635          1.115957           2.094322          -0.833145
# 15643          0.546546          -0.533750          -0.054690
# ...                 ...                ...                ...
# 41183         -0.174422           0.506124           0.351626
# 41185          0.756996          -0.255505          -0.016453
# 41187          0.481291          -1.529987          -0.214813
# 41191          1.489869          -4.189342           0.016007
# 41193         -1.740887           4.070407          -0.014408
#
#        ATS_DIFF_opp_diff  TEAM_COVERED_opp_diff  WL_PCT_diff  ATS_PCT_diff  \
# 15577           3.224664              -0.036495     0.000000      0.000000
# 15589         -14.859112              -0.442910     0.466667      0.300000
# 15621          -3.287805              -0.088328     0.125000      0.000000
# 15635          -2.150464              -0.231647    -0.089286      0.178571
# 15643          -0.073483              -0.096606     0.321429     -0.196429
# ...                  ...                    ...          ...           ...
# 41183           4.305675              -0.106575     0.148660      0.035773
# 41185           1.525084               0.195920    -0.157305     -0.045464
# 41187          -5.027617               0.076325    -0.145870     -0.035056
# 41191          -5.842388               0.051823    -0.143184     -0.034368
# 41193           7.658188               0.053361     0.132213      0.024370
#
#        AVG_SPREAD_diff  AVG_ML_diff  AVG_ATS_DIFF_diff  REST_diff  \
# 15577         1.833333     0.067786          -3.500000        1.0
# 15589         7.900000     0.880172          15.700000       -1.0
# 15621        -2.900000    -1.197584           2.157143        1.0
# 15635         0.517857    -1.098455           0.232143        1.0
# 15643        -7.678571    -0.629276          -1.035714       -1.0
# ...                ...          ...                ...        ...
# 41183        -3.216383    -0.150649          -0.299400        0.0
# 41185         3.308247     0.174094          -0.251856        0.0
# 41187         3.317791     0.167083           0.394171        0.0
# 41191         3.326311     0.156915           0.534466        0.0
# 41193        -3.257188    -0.147027          -0.763566        0.0
#
#        OREB_PCT_team_diff  OREB_PCT_opp_diff  DREB_PCT_team_diff  \
# 15577           -0.055326           0.119639           -0.119639
# 15589           -0.009183           0.056948           -0.056948
# 15621           -0.077545          -0.058557            0.058557
# 15635           -0.064605           0.126023           -0.126023
# 15643            0.062480          -0.075801            0.075801
# ...                   ...                ...                 ...
# 41183           -0.024815           0.075851           -0.075851
# 41185            0.011861          -0.058512            0.058512
# 41187            0.033774          -0.074057            0.074057
# 41191            0.021312          -0.053141            0.053141
# 41193           -0.024004           0.053209           -0.053209
#
#        DREB_PCT_opp_diff  REB_PCT_team_diff  REB_PCT_opp_diff  \
# 15577           0.055326          -0.084828          0.084828
# 15589           0.009183          -0.005871          0.005871
# 15621           0.077545           0.005677         -0.005677
# 15635           0.064605          -0.075661          0.075661
# 15643          -0.062480           0.059145         -0.059145
# ...                  ...                ...               ...
# 41183           0.024815          -0.047860          0.047860
# 41185          -0.011861           0.029233         -0.029233
# 41187          -0.033774           0.049737         -0.049737
# 41191          -0.021312           0.034808         -0.034808
# 41193           0.024004          -0.043311          0.043311
#
#        TS_PCT_team_diff  TS_PCT_opp_diff  EFG_PCT_team_diff  EFG_PCT_opp_diff  \
# 15577          0.033309         0.039705           0.037237          0.039834
# 15589          0.024821        -0.086348          -0.001416         -0.068187
# 15621          0.027031        -0.060742           0.013433         -0.066034
# 15635          0.036095        -0.016228           0.054868         -0.007592
# 15643          0.006939        -0.006036           0.008401          0.004723
# ...                 ...              ...                ...               ...
# 41183         -0.012969        -0.018301          -0.010589         -0.036553
# 41185         -0.007935         0.035832          -0.014395          0.057133
# 41187          0.000982         0.023962          -0.001716          0.039872
# 41191          0.008060         0.012586           0.013076          0.018175
# 41193         -0.018247        -0.001087          -0.020460         -0.008270
#
#        AST_RATIO_team_diff  AST_RATIO_opp_diff  TOV_PCT_team_diff  \
# 15577             0.443206           -0.902845           0.432949
# 15589            -0.589664           -0.059615          -0.172998
# 15621             0.713936           -4.066601           0.318576
# 15635             5.147102            2.012683          -3.702134
# 15643            -2.169407            0.249958          -2.483331
# ...                    ...                 ...                ...
# 41183             1.012604           -1.176661           0.050852
# 41185            -2.060442            2.193246          -0.310423
# 41187            -1.651894            1.773985          -0.732142
# 41191            -2.447681            2.481536          -0.431142
# 41193             1.724470           -1.749975           0.509103
#
#        TOV_PCT_opp_diff  team_elo_pred  team_rating_i  team_rating_n  \
# 15577          1.833472       0.341538    1415.020181    1442.679270
# 15589         -0.032534       0.194816    1278.319773    1275.581838
# 15621         -3.174742       0.710913    1511.462374    1519.559125
# 15635         -2.579865       0.463029    1449.843213    1462.087729
# 15643         -1.017763       0.777719    1538.109265    1545.676240
# ...                 ...            ...            ...            ...
# 41183          0.199945       0.743215    1873.595656    1887.720533
# 41185          0.177814       0.393894    1743.852634    1768.859894
# 41187          0.634390       0.464294    1768.859894    1758.834210
# 41191          0.335964       0.502679    1782.217423    1795.029273
# 41193         -0.415084       0.653888    1836.543894    1827.470876
#
#        opp_rating_i  opp_rating_n  elo_MOV_pred
# 15577   1598.056882   1570.397794         -6.54
# 15589   1593.828466   1596.566401        -11.27
# 15621   1424.147011   1416.050260          3.12
# 15635   1544.580516   1532.336000         -3.38
# 15643   1389.540944   1381.973969          5.31
# ...             ...           ...           ...
# 41183   1757.977511   1743.852634          4.13
# 41185   1887.720533   1862.713273         -5.14
# 41187   1862.713273   1872.738957         -3.35
# 41191   1849.355743   1836.543894         -2.40
# 41193   1795.029273   1804.102290          1.48
#
# [7527 rows x 103 columns]

# %% [markdown]
# ### Define Custom Scorer

# %%
tscv = TimeSeriesSplit()

# %%
def view_model_coefs(model, X_train):
    feature_names = X_train.columns
    
    try:
        coefficients = model.coef_[0]
    except:
        print("LGBoost or XGBoost")
        coefficients = model.feature_importances_

    coef_df = pd.DataFrame({'feature_name':feature_names,
                'coef':coefficients})

    coef_df = coef_df.loc[coef_df['coef']!=0].sort_values('coef')
    
    top_20_features = pd.concat([coef_df.head(10), coef_df.tail(10)])
    top_20_features.plot.barh('feature_name', figsize=(6,12))
    
    return coef_df


def test_model_at_threshold(df, best_model, X_train, y_train, X_test1, y_test1, test_idx1,
                           X_train2, y_train2, X_test2, y_test2, test_idx2):
    best_model.fit(X_train, y_train)
    try:
        probs1 = best_model.predict_proba(X_test1)
    except:
        decisions1 = best_model.decision_function(X_test1)
        probs1 = 1 / (1 + np.exp(-decisions1))
        probs1 = np.concatenate([np.zeros_like(probs1).reshape(-1,1), probs1.reshape(-1,1)], axis=1)
    bets, thresholds, best_threshold = find_optimal_threshold(df, probs1, test_idx1)
    test1_acc = best_model.score(X_test1, y_test1)
    print("test1_acc:", test1_acc)
    
    
    best_model.fit(X_train2, y_train2)
    
    try:
        probs2 = best_model.predict_proba(X_test2)
    except:
        decisions2 = best_model.decision_function(X_test2)
        probs2 = 1 / (1 + np.exp(-decisions2))
        probs2 = np.concatenate([np.zeros_like(probs2).reshape(-1,1), probs2.reshape(-1,1)], axis=1)
    
    test2_acc = best_model.score(X_test2, y_test2)
    print("test2_acc:", test2_acc)
    
    betting_df = create_betting_df(df, probs2, test_idx2)
    
    win_pct_at_thresh = betting_df.loc[~betting_df['prob_avg'].between(1-best_threshold, best_threshold), 'bet_won'].mean()
    num_games_bet1 = betting_df.loc[~betting_df['prob_avg'].between(1-best_threshold, best_threshold)].shape[0]
    print("win_percentage at ", best_threshold, ":", win_pct_at_thresh, "...Games Bet:", num_games_bet1)
    
#     threshold2 = best_threshold*1.03
    
#     win_pct_at_threshold2 = betting_df.loc[~betting_df['prob_avg'].between(1-threshold2, threshold2), 'bet_won'].mean()
#     num_games_bet2 = betting_df.loc[~betting_df['prob_avg'].between(1-threshold2, threshold2)].shape[0]

#     print("win_percentage at {}: {} ...Games Bet: {}".format(threshold2, win_pct_at_threshold2, num_games_bet2))
    

    select_bets = betting_df.loc[~betting_df['prob_avg'].between(1-best_threshold, best_threshold)]
    
    return select_bets, best_threshold

# %% [markdown]
# ## Training Models

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# Train Set: 2006-2015
# <br>Test Set: 2016-2020

# %%
X_train
# Out:
#          avg_ml  avg_spread  avg_point_spread_diff  points_covered_spread_by  \
# 15551  1.968208   -1.300000              -1.900000                 -2.599424
# 15556  3.360000    5.600000              -1.000000                 -0.616932
# 15557  1.930000    0.200000               5.200000                  5.279932
# 15558  2.035490    0.100000               3.700000                  2.894252
# 15560  1.814762   -2.100000              -2.300000                 -2.417035
# ...         ...         ...                    ...                       ...
# 41189  1.281021   -9.367647               0.602941                  0.231945
# 41190  1.282499   -9.330097               0.398058                 -1.841403
# 41191  1.472428   -6.400000              -0.100000                  3.285046
# 41192  1.474558   -6.356436               0.019802                  4.156610
# 41193  1.290190   -9.221154               0.278846                 -2.857330
#
#        FG2M_team_diff  FG2A_team_diff  FG3M_team_diff  FG3A_team_diff  \
# 15551       -0.575810        7.261337        1.148934        6.622988
# 15556        4.323655       10.223951       -1.990916       -4.518327
# 15557       -4.323655      -10.223951        1.990916        4.518327
# 15558        2.149081        9.286709        0.488364       -1.207028
# 15560       -3.092239        3.338606       -0.840770       -1.863964
# ...               ...             ...             ...             ...
# 41189       -0.786681       -0.582086        1.593153        3.217412
# 41190       -2.308044       -1.923904        1.833843        4.795702
# 41191        2.308044        1.923904       -1.833843       -4.795702
# 41192        3.277257        2.431520       -2.150465       -5.516144
# 41193       -3.277257       -2.431520        2.150465        5.516144
#
#        FTM_team_diff  FTA_team_diff  OREB_team_diff  DREB_team_diff  \
# 15551      -0.816903      -4.248272        4.494689        1.648116
# 15556       3.477449       5.215013        0.176992        1.397329
# 15557      -3.477449      -5.215013       -0.176992       -1.397329
# 15558       0.154331       2.195258        5.292423        1.873117
# 15560       1.172882      -0.353975       -0.096077        1.606446
# ...              ...            ...             ...             ...
# 41189       0.922036       0.587392       -0.807284        0.755402
# 41190       1.329841       0.828656       -0.226543        0.379854
# 41191      -1.329841      -0.828656        0.226543       -0.379854
# 41192      -0.696841      -0.445778        0.103885        0.758152
# 41193       0.696841       0.445778       -0.103885       -0.758152
#
#        REB_team_diff  AST_team_diff  STL_team_diff  BLK_team_diff  \
# 15551       6.142805       4.424190       0.493932       1.449000
# 15556       1.574321      -3.763937      -2.460282       0.158091
# 15557      -1.574321       3.763937       2.460282      -0.158091
# 15558       7.165539       3.111133      -1.586774      -0.779029
# 15560       1.510369      -3.047261      -1.152555       0.571463
# ...              ...            ...            ...            ...
# 41189      -0.051882       3.479550       0.447166       1.222646
# 41190       0.153312       3.431598      -0.097563       1.100376
# 41191      -0.153312      -3.431598       0.097563      -1.100376
# 41192       0.862037      -2.588423       0.787820      -0.590329
# 41193      -0.862037       2.588423      -0.787820       0.590329
#
#        TOV_team_diff  PF_team_diff  PTS_team_diff  PLUS_MINUS_team_diff  \
# 15551      -3.451833     -1.093185       1.478279             -2.022368
# 15556       1.194403      4.265342       6.152011            -11.563063
# 15557      -1.194403     -4.265342      -6.152011             11.563063
# 15558       0.666626     -0.873971       5.917584              4.536641
# 15560      -6.557348      1.924089      -7.533905             -0.654376
# ...              ...           ...            ...                   ...
# 41189       1.022656      1.334851       4.128134             -0.612905
# 41190       1.020388      1.101360       2.215282             -3.551672
# 41191      -1.020388     -1.101360      -2.215282              3.551672
# 41192      -1.118352     -0.991219      -0.593722              5.996547
# 41193       1.118352      0.991219       0.593722             -5.996547
#
#        E_OFF_RATING_team_diff  E_DEF_RATING_team_diff  E_NET_RATING_team_diff  \
# 15551               -2.621902               -0.945064               -1.721037
# 15556               -3.340881                7.198786              -10.586064
# 15557                3.340881               -7.198786               10.586064
# 15558                1.555112               -3.172780                4.727892
# 15560               -2.001702               -4.631014                2.607335
# ...                       ...                     ...                     ...
# 41189               -1.055512               -2.393717                1.329266
# 41190               -2.649989               -0.454304               -2.203729
# 41191                2.649989                0.454304                2.203729
# 41192                4.365023               -1.571160                5.923422
# 41193               -4.365023                1.571160               -5.923422
#
#        POSS_team_diff  PIE_team_diff  PTS_2PT_MR_team_diff  PTS_FB_team_diff  \
# 15551        3.771092      -0.004203             -7.343752          1.015506
# 15556        8.137555      -0.110093             -6.745086          7.102708
# 15557       -8.137555       0.110093              6.745086         -7.102708
# 15558        2.878465       0.032891              0.846768          2.920002
# 15560       -5.685956      -0.012588              9.174792          0.708045
# ...               ...            ...                   ...               ...
# 41189        5.317190       0.010747             -1.350087          2.756649
# 41190        4.785457      -0.011328             -2.615105          0.580936
# 41191       -4.785457       0.011328              2.615105         -0.580936
# 41192       -4.106898       0.041396              3.653613          0.377176
# 41193        4.106898      -0.041396             -3.653613         -0.377176
#
#        PTS_OFF_TOV_team_diff  PTS_PAINT_team_diff  AST_2PM_team_diff  \
# 15551              -0.291275             6.814339           3.979243
# 15556              -1.067984            14.759224          -1.253669
# 15557               1.067984           -14.759224           1.253669
# 15558              -1.078069             3.737809           2.529975
# 15560              -4.826729           -15.719221          -1.575052
# ...                      ...                  ...                ...
# 41189              -0.017579            -0.578646           2.695909
# 41190              -0.815835            -2.420818           2.426316
# 41191               0.815835             2.420818          -2.426316
# 41192               0.634247             3.378752          -1.283662
# 41193              -0.634247            -3.378752           1.283662
#
#        UAST_2PM_team_diff  AST_3PM_team_diff  UAST_3PM_team_diff  \
# 15551           -4.377036           0.654001            0.501551
# 15556            5.291373          -2.754463            0.299578
# 15557           -5.291373           2.754463           -0.299578
# 15558           -0.183097           0.534761           -0.244194
# 15560           -1.399016          -0.989257            0.487930
# ...                   ...                ...                 ...
# 41189           -3.382418           0.989091            0.403565
# 41190           -4.644206           1.090185            0.463209
# 41191            4.644206          -1.090185           -0.463209
# 41192            4.479780          -1.381173           -0.416886
# 41193           -4.479780           1.381173            0.416886
#
#        team_covered_opp_diff  RECORD_opp_diff  FG2M_opp_diff  FG2A_opp_diff  \
# 15551              -0.173378         0.046397       5.610901       7.406803
# 15556               0.237577         0.237577       5.306342      10.466655
# 15557              -0.237577        -0.237577      -5.306342     -10.466655
# 15558               0.066177        -0.153598      -5.631315     -11.504286
# 15560              -0.001088         0.237894       0.645236       7.463624
# ...                      ...              ...            ...            ...
# 41189              -0.169792        -0.143834       2.900440       9.900515
# 41190              -0.052810        -0.029448       4.210425      10.310475
# 41191               0.052810         0.029448      -4.210425     -10.310475
# 41192              -0.052473        -0.073498      -4.989399      -9.979427
# 41193               0.052473         0.073498       4.989399       9.979427
#
#        FG3M_opp_diff  FG3A_opp_diff  FTM_opp_diff  FTA_opp_diff  \
# 15551      -1.867403      -0.823912     -2.118947     -1.581207
# 15556       1.821274       3.126932      1.638568      2.391492
# 15557      -1.821274      -3.126932     -1.638568     -2.391492
# 15558       3.672609      11.847501      1.625748      3.392567
# 15560      -2.806911      -7.203208      0.250731      1.295759
# ...              ...            ...           ...           ...
# 41189      -1.524872      -2.497423      3.514775      4.956078
# 41190      -1.772392      -4.147719      2.663280      4.160453
# 41191       1.772392       4.147719     -2.663280     -4.160453
# 41192       2.095160       4.932965     -2.896953     -4.044402
# 41193      -2.095160      -4.932965      2.896953      4.044402
#
#        OREB_opp_diff  DREB_opp_diff  REB_opp_diff  AST_opp_diff  STL_opp_diff  \
# 15551       0.850773       7.125809      7.976582      1.828820     -3.576201
# 15556       1.772655       3.590608      5.363263      2.750971      1.580670
# 15557      -1.772655      -3.590608     -5.363263     -2.750971     -1.580670
# 15558      -1.665283       3.707919      2.042636      1.215965      0.336158
# 15560       2.287886       3.967116      6.255002      1.705440     -4.454007
# ...              ...            ...           ...           ...           ...
# 41189       4.138769       2.750007      6.888776     -1.233680      1.644306
# 41190       3.224874       2.775006      5.999880     -1.410313      1.979882
# 41191      -3.224874      -2.775006     -5.999880      1.410313     -1.979882
# 41192      -2.802380      -3.597520     -6.399901      0.769271     -2.481903
# 41193       2.802380       3.597520      6.399901     -0.769271      2.481903
#
#        BLK_opp_diff  TOV_opp_diff  PF_opp_diff  PTS_opp_diff  \
# 15551      0.950331     -0.898220    -2.521355      3.500647
# 15556      3.027643     -2.042490     3.482626     17.715074
# 15557     -3.027643      2.042490    -3.482626    -17.715074
# 15558     -0.000440      0.808185     4.714073      1.380943
# 15560     -0.057518     -1.312655    -2.458693     -6.879530
# ...             ...           ...          ...           ...
# 41189      0.242058      0.974007     0.474938      4.741039
# 41190      0.217849      0.776601     0.527445      5.766953
# 41191     -0.217849     -0.776601    -0.527445     -5.766953
# 41192     -0.596071     -0.498936    -0.474697     -6.590269
# 41193      0.596071      0.498936     0.474697      6.590269
#
#        PLUS_MINUS_opp_diff  E_OFF_RATING_opp_diff  E_DEF_RATING_opp_diff  \
# 15551             2.022368              -0.945064              -2.621902
# 15556            11.563063               7.198786              -3.340881
# 15557           -11.563063              -7.198786               3.340881
# 15558            -4.536641              -3.172780               1.555112
# 15560             0.654376              -4.631014              -2.001702
# ...                    ...                    ...                    ...
# 41189             0.612905              -2.393717              -1.055512
# 41190             3.551672              -0.454304              -2.649989
# 41191            -3.551672               0.454304               2.649989
# 41192            -5.996547              -1.571160               4.365023
# 41193             5.996547               1.571160              -4.365023
#
#        E_NET_RATING_opp_diff  POSS_opp_diff  PIE_opp_diff  \
# 15551               1.721037       3.595272      0.004203
# 15556              10.586064       9.014920      0.110093
# 15557             -10.586064      -9.014920     -0.110093
# 15558              -4.727892       3.436473     -0.032891
# 15560              -2.607335      -5.330905      0.012588
# ...                      ...            ...           ...
# 41189              -1.329266       4.917798     -0.010747
# 41190               2.203729       4.426006      0.011329
# 41191              -2.203729      -4.426006     -0.011329
# 41192              -5.923422      -4.183399     -0.041396
# 41193               5.923422       4.183399      0.041396
#
#        PTS_2PT_MR_opp_diff  PTS_FB_opp_diff  PTS_OFF_TOV_opp_diff  \
# 15551            -1.950380         1.222461             -4.223462
# 15556            -5.170399         4.523064              4.624869
# 15557             5.170399        -4.523064             -4.624869
# 15558            -0.527679        -1.073551              0.956582
# 15560             5.230528        -5.000899             -9.725372
# ...                    ...              ...                   ...
# 41189             0.858052         4.587366              1.374468
# 41190             2.172275         6.028654              2.037036
# 41191            -2.172275        -6.028654             -2.037036
# 41192            -3.255069        -6.325793             -1.733327
# 41193             3.255069         6.325793              1.733327
#
#        PTS_PAINT_opp_diff  AST_2PM_opp_diff  UAST_2PM_opp_diff  \
# 15551           12.996362          4.447852           0.943274
# 15556           15.901541          0.876755           4.213987
# 15557          -15.901541         -0.876755          -4.213987
# 15558          -10.478254         -1.619301          -3.614222
# 15560           -4.091705          4.397315          -3.507885
# ...                   ...               ...                ...
# 41189            5.131572          0.013434           2.877019
# 41190            6.518445          0.012095           4.189342
# 41191           -6.518445         -0.012095          -4.189342
# 41192           -7.066613         -0.910901          -4.070407
# 41193            7.066613          0.910901           4.070407
#
#        AST_3PM_opp_diff  UAST_3PM_opp_diff  WL_record_diff  ATS_record_diff  \
# 15551         -1.922786          -0.206613        0.000000         0.400000
# 15556          1.742595           0.336036       -0.200000        -0.200000
# 15557         -1.742595          -0.336036        0.200000         0.200000
# 15558          3.033064           0.241752        0.200000         0.200000
# 15560         -2.448262           0.062982       -0.266667         0.266667
# ...                 ...                ...             ...              ...
# 41189         -1.433185           0.093329        0.154369         0.093107
# 41190         -1.489869          -0.016007        0.143184         0.082445
# 41191          1.489869           0.016007       -0.143184        -0.082445
# 41192          1.740887           0.014408       -0.132213        -0.071989
# 41193         -1.740887          -0.014408        0.132213         0.071989
#
#        rest_diff  OREB_PCT_team_diff  OREB_PCT_opp_diff  DREB_PCT_team_diff  \
# 15551        0.0            0.017803           0.003636           -0.003636
# 15556        0.0           -0.024807           0.022560           -0.022560
# 15557        0.0            0.024807          -0.022560            0.022560
# 15558       -1.0            0.056706          -0.042883            0.042883
# 15560        0.0           -0.030581           0.030817           -0.030817
# ...          ...                 ...                ...                 ...
# 41189        0.0           -0.031504           0.066387           -0.066387
# 41190        0.0           -0.021312           0.053141           -0.053141
# 41191        0.0            0.021312          -0.053141            0.053141
# 41192        0.0            0.024004          -0.053209            0.053209
# 41193        0.0           -0.024004           0.053209           -0.053209
#
#        DREB_PCT_opp_diff  REB_PCT_team_diff  REB_PCT_opp_diff  \
# 15551          -0.017803          -0.017193          0.017193
# 15556           0.024807          -0.025690          0.025690
# 15557          -0.024807           0.025690         -0.025690
# 15558          -0.056706           0.028749         -0.028749
# 15560           0.030581          -0.030883          0.030883
# ...                  ...                ...               ...
# 41189           0.031504          -0.041294          0.041294
# 41190           0.021312          -0.034808          0.034808
# 41191          -0.021312           0.034808         -0.034808
# 41192          -0.024004           0.043311         -0.043311
# 41193           0.024004          -0.043311          0.043311
#
#        TS_PCT_team_diff  TS_PCT_opp_diff  EFG_PCT_team_diff  EFG_PCT_opp_diff  \
# 15551         -0.083842        -0.021807          -0.077382         -0.005346
# 15556         -0.011884         0.008047          -0.019697          0.016364
# 15557          0.011884        -0.008047           0.019697         -0.016364
# 15558         -0.024311         0.000683          -0.014345         -0.003761
# 15560         -0.056238        -0.043582          -0.067776         -0.045998
# ...                 ...              ...                ...               ...
# 41189          0.004643        -0.027345           0.002244         -0.036712
# 41190         -0.008060        -0.012586          -0.013076         -0.018175
# 41191          0.008060         0.012586           0.013076          0.018175
# 41192          0.018247         0.001087           0.020460          0.008270
# 41193         -0.018247        -0.001087          -0.020460         -0.008270
#
#        AST_RATIO_team_diff  AST_RATIO_opp_diff  TOV_PCT_team_diff  \
# 15551             3.823167            1.197866          -4.636984
# 15556            -5.706641            0.917673          -0.350913
# 15557             5.706641           -0.917673           0.350913
# 15558             2.788106            0.448940          -0.773073
# 15560            -1.890509            3.140517          -5.468067
# ...                    ...                 ...                ...
# 41189             2.335022           -2.441096           0.484047
# 41190             2.447681           -2.481536           0.431142
# 41191            -2.447681            2.481536          -0.431142
# 41192            -1.724470            1.749975          -0.509103
# 41193             1.724470           -1.749975           0.509103
#
#        TOV_PCT_opp_diff  team_elo_pred  team_rating_i  opp_rating_i  \
# 15551         -1.547139       0.593946    1459.855633   1462.790293
# 15556         -3.647433       0.203901    1305.855727   1473.475318
# 15557          3.647433       0.796099    1473.475318   1305.855727
# 15558          0.406421       0.618044    1426.239454   1273.636819
# 15560         -1.168818       0.485440    1584.712621   1525.832949
# ...                 ...            ...            ...           ...
# 41189         -0.351562       0.741328    1872.738957   1758.834210
# 41190         -0.335964       0.497321    1849.355743   1782.217423
# 41191          0.335964       0.502679    1782.217423   1849.355743
# 41192          0.415084       0.346112    1795.029273   1836.543894
# 41193         -0.415084       0.653888    1836.543894   1795.029273
#
#        elo_MOV_pred  spread
# 15551         -0.10    -5.5
# 15556         -5.99    10.5
# 15557          5.99   -10.5
# 15558          5.45    -2.5
# 15560          2.10     5.5
# ...             ...     ...
# 41189          4.07    -5.5
# 41190          2.40     2.0
# 41191         -2.40    -2.0
# 41192         -1.48     5.0
# 41193          1.48    -5.0
#
# [22761 rows x 86 columns]

# %%
def objective(trial):
    joblib.dump(study_lr, 'study_lr.pkl')
    
    lr_C = trial.suggest_float('C', 1e-5, 1e2, log=True)
    
    classifier_obj = Pipeline([('scaler', StandardScaler()),
                    ('logreg', LogisticRegression(solver='saga', C=lr_C,
                                                  penalty='l2', max_iter=10000,
                                                 verbose=1))])
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_lr'
storage_name = "sqlite:///{}.db".format(study_name)

study_lr = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True)

study_lr.optimize(objective, n_trials=200)
# Out:
# [I 2021-09-16 17:53:24,890] Using an existing study with name 'study_lr' instead of creating a new one.
# [I 2021-09-16 17:53:28,378] Trial 200 finished with value: 0.526127076192987 and parameters: {'C': 0.0035746610011868282}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:29,862] Trial 201 finished with value: 0.5258634326390721 and parameters: {'C': 0.0010322312868852811}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:31,299] Trial 202 finished with value: 0.5267070920116004 and parameters: {'C': 0.001299081242589474}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:32,676] Trial 203 finished with value: 0.5266543633008173 and parameters: {'C': 0.0013298611417576218}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:33,975] Trial 204 finished with value: 0.5238070129185342 and parameters: {'C': 0.0006836729315628786}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:35,424] Trial 205 finished with value: 0.5267070920116004 and parameters: {'C': 0.0018427369574696457}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:36,790] Trial 206 finished with value: 0.5255470603743738 and parameters: {'C': 0.0021090654332635217}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:38,097] Trial 207 finished with value: 0.5267070920116004 and parameters: {'C': 0.0016536109060217685}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:39,442] Trial 208 finished with value: 0.5268125494331664 and parameters: {'C': 0.001671438559868225}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:40,845] Trial 209 finished with value: 0.5263907197469022 and parameters: {'C': 0.0017835854703485284}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:42,195] Trial 210 finished with value: 0.52617980490377 and parameters: {'C': 0.0026399500541527364}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:43,541] Trial 211 finished with value: 0.5268652781439493 and parameters: {'C': 0.0015040520348873852}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:45,068] Trial 212 finished with value: 0.5267070920116004 and parameters: {'C': 0.001479879794833593}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:46,444] Trial 213 finished with value: 0.5268652781439493 and parameters: {'C': 0.0015078396688115116}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:47,757] Trial 214 finished with value: 0.5269180068547324 and parameters: {'C': 0.0016676905799617682}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:49,035] Trial 215 finished with value: 0.5260216187714211 and parameters: {'C': 0.004083052312704895}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:50,350] Trial 216 finished with value: 0.5267070920116004 and parameters: {'C': 0.001683486612049584}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:51,655] Trial 217 finished with value: 0.5255470603743738 and parameters: {'C': 0.002328764849801838}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:53,224] Trial 218 finished with value: 0.5260216187714211 and parameters: {'C': 0.0031069918457828764}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:54,640] Trial 219 finished with value: 0.5265489058792513 and parameters: {'C': 0.001619031064011692}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:55,968] Trial 220 finished with value: 0.5258634326390721 and parameters: {'C': 0.002025533233803513}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:57,362] Trial 221 finished with value: 0.5263907197469022 and parameters: {'C': 0.0015333269650993735}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:53:58,749] Trial 222 finished with value: 0.5266543633008174 and parameters: {'C': 0.0016608580840222656}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:00,072] Trial 223 finished with value: 0.5266016345900344 and parameters: {'C': 0.0013252335387036293}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:01,421] Trial 224 finished with value: 0.5249670445557607 and parameters: {'C': 0.0008131407188943698}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:02,740] Trial 225 finished with value: 0.5256525177959399 and parameters: {'C': 0.002337641169318364}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:04,058] Trial 226 finished with value: 0.5264434484576852 and parameters: {'C': 0.0014311602043062446}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:05,383] Trial 227 finished with value: 0.5257052465067229 and parameters: {'C': 0.0009588553027132102}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:06,693] Trial 228 finished with value: 0.5263379910361191 and parameters: {'C': 0.0018230667247218551}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:07,927] Trial 229 finished with value: 0.5249670445557606 and parameters: {'C': 0.0007854243428368772}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:09,212] Trial 230 finished with value: 0.5263907197469022 and parameters: {'C': 0.0030478517806130237}. Best is trial 63 with value: 0.5269372693726938.
# [I 2021-09-16 17:54:10,617] Trial 231 finished with value: 0.5270761929870814 and parameters: {'C': 0.0011798799724438123}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:11,875] Trial 232 finished with value: 0.5269180068547323 and parameters: {'C': 0.0011840504124186314}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:13,178] Trial 233 finished with value: 0.525916161349855 and parameters: {'C': 0.0010356357185662142}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:14,539] Trial 234 finished with value: 0.5266016345900343 and parameters: {'C': 0.0013023998314409901}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:15,777] Trial 235 finished with value: 0.5252834168204588 and parameters: {'C': 0.0008352380376821938}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:17,124] Trial 236 finished with value: 0.526074347482204 and parameters: {'C': 0.0019897056439356258}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:18,549] Trial 237 finished with value: 0.5269180068547323 and parameters: {'C': 0.001194775100981727}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:19,956] Trial 238 finished with value: 0.5268652781439493 and parameters: {'C': 0.0012079415661101647}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:21,274] Trial 239 finished with value: 0.5232797258107038 and parameters: {'C': 0.0006262369178388923}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:22,620] Trial 240 finished with value: 0.5256525177959399 and parameters: {'C': 0.0008578264985946523}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:23,959] Trial 241 finished with value: 0.5263907197469022 and parameters: {'C': 0.0012622923204953123}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:25,234] Trial 242 finished with value: 0.5265489058792513 and parameters: {'C': 0.0010766115665032001}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:26,479] Trial 243 finished with value: 0.5269707355655153 and parameters: {'C': 0.001213982775653229}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:27,899] Trial 244 finished with value: 0.5269180068547323 and parameters: {'C': 0.0011593820464543205}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:29,306] Trial 245 finished with value: 0.523437911943053 and parameters: {'C': 0.0006667602830596538}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:30,584] Trial 246 finished with value: 0.525810703928289 and parameters: {'C': 0.0010282915427155552}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:31,868] Trial 247 finished with value: 0.5256525177959399 and parameters: {'C': 0.0008546535823960551}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:33,087] Trial 248 finished with value: 0.5232269970999209 and parameters: {'C': 0.000489155503401769}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:34,448] Trial 249 finished with value: 0.5266543633008173 and parameters: {'C': 0.001269453144588918}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:35,783] Trial 250 finished with value: 0.5254943316635907 and parameters: {'C': 0.0009149885191221413}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:37,120] Trial 251 finished with value: 0.5266543633008173 and parameters: {'C': 0.00123953217919113}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:38,440] Trial 252 finished with value: 0.5231215396783548 and parameters: {'C': 0.0006293190465169186}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:39,711] Trial 253 finished with value: 0.5254416029528077 and parameters: {'C': 0.0021212981872159066}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:40,942] Trial 254 finished with value: 0.5267070920116004 and parameters: {'C': 0.0015108311382423904}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:42,162] Trial 255 finished with value: 0.5254416029528077 and parameters: {'C': 0.0009464491860195034}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:43,521] Trial 256 finished with value: 0.52617980490377 and parameters: {'C': 0.0025028877996622965}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:44,782] Trial 257 finished with value: 0.5267070920116004 and parameters: {'C': 0.0017008124574777212}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:46,111] Trial 258 finished with value: 0.5235433693646191 and parameters: {'C': 0.0006746525330900569}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:47,436] Trial 259 finished with value: 0.5268652781439493 and parameters: {'C': 0.0012082716871507971}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:48,680] Trial 260 finished with value: 0.526074347482204 and parameters: {'C': 0.0010444686058383014}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:49,939] Trial 261 finished with value: 0.5236488267861851 and parameters: {'C': 0.00044317459972732364}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:51,204] Trial 262 finished with value: 0.5248615871341945 and parameters: {'C': 0.0007707219463560801}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:52,448] Trial 263 finished with value: 0.5264961771684682 and parameters: {'C': 0.001351878011689025}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:54:53,760] Trial 264 finished with value: 0.5264434484576851 and parameters: {'C': 0.0011156882665967602}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:25,497] Trial 265 finished with value: 0.5201687318745056 and parameters: {'C': 73.43334936761921}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:26,781] Trial 266 finished with value: 0.5229106248352228 and parameters: {'C': 0.0005640023060343155}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:28,047] Trial 267 finished with value: 0.5255997890851569 and parameters: {'C': 0.002117632655866753}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:29,307] Trial 268 finished with value: 0.5252834168204588 and parameters: {'C': 0.0008344470959169435}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:30,698] Trial 269 finished with value: 0.5269707355655154 and parameters: {'C': 0.0011910738373788164}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:31,956] Trial 270 finished with value: 0.5267070920116004 and parameters: {'C': 0.0014694610068749342}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:33,318] Trial 271 finished with value: 0.52617980490377 and parameters: {'C': 0.0026316994211538626}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:34,677] Trial 272 finished with value: 0.5260216187714211 and parameters: {'C': 0.0010514889195217246}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:35,923] Trial 273 finished with value: 0.5249143158449775 and parameters: {'C': 0.000748911191668448}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:37,113] Trial 274 finished with value: 0.5267070920116004 and parameters: {'C': 0.0016428375901046367}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:38,561] Trial 275 finished with value: 0.5266543633008174 and parameters: {'C': 0.0012671446104518514}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:39,904] Trial 276 finished with value: 0.5254416029528078 and parameters: {'C': 0.002144931876277028}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:41,154] Trial 277 finished with value: 0.5225415238597416 and parameters: {'C': 0.0005367877536532693}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:42,528] Trial 278 finished with value: 0.5253888742420247 and parameters: {'C': 0.0009103906011870523}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:43,919] Trial 279 finished with value: 0.5267070920116004 and parameters: {'C': 0.001340369465620259}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:49,660] Trial 280 finished with value: 0.5251779593988927 and parameters: {'C': 0.1173174751353899}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:50,832] Trial 281 finished with value: 0.5249670445557606 and parameters: {'C': 0.0007504229291148149}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:52,113] Trial 282 finished with value: 0.5263907197469022 and parameters: {'C': 0.003456280336046299}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:53,458] Trial 283 finished with value: 0.5266016345900342 and parameters: {'C': 0.001706936265356636}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:54,815] Trial 284 finished with value: 0.525810703928289 and parameters: {'C': 0.0010269109113487578}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:56,138] Trial 285 finished with value: 0.525916161349855 and parameters: {'C': 0.00239260886497171}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:57,397] Trial 286 finished with value: 0.5269707355655153 and parameters: {'C': 0.0011730635882166256}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:57:58,849] Trial 287 finished with value: 0.5266543633008174 and parameters: {'C': 0.0016047041245039655}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:00,187] Trial 288 finished with value: 0.5238070129185342 and parameters: {'C': 0.0004294659153607615}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:01,480] Trial 289 finished with value: 0.5235433693646191 and parameters: {'C': 0.0006690422007398068}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:02,826] Trial 290 finished with value: 0.5269180068547323 and parameters: {'C': 0.0011524875561248153}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:04,101] Trial 291 finished with value: 0.5266543633008173 and parameters: {'C': 0.001901456039924477}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:05,333] Trial 292 finished with value: 0.5253361455312417 and parameters: {'C': 0.0008898377678399803}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:06,766] Trial 293 finished with value: 0.5268652781439493 and parameters: {'C': 0.0011707854560842708}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:52,218] Trial 294 finished with value: 0.5204851041392038 and parameters: {'C': 8.19478665328706}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:53,597] Trial 295 finished with value: 0.5266543633008174 and parameters: {'C': 0.0013723352788538137}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:54,840] Trial 296 finished with value: 0.5262852623253361 and parameters: {'C': 0.003233211407811276}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:56,137] Trial 297 finished with value: 0.5154758766148168 and parameters: {'C': 4.634018022191116e-05}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:57,524] Trial 298 finished with value: 0.525863432639072 and parameters: {'C': 0.0020204826576562915}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:58:58,745] Trial 299 finished with value: 0.5263907197469022 and parameters: {'C': 0.0012620489890420108}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:00,106] Trial 300 finished with value: 0.5231742683891378 and parameters: {'C': 0.0006128162209821752}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:01,449] Trial 301 finished with value: 0.5244924861587134 and parameters: {'C': 0.00504148346311897}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:02,696] Trial 302 finished with value: 0.5258107039282891 and parameters: {'C': 0.0009559817199742452}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:03,915] Trial 303 finished with value: 0.5264434484576852 and parameters: {'C': 0.0015292649374240917}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:05,170] Trial 304 finished with value: 0.525916161349855 and parameters: {'C': 0.0024193174930224534}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:08,056] Trial 305 finished with value: 0.5248088584234116 and parameters: {'C': 0.035862239351925555}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:09,358] Trial 306 finished with value: 0.5249143158449776 and parameters: {'C': 0.0007698806856333276}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:10,753] Trial 307 finished with value: 0.5264961771684682 and parameters: {'C': 0.001250223944053596}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:11,976] Trial 308 finished with value: 0.5268652781439493 and parameters: {'C': 0.0016779885018635451}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:13,186] Trial 309 finished with value: 0.5262852623253362 and parameters: {'C': 0.002742387999802194}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:14,501] Trial 310 finished with value: 0.5263907197469022 and parameters: {'C': 0.0018318371747118032}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:16,112] Trial 311 finished with value: 0.5220669654626945 and parameters: {'C': 0.00032909780839596533}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:17,990] Trial 312 finished with value: 0.5243343000263644 and parameters: {'C': 0.014858948418076006}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:19,278] Trial 313 finished with value: 0.525863432639072 and parameters: {'C': 0.0009647732703849222}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:20,561] Trial 314 finished with value: 0.5224887951489585 and parameters: {'C': 0.0005135457627413467}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:22,013] Trial 315 finished with value: 0.5265489058792512 and parameters: {'C': 0.001598691056748456}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:23,385] Trial 316 finished with value: 0.5268652781439493 and parameters: {'C': 0.0011614142826865937}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:24,639] Trial 317 finished with value: 0.5122594252570524 and parameters: {'C': 1.8810623639326115e-05}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:25,834] Trial 318 finished with value: 0.5253888742420249 and parameters: {'C': 0.002175926021472778}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:27,096] Trial 319 finished with value: 0.526074347482204 and parameters: {'C': 0.004070454682452426}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:28,375] Trial 320 finished with value: 0.5237542842077512 and parameters: {'C': 0.0006863654315899995}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:44,685] Trial 321 finished with value: 0.5247561297126285 and parameters: {'C': 0.6315500239398316}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:45,931] Trial 322 finished with value: 0.5263907197469022 and parameters: {'C': 0.0010593975657005798}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:47,213] Trial 323 finished with value: 0.5268652781439493 and parameters: {'C': 0.0015012379959794655}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:48,485] Trial 324 finished with value: 0.5262852623253362 and parameters: {'C': 0.0015585954857371903}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:49,807] Trial 325 finished with value: 0.5262852623253361 and parameters: {'C': 0.00256519335346633}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:51,076] Trial 326 finished with value: 0.5255997890851569 and parameters: {'C': 0.0008470439463791571}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:52,369] Trial 327 finished with value: 0.5266543633008174 and parameters: {'C': 0.0017515428005256354}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:53,815] Trial 328 finished with value: 0.5267598207223834 and parameters: {'C': 0.0011005058667883593}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:55,084] Trial 329 finished with value: 0.5260216187714211 and parameters: {'C': 0.0031333161779137303}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:56,347] Trial 330 finished with value: 0.5265489058792513 and parameters: {'C': 0.0013559407461775327}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:57,869] Trial 331 finished with value: 0.5230688109675719 and parameters: {'C': 0.0070620583661445135}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 17:59:59,163] Trial 332 finished with value: 0.5243870287371474 and parameters: {'C': 0.0007161254504724107}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:00,539] Trial 333 finished with value: 0.5259688900606381 and parameters: {'C': 0.0020107933084472303}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:01,820] Trial 334 finished with value: 0.5231215396783548 and parameters: {'C': 0.0004917632854965125}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:03,015] Trial 335 finished with value: 0.5253888742420247 and parameters: {'C': 0.0009095083001567377}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:04,409] Trial 336 finished with value: 0.5266016345900344 and parameters: {'C': 0.0013749340464436898}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:05,735] Trial 337 finished with value: 0.5253888742420247 and parameters: {'C': 0.0022413202798504893}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:07,110] Trial 338 finished with value: 0.5264961771684682 and parameters: {'C': 0.0010777453758097158}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:08,456] Trial 339 finished with value: 0.523332454521487 and parameters: {'C': 0.000666065200704152}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:09,893] Trial 340 finished with value: 0.5264961771684682 and parameters: {'C': 0.001587150691394844}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:11,275] Trial 341 finished with value: 0.5254943316635908 and parameters: {'C': 0.0009222738626957327}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:12,561] Trial 342 finished with value: 0.5265489058792513 and parameters: {'C': 0.0013301368689274781}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:13,931] Trial 343 finished with value: 0.5255997890851569 and parameters: {'C': 0.002355058710169983}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:15,317] Trial 344 finished with value: 0.5249143158449776 and parameters: {'C': 0.0008004664761450702}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:16,618] Trial 345 finished with value: 0.5269180068547323 and parameters: {'C': 0.0018709197846045118}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:17,907] Trial 346 finished with value: 0.5231215396783548 and parameters: {'C': 0.0005753739247442525}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:19,287] Trial 347 finished with value: 0.5263907197469021 and parameters: {'C': 0.0034688365671877225}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:20,577] Trial 348 finished with value: 0.5267598207223834 and parameters: {'C': 0.0011431497342354053}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:21,876] Trial 349 finished with value: 0.5267070920116004 and parameters: {'C': 0.001846763386472089}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:23,248] Trial 350 finished with value: 0.5265489058792513 and parameters: {'C': 0.001249238525133916}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:24,765] Trial 351 finished with value: 0.5256525177959399 and parameters: {'C': 0.0008459587728426299}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:26,225] Trial 352 finished with value: 0.5265489058792513 and parameters: {'C': 0.0018384333229575158}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:27,694] Trial 353 finished with value: 0.5262852623253362 and parameters: {'C': 0.002741568784839431}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:29,073] Trial 354 finished with value: 0.5233851832322699 and parameters: {'C': 0.00043655195351291855}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:30,431] Trial 355 finished with value: 0.5267070920116004 and parameters: {'C': 0.0011301442308023213}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:00:31,804] Trial 356 finished with value: 0.5230688109675719 and parameters: {'C': 0.0006342899198405602}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:35,645] Trial 357 finished with value: 0.5198523596098076 and parameters: {'C': 44.35331065640777}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:36,905] Trial 358 finished with value: 0.5267070920116004 and parameters: {'C': 0.0014805508119688018}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:38,265] Trial 359 finished with value: 0.5256525177959399 and parameters: {'C': 0.000948208373667606}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:40,418] Trial 360 finished with value: 0.5230160822567889 and parameters: {'C': 0.023480547780381635}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:41,828] Trial 361 finished with value: 0.521065119957817 and parameters: {'C': 0.00029947101124537973}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:43,308] Trial 362 finished with value: 0.5266016345900343 and parameters: {'C': 0.0018964644994212368}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:44,523] Trial 363 finished with value: 0.5264961771684682 and parameters: {'C': 0.0014029431846965912}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:45,725] Trial 364 finished with value: 0.5250725019773267 and parameters: {'C': 0.0008284792975535001}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:46,925] Trial 365 finished with value: 0.5262852623253361 and parameters: {'C': 0.002763388858249524}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:48,122] Trial 366 finished with value: 0.5267598207223834 and parameters: {'C': 0.0011304531590653243}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:49,512] Trial 367 finished with value: 0.526074347482204 and parameters: {'C': 0.0019788816326246966}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:50,730] Trial 368 finished with value: 0.5226469812813076 and parameters: {'C': 0.0005261397475449688}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:51,985] Trial 369 finished with value: 0.5263907197469022 and parameters: {'C': 0.0014384336859305745}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:53,214] Trial 370 finished with value: 0.5250725019773267 and parameters: {'C': 0.0007646303661753714}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:54,602] Trial 371 finished with value: 0.5268125494331664 and parameters: {'C': 0.001134791458980193}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:55,995] Trial 372 finished with value: 0.5254416029528078 and parameters: {'C': 0.0022389071331182764}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:57,334] Trial 373 finished with value: 0.5265489058792512 and parameters: {'C': 0.0015975223155692006}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:02:58,791] Trial 374 finished with value: 0.5244397574479305 and parameters: {'C': 0.004895511552052993}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:00,150] Trial 375 finished with value: 0.5255470603743738 and parameters: {'C': 0.0009173515575087832}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:01,369] Trial 376 finished with value: 0.5260216187714211 and parameters: {'C': 0.0037160513702734935}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:02,672] Trial 377 finished with value: 0.5230688109675719 and parameters: {'C': 0.0006473666126176195}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:03,943] Trial 378 finished with value: 0.5269707355655153 and parameters: {'C': 0.001226050002137346}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:07,935] Trial 379 finished with value: 0.5258634326390721 and parameters: {'C': 0.07053309485444592}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:09,311] Trial 380 finished with value: 0.5265489058792513 and parameters: {'C': 0.0015475146817678846}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:10,553] Trial 381 finished with value: 0.5263907197469022 and parameters: {'C': 0.00269577084157527}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:11,815] Trial 382 finished with value: 0.5260216187714211 and parameters: {'C': 0.0010512374206617854}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:13,032] Trial 383 finished with value: 0.5255470603743738 and parameters: {'C': 0.0020726145469949606}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:14,445] Trial 384 finished with value: 0.5247561297126285 and parameters: {'C': 0.0007438296939675208}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:15,731] Trial 385 finished with value: 0.5161613498549961 and parameters: {'C': 8.192689291396086e-05}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:17,072] Trial 386 finished with value: 0.5265489058792512 and parameters: {'C': 0.0013582268091123216}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:18,419] Trial 387 finished with value: 0.5238070129185342 and parameters: {'C': 0.00044977208252828106}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:19,657] Trial 388 finished with value: 0.5259688900606381 and parameters: {'C': 0.0010391611156757266}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:20,894] Trial 389 finished with value: 0.5263379910361192 and parameters: {'C': 0.0017913514059123394}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:22,191] Trial 390 finished with value: 0.5266016345900344 and parameters: {'C': 0.0013243060005183223}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:23,445] Trial 391 finished with value: 0.5248615871341946 and parameters: {'C': 0.0007944422090152176}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:32,351] Trial 392 finished with value: 0.5255470603743738 and parameters: {'C': 0.2322915794805443}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:33,592] Trial 393 finished with value: 0.526127076192987 and parameters: {'C': 0.0030015457293450735}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:34,843] Trial 394 finished with value: 0.5232797258107038 and parameters: {'C': 0.0006099581364669998}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:36,123] Trial 395 finished with value: 0.5264961771684682 and parameters: {'C': 0.0019194110267484667}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:37,421] Trial 396 finished with value: 0.5256525177959399 and parameters: {'C': 0.0009514160466728221}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:38,661] Trial 397 finished with value: 0.5265489058792513 and parameters: {'C': 0.0013833194416656622}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:40,029] Trial 398 finished with value: 0.5264434484576853 and parameters: {'C': 0.0010805964233787434}. Best is trial 231 with value: 0.5270761929870814.
# [I 2021-09-16 18:03:41,372] Trial 399 finished with value: 0.5255470603743738 and parameters: {'C': 0.002328630526539458}. Best is trial 231 with value: 0.5270761929870814.

# %%
lr_C = study_lr.best_params['C']
print(lr_C)
best_lr = Pipeline([('scaler', StandardScaler()),
                    ('logreg', LogisticRegression(solver='saga', C=lr_C,
                                                  penalty='l2', max_iter=10000,
                                                 verbose=1, random_state=23))])
best_lr.fit(X_train, y_train)

print(best_lr)

print("train_acc:", best_lr.score(X_train, y_train))
print("test_acc:", best_lr.score(X_test, y_test))

view_model_coefs(best_lr.named_steps['logreg'], X_train)
# Out:
# 0.0011798799724438123
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 19 epochs took 1 seconds
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('logreg',
#                  LogisticRegression(C=0.0011798799724438123, max_iter=10000,
#                                     random_state=23, solver='saga',
#                                     verbose=1))])
# train_acc: 0.5402223100918238
# test_acc: 0.5120743034055728
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s finished
#                 feature_name      coef
# 38             FG3A_opp_diff -0.048979
# 32        UAST_3PM_team_diff -0.048957
# 57           PTS_FB_opp_diff -0.047222
# 25      PTS_2PT_MR_team_diff -0.037064
# 48               PF_opp_diff -0.033033
# 5             FG2A_team_diff -0.030537
# 59        PTS_PAINT_opp_diff -0.028023
# 46              BLK_opp_diff -0.023345
# 60          AST_2PM_opp_diff -0.022647
# 16             TOV_team_diff -0.021961
# 65           ATS_record_diff -0.020578
# 30        UAST_2PM_team_diff -0.019720
# 44              AST_opp_diff -0.019427
# 19      PLUS_MINUS_team_diff -0.018901
# 4             FG2M_team_diff -0.017507
# 79         TOV_PCT_team_diff -0.016766
# 18             PTS_team_diff -0.015787
# 78        AST_RATIO_opp_diff -0.014413
# 40              FTA_opp_diff -0.013543
# 58      PTS_OFF_TOV_opp_diff -0.013358
# 68         OREB_PCT_opp_diff -0.012585
# 9              FTA_team_diff -0.012207
# 23            POSS_team_diff -0.011700
# 72          REB_PCT_opp_diff -0.011602
# 83              opp_rating_i -0.011283
# 1                 avg_spread -0.011083
# 54             POSS_opp_diff -0.009208
# 41             OREB_opp_diff -0.008070
# 75         EFG_PCT_team_diff -0.007996
# 10            OREB_team_diff -0.006816
# 55              PIE_opp_diff -0.006095
# 6             FG3M_team_diff -0.005985
# 70         DREB_PCT_opp_diff -0.005777
# 3   points_covered_spread_by -0.004639
# 35             FG2M_opp_diff -0.004573
# 13             AST_team_diff -0.004075
# 53     E_NET_RATING_opp_diff -0.002600
# 77       AST_RATIO_team_diff -0.002030
# 43              REB_opp_diff  0.000144
# 29         AST_2PM_team_diff  0.000964
# 2      avg_point_spread_diff  0.001457
# 0                     avg_ml  0.001965
# 64            WL_record_diff  0.001987
# 73          TS_PCT_team_diff  0.002411
# 22    E_NET_RATING_team_diff  0.002600
# 33     team_covered_opp_diff  0.004557
# 82             team_rating_i  0.004734
# 39              FTM_opp_diff  0.004826
# 42             DREB_opp_diff  0.005165
# 49              PTS_opp_diff  0.005242
# 47              TOV_opp_diff  0.005257
# 67        OREB_PCT_team_diff  0.005777
# 24             PIE_team_diff  0.006052
# 15             BLK_team_diff  0.006405
# 66                 rest_diff  0.006675
# 14             STL_team_diff  0.007744
# 12             REB_team_diff  0.009077
# 80          TOV_PCT_opp_diff  0.010330
# 37             FG3M_opp_diff  0.010895
# 81             team_elo_pred  0.011228
# 8              FTM_team_diff  0.011306
# 71         REB_PCT_team_diff  0.011602
# 84              elo_MOV_pred  0.011796
# 69        DREB_PCT_team_diff  0.012585
# 62          AST_3PM_opp_diff  0.014871
# 7             FG3A_team_diff  0.014894
# 21    E_DEF_RATING_team_diff  0.014939
# 51     E_OFF_RATING_opp_diff  0.014939
# 74           TS_PCT_opp_diff  0.015686
# 28       PTS_PAINT_team_diff  0.016330
# 76          EFG_PCT_opp_diff  0.016438
# 11            DREB_team_diff  0.016806
# 52     E_DEF_RATING_opp_diff  0.017873
# 20    E_OFF_RATING_team_diff  0.017873
# 61         UAST_2PM_opp_diff  0.018896
# 50       PLUS_MINUS_opp_diff  0.018901
# 36             FG2A_opp_diff  0.019967
# 31         AST_3PM_team_diff  0.021016
# 56       PTS_2PT_MR_opp_diff  0.027052
# 17              PF_team_diff  0.028327
# 63         UAST_3PM_opp_diff  0.029726
# 45              STL_opp_diff  0.045003
# 26          PTS_FB_team_diff  0.045822
# 34           RECORD_opp_diff  0.046876
# 85                    spread  0.063167
# 27     PTS_OFF_TOV_team_diff  0.069644

# %% [markdown]
# ## SVC

# %%
def objective(trial):    
    svc_C = trial.suggest_float('C', 1e-5, 1e2, log=True)
    
    classifier_obj = Pipeline(steps=[('scaler', StandardScaler()),
                ('svc', LinearSVC(C = svc_C,
                                loss='hinge',
                               max_iter=100000,
                                     random_state=23))])
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_svc_acc'
storage_name = "sqlite:///{}.db".format(study_name)

study_svc_acc = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True)

study_svc_acc.optimize(objective, n_trials=100)
# Out:
# [I 2021-09-16 18:03:42,674] Using an existing study with name 'study_svc_acc' instead of creating a new one.
# [I 2021-09-16 18:03:43,337] Trial 200 finished with value: 0.52617980490377 and parameters: {'C': 0.003525855628075335}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:44,036] Trial 201 finished with value: 0.5253888742420247 and parameters: {'C': 0.0021974948759239487}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:44,781] Trial 202 finished with value: 0.5269707355655153 and parameters: {'C': 0.006068663656441219}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:45,562] Trial 203 finished with value: 0.5268652781439493 and parameters: {'C': 0.006161529265740172}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:46,376] Trial 204 finished with value: 0.5268125494331664 and parameters: {'C': 0.00638765481231248}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:47,174] Trial 205 finished with value: 0.5264434484576852 and parameters: {'C': 0.007012303282783381}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:47,943] Trial 206 finished with value: 0.5269707355655153 and parameters: {'C': 0.00594356728042797}. Best is trial 189 with value: 0.5269899841855562.
# [I 2021-09-16 18:03:48,606] Trial 207 finished with value: 0.5270234642762984 and parameters: {'C': 0.005764933290447333}. Best is trial 207 with value: 0.5270234642762984.
# [I 2021-09-16 18:03:49,543] Trial 208 finished with value: 0.52617980490377 and parameters: {'C': 0.01532772257901614}. Best is trial 207 with value: 0.5270234642762984.
# [I 2021-09-16 18:03:50,375] Trial 209 finished with value: 0.5265489058792513 and parameters: {'C': 0.010631382920107787}. Best is trial 207 with value: 0.5270234642762984.
# [I 2021-09-16 18:03:51,127] Trial 210 finished with value: 0.5268125494331664 and parameters: {'C': 0.006291483585174967}. Best is trial 207 with value: 0.5270234642762984.
# [I 2021-09-16 18:03:51,832] Trial 211 finished with value: 0.5271289216978645 and parameters: {'C': 0.0061299203258862855}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:52,540] Trial 212 finished with value: 0.5269707355655153 and parameters: {'C': 0.005885955134227404}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:53,325] Trial 213 finished with value: 0.5269180068547323 and parameters: {'C': 0.0057489181819664675}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:54,147] Trial 214 finished with value: 0.5270234642762984 and parameters: {'C': 0.006515033943220536}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:54,826] Trial 215 finished with value: 0.5266016345900342 and parameters: {'C': 0.007586591143183405}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:55,547] Trial 216 finished with value: 0.5266543633008173 and parameters: {'C': 0.006206632150667929}. Best is trial 211 with value: 0.5271289216978645.
# [I 2021-09-16 18:03:56,413] Trial 217 finished with value: 0.5274452939625626 and parameters: {'C': 0.012650094724650195}. Best is trial 217 with value: 0.5274452939625626.
# [I 2021-09-16 18:03:57,385] Trial 218 finished with value: 0.5278671236488267 and parameters: {'C': 0.013261433131872932}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:03:58,311] Trial 219 finished with value: 0.5262325336145531 and parameters: {'C': 0.017945221560166938}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:03:59,457] Trial 220 finished with value: 0.5262852623253361 and parameters: {'C': 0.014931276937754569}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:00,496] Trial 221 finished with value: 0.5267598207223834 and parameters: {'C': 0.010689063865130731}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:01,298] Trial 222 finished with value: 0.5264434484576852 and parameters: {'C': 0.008038515908029826}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:02,170] Trial 223 finished with value: 0.5276562088056946 and parameters: {'C': 0.012398543757113849}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:03,134] Trial 224 finished with value: 0.5275507513841287 and parameters: {'C': 0.012559275450393198}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:04,103] Trial 225 finished with value: 0.525863432639072 and parameters: {'C': 0.018938571033276466}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:05,016] Trial 226 finished with value: 0.5277616662272606 and parameters: {'C': 0.012718039386638414}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:06,336] Trial 227 finished with value: 0.526285262325336 and parameters: {'C': 0.024227536467801607}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:07,168] Trial 228 finished with value: 0.5277089375164777 and parameters: {'C': 0.01224767206621075}. Best is trial 218 with value: 0.5278671236488267.
# [I 2021-09-16 18:04:07,977] Trial 229 finished with value: 0.5278671236488268 and parameters: {'C': 0.013471525078171056}. Best is trial 229 with value: 0.5278671236488268.
# [I 2021-09-16 18:04:09,194] Trial 230 finished with value: 0.5265489058792513 and parameters: {'C': 0.024634016313354417}. Best is trial 229 with value: 0.5278671236488268.
# [I 2021-09-16 18:04:10,099] Trial 231 finished with value: 0.5278671236488268 and parameters: {'C': 0.01306456968558025}. Best is trial 229 with value: 0.5278671236488268.
# [I 2021-09-16 18:04:11,020] Trial 232 finished with value: 0.5279725810703928 and parameters: {'C': 0.0131799668827233}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:12,219] Trial 233 finished with value: 0.5264961771684682 and parameters: {'C': 0.029587288696946983}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:13,356] Trial 234 finished with value: 0.5268652781439493 and parameters: {'C': 0.014643525421397432}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:14,641] Trial 235 finished with value: 0.5257052465067229 and parameters: {'C': 0.038773319029564934}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:15,600] Trial 236 finished with value: 0.5279725810703928 and parameters: {'C': 0.01316236960648477}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:16,462] Trial 237 finished with value: 0.5276034800949118 and parameters: {'C': 0.012188617319715944}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:17,320] Trial 238 finished with value: 0.5258107039282889 and parameters: {'C': 0.021266668608866536}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:18,301] Trial 239 finished with value: 0.5277089375164777 and parameters: {'C': 0.013350738637713005}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:19,556] Trial 240 finished with value: 0.5277089375164776 and parameters: {'C': 0.013587436262416507}. Best is trial 232 with value: 0.5279725810703928.
# [I 2021-09-16 18:04:20,439] Trial 241 finished with value: 0.5280253097811759 and parameters: {'C': 0.0129811373894625}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:21,293] Trial 242 finished with value: 0.5277616662272607 and parameters: {'C': 0.01345506541039078}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:22,340] Trial 243 finished with value: 0.5275507513841287 and parameters: {'C': 0.013312026101760605}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:23,320] Trial 244 finished with value: 0.5277089375164777 and parameters: {'C': 0.013356598481950635}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:24,231] Trial 245 finished with value: 0.5277089375164777 and parameters: {'C': 0.013648225876323899}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:25,115] Trial 246 finished with value: 0.5274980226733457 and parameters: {'C': 0.01374393996938841}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:26,094] Trial 247 finished with value: 0.52617980490377 and parameters: {'C': 0.018776688924816445}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:27,016] Trial 248 finished with value: 0.5273398365409966 and parameters: {'C': 0.014157168085292954}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:28,184] Trial 249 finished with value: 0.5270761929870813 and parameters: {'C': 0.0145667139216379}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:29,131] Trial 250 finished with value: 0.5264961771684682 and parameters: {'C': 0.029728275924018048}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:29,960] Trial 251 finished with value: 0.5277089375164777 and parameters: {'C': 0.012740393426116423}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:30,804] Trial 252 finished with value: 0.5280253097811759 and parameters: {'C': 0.012975940410958425}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:31,615] Trial 253 finished with value: 0.5277089375164777 and parameters: {'C': 0.013620816113875066}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:32,325] Trial 254 finished with value: 0.5274452939625626 and parameters: {'C': 0.013914742725726856}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:33,277] Trial 255 finished with value: 0.526232533614553 and parameters: {'C': 0.020472807202070963}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:34,122] Trial 256 finished with value: 0.5274452939625626 and parameters: {'C': 0.013854344790110667}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:35,366] Trial 257 finished with value: 0.5276034800949116 and parameters: {'C': 0.013278114510501815}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:36,226] Trial 258 finished with value: 0.5277089375164777 and parameters: {'C': 0.013110009625232224}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:37,325] Trial 259 finished with value: 0.5264961771684683 and parameters: {'C': 0.024582982247793636}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:38,224] Trial 260 finished with value: 0.5277616662272606 and parameters: {'C': 0.012254407258077886}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:39,475] Trial 261 finished with value: 0.5260216187714211 and parameters: {'C': 0.018351912476788152}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:40,697] Trial 262 finished with value: 0.5259161613498551 and parameters: {'C': 0.03944824481596154}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:41,773] Trial 263 finished with value: 0.5268125494331664 and parameters: {'C': 0.010882737496043826}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:42,652] Trial 264 finished with value: 0.5275507513841287 and parameters: {'C': 0.012033115176155504}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:43,673] Trial 265 finished with value: 0.526074347482204 and parameters: {'C': 0.020746577427581844}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:44,568] Trial 266 finished with value: 0.5269707355655153 and parameters: {'C': 0.011225481192240231}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:45,559] Trial 267 finished with value: 0.5263379910361191 and parameters: {'C': 0.016236324304414487}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:46,526] Trial 268 finished with value: 0.5268652781439493 and parameters: {'C': 0.02582470267733136}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:47,560] Trial 269 finished with value: 0.5275507513841287 and parameters: {'C': 0.011850914368552639}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:48,492] Trial 270 finished with value: 0.5268652781439493 and parameters: {'C': 0.011121222981778195}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:49,516] Trial 271 finished with value: 0.525863432639072 and parameters: {'C': 0.019891481052047317}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:50,592] Trial 272 finished with value: 0.5268652781439493 and parameters: {'C': 0.010718502455202629}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:51,552] Trial 273 finished with value: 0.5268125494331664 and parameters: {'C': 0.027027334999069726}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:52,563] Trial 274 finished with value: 0.5259161613498549 and parameters: {'C': 0.018035203494444218}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:53,343] Trial 275 finished with value: 0.5266016345900344 and parameters: {'C': 0.010619949733647611}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:54,444] Trial 276 finished with value: 0.526074347482204 and parameters: {'C': 0.015625964719853783}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:56,464] Trial 277 finished with value: 0.5262325336145531 and parameters: {'C': 0.03229089289811291}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:57,240] Trial 278 finished with value: 0.5278671236488268 and parameters: {'C': 0.012294504127685372}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:58,086] Trial 279 finished with value: 0.5269180068547323 and parameters: {'C': 0.010950071672821917}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:59,048] Trial 280 finished with value: 0.5259688900606381 and parameters: {'C': 0.018200102467593297}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:04:59,754] Trial 281 finished with value: 0.5270234642762984 and parameters: {'C': 0.009766483608992042}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:01,019] Trial 282 finished with value: 0.5258107039282891 and parameters: {'C': 0.023208015706983873}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:01,833] Trial 283 finished with value: 0.5274980226733457 and parameters: {'C': 0.013930269030093452}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:02,729] Trial 284 finished with value: 0.5264961771684683 and parameters: {'C': 0.01655641238032853}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:03,637] Trial 285 finished with value: 0.5269180068547324 and parameters: {'C': 0.009987062079070491}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:04,891] Trial 286 finished with value: 0.52617980490377 and parameters: {'C': 0.030105515754068567}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:05,944] Trial 287 finished with value: 0.5272871078302135 and parameters: {'C': 0.014450703698872329}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:07,407] Trial 288 finished with value: 0.5257052465067229 and parameters: {'C': 0.04391305600259304}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:08,207] Trial 289 finished with value: 0.5264434484576852 and parameters: {'C': 0.009018846394352777}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:09,408] Trial 290 finished with value: 0.5257579752175059 and parameters: {'C': 0.022289647880502663}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:10,288] Trial 291 finished with value: 0.5278143949380437 and parameters: {'C': 0.01228425543151898}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:11,278] Trial 292 finished with value: 0.526127076192987 and parameters: {'C': 0.017970583750881435}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:12,205] Trial 293 finished with value: 0.5267598207223834 and parameters: {'C': 0.009066051586494173}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:13,553] Trial 294 finished with value: 0.5242815713155813 and parameters: {'C': 0.05918517345851182}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:14,658] Trial 295 finished with value: 0.5277616662272606 and parameters: {'C': 0.012704581289164631}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:15,548] Trial 296 finished with value: 0.5261798049037701 and parameters: {'C': 0.02393293854672316}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:16,514] Trial 297 finished with value: 0.525968890060638 and parameters: {'C': 0.018064801403031492}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:17,515] Trial 298 finished with value: 0.5278143949380437 and parameters: {'C': 0.013481148652988018}. Best is trial 241 with value: 0.5280253097811759.
# [I 2021-09-16 18:05:18,340] Trial 299 finished with value: 0.5264434484576852 and parameters: {'C': 0.00903739121002727}. Best is trial 241 with value: 0.5280253097811759.

# %%
svc_C = study_svc_acc.best_params['C']
print('C:', svc_C)
best_svc = Pipeline(steps=[('scaler', StandardScaler()),
                ('svc', LinearSVC(C = svc_C,
                                loss='hinge',
                               max_iter=100000,
                                     random_state=23))]) 


best_svc.fit(X_train, y_train)

print("best_svc:", best_svc)


print("train_score:", best_svc.score(X_train, y_train))
print("test_score:", best_svc.score(X_test, y_test))
# Out:
# C: 0.0129811373894625
# best_svc: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc',
#                  LinearSVC(C=0.0129811373894625, loss='hinge', max_iter=100000,
#                            random_state=23))])
# train_score: 0.538684592065375
# test_score: 0.5104820875718709

# %%
# svc_pipe_rbf = Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc', SVC(random_state=23, probability=True))])



# params = {
#     'svc__C': np.logspace(-3,1,100)
# }

# svc_rbf_cv = GridSearchCV(svc_pipe_rbf, param_grid=params, scoring='roc_auc', cv=tscv, n_jobs=-1, verbose=1)


# svc_rbf_cv.fit(X_train, y_train)

# best_svc_rbf = svc_rbf_cv.best_estimator_
# print("best_svc_rbf:", best_svc_rbf)


# print("train_score:", best_svc_rbf.score(X_train, y_train))
# print("test_score:", best_svc_rbf.score(X_test, y_test))
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 189.3min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 451.8min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 584.5min finished
# best_svc_rbf: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc',
#                  SVC(C=0.29150530628251786, probability=True,
#                      random_state=23))])
# train_score: 0.5943226260051853
# test_score: 0.5101282618310482

# %% [markdown]
# ### SGD Hinge

# %%
def objective(trial):
    sgd_alpha = trial.suggest_float('alpha', 1e-5, 1e2, log=True)
    
    classifier_obj = Pipeline(steps=[('scaler', StandardScaler()),
                ('sgd', SGDClassifier(alpha = sgd_alpha,
                                      loss='modified_huber',
                               max_iter=10000,
                                     random_state=23))])
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_sgd'
storage_name = "sqlite:///{}.db".format(study_name)

study_sgd = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True)

study_sgd.optimize(objective, n_trials=500)
# Out:
# [I 2021-09-16 18:05:18,973] Using an existing study with name 'study_sgd' instead of creating a new one.
# [I 2021-09-16 18:05:19,955] Trial 1000 finished with value: 0.5245979435802794 and parameters: {'alpha': 0.1804510917704094}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:20,539] Trial 1001 finished with value: 0.523437911943053 and parameters: {'alpha': 0.36674318532678096}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:21,147] Trial 1002 finished with value: 0.5183232269970999 and parameters: {'alpha': 0.06778893558878843}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:21,737] Trial 1003 finished with value: 0.525863432639072 and parameters: {'alpha': 0.23120200935981056}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:22,361] Trial 1004 finished with value: 0.5245452148694965 and parameters: {'alpha': 0.20261139243254722}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:22,983] Trial 1005 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.15308381337108373}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:23,693] Trial 1006 finished with value: 0.521012391247034 and parameters: {'alpha': 0.0891469326425838}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:24,399] Trial 1007 finished with value: 0.5245979435802794 and parameters: {'alpha': 0.12327444510547104}. Best is trial 857 with value: 0.5262519768054823.
# [I 2021-09-16 18:05:25,024] Trial 1008 finished with value: 0.5288689691537043 and parameters: {'alpha': 0.26670520662745784}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:25,603] Trial 1009 finished with value: 0.5265489058792512 and parameters: {'alpha': 0.31319285214281856}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:26,268] Trial 1010 finished with value: 0.5243870287371474 and parameters: {'alpha': 0.7746723834193011}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:26,945] Trial 1011 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.5541670687825041}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:27,504] Trial 1012 finished with value: 0.5223306090166095 and parameters: {'alpha': 0.6386588680936633}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:28,194] Trial 1013 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.3742736799062697}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:28,725] Trial 1014 finished with value: 0.5233851832322699 and parameters: {'alpha': 1.043269213647985}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:29,313] Trial 1015 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.4652393571452336}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:29,881] Trial 1016 finished with value: 0.5262325336145531 and parameters: {'alpha': 0.42120730094584535}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:30,443] Trial 1017 finished with value: 0.5233851832322699 and parameters: {'alpha': 0.4889011868354588}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:31,024] Trial 1018 finished with value: 0.5233851832322699 and parameters: {'alpha': 0.4978701276547368}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:31,576] Trial 1019 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.5965014311116066}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:32,165] Trial 1020 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.5969722688822938}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:32,704] Trial 1021 finished with value: 0.5247561297126285 and parameters: {'alpha': 1.2962230275886673}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:33,375] Trial 1022 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.4178519930246328}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:34,057] Trial 1023 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.5732554245511031}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:34,634] Trial 1024 finished with value: 0.5222251515950436 and parameters: {'alpha': 0.6500189577846646}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:35,210] Trial 1025 finished with value: 0.5243343000263644 and parameters: {'alpha': 0.7744120330597819}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:35,774] Trial 1026 finished with value: 0.526127076192987 and parameters: {'alpha': 0.42440650580592904}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:36,414] Trial 1027 finished with value: 0.5223306090166095 and parameters: {'alpha': 1.1512356127625931}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:37,016] Trial 1028 finished with value: 0.5242815713155814 and parameters: {'alpha': 0.7414316981081057}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:37,580] Trial 1029 finished with value: 0.5249143158449776 and parameters: {'alpha': 0.8499669152126113}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:38,238] Trial 1030 finished with value: 0.5250197732665437 and parameters: {'alpha': 0.892314564264093}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:38,809] Trial 1031 finished with value: 0.5248088584234115 and parameters: {'alpha': 0.4559689170602631}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:39,453] Trial 1032 finished with value: 0.5237542842077512 and parameters: {'alpha': 0.6191228921319704}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:40,156] Trial 1033 finished with value: 0.523754284207751 and parameters: {'alpha': 0.5709158416371035}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:40,715] Trial 1034 finished with value: 0.5243870287371474 and parameters: {'alpha': 0.7753672234822238}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:41,298] Trial 1035 finished with value: 0.5239124703401002 and parameters: {'alpha': 0.4690440138063517}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:41,888] Trial 1036 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.40207938048746134}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:42,440] Trial 1037 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.4225562079239516}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:43,018] Trial 1038 finished with value: 0.5233324545214869 and parameters: {'alpha': 1.0380746620168257}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:43,676] Trial 1039 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.4601088118373299}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:44,356] Trial 1040 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.746307316553081}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:44,907] Trial 1041 finished with value: 0.5247561297126285 and parameters: {'alpha': 0.7903450888319195}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:45,588] Trial 1042 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.46371644718789723}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:46,155] Trial 1043 finished with value: 0.5228051674136568 and parameters: {'alpha': 0.6348277911429966}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:46,715] Trial 1044 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.41773209094758695}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:47,276] Trial 1045 finished with value: 0.5239651990508832 and parameters: {'alpha': 0.5673075263284258}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:47,879] Trial 1046 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.5154994419514964}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:48,546] Trial 1047 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.41259714457623425}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:49,129] Trial 1048 finished with value: 0.5245452148694965 and parameters: {'alpha': 0.7781295260195927}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:49,768] Trial 1049 finished with value: 0.5222251515950436 and parameters: {'alpha': 1.1665506039072424}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:50,310] Trial 1050 finished with value: 0.5246506722910625 and parameters: {'alpha': 0.8195389203898524}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:50,897] Trial 1051 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.4664305952111274}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:51,443] Trial 1052 finished with value: 0.5226469812813076 and parameters: {'alpha': 0.6362457001978461}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:52,130] Trial 1053 finished with value: 0.5247034010018454 and parameters: {'alpha': 0.9256235133079201}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:52,685] Trial 1054 finished with value: 0.5237015554969682 and parameters: {'alpha': 0.5148818851816979}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:53,271] Trial 1055 finished with value: 0.5232269970999209 and parameters: {'alpha': 0.4010530542943584}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:53,808] Trial 1056 finished with value: 0.5239651990508831 and parameters: {'alpha': 1.467339229624872}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:54,472] Trial 1057 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.5254374142089835}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:55,054] Trial 1058 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.37415682304285514}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:55,602] Trial 1059 finished with value: 0.5262325336145531 and parameters: {'alpha': 0.4196317395837185}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:56,261] Trial 1060 finished with value: 0.5233324545214869 and parameters: {'alpha': 0.7077532054299879}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:56,822] Trial 1061 finished with value: 0.5238597416293173 and parameters: {'alpha': 0.4701870202644526}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:57,360] Trial 1062 finished with value: 0.5245979435802794 and parameters: {'alpha': 0.974766319460778}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:57,974] Trial 1063 finished with value: 0.5224887951489585 and parameters: {'alpha': 0.6783822085981602}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:58,640] Trial 1064 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.4653521559474837}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:59,206] Trial 1065 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.42779545442340056}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:05:59,884] Trial 1066 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.557789983960234}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:00,428] Trial 1067 finished with value: 0.5222251515950436 and parameters: {'alpha': 0.6494726553946527}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:01,143] Trial 1068 finished with value: 0.5250725019773267 and parameters: {'alpha': 0.8768824086860276}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:01,809] Trial 1069 finished with value: 0.526127076192987 and parameters: {'alpha': 0.42427560281085025}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:02,362] Trial 1070 finished with value: 0.5222251515950436 and parameters: {'alpha': 1.1659528402955293}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:02,928] Trial 1071 finished with value: 0.5234906406538361 and parameters: {'alpha': 1.6954099981987496}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:03,468] Trial 1072 finished with value: 0.5220669654626945 and parameters: {'alpha': 0.6672116907663447}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:04,057] Trial 1073 finished with value: 0.5265489058792512 and parameters: {'alpha': 0.4100189463017228}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:04,622] Trial 1074 finished with value: 0.5250197732665436 and parameters: {'alpha': 0.4523725942078486}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:05,301] Trial 1075 finished with value: 0.5249143158449776 and parameters: {'alpha': 0.8653915738759906}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:05,995] Trial 1076 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.5882814747277632}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:06,574] Trial 1077 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.42697832364908483}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:07,134] Trial 1078 finished with value: 0.5248088584234115 and parameters: {'alpha': 1.0138926209561423}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:07,801] Trial 1079 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.692306849437801}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:08,376] Trial 1080 finished with value: 0.5244397574479304 and parameters: {'alpha': 0.4345573032755487}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:08,947] Trial 1081 finished with value: 0.5248088584234114 and parameters: {'alpha': 0.44723438679626454}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:09,613] Trial 1082 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.5381510449786802}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:10,196] Trial 1083 finished with value: 0.5241761138940152 and parameters: {'alpha': 0.4389238447575923}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:10,859] Trial 1084 finished with value: 0.5249670445557605 and parameters: {'alpha': 0.8474981913347154}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:11,391] Trial 1085 finished with value: 0.5220669654626944 and parameters: {'alpha': 0.6626182293108855}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:12,105] Trial 1086 finished with value: 0.5242815713155814 and parameters: {'alpha': 0.6018413562141868}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:12,773] Trial 1087 finished with value: 0.5240179277616661 and parameters: {'alpha': 0.4617939760937223}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:13,327] Trial 1088 finished with value: 0.5241233851832322 and parameters: {'alpha': 0.3895872012399303}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:13,876] Trial 1089 finished with value: 0.5231215396783548 and parameters: {'alpha': 0.6981002289607219}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:14,417] Trial 1090 finished with value: 0.5247034010018454 and parameters: {'alpha': 1.277985879915224}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:15,111] Trial 1091 finished with value: 0.526232533614553 and parameters: {'alpha': 0.41516316016524707}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:15,682] Trial 1092 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.5624754890483656}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:16,324] Trial 1093 finished with value: 0.5253888742420247 and parameters: {'alpha': 0.8854736560091424}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:16,902] Trial 1094 finished with value: 0.523332454521487 and parameters: {'alpha': 0.3678410104841534}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:17,460] Trial 1095 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.417966275412176}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:18,026] Trial 1096 finished with value: 0.5235960980754021 and parameters: {'alpha': 0.6162483401490944}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:18,595] Trial 1097 finished with value: 0.523437911943053 and parameters: {'alpha': 0.3995922666623258}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:19,161] Trial 1098 finished with value: 0.5245979435802794 and parameters: {'alpha': 0.8143824204599897}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:19,724] Trial 1099 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.40231788816599845}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:20,278] Trial 1100 finished with value: 0.5240706564724492 and parameters: {'alpha': 0.5310875279386374}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:20,825] Trial 1101 finished with value: 0.5236488267861852 and parameters: {'alpha': 1.1953125785645957}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:21,382] Trial 1102 finished with value: 0.5249670445557606 and parameters: {'alpha': 0.4485849687021593}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:22,043] Trial 1103 finished with value: 0.5235960980754021 and parameters: {'alpha': 0.7169628686378199}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:22,602] Trial 1104 finished with value: 0.52338518323227 and parameters: {'alpha': 0.3727224901412809}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:23,257] Trial 1105 finished with value: 0.5225415238597416 and parameters: {'alpha': 0.6370202768338676}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:23,922] Trial 1106 finished with value: 0.523437911943053 and parameters: {'alpha': 0.4847137931872864}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:24,468] Trial 1107 finished with value: 0.5247034010018455 and parameters: {'alpha': 0.9930832875255422}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:25,074] Trial 1108 finished with value: 0.523437911943053 and parameters: {'alpha': 0.337498160839081}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:25,626] Trial 1109 finished with value: 0.5264961771684682 and parameters: {'alpha': 0.4089255292777474}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:26,317] Trial 1110 finished with value: 0.5237015554969682 and parameters: {'alpha': 0.357791870768672}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:26,898] Trial 1111 finished with value: 0.523754284207751 and parameters: {'alpha': 0.571433946796037}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:27,568] Trial 1112 finished with value: 0.5231742683891378 and parameters: {'alpha': 0.34630987360709026}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:28,249] Trial 1113 finished with value: 0.5240706564724492 and parameters: {'alpha': 0.5642035017515524}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:28,941] Trial 1114 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.3771696193240362}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:29,489] Trial 1115 finished with value: 0.5250725019773266 and parameters: {'alpha': 0.871482807468838}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:30,179] Trial 1116 finished with value: 0.5241233851832323 and parameters: {'alpha': 0.5274302970702216}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:30,745] Trial 1117 finished with value: 0.5231215396783548 and parameters: {'alpha': 0.37069317927633344}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:31,319] Trial 1118 finished with value: 0.52338518323227 and parameters: {'alpha': 0.37315607555419184}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:31,866] Trial 1119 finished with value: 0.5212233060901661 and parameters: {'alpha': 2.149156020656239}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:32,413] Trial 1120 finished with value: 0.5245452148694965 and parameters: {'alpha': 0.7831186894230268}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:33,001] Trial 1121 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.5607867455714806}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:33,558] Trial 1122 finished with value: 0.5232269970999209 and parameters: {'alpha': 0.34653748763874315}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:34,232] Trial 1123 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.465203749396808}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:34,793] Trial 1124 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.735441814298505}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:35,372] Trial 1125 finished with value: 0.5233324545214869 and parameters: {'alpha': 0.35544742532740686}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:35,933] Trial 1126 finished with value: 0.5244924861587135 and parameters: {'alpha': 1.378615071849013}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:36,601] Trial 1127 finished with value: 0.5240179277616661 and parameters: {'alpha': 0.5351170712121024}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:37,188] Trial 1128 finished with value: 0.5237015554969682 and parameters: {'alpha': 0.3588176989581646}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:37,786] Trial 1129 finished with value: 0.5233851832322699 and parameters: {'alpha': 0.4875000668387113}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:38,348] Trial 1130 finished with value: 0.523596098075402 and parameters: {'alpha': 0.333908858072386}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:39,002] Trial 1131 finished with value: 0.5225942525705246 and parameters: {'alpha': 0.6829130092550753}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:39,687] Trial 1132 finished with value: 0.5263379910361192 and parameters: {'alpha': 0.32179795537790057}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:40,379] Trial 1133 finished with value: 0.5249143158449776 and parameters: {'alpha': 0.44971820953314195}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:41,077] Trial 1134 finished with value: 0.5232269970999209 and parameters: {'alpha': 0.3458694060723902}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:41,619] Trial 1135 finished with value: 0.523437911943053 and parameters: {'alpha': 1.0424565403640855}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:42,180] Trial 1136 finished with value: 0.523596098075402 and parameters: {'alpha': 0.49957419198292213}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:42,739] Trial 1137 finished with value: 0.5222251515950436 and parameters: {'alpha': 0.6590807436739987}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:43,404] Trial 1138 finished with value: 0.523596098075402 and parameters: {'alpha': 0.33376360962363044}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:44,105] Trial 1139 finished with value: 0.5263379910361191 and parameters: {'alpha': 0.4227708977709603}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:44,654] Trial 1140 finished with value: 0.5233324545214869 and parameters: {'alpha': 0.7093803070684465}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:45,240] Trial 1141 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.5167083340482198}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:45,802] Trial 1142 finished with value: 0.5233851832322699 and parameters: {'alpha': 0.47697426811466304}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:46,365] Trial 1143 finished with value: 0.5253361455312417 and parameters: {'alpha': 0.8849855071276216}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:47,019] Trial 1144 finished with value: 0.5237015554969681 and parameters: {'alpha': 0.6108661377937181}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:47,586] Trial 1145 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.3932746929663349}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:48,163] Trial 1146 finished with value: 0.5231742683891378 and parameters: {'alpha': 0.34240655294755545}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:48,733] Trial 1147 finished with value: 0.5233324545214869 and parameters: {'alpha': 1.038146562107579}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:49,305] Trial 1148 finished with value: 0.5240179277616662 and parameters: {'alpha': 0.5810782087480016}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:49,983] Trial 1149 finished with value: 0.5241233851832322 and parameters: {'alpha': 0.4315146298522191}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:50,690] Trial 1150 finished with value: 0.5241233851832322 and parameters: {'alpha': 0.3263803299258811}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:51,356] Trial 1151 finished with value: 0.5244397574479305 and parameters: {'alpha': 0.7570357672021192}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:52,010] Trial 1152 finished with value: 0.523543369364619 and parameters: {'alpha': 1.6481049544995379}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:52,553] Trial 1153 finished with value: 0.5247561297126285 and parameters: {'alpha': 0.4456011741618925}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:53,259] Trial 1154 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.33935111547102637}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:53,893] Trial 1155 finished with value: 0.5242815713155814 and parameters: {'alpha': 0.6066256670039086}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:54,466] Trial 1156 finished with value: 0.5264434484576851 and parameters: {'alpha': 0.32336359287992594}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:55,160] Trial 1157 finished with value: 0.5235960980754021 and parameters: {'alpha': 0.47853620300864214}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:55,735] Trial 1158 finished with value: 0.5242815713155813 and parameters: {'alpha': 0.32830712139086504}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:56,271] Trial 1159 finished with value: 0.5219615080411284 and parameters: {'alpha': 3.192651407586269}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:56,842] Trial 1160 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.6896323245041036}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:57,395] Trial 1161 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.4047238204018528}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:58,099] Trial 1162 finished with value: 0.523596098075402 and parameters: {'alpha': 0.4790735951782737}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:58,648] Trial 1163 finished with value: 0.5251252306881096 and parameters: {'alpha': 0.8588884374600738}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:59,318] Trial 1164 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.5371716025910076}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:06:59,896] Trial 1165 finished with value: 0.5229633535460059 and parameters: {'alpha': 1.0987622746038161}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:00,594] Trial 1166 finished with value: 0.526285262325336 and parameters: {'alpha': 0.4116481095878021}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:01,253] Trial 1167 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.6268261036089732}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:01,918] Trial 1168 finished with value: 0.5244397574479304 and parameters: {'alpha': 0.4350909756933189}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:02,471] Trial 1169 finished with value: 0.5248615871341946 and parameters: {'alpha': 0.8964800739628734}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:03,088] Trial 1170 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.4183030343399221}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:03,637] Trial 1171 finished with value: 0.5221196941734775 and parameters: {'alpha': 0.6642440210503361}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:04,190] Trial 1172 finished with value: 0.5246506722910624 and parameters: {'alpha': 0.44286564461476324}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:04,739] Trial 1173 finished with value: 0.5222778803058266 and parameters: {'alpha': 0.6485167958233711}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:05,303] Trial 1174 finished with value: 0.526232533614553 and parameters: {'alpha': 0.42536312447626495}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:05,870] Trial 1175 finished with value: 0.5249143158449776 and parameters: {'alpha': 0.9022566728300155}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:06,443] Trial 1176 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.5008972032510133}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:07,176] Trial 1177 finished with value: 0.5262325336145531 and parameters: {'alpha': 0.4203619066168005}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:07,730] Trial 1178 finished with value: 0.5231215396783548 and parameters: {'alpha': 0.6946056077977811}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:08,292] Trial 1179 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.5431486781024938}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:08,844] Trial 1180 finished with value: 0.5237542842077512 and parameters: {'alpha': 1.17609837785835}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:09,401] Trial 1181 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.4381783255315054}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:10,116] Trial 1182 finished with value: 0.5251252306881096 and parameters: {'alpha': 0.8590824171185169}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:10,777] Trial 1183 finished with value: 0.5242815713155814 and parameters: {'alpha': 0.6071158883805604}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:11,336] Trial 1184 finished with value: 0.5265489058792513 and parameters: {'alpha': 0.4080715717164548}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:12,009] Trial 1185 finished with value: 0.5241761138940152 and parameters: {'alpha': 0.4392146371131766}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:12,653] Trial 1186 finished with value: 0.5242815713155814 and parameters: {'alpha': 0.7413548228198674}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:13,320] Trial 1187 finished with value: 0.5263907197469021 and parameters: {'alpha': 0.4131773206583057}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:13,917] Trial 1188 finished with value: 0.5241761138940153 and parameters: {'alpha': 0.5963531697176098}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:14,497] Trial 1189 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.3713654463506866}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:15,154] Trial 1190 finished with value: 0.5246506722910624 and parameters: {'alpha': 1.3728998850619354}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:15,705] Trial 1191 finished with value: 0.5264434484576853 and parameters: {'alpha': 0.4277635851159667}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:16,279] Trial 1192 finished with value: 0.5240706564724492 and parameters: {'alpha': 0.5501314595346792}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:16,832] Trial 1193 finished with value: 0.5248615871341945 and parameters: {'alpha': 0.9039113271485236}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:17,500] Trial 1194 finished with value: 0.5237015554969682 and parameters: {'alpha': 0.3759196313288658}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:18,065] Trial 1195 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.5846423676625363}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:18,638] Trial 1196 finished with value: 0.5232269970999209 and parameters: {'alpha': 0.34608813954311257}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:19,302] Trial 1197 finished with value: 0.5245452148694965 and parameters: {'alpha': 0.7850465690454994}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:19,870] Trial 1198 finished with value: 0.5240706564724492 and parameters: {'alpha': 0.5301533368885079}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:20,425] Trial 1199 finished with value: 0.5265489058792513 and parameters: {'alpha': 0.40568465114907665}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:21,063] Trial 1200 finished with value: 0.52338518323227 and parameters: {'alpha': 0.3533391396475936}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:21,611] Trial 1201 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.721851934901016}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:22,204] Trial 1202 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.532937360173247}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:22,724] Trial 1203 finished with value: 0.5221724228842606 and parameters: {'alpha': 1.1590974189302121}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:23,284] Trial 1204 finished with value: 0.5234906406538361 and parameters: {'alpha': 0.3608847377613785}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:23,942] Trial 1205 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.5061444875172849}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:24,540] Trial 1206 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.32241924485536994}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:25,268] Trial 1207 finished with value: 0.5263379910361191 and parameters: {'alpha': 0.31934175980968915}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:25,953] Trial 1208 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.32138831089233577}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:26,525] Trial 1209 finished with value: 0.5264961771684682 and parameters: {'alpha': 0.318490601732629}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:27,099] Trial 1210 finished with value: 0.5268125494331664 and parameters: {'alpha': 0.3097193267519255}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:27,684] Trial 1211 finished with value: 0.5266543633008174 and parameters: {'alpha': 0.3028134807378568}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:28,391] Trial 1212 finished with value: 0.5266543633008173 and parameters: {'alpha': 0.3076199894067731}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:29,087] Trial 1213 finished with value: 0.5267070920116004 and parameters: {'alpha': 0.3100008200784123}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:29,674] Trial 1214 finished with value: 0.5265489058792513 and parameters: {'alpha': 0.29784800577649395}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:30,352] Trial 1215 finished with value: 0.5239651990508831 and parameters: {'alpha': 0.32983983587368965}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:30,952] Trial 1216 finished with value: 0.5265489058792513 and parameters: {'alpha': 0.3020035291294844}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:31,529] Trial 1217 finished with value: 0.5267070920116004 and parameters: {'alpha': 0.3050489134661576}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:32,241] Trial 1218 finished with value: 0.528499868178223 and parameters: {'alpha': 0.2742840217113473}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:32,827] Trial 1219 finished with value: 0.5264434484576853 and parameters: {'alpha': 0.29582179755872867}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:33,393] Trial 1220 finished with value: 0.5267598207223834 and parameters: {'alpha': 0.2999518958158964}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:34,003] Trial 1221 finished with value: 0.52844713946744 and parameters: {'alpha': 0.28887438111381686}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:34,680] Trial 1222 finished with value: 0.5267598207223834 and parameters: {'alpha': 0.2995002257704753}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:35,406] Trial 1223 finished with value: 0.528605325599789 and parameters: {'alpha': 0.27618772318282514}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:36,119] Trial 1224 finished with value: 0.52844713946744 and parameters: {'alpha': 0.2887417554914705}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:36,688] Trial 1225 finished with value: 0.528341682045874 and parameters: {'alpha': 0.28857776999837925}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:37,393] Trial 1226 finished with value: 0.528499868178223 and parameters: {'alpha': 0.2835055379870281}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:38,023] Trial 1227 finished with value: 0.528605325599789 and parameters: {'alpha': 0.2777250083209915}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:38,619] Trial 1228 finished with value: 0.528605325599789 and parameters: {'alpha': 0.29069339875780004}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:39,216] Trial 1229 finished with value: 0.528394410756657 and parameters: {'alpha': 0.2867962450947696}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:39,831] Trial 1230 finished with value: 0.5263379910361191 and parameters: {'alpha': 0.2490199420975311}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:40,530] Trial 1231 finished with value: 0.528499868178223 and parameters: {'alpha': 0.28342563346452937}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:41,224] Trial 1232 finished with value: 0.528499868178223 and parameters: {'alpha': 0.28337214524594073}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:41,818] Trial 1233 finished with value: 0.5286053255997891 and parameters: {'alpha': 0.2797936145314157}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:42,400] Trial 1234 finished with value: 0.528552596889006 and parameters: {'alpha': 0.28155964140292794}. Best is trial 1008 with value: 0.5288689691537043.
# [I 2021-09-16 18:07:43,008] Trial 1235 finished with value: 0.5289744265752703 and parameters: {'alpha': 0.2679661682744148}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:43,688] Trial 1236 finished with value: 0.5286053255997891 and parameters: {'alpha': 0.28134173170825527}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:44,395] Trial 1237 finished with value: 0.528552596889006 and parameters: {'alpha': 0.2774259425716537}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:45,003] Trial 1238 finished with value: 0.5287107830213551 and parameters: {'alpha': 0.2768270075350585}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:45,907] Trial 1239 finished with value: 0.5213814922225152 and parameters: {'alpha': 0.003604719602288524}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:46,493] Trial 1240 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.26300970964422027}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:47,201] Trial 1241 finished with value: 0.5287107830213551 and parameters: {'alpha': 0.2788746729638962}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:47,775] Trial 1242 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.2915131901030615}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:48,382] Trial 1243 finished with value: 0.5285525968890061 and parameters: {'alpha': 0.2736429160226415}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:49,022] Trial 1244 finished with value: 0.5285525968890061 and parameters: {'alpha': 0.2720418752052153}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:49,717] Trial 1245 finished with value: 0.5289744265752703 and parameters: {'alpha': 0.26693702453996865}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:50,317] Trial 1246 finished with value: 0.5288689691537043 and parameters: {'alpha': 0.26725829379797383}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:50,895] Trial 1247 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.25986765978298537}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:51,486] Trial 1248 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.25775625663746515}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:52,205] Trial 1249 finished with value: 0.5266016345900343 and parameters: {'alpha': 0.2643105983175504}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:52,874] Trial 1250 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.25746019859177993}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:53,467] Trial 1251 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.2601786498729964}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:54,077] Trial 1252 finished with value: 0.5286053255997891 and parameters: {'alpha': 0.2716863268322938}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:54,662] Trial 1253 finished with value: 0.5285525968890061 and parameters: {'alpha': 0.27204834428821184}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:55,258] Trial 1254 finished with value: 0.5266016345900343 and parameters: {'alpha': 0.2644080515379975}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:55,856] Trial 1255 finished with value: 0.5266016345900343 and parameters: {'alpha': 0.26439864508198796}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:56,445] Trial 1256 finished with value: 0.5276562088056947 and parameters: {'alpha': 0.26495537835339406}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:57,217] Trial 1257 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.2544317035828349}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:58,002] Trial 1258 finished with value: 0.5000263643553915 and parameters: {'alpha': 37.865351937163204}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:58,593] Trial 1259 finished with value: 0.526127076192987 and parameters: {'alpha': 0.24176463238501714}. Best is trial 1235 with value: 0.5289744265752703.
# [I 2021-09-16 18:07:59,178] Trial 1260 finished with value: 0.5290271552860533 and parameters: {'alpha': 0.26825005402846946}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:07:59,875] Trial 1261 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.2507717876884902}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:00,476] Trial 1262 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.262858464575295}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:01,126] Trial 1263 finished with value: 0.5262325336145531 and parameters: {'alpha': 0.26029334482399297}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:02,010] Trial 1264 finished with value: 0.5181650408647508 and parameters: {'alpha': 0.014320107384856685}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:03,464] Trial 1265 finished with value: 0.5098339045610335 and parameters: {'alpha': 0.00048165917179958286}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:04,139] Trial 1266 finished with value: 0.5264961771684682 and parameters: {'alpha': 0.2513683503098588}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:04,849] Trial 1267 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.25242901483095387}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:05,429] Trial 1268 finished with value: 0.5286053255997891 and parameters: {'alpha': 0.272154607952262}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:08:06,119] Trial 1269 finished with value: 0.5263379910361191 and parameters: {'alpha': 0.2535128285517071}. Best is trial 1260 with value: 0.5290271552860533.
# ...
# [I 2021-09-16 18:09:40,651] Trial 1410 finished with value: 0.5239651990508831 and parameters: {'alpha': 0.531964496955827}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:41,248] Trial 1411 finished with value: 0.5247034010018454 and parameters: {'alpha': 0.19195000044114396}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:41,967] Trial 1412 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.343125616538389}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:42,559] Trial 1413 finished with value: 0.5266016345900343 and parameters: {'alpha': 0.26433962017092094}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:43,256] Trial 1414 finished with value: 0.5242815713155813 and parameters: {'alpha': 0.18336157723543575}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:43,942] Trial 1415 finished with value: 0.5232797258107039 and parameters: {'alpha': 0.4007960163164955}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:44,533] Trial 1416 finished with value: 0.5286053255997891 and parameters: {'alpha': 0.27226487838188407}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:45,148] Trial 1417 finished with value: 0.5265489058792513 and parameters: {'alpha': 0.2508500667396223}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:45,811] Trial 1418 finished with value: 0.5240706564724492 and parameters: {'alpha': 0.5303017142717763}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:46,508] Trial 1419 finished with value: 0.5248088584234115 and parameters: {'alpha': 0.17922339348020735}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:47,109] Trial 1420 finished with value: 0.5236488267861851 and parameters: {'alpha': 0.34946479499119193}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:47,692] Trial 1421 finished with value: 0.5263379910361191 and parameters: {'alpha': 0.2528322419519299}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:48,398] Trial 1422 finished with value: 0.5247561297126285 and parameters: {'alpha': 0.18774819284084596}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:49,159] Trial 1423 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.37029768638913246}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:49,825] Trial 1424 finished with value: 0.5243343000263643 and parameters: {'alpha': 0.5203832332061149}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:50,506] Trial 1425 finished with value: 0.5236488267861851 and parameters: {'alpha': 0.3328340821858548}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:51,112] Trial 1426 finished with value: 0.5250725019773267 and parameters: {'alpha': 0.17748322139156905}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:51,702] Trial 1427 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.2598091167201773}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:52,306] Trial 1428 finished with value: 0.52617980490377 and parameters: {'alpha': 0.2419335587533443}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:52,894] Trial 1429 finished with value: 0.5266016345900342 and parameters: {'alpha': 0.4097705313796465}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:53,594] Trial 1430 finished with value: 0.5137358291589771 and parameters: {'alpha': 0.01974672609497839}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:54,196] Trial 1431 finished with value: 0.5254416029528077 and parameters: {'alpha': 0.17309254662107995}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:54,858] Trial 1432 finished with value: 0.5239651990508832 and parameters: {'alpha': 0.518669637183906}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:55,537] Trial 1433 finished with value: 0.526232533614553 and parameters: {'alpha': 0.3242232957964832}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:56,235] Trial 1434 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.2460953688426562}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:56,806] Trial 1435 finished with value: 0.5239651990508831 and parameters: {'alpha': 0.3903635523445419}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:57,411] Trial 1436 finished with value: 0.5253361455312417 and parameters: {'alpha': 0.17408136813935543}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:58,039] Trial 1437 finished with value: 0.5264961771684683 and parameters: {'alpha': 0.2629715461908048}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:58,598] Trial 1438 finished with value: 0.5240179277616662 and parameters: {'alpha': 0.5188228460969776}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:59,205] Trial 1439 finished with value: 0.5249143158449776 and parameters: {'alpha': 0.18613891893343945}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:09:59,807] Trial 1440 finished with value: 0.5263907197469022 and parameters: {'alpha': 0.3158598083146741}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:00,516] Trial 1441 finished with value: 0.5254943316635908 and parameters: {'alpha': 0.21256689700300302}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:01,128] Trial 1442 finished with value: 0.523437911943053 and parameters: {'alpha': 0.4035986662945242}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:01,658] Trial 1443 finished with value: 0.520748747693119 and parameters: {'alpha': 2.8096229973829385}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:02,354] Trial 1444 finished with value: 0.5263907197469021 and parameters: {'alpha': 0.32356056609517936}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:02,960] Trial 1445 finished with value: 0.526127076192987 and parameters: {'alpha': 0.23891370015136298}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:03,562] Trial 1446 finished with value: 0.5254943316635907 and parameters: {'alpha': 0.17251556645578725}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:04,253] Trial 1447 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.5574485647848937}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:04,949] Trial 1448 finished with value: 0.5263379910361192 and parameters: {'alpha': 0.26216490985563484}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:05,541] Trial 1449 finished with value: 0.5240179277616662 and parameters: {'alpha': 0.38977823927149235}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:06,154] Trial 1450 finished with value: 0.525916161349855 and parameters: {'alpha': 0.16808348058240205}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:06,747] Trial 1451 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.24653710051826533}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:07,427] Trial 1452 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.33108084130097026}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:08,042] Trial 1453 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.5845901318544579}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:08,600] Trial 1454 finished with value: 0.5238070129185342 and parameters: {'alpha': 0.4705938043631577}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:09,202] Trial 1455 finished with value: 0.5268125494331664 and parameters: {'alpha': 0.3098494129061039}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:09,816] Trial 1456 finished with value: 0.5248615871341946 and parameters: {'alpha': 0.18451513433662767}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:10,383] Trial 1457 finished with value: 0.5238597416293171 and parameters: {'alpha': 0.3909559664489788}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:11,007] Trial 1458 finished with value: 0.525968890060638 and parameters: {'alpha': 0.24506691420605028}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:11,583] Trial 1459 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.6022659782306423}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:12,193] Trial 1460 finished with value: 0.523754284207751 and parameters: {'alpha': 0.3321296924956868}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:12,877] Trial 1461 finished with value: 0.5000263643553915 and parameters: {'alpha': 21.14412532658833}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:13,582] Trial 1462 finished with value: 0.5252306881096758 and parameters: {'alpha': 0.21057254130329645}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:14,178] Trial 1463 finished with value: 0.5254416029528077 and parameters: {'alpha': 0.17311075264304582}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:14,744] Trial 1464 finished with value: 0.526127076192987 and parameters: {'alpha': 0.4239869118512066}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:15,387] Trial 1465 finished with value: 0.5263379910361192 and parameters: {'alpha': 0.25194277233327905}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:18,122] Trial 1466 finished with value: 0.503453730556288 and parameters: {'alpha': 1.0086780999816105e-05}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:18,705] Trial 1467 finished with value: 0.5264434484576853 and parameters: {'alpha': 0.31339157568624576}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:19,787] Trial 1468 finished with value: 0.518639599261798 and parameters: {'alpha': 0.0030019648556466575}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:20,392] Trial 1469 finished with value: 0.5256525177959399 and parameters: {'alpha': 0.1599449996079904}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:20,993] Trial 1470 finished with value: 0.5242288426047983 and parameters: {'alpha': 0.46114061865579303}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:21,600] Trial 1471 finished with value: 0.526127076192987 and parameters: {'alpha': 0.24550895463012248}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:22,212] Trial 1472 finished with value: 0.5258107039282891 and parameters: {'alpha': 0.21776645349225912}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:22,892] Trial 1473 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.577725329001922}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:23,617] Trial 1474 finished with value: 0.5242815713155813 and parameters: {'alpha': 0.3281101847730642}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:24,189] Trial 1475 finished with value: 0.5230688109675719 and parameters: {'alpha': 0.3703130102353362}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:24,808] Trial 1476 finished with value: 0.5252834168204588 and parameters: {'alpha': 0.17186575448109317}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:25,531] Trial 1477 finished with value: 0.5289216978644872 and parameters: {'alpha': 0.268298461767028}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:26,155] Trial 1478 finished with value: 0.5255470603743738 and parameters: {'alpha': 0.17021114122435183}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:26,769] Trial 1479 finished with value: 0.526127076192987 and parameters: {'alpha': 0.23607640018700046}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:27,366] Trial 1480 finished with value: 0.5248615871341945 and parameters: {'alpha': 0.4444224130960455}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:27,987] Trial 1481 finished with value: 0.5267070920116004 and parameters: {'alpha': 0.31077431416471896}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:28,631] Trial 1482 finished with value: 0.5239651990508831 and parameters: {'alpha': 0.1538420182908925}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:29,277] Trial 1483 finished with value: 0.525757975217506 and parameters: {'alpha': 0.23419717410268304}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:29,880] Trial 1484 finished with value: 0.5220669654626944 and parameters: {'alpha': 0.669077906481824}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:30,524] Trial 1485 finished with value: 0.5000790930661746 and parameters: {'alpha': 8.75565637696934}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:31,124] Trial 1486 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.38281562573207834}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:31,721] Trial 1487 finished with value: 0.5245979435802794 and parameters: {'alpha': 0.2018834064575946}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:32,416] Trial 1488 finished with value: 0.5287107830213551 and parameters: {'alpha': 0.2765386308047825}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:33,033] Trial 1489 finished with value: 0.5239124703401001 and parameters: {'alpha': 0.5658600708481145}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:33,653] Trial 1490 finished with value: 0.5250725019773266 and parameters: {'alpha': 0.1755904627676619}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:34,594] Trial 1491 finished with value: 0.5252306881096758 and parameters: {'alpha': 0.00514817183998027}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:35,196] Trial 1492 finished with value: 0.528552596889006 and parameters: {'alpha': 0.27972595861887467}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:35,766] Trial 1493 finished with value: 0.5241233851832323 and parameters: {'alpha': 0.4297863002105253}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:36,471] Trial 1494 finished with value: 0.5250725019773266 and parameters: {'alpha': 0.21022027979789715}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:37,092] Trial 1495 finished with value: 0.5241233851832322 and parameters: {'alpha': 0.15246083596459564}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:37,680] Trial 1496 finished with value: 0.5264434484576852 and parameters: {'alpha': 0.32298323273507523}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:38,264] Trial 1497 finished with value: 0.5247561297126285 and parameters: {'alpha': 0.4449199469372914}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:38,974] Trial 1498 finished with value: 0.5262852623253361 and parameters: {'alpha': 0.24313003940774153}. Best is trial 1260 with value: 0.5290271552860533.
# [I 2021-09-16 18:10:39,584] Trial 1499 finished with value: 0.5255997890851568 and parameters: {'alpha': 0.16019898427481594}. Best is trial 1260 with value: 0.5290271552860533.

# %%
sgd_alpha = study_sgd.best_params['alpha']
print(sgd_alpha)
best_sgd = Pipeline(steps=[('scaler', StandardScaler()),
                ('sgd', SGDClassifier(alpha = sgd_alpha,
                                      loss='modified_huber',
                               max_iter=10000,
                                     random_state=23))])


print("best_sgd:", best_sgd)

best_sgd.fit(X_train, y_train)

print("train_score:", best_sgd.score(X_train, y_train))
print("test_score:", best_sgd.score(X_test, y_test))

view_model_coefs(best_sgd.named_steps['sgd'], X_train)
# Out:
# 0.26825005402846946
# best_sgd: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('sgd',
#                  SGDClassifier(alpha=0.26825005402846946, loss='modified_huber',
#                                max_iter=10000, random_state=23))])
# train_score: 0.5405298536971135
# test_score: 0.5107474568774878
#                 feature_name      coef
# 32        UAST_3PM_team_diff -0.023794
# 38             FG3A_opp_diff -0.023458
# 57           PTS_FB_opp_diff -0.023349
# 25      PTS_2PT_MR_team_diff -0.018935
# 48               PF_opp_diff -0.016722
# 5             FG2A_team_diff -0.016246
# 16             TOV_team_diff -0.013546
# 59        PTS_PAINT_opp_diff -0.012668
# 46              BLK_opp_diff -0.012318
# 79         TOV_PCT_team_diff -0.011154
# 60          AST_2PM_opp_diff -0.010449
# 65           ATS_record_diff -0.010060
# 30        UAST_2PM_team_diff -0.009242
# 19      PLUS_MINUS_team_diff -0.009202
# 44              AST_opp_diff -0.008791
# 4             FG2M_team_diff -0.008478
# 40              FTA_opp_diff -0.008407
# 58      PTS_OFF_TOV_opp_diff -0.008055
# 83              opp_rating_i -0.007681
# 78        AST_RATIO_opp_diff -0.006305
# 18             PTS_team_diff -0.006043
# 68         OREB_PCT_opp_diff -0.005812
# 9              FTA_team_diff -0.005592
# 72          REB_PCT_opp_diff -0.005568
# 23            POSS_team_diff -0.004941
# 1                 avg_spread -0.004777
# 10            OREB_team_diff -0.004751
# 55              PIE_opp_diff -0.004229
# 54             POSS_opp_diff -0.003726
# 75         EFG_PCT_team_diff -0.002672
# 41             OREB_opp_diff -0.002624
# 53     E_NET_RATING_opp_diff -0.002472
# 6             FG3M_team_diff -0.002122
# 70         DREB_PCT_opp_diff -0.002080
# 13             AST_team_diff -0.002078
# 3   points_covered_spread_by -0.002036
# 77       AST_RATIO_team_diff -0.001462
# 35             FG2M_opp_diff -0.000647
# 29         AST_2PM_team_diff  0.000378
# 2      avg_point_spread_diff  0.000783
# 33     team_covered_opp_diff  0.001157
# 47              TOV_opp_diff  0.001239
# 39              FTM_opp_diff  0.001477
# 43              REB_opp_diff  0.001519
# 82             team_rating_i  0.001821
# 67        OREB_PCT_team_diff  0.002080
# 0                     avg_ml  0.002115
# 64            WL_record_diff  0.002224
# 22    E_NET_RATING_team_diff  0.002472
# 15             BLK_team_diff  0.002655
# 14             STL_team_diff  0.002902
# 73          TS_PCT_team_diff  0.003040
# 80          TOV_PCT_opp_diff  0.003205
# 42             DREB_opp_diff  0.003505
# 66                 rest_diff  0.003583
# 49              PTS_opp_diff  0.004193
# 24             PIE_team_diff  0.004205
# 12             REB_team_diff  0.005324
# 71         REB_PCT_team_diff  0.005568
# 69        DREB_PCT_team_diff  0.005812
# 37             FG3M_opp_diff  0.006568
# 84              elo_MOV_pred  0.006997
# 81             team_elo_pred  0.007214
# 8              FTM_team_diff  0.007231
# 74           TS_PCT_opp_diff  0.007575
# 7             FG3A_team_diff  0.008513
# 28       PTS_PAINT_team_diff  0.008825
# 76          EFG_PCT_opp_diff  0.008858
# 21    E_DEF_RATING_team_diff  0.008894
# 51     E_OFF_RATING_opp_diff  0.008894
# 62          AST_3PM_opp_diff  0.008944
# 50       PLUS_MINUS_opp_diff  0.009202
# 11            DREB_team_diff  0.010472
# 61         UAST_2PM_opp_diff  0.010770
# 36             FG2A_opp_diff  0.011623
# 20    E_OFF_RATING_team_diff  0.011988
# 52     E_DEF_RATING_opp_diff  0.011988
# 31         AST_3PM_team_diff  0.012030
# 17              PF_team_diff  0.013587
# 56       PTS_2PT_MR_opp_diff  0.013902
# 63         UAST_3PM_opp_diff  0.015688
# 45              STL_opp_diff  0.022405
# 34           RECORD_opp_diff  0.023359
# 26          PTS_FB_team_diff  0.023597
# 85                    spread  0.032065
# 27     PTS_OFF_TOV_team_diff  0.035245

# %% [markdown]
# ### LGBClassifier

# %%
def objective(trial):    
    min_child_weight = trial.suggest_int('min_child_weight', 1, 16)
    subsample = trial.suggest_float('subsample', 0.6, 1)
    max_depth = trial.suggest_int('max_depth', 3, 20)
    reg_lambda = trial.suggest_float('reg_lambda', 0, 20)
    reg_alpha = trial.suggest_float('reg_alpha', 0, 5),
    num_leaves = trial.suggest_int('num_leaves', 2, 256)
    feature_fraction = trial.suggest_float('feature_fraction', 0.01, 1.0)
    learning_rate = trial.suggest_float('learning_rate', 1e-3, 1.0, log=True)
    
    classifier_obj = lgb.LGBMClassifier(feature_fraction=feature_fraction,
                                        max_depth=max_depth,
                                        min_child_weight=min_child_weight,
                                        num_leaves=num_leaves, 
                                        random_state=23,
                                        reg_alpha=reg_alpha, 
                                        reg_lambda=reg_lambda,
                                       learning_rate=learning_rate)
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_lgbc'
storage_name = "sqlite:///{}.db".format(study_name)

study_lgbc = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True)

study_lgbc.optimize(objective, n_trials=100)
# Out:
# [I 2021-09-16 18:10:40,312] Using an existing study with name 'study_lgbc' instead of creating a new one.
# [I 2021-09-16 18:10:42,971] Trial 1129 finished with value: 0.5171104666490904 and parameters: {'min_child_weight': 3, 'subsample': 0.9659340286614148, 'max_depth': 5, 'reg_lambda': 19.69624158294228, 'reg_alpha': 0.4735424468279292, 'num_leaves': 256, 'feature_fraction': 0.3018001016021523, 'learning_rate': 0.14379420064968998}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:44,503] Trial 1130 finished with value: 0.5170050092275245 and parameters: {'min_child_weight': 6, 'subsample': 0.869786834335615, 'max_depth': 3, 'reg_lambda': 18.871744133600803, 'reg_alpha': 3.309758338521661, 'num_leaves': 248, 'feature_fraction': 0.24471385362452425, 'learning_rate': 0.038041239643070233}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:46,651] Trial 1131 finished with value: 0.5150540469285525 and parameters: {'min_child_weight': 9, 'subsample': 0.6304069446818823, 'max_depth': 5, 'reg_lambda': 17.312799850996555, 'reg_alpha': 3.1212904667127908, 'num_leaves': 118, 'feature_fraction': 0.35763968695419573, 'learning_rate': 0.07831599715733206}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:51,102] Trial 1132 finished with value: 0.5136831004481941 and parameters: {'min_child_weight': 8, 'subsample': 0.6894924029161099, 'max_depth': 9, 'reg_lambda': 19.344299287250486, 'reg_alpha': 3.528540654143597, 'num_leaves': 121, 'feature_fraction': 0.44715968430496944, 'learning_rate': 0.0011449868759728556}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:52,904] Trial 1133 finished with value: 0.5177959398892698 and parameters: {'min_child_weight': 5, 'subsample': 0.7516294301497389, 'max_depth': 4, 'reg_lambda': 7.83850656623231, 'reg_alpha': 3.3892904391986503, 'num_leaves': 106, 'feature_fraction': 0.32829760568807237, 'learning_rate': 0.006930179936287462}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:54,727] Trial 1134 finished with value: 0.5176904824677037 and parameters: {'min_child_weight': 6, 'subsample': 0.7603230145240866, 'max_depth': 4, 'reg_lambda': 19.996422569918064, 'reg_alpha': 3.769928960143722, 'num_leaves': 152, 'feature_fraction': 0.29263856856877013, 'learning_rate': 0.030352103735290334}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:57,287] Trial 1135 finished with value: 0.5209596625362509 and parameters: {'min_child_weight': 7, 'subsample': 0.6715184047693284, 'max_depth': 6, 'reg_lambda': 18.155858794864475, 'reg_alpha': 1.5131625206039372, 'num_leaves': 56, 'feature_fraction': 0.3955465902654722, 'learning_rate': 0.06148411422622706}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:10:59,049] Trial 1136 finished with value: 0.5171631953598734 and parameters: {'min_child_weight': 12, 'subsample': 0.7345426566618051, 'max_depth': 5, 'reg_lambda': 18.77000881555222, 'reg_alpha': 3.5890247853423256, 'num_leaves': 169, 'feature_fraction': 0.2180187380617696, 'learning_rate': 0.012576388966085135}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:00,792] Trial 1137 finished with value: 0.5206432902715529 and parameters: {'min_child_weight': 8, 'subsample': 0.6385584259246544, 'max_depth': 4, 'reg_lambda': 16.83001565369051, 'reg_alpha': 3.452540134329049, 'num_leaves': 44, 'feature_fraction': 0.31279337582002315, 'learning_rate': 0.09373923838908625}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:02,339] Trial 1138 finished with value: 0.513313999472713 and parameters: {'min_child_weight': 7, 'subsample': 0.6008337279771081, 'max_depth': 3, 'reg_lambda': 17.872106796936922, 'reg_alpha': 3.2878849867816755, 'num_leaves': 204, 'feature_fraction': 0.27518550206056985, 'learning_rate': 0.0015398669413889253}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:04,128] Trial 1139 finished with value: 0.5170577379383074 and parameters: {'min_child_weight': 6, 'subsample': 0.6476990291427753, 'max_depth': 4, 'reg_lambda': 19.38232388185958, 'reg_alpha': 3.6413449831978553, 'num_leaves': 144, 'feature_fraction': 0.37658405649090343, 'learning_rate': 0.3794592388812978}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:05,669] Trial 1140 finished with value: 0.5127339836540996 and parameters: {'min_child_weight': 5, 'subsample': 0.7097044029740328, 'max_depth': 3, 'reg_lambda': 18.506299352788478, 'reg_alpha': 3.202318850358008, 'num_leaves': 71, 'feature_fraction': 0.34002906462600296, 'learning_rate': 0.004114727036517035}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:07,512] Trial 1141 finished with value: 0.5133667281834959 and parameters: {'min_child_weight': 7, 'subsample': 0.774889675659975, 'max_depth': 5, 'reg_lambda': 19.01603447525217, 'reg_alpha': 3.3670731406351533, 'num_leaves': 97, 'feature_fraction': 0.2576751390822696, 'learning_rate': 0.6246408371244486}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:09,275] Trial 1142 finished with value: 0.5146322172422884 and parameters: {'min_child_weight': 4, 'subsample': 0.7001728195150858, 'max_depth': 4, 'reg_lambda': 18.286171994927955, 'reg_alpha': 3.492484410533678, 'num_leaves': 240, 'feature_fraction': 0.3139867863161813, 'learning_rate': 0.005515602073967202}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:11,060] Trial 1143 finished with value: 0.5148431320854205 and parameters: {'min_child_weight': 13, 'subsample': 0.8557150122782109, 'max_depth': 4, 'reg_lambda': 19.64550162030865, 'reg_alpha': 3.716991663160345, 'num_leaves': 123, 'feature_fraction': 0.358937619791629, 'learning_rate': 0.023538863656607182}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:13,355] Trial 1144 finished with value: 0.5164249934089111 and parameters: {'min_child_weight': 6, 'subsample': 0.7192452272819253, 'max_depth': 5, 'reg_lambda': 17.695289978976994, 'reg_alpha': 3.0666687420246146, 'num_leaves': 62, 'feature_fraction': 0.4086514300137739, 'learning_rate': 0.015737680432768852}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:15,025] Trial 1145 finished with value: 0.5127867123648826 and parameters: {'min_child_weight': 6, 'subsample': 0.9823799650755006, 'max_depth': 4, 'reg_lambda': 19.089228785900136, 'reg_alpha': 0.6928688022981534, 'num_leaves': 39, 'feature_fraction': 0.2862239218441343, 'learning_rate': 0.29033972714640327}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:17,333] Trial 1146 finished with value: 0.5106248352227788 and parameters: {'min_child_weight': 8, 'subsample': 0.6221913963579053, 'max_depth': 5, 'reg_lambda': 18.70154316506471, 'reg_alpha': 3.5191158994368874, 'num_leaves': 115, 'feature_fraction': 0.43384537111575316, 'learning_rate': 0.46424870149678743}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:22,061] Trial 1147 finished with value: 0.5172159240706564 and parameters: {'min_child_weight': 7, 'subsample': 0.659081672462698, 'max_depth': 15, 'reg_lambda': 19.423792334708974, 'reg_alpha': 3.3544263056695782, 'num_leaves': 159, 'feature_fraction': 0.3355148564909263, 'learning_rate': 0.0010287584293465332}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:23,659] Trial 1148 finished with value: 0.5166359082520432 and parameters: {'min_child_weight': 5, 'subsample': 0.673117078818855, 'max_depth': 3, 'reg_lambda': 18.139040241844977, 'reg_alpha': 3.229385135968607, 'num_leaves': 177, 'feature_fraction': 0.38189262295660215, 'learning_rate': 0.00284443026863421}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:25,382] Trial 1149 finished with value: 0.5216451357764302 and parameters: {'min_child_weight': 6, 'subsample': 0.6165851307436095, 'max_depth': 4, 'reg_lambda': 18.61941731032493, 'reg_alpha': 3.815868235059934, 'num_leaves': 224, 'feature_fraction': 0.29964690941252436, 'learning_rate': 0.15066205802935217}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:26,954] Trial 1150 finished with value: 0.5169522805167415 and parameters: {'min_child_weight': 7, 'subsample': 0.6826321943384668, 'max_depth': 4, 'reg_lambda': 19.03668796902296, 'reg_alpha': 3.6239665406431025, 'num_leaves': 88, 'feature_fraction': 0.236438952781394, 'learning_rate': 0.009780100685624092}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:28,496] Trial 1151 finished with value: 0.5130503559187979 and parameters: {'min_child_weight': 6, 'subsample': 0.7932090180023639, 'max_depth': 3, 'reg_lambda': 17.479596011411388, 'reg_alpha': 1.3972708072879017, 'num_leaves': 166, 'feature_fraction': 0.32421555186495976, 'learning_rate': 0.0017294092126381691}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:30,183] Trial 1152 finished with value: 0.515950435011864 and parameters: {'min_child_weight': 5, 'subsample': 0.6922614767998458, 'max_depth': 4, 'reg_lambda': 19.689242034266194, 'reg_alpha': 3.3785195752669193, 'num_leaves': 192, 'feature_fraction': 0.2729841399761084, 'learning_rate': 0.003362543998727765}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:32,200] Trial 1153 finished with value: 0.5080411283944108 and parameters: {'min_child_weight': 8, 'subsample': 0.9164114408035642, 'max_depth': 5, 'reg_lambda': 18.3809110923108, 'reg_alpha': 3.4574741137265455, 'num_leaves': 134, 'feature_fraction': 0.35007441717691845, 'learning_rate': 0.9883631175829403}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:34,081] Trial 1154 finished with value: 0.5170050092275245 and parameters: {'min_child_weight': 16, 'subsample': 0.6523836726250908, 'max_depth': 4, 'reg_lambda': 1.6228371939109252, 'reg_alpha': 3.5595837318014625, 'num_leaves': 83, 'feature_fraction': 0.4663951516539171, 'learning_rate': 0.11910048463545539}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:36,455] Trial 1155 finished with value: 0.5172686527814395 and parameters: {'min_child_weight': 7, 'subsample': 0.7406025330435294, 'max_depth': 6, 'reg_lambda': 19.163089980777574, 'reg_alpha': 3.2822877607401324, 'num_leaves': 218, 'feature_fraction': 0.3110092605324375, 'learning_rate': 0.18675350767475946}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:38,032] Trial 1156 finished with value: 0.5181123121539678 and parameters: {'min_child_weight': 6, 'subsample': 0.7669658902176396, 'max_depth': 3, 'reg_lambda': 17.92219718022399, 'reg_alpha': 3.694527975567175, 'num_leaves': 37, 'feature_fraction': 0.365119425634542, 'learning_rate': 0.07582068633425698}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:39,901] Trial 1157 finished with value: 0.5163722646981281 and parameters: {'min_child_weight': 9, 'subsample': 0.8321599480437204, 'max_depth': 5, 'reg_lambda': 18.65146891559689, 'reg_alpha': 0.15672087075006338, 'num_leaves': 181, 'feature_fraction': 0.289371058039539, 'learning_rate': 0.047641084621991105}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:41,797] Trial 1158 finished with value: 0.5163722646981281 and parameters: {'min_child_weight': 7, 'subsample': 0.634190040140434, 'max_depth': 4, 'reg_lambda': 19.405574092983816, 'reg_alpha': 3.1515447778609382, 'num_leaves': 146, 'feature_fraction': 0.3947544723152808, 'learning_rate': 0.0021224183630159923}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:43,609] Trial 1159 finished with value: 0.506090166095439 and parameters: {'min_child_weight': 8, 'subsample': 0.6636796567472831, 'max_depth': 5, 'reg_lambda': 18.907813076683492, 'reg_alpha': 2.9447338565595804, 'num_leaves': 208, 'feature_fraction': 0.26330935515108866, 'learning_rate': 0.7338299763196334}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:45,264] Trial 1160 finished with value: 0.513313999472713 and parameters: {'min_child_weight': 5, 'subsample': 0.6099933568289888, 'max_depth': 3, 'reg_lambda': 19.679564306140026, 'reg_alpha': 3.4124553746588444, 'num_leaves': 198, 'feature_fraction': 0.41738542871422707, 'learning_rate': 0.5366238709274527}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:47,056] Trial 1161 finished with value: 0.5167940943843923 and parameters: {'min_child_weight': 4, 'subsample': 0.9472952926319959, 'max_depth': 4, 'reg_lambda': 18.177976439566976, 'reg_alpha': 3.538119992442968, 'num_leaves': 244, 'feature_fraction': 0.33281534976466437, 'learning_rate': 0.027410003245190367}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:48,790] Trial 1162 finished with value: 0.51605589243343 and parameters: {'min_child_weight': 8, 'subsample': 0.8992105146547371, 'max_depth': 4, 'reg_lambda': 17.18691291564152, 'reg_alpha': 3.3109653820876788, 'num_leaves': 92, 'feature_fraction': 0.30181352388455457, 'learning_rate': 0.0013504044969622426}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:51,082] Trial 1163 finished with value: 0.518428684418666 and parameters: {'min_child_weight': 6, 'subsample': 0.8155538755858782, 'max_depth': 5, 'reg_lambda': 17.804416474902137, 'reg_alpha': 1.6216725106879375, 'num_leaves': 161, 'feature_fraction': 0.35249503924328107, 'learning_rate': 0.007332081879382193}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:53,441] Trial 1164 finished with value: 0.5143158449775903 and parameters: {'min_child_weight': 5, 'subsample': 0.991717226933806, 'max_depth': 6, 'reg_lambda': 5.613328764346978, 'reg_alpha': 0.01378893237078796, 'num_leaves': 215, 'feature_fraction': 0.24946472766274, 'learning_rate': 0.0062469358796304495}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:55,257] Trial 1165 finished with value: 0.515897706301081 and parameters: {'min_child_weight': 13, 'subsample': 0.643077210310737, 'max_depth': 4, 'reg_lambda': 19.221340576891933, 'reg_alpha': 3.4784503649450667, 'num_leaves': 252, 'feature_fraction': 0.3834348364841323, 'learning_rate': 0.0025303808829687103}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:57,762] Trial 1166 finished with value: 0.5172159240706564 and parameters: {'min_child_weight': 7, 'subsample': 0.7243874285686284, 'max_depth': 5, 'reg_lambda': 18.49634749286354, 'reg_alpha': 3.6206471075723763, 'num_leaves': 47, 'feature_fraction': 0.48636288016807044, 'learning_rate': 0.020716400254942494}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:11:59,408] Trial 1167 finished with value: 0.5170577379383074 and parameters: {'min_child_weight': 7, 'subsample': 0.7515007568044252, 'max_depth': 3, 'reg_lambda': 18.90069125889355, 'reg_alpha': 3.091714276604986, 'num_leaves': 113, 'feature_fraction': 0.2789214841307746, 'learning_rate': 0.00807462896119576}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:01,194] Trial 1168 finished with value: 0.5192196150804113 and parameters: {'min_child_weight': 6, 'subsample': 0.708893658319947, 'max_depth': 4, 'reg_lambda': 19.700215620099247, 'reg_alpha': 3.2025217613277337, 'num_leaves': 139, 'feature_fraction': 0.3222119608894377, 'learning_rate': 0.2709537568293891}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:03,353] Trial 1169 finished with value: 0.5166886369628262 and parameters: {'min_child_weight': 6, 'subsample': 0.7820605205276843, 'max_depth': 5, 'reg_lambda': 14.820610799744966, 'reg_alpha': 2.753860162179241, 'num_leaves': 184, 'feature_fraction': 0.3438307061537339, 'learning_rate': 0.013142719244464843}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:05,013] Trial 1170 finished with value: 0.51099393619826 and parameters: {'min_child_weight': 8, 'subsample': 0.8012184085471767, 'max_depth': 4, 'reg_lambda': 16.636050653684183, 'reg_alpha': 3.7754294525434817, 'num_leaves': 236, 'feature_fraction': 0.3013347689294617, 'learning_rate': 0.2392851913810481}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:06,625] Trial 1171 finished with value: 0.5138940152913262 and parameters: {'min_child_weight': 5, 'subsample': 0.8627370064305828, 'max_depth': 3, 'reg_lambda': 18.318364221498253, 'reg_alpha': 3.430126211151312, 'num_leaves': 230, 'feature_fraction': 0.36523821125557016, 'learning_rate': 0.0048398426306898515}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:08,559] Trial 1172 finished with value: 0.5212760348009491 and parameters: {'min_child_weight': 9, 'subsample': 0.6002323089227828, 'max_depth': 4, 'reg_lambda': 9.426384806461154, 'reg_alpha': 1.2684363899991404, 'num_leaves': 174, 'feature_fraction': 0.5106845296436242, 'learning_rate': 0.05504299751969409}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:10,799] Trial 1173 finished with value: 0.5161086211442131 and parameters: {'min_child_weight': 14, 'subsample': 0.9301062576705987, 'max_depth': 5, 'reg_lambda': 17.550267043678147, 'reg_alpha': 3.595037155523357, 'num_leaves': 226, 'feature_fraction': 0.45280297199369096, 'learning_rate': 0.3897891380755273}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:12,707] Trial 1174 finished with value: 0.5176377537569208 and parameters: {'min_child_weight': 7, 'subsample': 0.6263413450546325, 'max_depth': 4, 'reg_lambda': 19.34101878518417, 'reg_alpha': 4.0784476676882075, 'num_leaves': 101, 'feature_fraction': 0.40767943294855713, 'learning_rate': 0.09364673743805627}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:14,454] Trial 1175 finished with value: 0.5152649617716847 and parameters: {'min_child_weight': 6, 'subsample': 0.8435793640400959, 'max_depth': 4, 'reg_lambda': 18.86414150546306, 'reg_alpha': 2.4211665152413726, 'num_leaves': 104, 'feature_fraction': 0.32059725322568594, 'learning_rate': 0.004121799851769303}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:15,937] Trial 1176 finished with value: 0.5162140785657792 and parameters: {'min_child_weight': 4, 'subsample': 0.6952956668226202, 'max_depth': 3, 'reg_lambda': 18.00191893915535, 'reg_alpha': 3.324930262251081, 'num_leaves': 125, 'feature_fraction': 0.2814788984857213, 'learning_rate': 0.01637672815674414}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:18,092] Trial 1177 finished with value: 0.5194305299235433 and parameters: {'min_child_weight': 5, 'subsample': 0.8787332263843362, 'max_depth': 5, 'reg_lambda': 18.58600079017185, 'reg_alpha': 3.874839913651955, 'num_leaves': 63, 'feature_fraction': 0.33769926397240274, 'learning_rate': 0.04053737601866182}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:19,839] Trial 1178 finished with value: 0.5094120748747694 and parameters: {'min_child_weight': 7, 'subsample': 0.7163207393064043, 'max_depth': 4, 'reg_lambda': 19.946873948291667, 'reg_alpha': 3.4962860651291874, 'num_leaves': 134, 'feature_fraction': 0.26273077840727, 'learning_rate': 0.6565851684471182}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:22,295] Trial 1179 finished with value: 0.5176904824677038 and parameters: {'min_child_weight': 8, 'subsample': 0.6791514561562056, 'max_depth': 6, 'reg_lambda': 19.285850150777005, 'reg_alpha': 3.2577573457829456, 'num_leaves': 56, 'feature_fraction': 0.3033354168762442, 'learning_rate': 0.01156274294231933}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:24,156] Trial 1180 finished with value: 0.5199578170313736 and parameters: {'min_child_weight': 6, 'subsample': 0.6481988945813383, 'max_depth': 4, 'reg_lambda': 18.86642569423524, 'reg_alpha': 3.69995804613943, 'num_leaves': 210, 'feature_fraction': 0.4349015632843059, 'learning_rate': 0.12583097000807242}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:26,076] Trial 1181 finished with value: 0.5160558924334301 and parameters: {'min_child_weight': 7, 'subsample': 0.7342962400534063, 'max_depth': 5, 'reg_lambda': 19.62305348681323, 'reg_alpha': 3.4005290355724336, 'num_leaves': 69, 'feature_fraction': 0.22947928344258178, 'learning_rate': 0.03575192151669276}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:27,703] Trial 1182 finished with value: 0.5075665699973636 and parameters: {'min_child_weight': 6, 'subsample': 0.8217848438519526, 'max_depth': 3, 'reg_lambda': 6.6998735997347545, 'reg_alpha': 3.5370577825281564, 'num_leaves': 88, 'feature_fraction': 0.37655578724661587, 'learning_rate': 0.8703855625651978}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:29,445] Trial 1183 finished with value: 0.5142103875560242 and parameters: {'min_child_weight': 11, 'subsample': 0.6656099708984231, 'max_depth': 4, 'reg_lambda': 18.26989164642092, 'reg_alpha': 3.6307642565963647, 'num_leaves': 202, 'feature_fraction': 0.29011135465761684, 'learning_rate': 0.07068366991011042}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:31,505] Trial 1184 finished with value: 0.5192723437911944 and parameters: {'min_child_weight': 8, 'subsample': 0.6141728967402325, 'max_depth': 5, 'reg_lambda': 17.56496421713409, 'reg_alpha': 0.9843816118281621, 'num_leaves': 40, 'feature_fraction': 0.3203256658778435, 'learning_rate': 0.060003205612019564}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:33,291] Trial 1185 finished with value: 0.5213287635117322 and parameters: {'min_child_weight': 5, 'subsample': 0.9999350781356141, 'max_depth': 4, 'reg_lambda': 19.197623307191545, 'reg_alpha': 3.00612854941436, 'num_leaves': 149, 'feature_fraction': 0.39392839128664525, 'learning_rate': 0.16617466190034605}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:36,529] Trial 1186 finished with value: 0.5143685736883734 and parameters: {'min_child_weight': 13, 'subsample': 0.7557611129084377, 'max_depth': 19, 'reg_lambda': 10.685798857617666, 'reg_alpha': 3.176299803527578, 'num_leaves': 130, 'feature_fraction': 0.24993887098458295, 'learning_rate': 0.029869845299880016}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:40,470] Trial 1187 finished with value: 0.5134721856050619 and parameters: {'min_child_weight': 15, 'subsample': 0.6395065253718922, 'max_depth': 20, 'reg_lambda': 18.601180433385796, 'reg_alpha': 3.35706517392525, 'num_leaves': 180, 'feature_fraction': 0.3568758768551208, 'learning_rate': 0.21240113588499696}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:42,580] Trial 1188 finished with value: 0.5154758766148169 and parameters: {'min_child_weight': 7, 'subsample': 0.6851462432529174, 'max_depth': 5, 'reg_lambda': 17.144905011001246, 'reg_alpha': 3.461926863443899, 'num_leaves': 251, 'feature_fraction': 0.3395371573001084, 'learning_rate': 0.003445912182217607}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:44,072] Trial 1189 finished with value: 0.5214342209332982 and parameters: {'min_child_weight': 6, 'subsample': 0.772006261671808, 'max_depth': 3, 'reg_lambda': 17.997383706804374, 'reg_alpha': 3.243609261454689, 'num_leaves': 107, 'feature_fraction': 0.2744718856759288, 'learning_rate': 0.32367465878538887}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:45,982] Trial 1190 finished with value: 0.5197996308990246 and parameters: {'min_child_weight': 3, 'subsample': 0.7016076747057103, 'max_depth': 4, 'reg_lambda': 19.673239167636037, 'reg_alpha': 3.756972929466855, 'num_leaves': 191, 'feature_fraction': 0.3034955861350779, 'learning_rate': 0.009615383100018289}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:49,992] Trial 1191 finished with value: 0.5129976272080148 and parameters: {'min_child_weight': 7, 'subsample': 0.7452046679449346, 'max_depth': 10, 'reg_lambda': 18.87539631943555, 'reg_alpha': 3.556785696553174, 'num_leaves': 96, 'feature_fraction': 0.42254766181679204, 'learning_rate': 0.10492341888144885}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:51,954] Trial 1192 finished with value: 0.5157922488795149 and parameters: {'min_child_weight': 6, 'subsample': 0.9569801735594206, 'max_depth': 4, 'reg_lambda': 18.385753939739672, 'reg_alpha': 3.3780966971421433, 'num_leaves': 246, 'feature_fraction': 0.3643666870175006, 'learning_rate': 0.0015619005392010395}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:54,500] Trial 1193 finished with value: 0.5192723437911944 and parameters: {'min_child_weight': 8, 'subsample': 0.6077772030845985, 'max_depth': 6, 'reg_lambda': 19.341989855330198, 'reg_alpha': 3.0847200819135807, 'num_leaves': 111, 'feature_fraction': 0.3203023882107827, 'learning_rate': 0.08421906811023239}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:12:59,573] Trial 1194 finished with value: 0.5148431320854205 and parameters: {'min_child_weight': 5, 'subsample': 0.7288017766858506, 'max_depth': 17, 'reg_lambda': 18.97387362472599, 'reg_alpha': 3.6461432762043096, 'num_leaves': 256, 'feature_fraction': 0.29060913093784435, 'learning_rate': 0.0026096261584969064}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:02,275] Trial 1195 finished with value: 0.5152122330609016 and parameters: {'min_child_weight': 6, 'subsample': 0.97049103917484, 'max_depth': 8, 'reg_lambda': 17.80515139539095, 'reg_alpha': 3.4718720463005197, 'num_leaves': 36, 'feature_fraction': 0.37967626085452183, 'learning_rate': 0.5014072103413597}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:03,808] Trial 1196 finished with value: 0.5141576588452412 and parameters: {'min_child_weight': 4, 'subsample': 0.6559986612033636, 'max_depth': 3, 'reg_lambda': 18.518570533592225, 'reg_alpha': 0.7758750656479062, 'num_leaves': 47, 'feature_fraction': 0.3401269814692325, 'learning_rate': 0.001935957308247968}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:05,709] Trial 1197 finished with value: 0.5175850250461377 and parameters: {'min_child_weight': 7, 'subsample': 0.6289693536590246, 'max_depth': 5, 'reg_lambda': 19.585227017797717, 'reg_alpha': 3.302003831018341, 'num_leaves': 139, 'feature_fraction': 0.2573052119289816, 'learning_rate': 0.026295773206559618}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:07,524] Trial 1198 finished with value: 0.5167413656736093 and parameters: {'min_child_weight': 12, 'subsample': 0.7894334811837963, 'max_depth': 4, 'reg_lambda': 16.34715761909753, 'reg_alpha': 2.8817784031357596, 'num_leaves': 221, 'feature_fraction': 0.3133306887481446, 'learning_rate': 0.01894777686901753}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:12,977] Trial 1199 finished with value: 0.5150013182177696 and parameters: {'min_child_weight': 5, 'subsample': 0.8079661386636726, 'max_depth': 13, 'reg_lambda': 18.086034144686987, 'reg_alpha': 3.5327640699997733, 'num_leaves': 203, 'feature_fraction': 0.35587388690446925, 'learning_rate': 0.014436343983021528}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:15,605] Trial 1200 finished with value: 0.5137885578697601 and parameters: {'min_child_weight': 13, 'subsample': 0.6682656838343516, 'max_depth': 5, 'reg_lambda': 19.95225079568524, 'reg_alpha': 3.4022271324335356, 'num_leaves': 198, 'feature_fraction': 0.545562810990555, 'learning_rate': 0.0010097006397160428}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:17,337] Trial 1201 finished with value: 0.5189032428157132 and parameters: {'min_child_weight': 14, 'subsample': 0.6228661815370184, 'max_depth': 3, 'reg_lambda': 18.926800521832682, 'reg_alpha': 3.686910777213024, 'num_leaves': 172, 'feature_fraction': 0.5863451678333641, 'learning_rate': 0.02276575827621839}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:21,209] Trial 1202 finished with value: 0.5154758766148169 and parameters: {'min_child_weight': 9, 'subsample': 0.6760668234176094, 'max_depth': 16, 'reg_lambda': 19.298960304849498, 'reg_alpha': 3.1475191726826366, 'num_leaves': 164, 'feature_fraction': 0.27719302642171584, 'learning_rate': 0.0013745432888785359}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:23,105] Trial 1203 finished with value: 0.5171104666490904 and parameters: {'min_child_weight': 7, 'subsample': 0.9097091425070996, 'max_depth': 4, 'reg_lambda': 17.421047750491294, 'reg_alpha': 3.247245269693596, 'num_leaves': 148, 'feature_fraction': 0.3999923554419538, 'learning_rate': 0.005694972114829253}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:25,212] Trial 1204 finished with value: 0.5177959398892698 and parameters: {'min_child_weight': 8, 'subsample': 0.8475862154351331, 'max_depth': 5, 'reg_lambda': 18.572902760700757, 'reg_alpha': 3.584621872677512, 'num_leaves': 231, 'feature_fraction': 0.33039518577056554, 'learning_rate': 0.14880226829736048}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:26,860] Trial 1205 finished with value: 0.5149485895069865 and parameters: {'min_child_weight': 6, 'subsample': 0.7605676140852113, 'max_depth': 4, 'reg_lambda': 19.958151746595068, 'reg_alpha': 3.845219263644276, 'num_leaves': 159, 'feature_fraction': 0.297471297093291, 'learning_rate': 0.40688348304406186}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:30,102] Trial 1206 finished with value: 0.5201160031637226 and parameters: {'min_child_weight': 7, 'subsample': 0.6486114745451962, 'max_depth': 5, 'reg_lambda': 18.184162242422765, 'reg_alpha': 2.6819786417265563, 'num_leaves': 86, 'feature_fraction': 0.857270935637882, 'learning_rate': 0.045378996642097616}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:32,879] Trial 1207 finished with value: 0.5173213814922226 and parameters: {'min_child_weight': 6, 'subsample': 0.8907755561574819, 'max_depth': 6, 'reg_lambda': 19.120902180499026, 'reg_alpha': 3.4595227386914904, 'num_leaves': 239, 'feature_fraction': 0.4458397533804644, 'learning_rate': 0.19378437467085272}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:34,815] Trial 1208 finished with value: 0.5162668072765622 and parameters: {'min_child_weight': 5, 'subsample': 0.7178835128055102, 'max_depth': 4, 'reg_lambda': 18.70949481328346, 'reg_alpha': 3.4255675855565952, 'num_leaves': 209, 'feature_fraction': 0.38029729239278387, 'learning_rate': 0.008520717638324902}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:36,889] Trial 1209 finished with value: 0.5153704191932507 and parameters: {'min_child_weight': 8, 'subsample': 0.8337452052014672, 'max_depth': 3, 'reg_lambda': 19.36786614798177, 'reg_alpha': 3.2830080105310357, 'num_leaves': 188, 'feature_fraction': 0.7745732338459885, 'learning_rate': 0.5960799889642585}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:39,773] Trial 1210 finished with value: 0.5144740311099393 and parameters: {'min_child_weight': 6, 'subsample': 0.6164343535256916, 'max_depth': 4, 'reg_lambda': 17.732585381693244, 'reg_alpha': 3.6923059553616673, 'num_leaves': 60, 'feature_fraction': 0.981133743071826, 'learning_rate': 0.010656226750089209}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:41,409] Trial 1211 finished with value: 0.5148431320854205 and parameters: {'min_child_weight': 7, 'subsample': 0.6919927205190667, 'max_depth': 4, 'reg_lambda': 19.983974547376206, 'reg_alpha': 3.3592163520098572, 'num_leaves': 235, 'feature_fraction': 0.26631772244031515, 'learning_rate': 0.0022032694475942996}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:43,783] Trial 1212 finished with value: 0.5138412865805432 and parameters: {'min_child_weight': 5, 'subsample': 0.7012785057406598, 'max_depth': 5, 'reg_lambda': 17.04321788672256, 'reg_alpha': 3.5578894664827687, 'num_leaves': 132, 'feature_fraction': 0.4163551549107587, 'learning_rate': 0.003027577414209708}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:45,253] Trial 1213 finished with value: 0.5131030846295808 and parameters: {'min_child_weight': 6, 'subsample': 0.6334874930041807, 'max_depth': 3, 'reg_lambda': 18.336485792382362, 'reg_alpha': 0.3114962143520048, 'num_leaves': 67, 'feature_fraction': 0.3081693528876925, 'learning_rate': 0.0011841256412909765}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:48,305] Trial 1214 finished with value: 0.5049301344582126 and parameters: {'min_child_weight': 8, 'subsample': 0.659785555873856, 'max_depth': 18, 'reg_lambda': 18.99334241147897, 'reg_alpha': 3.960539540893944, 'num_leaves': 213, 'feature_fraction': 0.2282077732052003, 'learning_rate': 0.7562817136539047}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:50,151] Trial 1215 finished with value: 0.5155813340363828 and parameters: {'min_child_weight': 7, 'subsample': 0.7782121654936205, 'max_depth': 4, 'reg_lambda': 19.458045636628057, 'reg_alpha': 3.1848791101357765, 'num_leaves': 143, 'feature_fraction': 0.3520214939526656, 'learning_rate': 0.004055098051185568}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:51,887] Trial 1216 finished with value: 0.5145267598207224 and parameters: {'min_child_weight': 6, 'subsample': 0.7088253073745863, 'max_depth': 4, 'reg_lambda': 18.729700228740043, 'reg_alpha': 2.5815623625830115, 'num_leaves': 130, 'feature_fraction': 0.2862430699077331, 'learning_rate': 0.004534979953262339}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:53,676] Trial 1217 finished with value: 0.51099393619826 and parameters: {'min_child_weight': 4, 'subsample': 0.6401539383198979, 'max_depth': 4, 'reg_lambda': 18.101673145903952, 'reg_alpha': 3.6179206295944506, 'num_leaves': 55, 'feature_fraction': 0.3225428451713818, 'learning_rate': 0.3621359491790636}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:55,814] Trial 1218 finished with value: 0.5181123121539678 and parameters: {'min_child_weight': 7, 'subsample': 0.7359883328196246, 'max_depth': 5, 'reg_lambda': 19.099867555653766, 'reg_alpha': 3.334822924708264, 'num_leaves': 219, 'feature_fraction': 0.3700172454860796, 'learning_rate': 0.03416718674389238}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:57,282] Trial 1219 finished with value: 0.5162140785657792 and parameters: {'min_child_weight': 5, 'subsample': 0.6057335906757876, 'max_depth': 3, 'reg_lambda': 19.6149084046303, 'reg_alpha': 0.4464275810259263, 'num_leaves': 118, 'feature_fraction': 0.33782024573001773, 'learning_rate': 0.061952327332901305}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:13:59,543] Trial 1220 finished with value: 0.5123648826786185 and parameters: {'min_child_weight': 8, 'subsample': 0.9228631010451764, 'max_depth': 5, 'reg_lambda': 17.743814398803814, 'reg_alpha': 3.765642655823196, 'num_leaves': 172, 'feature_fraction': 0.4676533825389299, 'learning_rate': 0.30079149220655865}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:01,201] Trial 1221 finished with value: 0.518481413129449 and parameters: {'min_child_weight': 7, 'subsample': 0.7247557734674279, 'max_depth': 4, 'reg_lambda': 18.521674129035816, 'reg_alpha': 3.0395553464193057, 'num_leaves': 43, 'feature_fraction': 0.24493036639140908, 'learning_rate': 0.10494278781237325}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:02,807] Trial 1222 finished with value: 0.518270498286317 and parameters: {'min_child_weight': 9, 'subsample': 0.6859034094140861, 'max_depth': 3, 'reg_lambda': 19.992468245723714, 'reg_alpha': 3.461370172090233, 'num_leaves': 125, 'feature_fraction': 0.398583641862301, 'learning_rate': 0.46574102117083876}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:04,801] Trial 1223 finished with value: 0.5164777221196941 and parameters: {'min_child_weight': 6, 'subsample': 0.6766208712312731, 'max_depth': 5, 'reg_lambda': 18.773877495238093, 'reg_alpha': 3.536025204604507, 'num_leaves': 242, 'feature_fraction': 0.29182578104131224, 'learning_rate': 0.0016689163079592893}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:06,494] Trial 1224 finished with value: 0.5132612707619298 and parameters: {'min_child_weight': 6, 'subsample': 0.6254225828612173, 'max_depth': 4, 'reg_lambda': 19.292303650024248, 'reg_alpha': 3.3774622103428085, 'num_leaves': 96, 'feature_fraction': 0.26198013164560263, 'learning_rate': 0.2394710938581364}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:09,525] Trial 1225 finished with value: 0.518217769575534 and parameters: {'min_child_weight': 5, 'subsample': 0.8728340623205445, 'max_depth': 7, 'reg_lambda': 18.243066881615647, 'reg_alpha': 3.2284113223070494, 'num_leaves': 155, 'feature_fraction': 0.3102547047969421, 'learning_rate': 0.012926256501731646}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:11,366] Trial 1226 finished with value: 0.5161613498549961 and parameters: {'min_child_weight': 13, 'subsample': 0.7447857154730503, 'max_depth': 4, 'reg_lambda': 17.396212594466125, 'reg_alpha': 1.1085268543608835, 'num_leaves': 80, 'feature_fraction': 0.34852578432413295, 'learning_rate': 0.006634060086078853}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:13,907] Trial 1227 finished with value: 0.5180595834431848 and parameters: {'min_child_weight': 7, 'subsample': 0.6003489924410744, 'max_depth': 5, 'reg_lambda': 17.96256950974895, 'reg_alpha': 3.4831041896528947, 'num_leaves': 180, 'feature_fraction': 0.4256696471677827, 'learning_rate': 0.005036920667460329}. Best is trial 15 with value: 0.5270426989984185.
# [I 2021-09-16 18:14:15,403] Trial 1228 finished with value: 0.5202214605852887 and parameters: {'min_child_weight': 8, 'subsample': 0.7945149246419262, 'max_depth': 3, 'reg_lambda': 19.095957722204616, 'reg_alpha': 3.6359521391400587, 'num_leaves': 196, 'feature_fraction': 0.27875176468069407, 'learning_rate': 0.13749586353304374}. Best is trial 15 with value: 0.5270426989984185.

# %%
lgbc_params = study_lgbc.best_trial.params
lgbc_params['random_state'] = 23
best_lgbc = lgb.LGBMClassifier()
best_lgbc.set_params(**lgbc_params)
print("best_lgbc:", best_lgbc)

best_lgbc.fit(X_train, y_train)

print("train_acc:", best_lgbc.score(X_train, y_train))
print("test_acc:", best_lgbc.score(X_test, y_test))


view_model_coefs(best_lgbc, X_train)
# Out:
# best_lgbc: LGBMClassifier(feature_fraction=0.7796269937403173, max_depth=5,
#                min_child_weight=7, num_leaves=16860, random_state=23,
#                reg_alpha=3.571940784753475, reg_lambda=17.76958546447963)
# [LightGBM] [Warning] feature_fraction is set=0.7796269937403173, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7796269937403173
# train_acc: 0.7327006722024516
# test_acc: 0.5027863777089784
# LGBoost or XGBoost
#                 feature_name  coef
# 66                 rest_diff     1
# 53     E_NET_RATING_opp_diff     2
# 55              PIE_opp_diff     3
# 51     E_OFF_RATING_opp_diff     4
# 70         DREB_PCT_opp_diff     7
# 22    E_NET_RATING_team_diff     9
# 52     E_DEF_RATING_opp_diff     9
# 19      PLUS_MINUS_team_diff     9
# 64            WL_record_diff    12
# 24             PIE_team_diff    12
# 73          TS_PCT_team_diff    14
# 69        DREB_PCT_team_diff    16
# 4             FG2M_team_diff    17
# 84              elo_MOV_pred    17
# 72          REB_PCT_opp_diff    17
# 49              PTS_opp_diff    18
# 12             REB_team_diff    18
# 20    E_OFF_RATING_team_diff    18
# 21    E_DEF_RATING_team_diff    19
# 81             team_elo_pred    19
# 13             AST_team_diff    19
# 75         EFG_PCT_team_diff    21
# 59        PTS_PAINT_opp_diff    21
# 35             FG2M_opp_diff    23
# 36             FG2A_opp_diff    24
# 1                 avg_spread    24
# 62          AST_3PM_opp_diff    24
# 74           TS_PCT_opp_diff    24
# 28       PTS_PAINT_team_diff    24
# 67        OREB_PCT_team_diff    24
# 80          TOV_PCT_opp_diff    25
# 79         TOV_PCT_team_diff    25
# 6             FG3M_team_diff    26
# 5             FG2A_team_diff    26
# 44              AST_opp_diff    27
# 11            DREB_team_diff    28
# 71         REB_PCT_team_diff    28
# 77       AST_RATIO_team_diff    29
# 34           RECORD_opp_diff    31
# 43              REB_opp_diff    31
# 47              TOV_opp_diff    32
# 68         OREB_PCT_opp_diff    33
# 58      PTS_OFF_TOV_opp_diff    34
# 61         UAST_2PM_opp_diff    34
# 54             POSS_opp_diff    34
# 0                     avg_ml    34
# 60          AST_2PM_opp_diff    35
# 8              FTM_team_diff    35
# 7             FG3A_team_diff    35
# 40              FTA_opp_diff    35
# 10            OREB_team_diff    36
# 42             DREB_opp_diff    37
# 23            POSS_team_diff    37
# 31         AST_3PM_team_diff    37
# 46              BLK_opp_diff    38
# 41             OREB_opp_diff    39
# 15             BLK_team_diff    39
# 29         AST_2PM_team_diff    40
# 30        UAST_2PM_team_diff    40
# 65           ATS_record_diff    40
# 2      avg_point_spread_diff    41
# 27     PTS_OFF_TOV_team_diff    42
# 82             team_rating_i    43
# 14             STL_team_diff    43
# 85                    spread    43
# 39              FTM_opp_diff    43
# 78        AST_RATIO_opp_diff    44
# 18             PTS_team_diff    44
# 26          PTS_FB_team_diff    44
# 16             TOV_team_diff    45
# 76          EFG_PCT_opp_diff    45
# 83              opp_rating_i    45
# 17              PF_team_diff    47
# 45              STL_opp_diff    47
# 9              FTA_team_diff    48
# 63         UAST_3PM_opp_diff    49
# 25      PTS_2PT_MR_team_diff    54
# 38             FG3A_opp_diff    54
# 57           PTS_FB_opp_diff    54
# 33     team_covered_opp_diff    56
# 3   points_covered_spread_by    56
# 37             FG3M_opp_diff    57
# 32        UAST_3PM_team_diff    57
# 48               PF_opp_diff    60
# 56       PTS_2PT_MR_opp_diff    70

# %% [markdown]
# ### KNNeighbors

# %%
def objective(trial):    

    n_neighbors = trial.suggest_int('n_neighbors', 1, 52)
    
    classifier_obj = Pipeline(steps=[('scaler', StandardScaler()),
                ('knn',
                 KNeighborsClassifier(n_neighbors=n_neighbors))]) 
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_knn'
storage_name = "sqlite:///{}.db".format(study_name)

search_space = {'n_neighbors':np.arange(1, 51).tolist()}

study_knn = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True,
                               sampler = optuna.samplers.GridSampler(search_space))

study_knn.optimize(objective)
# Out:
# [I 2021-09-16 22:49:15,334] Using an existing study with name 'study_knn' instead of creating a new one.
# [W 2021-09-16 22:49:15,377] `GridSampler` is re-evaluating a configuration because the grid has been exhausted. This may happen due to a timing issue during distributed optimization or when re-running optimizations on already finished studies.
# [I 2021-09-16 22:49:45,273] Trial 50 finished with value: 0.5029264434484577 and parameters: {'n_neighbors': 3}. Best is trial 29 with value: 0.5113863995782815.

# %%
best_n = study_knn.best_trial.params['n_neighbors']

best_knn = Pipeline(steps=[('scaler', StandardScaler()),
                ('knn', KNeighborsClassifier(n_neighbors=best_n))])

best_knn.fit(X_train, y_train)
print(best_knn.score(X_train, y_train))
print(best_knn.score(X_test, y_test))
# Out:
# 0.5808620007908264
# 0.5149933657673595

# %% [markdown]
# ### Random Forest

# %%
def objective(trial):    
    min_samples_split = trial.suggest_float('min_samples_split', 0.01, 0.5)
#     subsample = trial.suggest_float('subsample', 0.6, 1)
    max_depth = trial.suggest_int('max_depth', 3, 32)
    min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.01, 0.5)

    classifier_obj = RandomForestClassifier(max_depth=max_depth, min_samples_leaf=min_samples_leaf,
                       min_samples_split=min_samples_split, random_state=23)
    
    score = cross_val_score(classifier_obj, X_train, y_train, n_jobs=-1,
                           cv=tscv, scoring='accuracy')
    
    
    score_avg = score.mean()
    
    return score_avg

study_name = 'study_rf'
storage_name = "sqlite:///{}.db".format(study_name)

study_rf = optuna.create_study(study_name = study_name, direction='maximize', 
                               storage = storage_name, load_if_exists=True)

study_rf.optimize(objective, n_trials=250)
# Out:
# [I 2021-09-16 22:54:43,229] Using an existing study with name 'study_rf' instead of creating a new one.
# [I 2021-09-16 22:54:51,317] Trial 300 finished with value: 0.5173741102030055 and parameters: {'min_samples_split': 0.0487934038505478, 'max_depth': 27, 'min_samples_leaf': 0.028690549167731234}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:54:57,819] Trial 301 finished with value: 0.5173741102030055 and parameters: {'min_samples_split': 0.10146506424604637, 'max_depth': 28, 'min_samples_leaf': 0.038043408320665516}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:04,269] Trial 302 finished with value: 0.5176377537569206 and parameters: {'min_samples_split': 0.13342417387375652, 'max_depth': 23, 'min_samples_leaf': 0.021772856829156625}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:09,884] Trial 303 finished with value: 0.5164249934089112 and parameters: {'min_samples_split': 0.12154577713944692, 'max_depth': 26, 'min_samples_leaf': 0.05082128680679175}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:18,635] Trial 304 finished with value: 0.5183232269971 and parameters: {'min_samples_split': 0.018293026636475352, 'max_depth': 25, 'min_samples_leaf': 0.01693528337638825}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:25,323] Trial 305 finished with value: 0.5181650408647509 and parameters: {'min_samples_split': 0.09810900368531418, 'max_depth': 24, 'min_samples_leaf': 0.03187945554964517}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:30,440] Trial 306 finished with value: 0.5154758766148169 and parameters: {'min_samples_split': 0.010587553759737824, 'max_depth': 26, 'min_samples_leaf': 0.0639897951102199}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:36,260] Trial 307 finished with value: 0.516108621144213 and parameters: {'min_samples_split': 0.1108925588765901, 'max_depth': 24, 'min_samples_leaf': 0.04324952088616567}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:40,401] Trial 308 finished with value: 0.5166886369628263 and parameters: {'min_samples_split': 0.3138069925448138, 'max_depth': 28, 'min_samples_leaf': 0.02526630564494995}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:46,973] Trial 309 finished with value: 0.5211705773793831 and parameters: {'min_samples_split': 0.14372649793886902, 'max_depth': 25, 'min_samples_leaf': 0.01692374380929601}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:55:56,721] Trial 310 finished with value: 0.5175850250461376 and parameters: {'min_samples_split': 0.03328320590065022, 'max_depth': 25, 'min_samples_leaf': 0.010486318858451816}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:02,545] Trial 311 finished with value: 0.518639599261798 and parameters: {'min_samples_split': 0.13098125095896707, 'max_depth': 27, 'min_samples_leaf': 0.034464840972643115}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:07,866] Trial 312 finished with value: 0.5154231479040338 and parameters: {'min_samples_split': 0.13813485257304348, 'max_depth': 6, 'min_samples_leaf': 0.050207862706298304}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:10,044] Trial 313 finished with value: 0.5104666490904298 and parameters: {'min_samples_split': 0.14393631216123143, 'max_depth': 26, 'min_samples_leaf': 0.23216162929150075}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:16,427] Trial 314 finished with value: 0.5196414447666754 and parameters: {'min_samples_split': 0.12329768403271592, 'max_depth': 25, 'min_samples_leaf': 0.025858893489045326}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:24,681] Trial 315 finished with value: 0.5167940943843924 and parameters: {'min_samples_split': 0.09303568726571182, 'max_depth': 20, 'min_samples_leaf': 0.01059441648304901}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:28,617] Trial 316 finished with value: 0.5126285262325336 and parameters: {'min_samples_split': 0.2907521066845405, 'max_depth': 24, 'min_samples_leaf': 0.05907365559648066}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:34,586] Trial 317 finished with value: 0.518534141840232 and parameters: {'min_samples_split': 0.10888800906946328, 'max_depth': 26, 'min_samples_leaf': 0.041128590638772174}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:41,076] Trial 318 finished with value: 0.5189032428157131 and parameters: {'min_samples_split': 0.0876420629429499, 'max_depth': 27, 'min_samples_leaf': 0.03239596650297605}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:48,921] Trial 319 finished with value: 0.5166359082520433 and parameters: {'min_samples_split': 0.06393547978901161, 'max_depth': 22, 'min_samples_leaf': 0.019430833255178335}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:56:54,671] Trial 320 finished with value: 0.5195359873451094 and parameters: {'min_samples_split': 0.10121589402269045, 'max_depth': 26, 'min_samples_leaf': 0.047885389646428994}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:02,383] Trial 321 finished with value: 0.5165304508304772 and parameters: {'min_samples_split': 0.12034895008863293, 'max_depth': 23, 'min_samples_leaf': 0.01001140526421375}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:07,102] Trial 322 finished with value: 0.5148958607962035 and parameters: {'min_samples_split': 0.1044773297612795, 'max_depth': 29, 'min_samples_leaf': 0.07630096473363879}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:14,650] Trial 323 finished with value: 0.5142631162668072 and parameters: {'min_samples_split': 0.02576867126483267, 'max_depth': 27, 'min_samples_leaf': 0.025917757893842142}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:21,143] Trial 324 finished with value: 0.5156867914579489 and parameters: {'min_samples_split': 0.05549417502683284, 'max_depth': 25, 'min_samples_leaf': 0.038023599994790824}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:23,359] Trial 325 finished with value: 0.5082520432375428 and parameters: {'min_samples_split': 0.0762348323866221, 'max_depth': 24, 'min_samples_leaf': 0.27063224058371255}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:29,132] Trial 326 finished with value: 0.5167940943843924 and parameters: {'min_samples_split': 0.04037069814311909, 'max_depth': 26, 'min_samples_leaf': 0.05567827932024145}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:35,889] Trial 327 finished with value: 0.5196414447666754 and parameters: {'min_samples_split': 0.11566970332938714, 'max_depth': 27, 'min_samples_leaf': 0.022177395179449312}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:41,658] Trial 328 finished with value: 0.5189032428157132 and parameters: {'min_samples_split': 0.13096182512760007, 'max_depth': 26, 'min_samples_leaf': 0.03487368396577605}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:47,635] Trial 329 finished with value: 0.5177959398892698 and parameters: {'min_samples_split': 0.08775320055778049, 'max_depth': 25, 'min_samples_leaf': 0.045996254181032536}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:54,658] Trial 330 finished with value: 0.5175322963353546 and parameters: {'min_samples_split': 0.09669865959580468, 'max_depth': 28, 'min_samples_leaf': 0.019447121440027824}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:57:59,654] Trial 331 finished with value: 0.516108621144213 and parameters: {'min_samples_split': 0.11147884529681787, 'max_depth': 25, 'min_samples_leaf': 0.0662806619492003}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:04,211] Trial 332 finished with value: 0.5160031637226469 and parameters: {'min_samples_split': 0.2646948596483054, 'max_depth': 25, 'min_samples_leaf': 0.029874475573004124}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:10,487] Trial 333 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.01612427757402849, 'max_depth': 24, 'min_samples_leaf': 0.04238457909476356}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:16,431] Trial 334 finished with value: 0.5183232269970999 and parameters: {'min_samples_split': 0.18336065327884332, 'max_depth': 26, 'min_samples_leaf': 0.018380595831542973}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:21,441] Trial 335 finished with value: 0.5147904033746374 and parameters: {'min_samples_split': 0.14986176656140518, 'max_depth': 28, 'min_samples_leaf': 0.05687784954782042}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:27,527] Trial 336 finished with value: 0.518375955707883 and parameters: {'min_samples_split': 0.12272844708714313, 'max_depth': 27, 'min_samples_leaf': 0.034384034405961376}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:34,197] Trial 337 finished with value: 0.5199050883205906 and parameters: {'min_samples_split': 0.10504373783112828, 'max_depth': 21, 'min_samples_leaf': 0.02550956130475327}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:43,356] Trial 338 finished with value: 0.5166359082520432 and parameters: {'min_samples_split': 0.06788574166380779, 'max_depth': 26, 'min_samples_leaf': 0.010284139429989668}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:46,420] Trial 339 finished with value: 0.5106775639335618 and parameters: {'min_samples_split': 0.23233873572640568, 'max_depth': 24, 'min_samples_leaf': 0.14981068589163715}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:52,808] Trial 340 finished with value: 0.5149485895069865 and parameters: {'min_samples_split': 0.034922369761104105, 'max_depth': 25, 'min_samples_leaf': 0.039446296086544756}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:53,763] Trial 341 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.08321685064025014, 'max_depth': 23, 'min_samples_leaf': 0.38707116544117703}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:58:58,819] Trial 342 finished with value: 0.5162668072765622 and parameters: {'min_samples_split': 0.1669576439841354, 'max_depth': 27, 'min_samples_leaf': 0.05240094495479303}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:05,783] Trial 343 finished with value: 0.520801476403902 and parameters: {'min_samples_split': 0.09341461601104724, 'max_depth': 30, 'min_samples_leaf': 0.028948119367394443}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:12,560] Trial 344 finished with value: 0.5176377537569207 and parameters: {'min_samples_split': 0.09850968043611442, 'max_depth': 31, 'min_samples_leaf': 0.02623211027845209}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:20,271] Trial 345 finished with value: 0.5181123121539678 and parameters: {'min_samples_split': 0.08986299532732973, 'max_depth': 26, 'min_samples_leaf': 0.017896280805005844}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:26,473] Trial 346 finished with value: 0.5174268389137886 and parameters: {'min_samples_split': 0.1148565598351448, 'max_depth': 24, 'min_samples_leaf': 0.030612125136445546}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:28,614] Trial 347 finished with value: 0.5096757184286844 and parameters: {'min_samples_split': 0.07731868399369689, 'max_depth': 25, 'min_samples_leaf': 0.2160622387930711}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:36,386] Trial 348 finished with value: 0.518745056683364 and parameters: {'min_samples_split': 0.10383342970622234, 'max_depth': 30, 'min_samples_leaf': 0.010247497567992175}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:40,165] Trial 349 finished with value: 0.5148958607962035 and parameters: {'min_samples_split': 0.35424382716683434, 'max_depth': 26, 'min_samples_leaf': 0.025500898717108447}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:46,375] Trial 350 finished with value: 0.5171631953598734 and parameters: {'min_samples_split': 0.09344933781378516, 'max_depth': 25, 'min_samples_leaf': 0.03824613796524489}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:53,077] Trial 351 finished with value: 0.5197469021882416 and parameters: {'min_samples_split': 0.1247259288335478, 'max_depth': 26, 'min_samples_leaf': 0.018904056038167832}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 22:59:57,814] Trial 352 finished with value: 0.5188505141049301 and parameters: {'min_samples_split': 0.11411674275112163, 'max_depth': 3, 'min_samples_leaf': 0.02970530551697324}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:03,737] Trial 353 finished with value: 0.5155286053255999 and parameters: {'min_samples_split': 0.10451513099715821, 'max_depth': 10, 'min_samples_leaf': 0.043020945023212784}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:11,090] Trial 354 finished with value: 0.5192723437911942 and parameters: {'min_samples_split': 0.08408814790040703, 'max_depth': 15, 'min_samples_leaf': 0.01991565353215905}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:16,975] Trial 355 finished with value: 0.5182704982863169 and parameters: {'min_samples_split': 0.13130756862788798, 'max_depth': 24, 'min_samples_leaf': 0.03443150234697287}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:24,308] Trial 356 finished with value: 0.5199578170313736 and parameters: {'min_samples_split': 0.09554346768845422, 'max_depth': 17, 'min_samples_leaf': 0.01753102698433155}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:30,254] Trial 357 finished with value: 0.5166359082520433 and parameters: {'min_samples_split': 0.052211704939113035, 'max_depth': 25, 'min_samples_leaf': 0.04775907972869806}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:34,661] Trial 358 finished with value: 0.5161086211442131 and parameters: {'min_samples_split': 0.2760562766560377, 'max_depth': 23, 'min_samples_leaf': 0.03063788543484549}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:40,264] Trial 359 finished with value: 0.5179541260216188 and parameters: {'min_samples_split': 0.14101686370200567, 'max_depth': 31, 'min_samples_leaf': 0.04038941894655994}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:48,996] Trial 360 finished with value: 0.5193250725019773 and parameters: {'min_samples_split': 0.0698932155870945, 'max_depth': 26, 'min_samples_leaf': 0.010337190849197814}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:55,508] Trial 361 finished with value: 0.518586870551015 and parameters: {'min_samples_split': 0.10934810199422336, 'max_depth': 27, 'min_samples_leaf': 0.025223935528675124}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:00:59,570] Trial 362 finished with value: 0.5155286053255997 and parameters: {'min_samples_split': 0.25821058337233277, 'max_depth': 25, 'min_samples_leaf': 0.06103380115382107}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:05,077] Trial 363 finished with value: 0.5167940943843922 and parameters: {'min_samples_split': 0.11996695418940552, 'max_depth': 22, 'min_samples_leaf': 0.0514896513502515}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:11,450] Trial 364 finished with value: 0.5179541260216187 and parameters: {'min_samples_split': 0.0944554736568539, 'max_depth': 25, 'min_samples_leaf': 0.03447691519067382}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:18,450] Trial 365 finished with value: 0.5201687318745056 and parameters: {'min_samples_split': 0.10470100230262828, 'max_depth': 24, 'min_samples_leaf': 0.01907679174114663}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:26,864] Trial 366 finished with value: 0.5193778012127603 and parameters: {'min_samples_split': 0.08459485550769154, 'max_depth': 24, 'min_samples_leaf': 0.01013071776334136}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:33,707] Trial 367 finished with value: 0.5183232269971 and parameters: {'min_samples_split': 0.1076193972560811, 'max_depth': 23, 'min_samples_leaf': 0.020431465213135512}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:40,300] Trial 368 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.12486413211294815, 'max_depth': 26, 'min_samples_leaf': 0.019492750347153656}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:46,665] Trial 369 finished with value: 0.5205905615607699 and parameters: {'min_samples_split': 0.1138668767353392, 'max_depth': 24, 'min_samples_leaf': 0.027771002924109035}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:52,995] Trial 370 finished with value: 0.5191668863696283 and parameters: {'min_samples_split': 0.11738788178062022, 'max_depth': 19, 'min_samples_leaf': 0.025937393624780418}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:01:59,388] Trial 371 finished with value: 0.5190614289480622 and parameters: {'min_samples_split': 0.13523749180213948, 'max_depth': 24, 'min_samples_leaf': 0.01988514068610603}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:05,500] Trial 372 finished with value: 0.5166886369628262 and parameters: {'min_samples_split': 0.12769624750039207, 'max_depth': 24, 'min_samples_leaf': 0.02830929150854826}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:12,560] Trial 373 finished with value: 0.5193250725019773 and parameters: {'min_samples_split': 0.11354155482106727, 'max_depth': 14, 'min_samples_leaf': 0.01769722723195395}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:18,582] Trial 374 finished with value: 0.515950435011864 and parameters: {'min_samples_split': 0.106271486754286, 'max_depth': 25, 'min_samples_leaf': 0.039373721348073376}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:24,986] Trial 375 finished with value: 0.5192723437911944 and parameters: {'min_samples_split': 0.11472502893466581, 'max_depth': 24, 'min_samples_leaf': 0.026808675063820488}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:25,949] Trial 376 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.14228985656215543, 'max_depth': 25, 'min_samples_leaf': 0.4953728869263813}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:33,930] Trial 377 finished with value: 0.5157395201687318 and parameters: {'min_samples_split': 0.09753866465390242, 'max_depth': 25, 'min_samples_leaf': 0.010496083802960552}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:39,820] Trial 378 finished with value: 0.5182177695755339 and parameters: {'min_samples_split': 0.1233612615396695, 'max_depth': 24, 'min_samples_leaf': 0.03489649713215267}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:46,841] Trial 379 finished with value: 0.5191141576588452 and parameters: {'min_samples_split': 0.10652730523767291, 'max_depth': 32, 'min_samples_leaf': 0.01862548793776423}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:52,333] Trial 380 finished with value: 0.5172159240706564 and parameters: {'min_samples_split': 0.13115141209700526, 'max_depth': 26, 'min_samples_leaf': 0.04500842777321643}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:02:59,161] Trial 381 finished with value: 0.5173213814922225 and parameters: {'min_samples_split': 0.09849825453893661, 'max_depth': 25, 'min_samples_leaf': 0.028967327115776077}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:06,763] Trial 382 finished with value: 0.5168995518059584 and parameters: {'min_samples_split': 0.11782164511220825, 'max_depth': 24, 'min_samples_leaf': 0.010111084283321905}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:14,220] Trial 383 finished with value: 0.5153704191932507 and parameters: {'min_samples_split': 0.043896366336264564, 'max_depth': 25, 'min_samples_leaf': 0.026769028992891176}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:20,614] Trial 384 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.09124820079658985, 'max_depth': 26, 'min_samples_leaf': 0.03714427493618079}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:27,612] Trial 385 finished with value: 0.5191141576588453 and parameters: {'min_samples_split': 0.10750264849325858, 'max_depth': 26, 'min_samples_leaf': 0.018616575653698415}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:33,273] Trial 386 finished with value: 0.5200632744529397 and parameters: {'min_samples_split': 0.11940049873555225, 'max_depth': 24, 'min_samples_leaf': 0.04470904392619398}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:38,735] Trial 387 finished with value: 0.518639599261798 and parameters: {'min_samples_split': 0.1321448182588308, 'max_depth': 23, 'min_samples_leaf': 0.04656608304698512}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:41,401] Trial 388 finished with value: 0.5114157658845241 and parameters: {'min_samples_split': 0.14881075721701778, 'max_depth': 24, 'min_samples_leaf': 0.17690830288240364}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:47,625] Trial 389 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.1198570977064712, 'max_depth': 23, 'min_samples_leaf': 0.028504548912453326}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:03:55,237] Trial 390 finished with value: 0.5155286053255997 and parameters: {'min_samples_split': 0.11221279933161442, 'max_depth': 24, 'min_samples_leaf': 0.01003173228299179}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:00,995] Trial 391 finished with value: 0.5176377537569207 and parameters: {'min_samples_split': 0.13128506526005573, 'max_depth': 25, 'min_samples_leaf': 0.0380510138478238}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:07,161] Trial 392 finished with value: 0.5187450566833641 and parameters: {'min_samples_split': 0.1602493889135058, 'max_depth': 27, 'min_samples_leaf': 0.019675960712963913}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:13,649] Trial 393 finished with value: 0.5174268389137886 and parameters: {'min_samples_split': 0.10189615202166058, 'max_depth': 24, 'min_samples_leaf': 0.029157223137891673}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:19,133] Trial 394 finished with value: 0.5177432111784868 and parameters: {'min_samples_split': 0.12164212416463462, 'max_depth': 25, 'min_samples_leaf': 0.046800926301019924}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:25,959] Trial 395 finished with value: 0.5177432111784867 and parameters: {'min_samples_split': 0.11291877788038435, 'max_depth': 23, 'min_samples_leaf': 0.020253733361607695}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:31,613] Trial 396 finished with value: 0.5194305299235434 and parameters: {'min_samples_split': 0.13935655907665148, 'max_depth': 31, 'min_samples_leaf': 0.03622807212334117}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:36,852] Trial 397 finished with value: 0.5155286053255997 and parameters: {'min_samples_split': 0.02133182992754556, 'max_depth': 26, 'min_samples_leaf': 0.059181537842614235}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:43,097] Trial 398 finished with value: 0.5195887160558924 and parameters: {'min_samples_split': 0.1212709528557415, 'max_depth': 27, 'min_samples_leaf': 0.026208646269152768}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:48,745] Trial 399 finished with value: 0.5163195359873451 and parameters: {'min_samples_split': 0.12436778071002416, 'max_depth': 25, 'min_samples_leaf': 0.04223628712590726}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:56,005] Trial 400 finished with value: 0.5174795676245715 and parameters: {'min_samples_split': 0.10231442258796435, 'max_depth': 26, 'min_samples_leaf': 0.018068467463633775}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:04:58,118] Trial 401 finished with value: 0.5090429738992881 and parameters: {'min_samples_split': 0.09123150446001453, 'max_depth': 24, 'min_samples_leaf': 0.24542771905379332}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:04,346] Trial 402 finished with value: 0.5188505141049301 and parameters: {'min_samples_split': 0.11112578936497106, 'max_depth': 25, 'min_samples_leaf': 0.03337408838235171}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:09,663] Trial 403 finished with value: 0.5182177695755339 and parameters: {'min_samples_split': 0.1398784797373208, 'max_depth': 26, 'min_samples_leaf': 0.052214274648152016}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:12,943] Trial 404 finished with value: 0.5151595043501187 and parameters: {'min_samples_split': 0.1282745129144759, 'max_depth': 30, 'min_samples_leaf': 0.13167912017616418}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:17,823] Trial 405 finished with value: 0.5152649617716847 and parameters: {'min_samples_split': 0.09912886436607549, 'max_depth': 24, 'min_samples_leaf': 0.07249440277444236}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:24,864] Trial 406 finished with value: 0.518692327972581 and parameters: {'min_samples_split': 0.11157519008054512, 'max_depth': 24, 'min_samples_leaf': 0.017659955881617173}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:29,227] Trial 407 finished with value: 0.5156340627471658 and parameters: {'min_samples_split': 0.2872258691882553, 'max_depth': 27, 'min_samples_leaf': 0.02819381048453646}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:35,347] Trial 408 finished with value: 0.5164777221196941 and parameters: {'min_samples_split': 0.0913653103367409, 'max_depth': 25, 'min_samples_leaf': 0.0401023633865582}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:43,229] Trial 409 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.1028426911399697, 'max_depth': 25, 'min_samples_leaf': 0.010680101690327575}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:51,051] Trial 410 finished with value: 0.5146849459530715 and parameters: {'min_samples_split': 0.01208346884234076, 'max_depth': 26, 'min_samples_leaf': 0.024064618706632228}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:05:56,802] Trial 411 finished with value: 0.5165304508304771 and parameters: {'min_samples_split': 0.03360174959926292, 'max_depth': 27, 'min_samples_leaf': 0.050824477544041555}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:02,324] Trial 412 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.15180025007427056, 'max_depth': 26, 'min_samples_leaf': 0.034077594003005335}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:09,330] Trial 413 finished with value: 0.5189559715264961 and parameters: {'min_samples_split': 0.11691174543751781, 'max_depth': 24, 'min_samples_leaf': 0.01851917803552296}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:14,381] Trial 414 finished with value: 0.5161613498549962 and parameters: {'min_samples_split': 0.02912868208205984, 'max_depth': 8, 'min_samples_leaf': 0.06491262561797602}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:19,278] Trial 415 finished with value: 0.5142631162668072 and parameters: {'min_samples_split': 0.20205325257778994, 'max_depth': 23, 'min_samples_leaf': 0.04370451580435305}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:26,215] Trial 416 finished with value: 0.5190614289480623 and parameters: {'min_samples_split': 0.0788735861472167, 'max_depth': 25, 'min_samples_leaf': 0.026771064259342867}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:30,478] Trial 417 finished with value: 0.5144213023991563 and parameters: {'min_samples_split': 0.12939717131802053, 'max_depth': 27, 'min_samples_leaf': 0.08686441481345118}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:36,506] Trial 418 finished with value: 0.5165304508304771 and parameters: {'min_samples_split': 0.1186730827027005, 'max_depth': 26, 'min_samples_leaf': 0.03306982508225029}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:43,574] Trial 419 finished with value: 0.518692327972581 and parameters: {'min_samples_split': 0.10512370568609872, 'max_depth': 16, 'min_samples_leaf': 0.017400400507487347}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:53,715] Trial 420 finished with value: 0.5191668863696283 and parameters: {'min_samples_split': 0.022853894799314142, 'max_depth': 25, 'min_samples_leaf': 0.010504436729025068}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:06:59,030] Trial 421 finished with value: 0.5173741102030054 and parameters: {'min_samples_split': 0.13544166465820234, 'max_depth': 22, 'min_samples_leaf': 0.052130763051655704}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:01,127] Trial 422 finished with value: 0.5087793303453731 and parameters: {'min_samples_split': 0.1113889975452593, 'max_depth': 28, 'min_samples_leaf': 0.28036889700571505}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:07,527] Trial 423 finished with value: 0.518639599261798 and parameters: {'min_samples_split': 0.09506373820347994, 'max_depth': 24, 'min_samples_leaf': 0.03724580805118459}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:10,849] Trial 424 finished with value: 0.5144213023991563 and parameters: {'min_samples_split': 0.43328638281763693, 'max_depth': 25, 'min_samples_leaf': 0.025187576295915195}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:17,046] Trial 425 finished with value: 0.5180068547324018 and parameters: {'min_samples_split': 0.08596367584991632, 'max_depth': 24, 'min_samples_leaf': 0.0420502446840773}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:22,578] Trial 426 finished with value: 0.518692327972581 and parameters: {'min_samples_split': 0.12394396738781609, 'max_depth': 4, 'min_samples_leaf': 0.025873575593128875}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:25,817] Trial 427 finished with value: 0.5152122330609016 and parameters: {'min_samples_split': 0.40264052240155157, 'max_depth': 28, 'min_samples_leaf': 0.0567931113626054}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:32,228] Trial 428 finished with value: 0.5166359082520433 and parameters: {'min_samples_split': 0.09962850741689588, 'max_depth': 23, 'min_samples_leaf': 0.033793606448377846}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:37,388] Trial 429 finished with value: 0.5166359082520432 and parameters: {'min_samples_split': 0.24010075494069993, 'max_depth': 26, 'min_samples_leaf': 0.017849804759793846}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:43,571] Trial 430 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.04997891920000221, 'max_depth': 26, 'min_samples_leaf': 0.044140165353930456}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:51,332] Trial 431 finished with value: 0.5171104666490904 and parameters: {'min_samples_split': 0.10568232160245081, 'max_depth': 25, 'min_samples_leaf': 0.010398823634253242}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:07:57,733] Trial 432 finished with value: 0.518639599261798 and parameters: {'min_samples_split': 0.11773790146433741, 'max_depth': 27, 'min_samples_leaf': 0.026174489281644932}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:04,261] Trial 433 finished with value: 0.5154758766148169 and parameters: {'min_samples_split': 0.010725959603839133, 'max_depth': 26, 'min_samples_leaf': 0.03551660040910221}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:10,619] Trial 434 finished with value: 0.5177959398892698 and parameters: {'min_samples_split': 0.14150420240446593, 'max_depth': 29, 'min_samples_leaf': 0.021058501402378714}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:11,536] Trial 435 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.10987713051807992, 'max_depth': 25, 'min_samples_leaf': 0.35021907052801104}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:17,396] Trial 436 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.08863578531529953, 'max_depth': 24, 'min_samples_leaf': 0.04798193040126038}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:23,867] Trial 437 finished with value: 0.5172159240706564 and parameters: {'min_samples_split': 0.09714745534286534, 'max_depth': 24, 'min_samples_leaf': 0.031002320429878768}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:28,992] Trial 438 finished with value: 0.5156867914579488 and parameters: {'min_samples_split': 0.12784389751878636, 'max_depth': 26, 'min_samples_leaf': 0.062341120577654396}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:36,386] Trial 439 finished with value: 0.5177432111784868 and parameters: {'min_samples_split': 0.12147810119803469, 'max_depth': 25, 'min_samples_leaf': 0.010499567113283476}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:44,507] Trial 440 finished with value: 0.5194305299235433 and parameters: {'min_samples_split': 0.036255584650138596, 'max_depth': 27, 'min_samples_leaf': 0.020702629595252917}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:50,684] Trial 441 finished with value: 0.5177959398892698 and parameters: {'min_samples_split': 0.07567365788723932, 'max_depth': 25, 'min_samples_leaf': 0.04125543324439106}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:51,637] Trial 442 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.1090167570654412, 'max_depth': 23, 'min_samples_leaf': 0.41685722702447126}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:08:54,512] Trial 443 finished with value: 0.510941207487477 and parameters: {'min_samples_split': 0.27452340379460205, 'max_depth': 26, 'min_samples_leaf': 0.1611491045944597}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:01,138] Trial 444 finished with value: 0.5171631953598734 and parameters: {'min_samples_split': 0.09598701819715488, 'max_depth': 24, 'min_samples_leaf': 0.03094062688422399}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:06,625] Trial 445 finished with value: 0.5171104666490904 and parameters: {'min_samples_split': 0.08022999558970068, 'max_depth': 25, 'min_samples_leaf': 0.054453266191399174}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:10,223] Trial 446 finished with value: 0.5149485895069865 and parameters: {'min_samples_split': 0.11881748897318231, 'max_depth': 27, 'min_samples_leaf': 0.1185757038621118}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:18,079] Trial 447 finished with value: 0.5171631953598735 and parameters: {'min_samples_split': 0.06275509263415671, 'max_depth': 28, 'min_samples_leaf': 0.019372432319728527}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:24,589] Trial 448 finished with value: 0.5155813340363828 and parameters: {'min_samples_split': 0.027210258546262116, 'max_depth': 26, 'min_samples_leaf': 0.03796106748203032}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:29,417] Trial 449 finished with value: 0.5151067756393355 and parameters: {'min_samples_split': 0.10211310515846564, 'max_depth': 23, 'min_samples_leaf': 0.07382542730660913}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:31,943] Trial 450 finished with value: 0.5106248352227788 and parameters: {'min_samples_split': 0.11339278344007078, 'max_depth': 26, 'min_samples_leaf': 0.18725172470052515}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:39,621] Trial 451 finished with value: 0.5189032428157132 and parameters: {'min_samples_split': 0.08799980248637593, 'max_depth': 24, 'min_samples_leaf': 0.02668920801460014}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:45,602] Trial 452 finished with value: 0.518534141840232 and parameters: {'min_samples_split': 0.1064014712604592, 'max_depth': 25, 'min_samples_leaf': 0.04690106987888526}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:50,591] Trial 453 finished with value: 0.5177432111784868 and parameters: {'min_samples_split': 0.2637501666980164, 'max_depth': 24, 'min_samples_leaf': 0.023124528114013165}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:09:57,168] Trial 454 finished with value: 0.5164249934089111 and parameters: {'min_samples_split': 0.13380106445923534, 'max_depth': 27, 'min_samples_leaf': 0.01077405864013535}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:02,876] Trial 455 finished with value: 0.51605589243343 and parameters: {'min_samples_split': 0.09445243809193613, 'max_depth': 25, 'min_samples_leaf': 0.03504866012139633}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:09,319] Trial 456 finished with value: 0.5183232269970999 and parameters: {'min_samples_split': 0.103521998326323, 'max_depth': 32, 'min_samples_leaf': 0.01941605781953978}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:14,090] Trial 457 finished with value: 0.5155813340363827 and parameters: {'min_samples_split': 0.020789012493953655, 'max_depth': 26, 'min_samples_leaf': 0.05942111072585826}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:20,537] Trial 458 finished with value: 0.5195887160558923 and parameters: {'min_samples_split': 0.042421838025737846, 'max_depth': 25, 'min_samples_leaf': 0.03140695830697588}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:25,861] Trial 459 finished with value: 0.5174268389137885 and parameters: {'min_samples_split': 0.11662488742308821, 'max_depth': 22, 'min_samples_leaf': 0.04502343428994688}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:32,296] Trial 460 finished with value: 0.5181650408647508 and parameters: {'min_samples_split': 0.08526489612270707, 'max_depth': 24, 'min_samples_leaf': 0.027458503484240365}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:37,537] Trial 461 finished with value: 0.5176904824677037 and parameters: {'min_samples_split': 0.12640494540205177, 'max_depth': 29, 'min_samples_leaf': 0.04077086318810736}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:43,962] Trial 462 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.10950689892787036, 'max_depth': 25, 'min_samples_leaf': 0.01761628117090308}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:47,730] Trial 463 finished with value: 0.5156340627471658 and parameters: {'min_samples_split': 0.24946192288397795, 'max_depth': 23, 'min_samples_leaf': 0.06928301386626817}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:48,605] Trial 464 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.15336144917830416, 'max_depth': 27, 'min_samples_leaf': 0.4785709627091864}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:53,429] Trial 465 finished with value: 0.5154758766148168 and parameters: {'min_samples_split': 0.13122332782450113, 'max_depth': 28, 'min_samples_leaf': 0.05019130034255608}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:10:59,070] Trial 466 finished with value: 0.5181123121539677 and parameters: {'min_samples_split': 0.11684962282286183, 'max_depth': 26, 'min_samples_leaf': 0.032383419021544235}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:04,886] Trial 467 finished with value: 0.5213287635117322 and parameters: {'min_samples_split': 0.14394603851426993, 'max_depth': 26, 'min_samples_leaf': 0.017348598109538215}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:11,341] Trial 468 finished with value: 0.5171631953598734 and parameters: {'min_samples_split': 0.13684378336159583, 'max_depth': 27, 'min_samples_leaf': 0.010557407286544897}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:16,800] Trial 469 finished with value: 0.5173213814922226 and parameters: {'min_samples_split': 0.14772651872664272, 'max_depth': 30, 'min_samples_leaf': 0.0225448720724645}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:23,057] Trial 470 finished with value: 0.5176904824677038 and parameters: {'min_samples_split': 0.14446492099292282, 'max_depth': 26, 'min_samples_leaf': 0.010754989581828576}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:29,390] Trial 471 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.13999766269187738, 'max_depth': 25, 'min_samples_leaf': 0.010157463205356166}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:35,196] Trial 472 finished with value: 0.5175322963353546 and parameters: {'min_samples_split': 0.1285619091683314, 'max_depth': 24, 'min_samples_leaf': 0.02076096928094491}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:40,373] Trial 473 finished with value: 0.5163195359873451 and parameters: {'min_samples_split': 0.1577028040927917, 'max_depth': 26, 'min_samples_leaf': 0.028952979571805208}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:46,389] Trial 474 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.12602976151966572, 'max_depth': 25, 'min_samples_leaf': 0.01970493970104366}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:51,857] Trial 475 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.14601505395959852, 'max_depth': 27, 'min_samples_leaf': 0.027389028138925492}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:11:57,336] Trial 476 finished with value: 0.5169522805167414 and parameters: {'min_samples_split': 0.1144042408944557, 'max_depth': 25, 'min_samples_leaf': 0.03397953532884654}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:02,832] Trial 477 finished with value: 0.5189032428157131 and parameters: {'min_samples_split': 0.17643518791094923, 'max_depth': 26, 'min_samples_leaf': 0.01845085573126612}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:08,128] Trial 478 finished with value: 0.5172159240706564 and parameters: {'min_samples_split': 0.12274657998460206, 'max_depth': 24, 'min_samples_leaf': 0.03726096621883646}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:15,090] Trial 479 finished with value: 0.5153704191932508 and parameters: {'min_samples_split': 0.010052895400088968, 'max_depth': 28, 'min_samples_leaf': 0.024613851717563036}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:20,967] Trial 480 finished with value: 0.5163195359873451 and parameters: {'min_samples_split': 0.1710503253622775, 'max_depth': 26, 'min_samples_leaf': 0.010052339759157019}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:26,465] Trial 481 finished with value: 0.5158449775902979 and parameters: {'min_samples_split': 0.10042285632068088, 'max_depth': 25, 'min_samples_leaf': 0.040504823013129895}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:32,855] Trial 482 finished with value: 0.5165831795412601 and parameters: {'min_samples_split': 0.10654435927551283, 'max_depth': 31, 'min_samples_leaf': 0.018908057795764904}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:37,932] Trial 483 finished with value: 0.5167413656736093 and parameters: {'min_samples_split': 0.16046746996764538, 'max_depth': 24, 'min_samples_leaf': 0.029953069824232542}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:43,672] Trial 484 finished with value: 0.5184814131294491 and parameters: {'min_samples_split': 0.13928995616690176, 'max_depth': 23, 'min_samples_leaf': 0.01933411524858557}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:48,558] Trial 485 finished with value: 0.5167940943843924 and parameters: {'min_samples_split': 0.1220072617298853, 'max_depth': 29, 'min_samples_leaf': 0.053052270256292264}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:54,166] Trial 486 finished with value: 0.5158449775902979 and parameters: {'min_samples_split': 0.1122897202814386, 'max_depth': 27, 'min_samples_leaf': 0.03502775055082381}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:12:57,070] Trial 487 finished with value: 0.5157395201687318 and parameters: {'min_samples_split': 0.4658893215254841, 'max_depth': 26, 'min_samples_leaf': 0.029179908118909234}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:02,569] Trial 488 finished with value: 0.5151595043501187 and parameters: {'min_samples_split': 0.1005484790819358, 'max_depth': 25, 'min_samples_leaf': 0.04242862727878115}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:06,679] Trial 489 finished with value: 0.516003163722647 and parameters: {'min_samples_split': 0.31196842487289195, 'max_depth': 23, 'min_samples_leaf': 0.010032786003796246}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:07,689] Trial 490 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.1298751825907916, 'max_depth': 27, 'min_samples_leaf': 0.32155095742908957}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:11,281] Trial 491 finished with value: 0.5181123121539677 and parameters: {'min_samples_split': 0.34175570067552774, 'max_depth': 26, 'min_samples_leaf': 0.02396134995973509}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:16,508] Trial 492 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.09048765080221441, 'max_depth': 24, 'min_samples_leaf': 0.048546513984417075}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:22,811] Trial 493 finished with value: 0.5212760348009491 and parameters: {'min_samples_split': 0.11438876652607298, 'max_depth': 25, 'min_samples_leaf': 0.01944799336759522}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:29,444] Trial 494 finished with value: 0.5190614289480623 and parameters: {'min_samples_split': 0.098431127221199, 'max_depth': 25, 'min_samples_leaf': 0.017859576130871083}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:35,881] Trial 495 finished with value: 0.518797785394147 and parameters: {'min_samples_split': 0.10986358846742753, 'max_depth': 26, 'min_samples_leaf': 0.016883693269579045}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:41,733] Trial 496 finished with value: 0.5189559715264961 and parameters: {'min_samples_split': 0.10970305990062992, 'max_depth': 25, 'min_samples_leaf': 0.02652927086155028}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:49,016] Trial 497 finished with value: 0.5155813340363828 and parameters: {'min_samples_split': 0.0925930136007437, 'max_depth': 25, 'min_samples_leaf': 0.010831308430189153}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:13:55,618] Trial 498 finished with value: 0.5170577379383074 and parameters: {'min_samples_split': 0.01893977934509284, 'max_depth': 26, 'min_samples_leaf': 0.02669537691156755}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:02,422] Trial 499 finished with value: 0.5168468230951754 and parameters: {'min_samples_split': 0.11748048756311519, 'max_depth': 19, 'min_samples_leaf': 0.010023003850922113}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:06,729] Trial 500 finished with value: 0.516161349854996 and parameters: {'min_samples_split': 0.2816064988965561, 'max_depth': 27, 'min_samples_leaf': 0.0205429896103314}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:12,200] Trial 501 finished with value: 0.5180068547324017 and parameters: {'min_samples_split': 0.13229087117450483, 'max_depth': 26, 'min_samples_leaf': 0.033942674323276745}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:16,125] Trial 502 finished with value: 0.5165831795412602 and parameters: {'min_samples_split': 0.29877071010128464, 'max_depth': 25, 'min_samples_leaf': 0.026032249449127777}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:20,890] Trial 503 finished with value: 0.5174268389137886 and parameters: {'min_samples_split': 0.18743685515499303, 'max_depth': 25, 'min_samples_leaf': 0.03577819412079824}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:27,196] Trial 504 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.1049284745263817, 'max_depth': 27, 'min_samples_leaf': 0.018347493285238554}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:33,106] Trial 505 finished with value: 0.5166359082520433 and parameters: {'min_samples_split': 0.09612008849972699, 'max_depth': 28, 'min_samples_leaf': 0.032988003242486935}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:40,725] Trial 506 finished with value: 0.518534141840232 and parameters: {'min_samples_split': 0.029485826795035766, 'max_depth': 26, 'min_samples_leaf': 0.01879152371265655}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:44,020] Trial 507 finished with value: 0.5168468230951754 and parameters: {'min_samples_split': 0.3720420342571302, 'max_depth': 26, 'min_samples_leaf': 0.025862184183106464}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:49,170] Trial 508 finished with value: 0.5167940943843924 and parameters: {'min_samples_split': 0.11891097983470353, 'max_depth': 24, 'min_samples_leaf': 0.03906799487451947}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:54,358] Trial 509 finished with value: 0.5165831795412601 and parameters: {'min_samples_split': 0.21477404434715444, 'max_depth': 25, 'min_samples_leaf': 0.01053652250211521}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:56,235] Trial 510 finished with value: 0.5074611125757975 and parameters: {'min_samples_split': 0.1482856138309484, 'max_depth': 25, 'min_samples_leaf': 0.2568714080819573}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:14:58,060] Trial 511 finished with value: 0.5106775639335618 and parameters: {'min_samples_split': 0.08486940892159565, 'max_depth': 27, 'min_samples_leaf': 0.29847694357621807}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:03,794] Trial 512 finished with value: 0.5196941734774585 and parameters: {'min_samples_split': 0.10959464776589752, 'max_depth': 26, 'min_samples_leaf': 0.025486474911345248}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:08,874] Trial 513 finished with value: 0.518481413129449 and parameters: {'min_samples_split': 0.13616729382887324, 'max_depth': 28, 'min_samples_leaf': 0.0397311335479789}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:14,652] Trial 514 finished with value: 0.518428684418666 and parameters: {'min_samples_split': 0.12698231847395755, 'max_depth': 24, 'min_samples_leaf': 0.02164410043349469}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:20,379] Trial 515 finished with value: 0.5168995518059584 and parameters: {'min_samples_split': 0.10058358573324705, 'max_depth': 26, 'min_samples_leaf': 0.032562639925570985}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:25,096] Trial 516 finished with value: 0.5161086211442131 and parameters: {'min_samples_split': 0.11388599021998021, 'max_depth': 25, 'min_samples_leaf': 0.057925916435048755}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:31,148] Trial 517 finished with value: 0.5212760348009492 and parameters: {'min_samples_split': 0.12286986456251049, 'max_depth': 27, 'min_samples_leaf': 0.016555681145526517}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:37,148] Trial 518 finished with value: 0.5193250725019773 and parameters: {'min_samples_split': 0.12816748757838362, 'max_depth': 28, 'min_samples_leaf': 0.018866819275920356}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:43,309] Trial 519 finished with value: 0.5192723437911942 and parameters: {'min_samples_split': 0.14144114666926805, 'max_depth': 27, 'min_samples_leaf': 0.01110599426187743}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:49,317] Trial 520 finished with value: 0.5183232269971 and parameters: {'min_samples_split': 0.12252515411601345, 'max_depth': 28, 'min_samples_leaf': 0.01935570778405089}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:56,984] Trial 521 finished with value: 0.5177959398892698 and parameters: {'min_samples_split': 0.02235204178284309, 'max_depth': 27, 'min_samples_leaf': 0.016956214130230532}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:15:58,927] Trial 522 finished with value: 0.5087793303453731 and parameters: {'min_samples_split': 0.13690874715625187, 'max_depth': 27, 'min_samples_leaf': 0.21123044967730376}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:04,914] Trial 523 finished with value: 0.5190087002372792 and parameters: {'min_samples_split': 0.1529063258158734, 'max_depth': 27, 'min_samples_leaf': 0.010706538757001904}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:08,531] Trial 524 finished with value: 0.5148431320854205 and parameters: {'min_samples_split': 0.11997007961260334, 'max_depth': 29, 'min_samples_leaf': 0.10378635438436509}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:13,962] Trial 525 finished with value: 0.5176904824677037 and parameters: {'min_samples_split': 0.12947615654232697, 'max_depth': 26, 'min_samples_leaf': 0.027595089271000357}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:22,959] Trial 526 finished with value: 0.5178486686000527 and parameters: {'min_samples_split': 0.010173219038858438, 'max_depth': 27, 'min_samples_leaf': 0.010349253761157452}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:28,503] Trial 527 finished with value: 0.5180068547324018 and parameters: {'min_samples_split': 0.11256104393531355, 'max_depth': 21, 'min_samples_leaf': 0.03303699742538704}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:32,438] Trial 528 finished with value: 0.5170050092275245 and parameters: {'min_samples_split': 0.10254993259850309, 'max_depth': 26, 'min_samples_leaf': 0.08161852341225814}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:38,815] Trial 529 finished with value: 0.515950435011864 and parameters: {'min_samples_split': 0.07539958509124407, 'max_depth': 30, 'min_samples_leaf': 0.024588719825275357}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:43,433] Trial 530 finished with value: 0.5163195359873451 and parameters: {'min_samples_split': 0.16809111673258148, 'max_depth': 26, 'min_samples_leaf': 0.042679512243892485}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:49,048] Trial 531 finished with value: 0.5195887160558925 and parameters: {'min_samples_split': 0.11806736307912638, 'max_depth': 28, 'min_samples_leaf': 0.027229934713831713}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:16:57,697] Trial 532 finished with value: 0.5153176904824677 and parameters: {'min_samples_split': 0.03672747991946887, 'max_depth': 25, 'min_samples_leaf': 0.010033074929467947}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:04,123] Trial 533 finished with value: 0.5183759557078831 and parameters: {'min_samples_split': 0.08971681940562762, 'max_depth': 27, 'min_samples_leaf': 0.018846722419334338}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:07,151] Trial 534 finished with value: 0.5146322172422885 and parameters: {'min_samples_split': 0.10726836062357277, 'max_depth': 26, 'min_samples_leaf': 0.1397017637241656}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:12,333] Trial 535 finished with value: 0.5205905615607699 and parameters: {'min_samples_split': 0.13602650052304255, 'max_depth': 18, 'min_samples_leaf': 0.035720741361599716}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:17,445] Trial 536 finished with value: 0.5187977853941471 and parameters: {'min_samples_split': 0.14648288189979558, 'max_depth': 17, 'min_samples_leaf': 0.0318888535974734}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:22,743] Trial 537 finished with value: 0.5172159240706564 and parameters: {'min_samples_split': 0.15468356277585066, 'max_depth': 12, 'min_samples_leaf': 0.021441098141786036}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:27,840] Trial 538 finished with value: 0.5179013973108357 and parameters: {'min_samples_split': 0.13692122722961364, 'max_depth': 11, 'min_samples_leaf': 0.03951964410109908}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:33,193] Trial 539 finished with value: 0.518375955707883 and parameters: {'min_samples_split': 0.13153372435565705, 'max_depth': 16, 'min_samples_leaf': 0.02800707019644696}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:38,810] Trial 540 finished with value: 0.5196414447666754 and parameters: {'min_samples_split': 0.14182709992428194, 'max_depth': 23, 'min_samples_leaf': 0.018853231428582362}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:44,050] Trial 541 finished with value: 0.5171631953598734 and parameters: {'min_samples_split': 0.12655378721507438, 'max_depth': 20, 'min_samples_leaf': 0.03387566544279244}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:48,641] Trial 542 finished with value: 0.5153176904824678 and parameters: {'min_samples_split': 0.1594185616954512, 'max_depth': 24, 'min_samples_leaf': 0.04563204145506549}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:49,518] Trial 543 finished with value: 0.49997363564460845 and parameters: {'min_samples_split': 0.12124060429403893, 'max_depth': 22, 'min_samples_leaf': 0.4467057281572606}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:17:55,192] Trial 544 finished with value: 0.5175850250461377 and parameters: {'min_samples_split': 0.13588900845408172, 'max_depth': 13, 'min_samples_leaf': 0.01969424625701381}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:18:00,839] Trial 545 finished with value: 0.5191668863696284 and parameters: {'min_samples_split': 0.11321550147499787, 'max_depth': 24, 'min_samples_leaf': 0.028587397175409042}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:18:05,979] Trial 546 finished with value: 0.5163722646981281 and parameters: {'min_samples_split': 0.12327058700576499, 'max_depth': 23, 'min_samples_leaf': 0.03711842045868546}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:18:13,025] Trial 547 finished with value: 0.5159504350118639 and parameters: {'min_samples_split': 0.09659347218633908, 'max_depth': 18, 'min_samples_leaf': 0.010234100825925315}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:18:18,881] Trial 548 finished with value: 0.5191668863696283 and parameters: {'min_samples_split': 0.10554181829287634, 'max_depth': 25, 'min_samples_leaf': 0.02488033803460399}. Best is trial 243 with value: 0.5231945176594623.
# [I 2021-09-16 23:18:25,152] Trial 549 finished with value: 0.5147904033746376 and parameters: {'min_samples_split': 0.1437127526589009, 'max_depth': 24, 'min_samples_leaf': 0.010060354482618774}. Best is trial 243 with value: 0.5231945176594623.

# %%
print(study_rf.best_params)

max_depth = study_rf.best_params['max_depth']
min_samples_leaf = study_rf.best_params['min_samples_leaf']
min_samples_split = study_rf.best_params['min_samples_split']


best_rf = RandomForestClassifier(max_depth=max_depth,
                                min_samples_leaf=min_samples_leaf,
                                min_samples_split=min_samples_split,
                                random_state=23)
# Out:
# {'max_depth': 25, 'min_samples_leaf': 0.01976415081790831, 'min_samples_split': 0.10607525263857515}

# %%
best_rf.fit(X_train, y_train)

print("rf train_acc:", best_rf.score(X_train, y_train))
print("rf test_acc:", best_rf.score(X_test, y_test))
# Out:
# rf train_acc: 0.564650059311981
# rf test_acc: 0.5072091994692614

# %%
view_model_coefs(best_rf, X_train)
# Out:
# LGBoost or XGBoost
#                 feature_name      coef
# 66                 rest_diff  0.000972
# 37             FG3M_opp_diff  0.001429
# 20    E_OFF_RATING_team_diff  0.001514
# 53     E_NET_RATING_opp_diff  0.002010
# 52     E_DEF_RATING_opp_diff  0.002091
# 16             TOV_team_diff  0.002362
# 50       PLUS_MINUS_opp_diff  0.002448
# 70         DREB_PCT_opp_diff  0.002520
# 49              PTS_opp_diff  0.002743
# 13             AST_team_diff  0.003057
# 40              FTA_opp_diff  0.003295
# 82             team_rating_i  0.003349
# 8              FTM_team_diff  0.003410
# 81             team_elo_pred  0.003425
# 11            DREB_team_diff  0.003465
# 55              PIE_opp_diff  0.003916
# 71         REB_PCT_team_diff  0.004120
# 21    E_DEF_RATING_team_diff  0.004511
# 36             FG2A_opp_diff  0.004626
# 83              opp_rating_i  0.004650
# 72          REB_PCT_opp_diff  0.004758
# 19      PLUS_MINUS_team_diff  0.005257
# 10            OREB_team_diff  0.005337
# 39              FTM_opp_diff  0.005431
# 24             PIE_team_diff  0.005489
# 79         TOV_PCT_team_diff  0.005588
# 42             DREB_opp_diff  0.005612
# 84              elo_MOV_pred  0.005631
# 46              BLK_opp_diff  0.005694
# 75         EFG_PCT_team_diff  0.005724
# 67        OREB_PCT_team_diff  0.005783
# 22    E_NET_RATING_team_diff  0.005812
# 23            POSS_team_diff  0.005833
# 51     E_OFF_RATING_opp_diff  0.006010
# 48               PF_opp_diff  0.006221
# 64            WL_record_diff  0.006473
# 1                 avg_spread  0.006485
# 9              FTA_team_diff  0.006487
# 29         AST_2PM_team_diff  0.006502
# 73          TS_PCT_team_diff  0.006865
# 14             STL_team_diff  0.007245
# 45              STL_opp_diff  0.007290
# 30        UAST_2PM_team_diff  0.007438
# 15             BLK_team_diff  0.007663
# 17              PF_team_diff  0.007667
# 3   points_covered_spread_by  0.007716
# 43              REB_opp_diff  0.007724
# 28       PTS_PAINT_team_diff  0.007855
# 47              TOV_opp_diff  0.009147
# 6             FG3M_team_diff  0.009249
# 2      avg_point_spread_diff  0.009381
# 65           ATS_record_diff  0.009542
# 69        DREB_PCT_team_diff  0.010057
# 58      PTS_OFF_TOV_opp_diff  0.010142
# 61         UAST_2PM_opp_diff  0.010275
# 33     team_covered_opp_diff  0.010910
# 35             FG2M_opp_diff  0.011093
# 68         OREB_PCT_opp_diff  0.011163
# 54             POSS_opp_diff  0.011731
# 77       AST_RATIO_team_diff  0.011981
# 0                     avg_ml  0.012038
# 12             REB_team_diff  0.012103
# 76          EFG_PCT_opp_diff  0.012121
# 80          TOV_PCT_opp_diff  0.012151
# 34           RECORD_opp_diff  0.014485
# 62          AST_3PM_opp_diff  0.014602
# 85                    spread  0.015069
# 59        PTS_PAINT_opp_diff  0.018102
# 38             FG3A_opp_diff  0.018749
# 26          PTS_FB_team_diff  0.019376
# 44              AST_opp_diff  0.019534
# 18             PTS_team_diff  0.020326
# 74           TS_PCT_opp_diff  0.021964
# 4             FG2M_team_diff  0.022519
# 78        AST_RATIO_opp_diff  0.023398
# 32        UAST_3PM_team_diff  0.026255
# 63         UAST_3PM_opp_diff  0.028852
# 56       PTS_2PT_MR_opp_diff  0.029076
# 5             FG2A_team_diff  0.030273
# 60          AST_2PM_opp_diff  0.031766
# 41             OREB_opp_diff  0.032465
# 27     PTS_OFF_TOV_team_diff  0.035750
# 25      PTS_2PT_MR_team_diff  0.038456
# 57           PTS_FB_opp_diff  0.040444
# 31         AST_3PM_team_diff  0.042942
# 7             FG3A_team_diff  0.045011

# %% [markdown]
# ## Stacked Classifier

# %%
estimators = [('log', best_lr), ('sgd', best_sgd),
              ('svc', best_svc), ('lgbc', best_lgbc), 
              ('rf', best_rf), ('knn', best_knn)]


stacked_clf = StackingClassifier(estimators = estimators, final_estimator = LogisticRegression(),
                                 n_jobs=-1, verbose=1)


# stacked_clf2.fit(X_train, y_train)


# print("stacked clf train_acc:", stacked_clf2.score(X_train, y_train))
# print("stacked clf test_acc:", stacked_clf2.score(X_test, y_test))

cutoffs = [cutoff_16, cutoff_17, cutoff_18, cutoff_19, cutoff_20, cutoff_21]

threshold = 0.53

for estimator in [stacked_clf]:
    season = []
    win_pcts = []
    rois = []
    profits = []
    num_games_bet = []
    best_thresholds = []
    for i in range(len(cutoffs)-1):
        X_train1, X_test1, y_train1, y_test1, train_idx1, test_idx1 = split_prep_data(df_ewm_19_diffs, cutoffs[i])

        X_test1, y_test1, test_idx1 = (X_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       y_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       X_test1.loc[cutoffs[i]+1:cutoffs[i+1]].index)

        print(i)
        print("test set 1:", np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='D'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='D'))

        year = (np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='Y'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='Y'))


        estimator.fit(X_train1, y_train1)
        try:
            y_probs = estimator.predict_proba(X_test1)
        except:
            decisions = estimator.decision_function(X_test1)
            y_probs = 1 / (1 + np.exp(-decisions))
            y_probs = np.concatenate([np.zeros_like(y_probs).reshape(-1,1), y_probs.reshape(-1,1)], axis=1)
        
        betting_df = create_betting_df(df_ewm_19_diffs, y_probs, test_idx1)

        
        select_bets = betting_df.loc[~betting_df['prob_avg'].between(1-threshold, threshold)]
        
        selected_bets, roi, profit, win_pct = simulate_bets_3(select_bets)

        season.append(year)
        best_thresholds.append(threshold)
        win_pcts.append(win_pct)
        profits.append(profit)
        rois.append(roi)
        num_games_bet.append(selected_bets.shape[0])

    results_by_season = pd.DataFrame({
                                    'season':season,
                                    'best_threshold':best_thresholds,
                                     'win_pcts':win_pcts,
                                     'num_games_bet':num_games_bet,
                                     'rois':rois,
                                      'profits':profits
                                     })
    
    print('\n', estimator)
    print(results_by_season)

results_by_season
# Out:
# 0
# test set 1: 2016-11-04 - 2017-06-12
# min balance: 15.36363636363648
# max balance: 188.09090909090864
# final balance: 157.36363636363575
# win percentage 53.800000000000004
# profit: 57.36363636363626 risk: 2203.0
# ROI: 2.6
# 1
# test set 1: 2017-10-28 - 2018-06-08
# min balance: 12.727272727272808
# max balance: 158.18181818181813
# final balance: 97.45454545454537
# win percentage 52.27
# profit: -2.5454545454547315 risk: 2366.0
# ROI: -0.11
# 2
# test set 1: 2018-10-26 - 2019-06-13
# min balance: 32.545454545454554
# max balance: 200.3636363636354
# final balance: 128.90909090908974
# win percentage 52.900000000000006
# profit: 28.909090909090878 risk: 1821.0
# ROI: 1.59
# 3
# test set 1: 2019-11-01 - 2020-10-11
# min balance: 93.27272727272727
# max balance: 168.27272727272694
# final balance: 147.9999999999994
# win percentage 54.15
# profit: 47.999999999999886 risk: 1590.0
# ROI: 3.02
# 4
# test set 1: 2021-01-01 - 2021-07-20
# min balance: 103.72727272727273
# max balance: 176.7272727272724
# final balance: 170.36363636363532
# win percentage 56.589999999999996
# profit: 70.36363636363632 risk: 909.0
# ROI: 7.739999999999999
#
#  StackingClassifier(estimators=[('log',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('logreg',
#                                                  LogisticRegression(C=0.0011798799724438123,
#                                                                     max_iter=10000,
#                                                                     random_state=23,
#                                                                     solver='saga',
#                                                                     verbose=1))])),
#                                ('sgd',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('sgd',
#                                                  SGDClassifier(alpha=0.26825005402846946,
#                                                                loss='modified_huber',
#                                                                max_iter=10000,
#                                                                random_state=23))]))...
#                                                reg_alpha=3.571940784753475,
#                                                reg_lambda=17.76958546447963)),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=25,
#                                                        min_samples_leaf=0.01976415081790831,
#                                                        min_samples_split=0.10607525263857515,
#                                                        random_state=23)),
#                                ('knn',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('knn',
#                                                  KNeighborsClassifier(n_neighbors=24))]))],
#                    final_estimator=LogisticRegression(), n_jobs=-1, verbose=1)
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.537975            474  0.026039
# 1  (2017, -, 2018)            0.53  0.522682            507 -0.001076
# 2  (2018, -, 2019)            0.53  0.528967            397  0.015875
# 3  (2019, -, 2020)            0.53  0.541547            349  0.030189
# 4  (2021, -, 2021)            0.53  0.565854            205  0.077408
#
#      profits
# 0  57.363636
# 1  -2.545455
# 2  28.909091
# 3  48.000000
# 4  70.363636
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.537975            474  0.026039
# 1  (2017, -, 2018)            0.53  0.522682            507 -0.001076
# 2  (2018, -, 2019)            0.53  0.528967            397  0.015875
# 3  (2019, -, 2020)            0.53  0.541547            349  0.030189
# 4  (2021, -, 2021)            0.53  0.565854            205  0.077408
#
#      profits
# 0  57.363636
# 1  -2.545455
# 2  28.909091
# 3  48.000000
# 4  70.363636

# %%
best_lr_acc = Pipeline(steps=[('scaler', StandardScaler()),
                ('logreg',
                 LogisticRegression(C=0.001258237256125393, max_iter=10000,
                                    random_state=22, solver='saga',
                                    verbose=1))])

best_svc_acc = Pipeline(steps=[('scaler', StandardScaler()),
                ('svc',
                 LinearSVC(C=0.003958061983606178, loss='hinge',
                           max_iter=100000, random_state=23))])

best_sgd_acc = Pipeline(steps=[('scaler', StandardScaler()),
                ('sgd',
                 SGDClassifier(alpha=0.1572381278512917, loss='modified_huber',
                               max_iter=10000, random_state=23))])

best_lgbc_acc = lgb.LGBMClassifier(feature_fraction=0.7796269937403173, max_depth=5,
               min_child_weight=7, num_leaves=16860, random_state=22,
               reg_alpha=3.571940784753475, reg_lambda=17.76958546447963)

best_knn_acc = Pipeline(steps=[('scaler', StandardScaler()),
                ('knn', KNeighborsClassifier(n_neighbors=24))])

best_rf_acc = RandomForestClassifier(max_depth=25,
                                min_samples_leaf=0.019764150817908317,
                                min_samples_split=0.10607525263857515,
                                random_state=22)

estimators2 = [('log', best_lr_acc), ('sgd', best_sgd_acc),
              ('svc', best_svc_acc), ('lgbc', best_lgbc_acc), 
              ('rf', best_rf_acc), ('knn', best_knn_acc)]


stacked_clf2 = StackingClassifier(estimators = estimators2, final_estimator = LogisticRegression(),
                                 n_jobs=-1, verbose=1)


# stacked_clf2.fit(X_train, y_train)


# print("stacked clf train_acc:", stacked_clf2.score(X_train, y_train))
# print("stacked clf test_acc:", stacked_clf2.score(X_test, y_test))

# %%
cutoffs = [cutoff_16, cutoff_17, cutoff_18, cutoff_19, cutoff_20, cutoff_21]

threshold = 0.53

for estimator in [stacked_clf2]:
    season = []
    win_pcts = []
    rois = []
    profits = []
    num_games_bet = []
    best_thresholds = []
    for i in range(len(cutoffs)-1):
        X_train1, X_test1, y_train1, y_test1, train_idx1, test_idx1 = split_prep_data(df_ewm_19_diffs, cutoffs[i])

        X_test1, y_test1, test_idx1 = (X_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       y_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       X_test1.loc[cutoffs[i]+1:cutoffs[i+1]].index)

        print(i)
        print("test set 1:", np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='D'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='D'))

        year = (np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='Y'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='Y'))


        estimator.fit(X_train1, y_train1)
        try:
            y_probs = estimator.predict_proba(X_test1)
        except:
            decisions = estimator.decision_function(X_test1)
            y_probs = 1 / (1 + np.exp(-decisions))
            y_probs = np.concatenate([np.zeros_like(y_probs).reshape(-1,1), y_probs.reshape(-1,1)], axis=1)
        
        betting_df = create_betting_df(df_ewm_19_diffs, y_probs, test_idx1)

        
        select_bets = betting_df.loc[~betting_df['prob_avg'].between(1-threshold, threshold)]
        
        selected_bets, roi, profit, win_pct = simulate_bets_3(select_bets)

        season.append(year)
        best_thresholds.append(threshold)
        win_pcts.append(win_pct)
        profits.append(profit)
        rois.append(roi)
        num_games_bet.append(selected_bets.shape[0])

    results_by_season = pd.DataFrame({
                                    'season':season,
                                    'best_threshold':best_thresholds,
                                     'win_pcts':win_pcts,
                                     'num_games_bet':num_games_bet,
                                     'rois':rois,
                                      'profits':profits
                                     })
    
    print('\n', estimator)
    print(results_by_season)

results_by_season
# Out:
# 0
# test set 1: 2016-11-04 - 2017-06-12
# min balance: 6.545454545454625
# max balance: 189.99999999999957
# final balance: 165.63636363636303
# win percentage 53.620000000000005
# profit: 65.63636363636351 risk: 2189.0
# ROI: 3.0
# 1
# test set 1: 2017-10-28 - 2018-06-08
# min balance: 11.36363636363652
# max balance: 158.45454545454544
# final balance: 52.09090909090921
# win percentage 51.32
# profit: -47.90909090909099 risk: 2482.0
# ROI: -1.9300000000000002
# 2
# test set 1: 2018-10-26 - 2019-06-13
# min balance: 27.090909090909136
# max balance: 181.4545454545445
# final balance: 119.90909090908988
# win percentage 52.55
# profit: 19.909090909090878 risk: 1893.0
# ROI: 1.05
# 3
# test set 1: 2019-11-01 - 2020-10-11
# min balance: 92.81818181818183
# max balance: 180.7272727272722
# final balance: 134.18181818181765
# win percentage 53.52
# profit: 34.18181818181813 risk: 1621.0
# ROI: 2.11
# 4
# test set 1: 2021-01-01 - 2021-07-20
# min balance: 98.63636363636364
# max balance: 214.36363636363544
# final balance: 190.6363636363623
# win percentage 56.95
# profit: 90.63636363636363 risk: 988.0
# ROI: 9.17
#
#  StackingClassifier(estimators=[('log',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('logreg',
#                                                  LogisticRegression(C=0.001258237256125393,
#                                                                     max_iter=10000,
#                                                                     random_state=22,
#                                                                     solver='saga',
#                                                                     verbose=1))])),
#                                ('sgd',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('sgd',
#                                                  SGDClassifier(alpha=0.1572381278512917,
#                                                                loss='modified_huber',
#                                                                max_iter=10000,
#                                                                random_state=23))])),
#                                (...
#                                                reg_alpha=3.571940784753475,
#                                                reg_lambda=17.76958546447963)),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=25,
#                                                        min_samples_leaf=0.01976415081790832,
#                                                        min_samples_split=0.10607525263857515,
#                                                        random_state=22)),
#                                ('knn',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('knn',
#                                                  KNeighborsClassifier(n_neighbors=24))]))],
#                    final_estimator=LogisticRegression(), n_jobs=-1, verbose=1)
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.536170            470  0.029985
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.019303
# 2  (2018, -, 2019)            0.53  0.525547            411  0.010517
# 3  (2019, -, 2020)            0.53  0.535211            355  0.021087
# 4  (2021, -, 2021)            0.53  0.569507            223  0.091737
#
#      profits
# 0  65.636364
# 1 -47.909091
# 2  19.909091
# 3  34.181818
# 4  90.636364
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.536170            470  0.029985
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.019303
# 2  (2018, -, 2019)            0.53  0.525547            411  0.010517
# 3  (2019, -, 2020)            0.53  0.535211            355  0.021087
# 4  (2021, -, 2021)            0.53  0.569507            223  0.091737
#
#      profits
# 0  65.636364
# 1 -47.909091
# 2  19.909091
# 3  34.181818
# 4  90.636364

# %%
cutoffs = [cutoff_16, cutoff_17, cutoff_18, cutoff_19, cutoff_20, cutoff_21]

threshold = 0.53

for estimator in [stacked_clf2]:
    season = []
    win_pcts = []
    rois = []
    profits = []
    num_games_bet = []
    best_thresholds = []
    for i in range(len(cutoffs)-1):
        X_train1, X_test1, y_train1, y_test1, train_idx1, test_idx1 = split_prep_data(df_ewm_19_diffs, cutoffs[i])

        X_test1, y_test1, test_idx1 = (X_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       y_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       X_test1.loc[cutoffs[i]+1:cutoffs[i+1]].index)

        print(i)
        print("test set 1:", np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='D'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='D'))

        year = (np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='Y'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='Y'))


        estimator.fit(X_train1, y_train1)
        try:
            y_probs = estimator.predict_proba(X_test1)
        except:
            decisions = estimator.decision_function(X_test1)
            y_probs = 1 / (1 + np.exp(-decisions))
            y_probs = np.concatenate([np.zeros_like(y_probs).reshape(-1,1), y_probs.reshape(-1,1)], axis=1)
        
        betting_df = create_betting_df(df_ewm_19_diffs, y_probs, test_idx1)

        
        select_bets = betting_df.loc[~betting_df['prob_avg'].between(1-threshold, threshold)]
        
        selected_bets, roi, profit, win_pct = simulate_bets_2(select_bets, unit_pct=0.03)

        season.append(year)
        best_thresholds.append(threshold)
        win_pcts.append(win_pct)
        profits.append(profit)
        rois.append(roi)
        num_games_bet.append(selected_bets.shape[0])

    results_by_season = pd.DataFrame({
                                    'season':season,
                                    'best_threshold':best_thresholds,
                                     'win_pcts':win_pcts,
                                     'num_games_bet':num_games_bet,
                                     'rois':rois,
                                      'profits':profits
                                     })
    
    print('\n', estimator)
    print(results_by_season)

results_by_season
# Out:
# 0
# test set 1: 2016-11-04 - 2017-06-12
# min balance: 51.95931418569775
# max balance: 137.1196961017868
# final balance: 118.65264767409444
# win percentage 53.73
# profit: 18.652647674094396 risk: 1192.5157733411133
# ROI: 1.5599999999999998
# 1
# test set 1: 2017-10-28 - 2018-06-08
# min balance: 53.078477196476335
# max balance: 127.18206300089665
# final balance: 58.29532195061766
# win percentage 51.32
# profit: -41.70467804938244 risk: 1350.6986843431337
# ROI: -3.09
# 2
# test set 1: 2018-10-26 - 2019-06-13
# min balance: 57.47882989311353
# max balance: 135.63678545005874
# final balance: 88.02620525821162
# win percentage 52.55
# profit: -11.973794741788538 risk: 1205.5090846965707
# ROI: -0.9900000000000001
# 3
# test set 1: 2019-11-01 - 2020-10-11
# min balance: 84.64415680167593
# max balance: 148.53485625163472
# final balance: 106.15598328445795
# win percentage 53.39
# profit: 6.155983284457989 risk: 1146.171180097704
# ROI: 0.54
# 4
# test set 1: 2021-01-01 - 2021-07-20
# min balance: 99.64545454545456
# max balance: 210.19439280369414
# final balance: 163.74867588537154
# win percentage 56.95
# profit: 63.748675885371426 risk: 1011.0410842746564
# ROI: 6.3100000000000005
#
#  StackingClassifier(estimators=[('log',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('logreg',
#                                                  LogisticRegression(C=0.001258237256125393,
#                                                                     max_iter=10000,
#                                                                     random_state=22,
#                                                                     solver='saga',
#                                                                     verbose=1))])),
#                                ('sgd',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('sgd',
#                                                  SGDClassifier(alpha=0.1572381278512917,
#                                                                loss='modified_huber',
#                                                                max_iter=10000,
#                                                                random_state=23))])),
#                                (...
#                                                reg_alpha=3.571940784753475,
#                                                reg_lambda=17.76958546447963)),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=25,
#                                                        min_samples_leaf=0.01976415081790832,
#                                                        min_samples_split=0.10607525263857515,
#                                                        random_state=22)),
#                                ('knn',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('knn',
#                                                  KNeighborsClassifier(n_neighbors=24))]))],
#                    final_estimator=LogisticRegression(), n_jobs=-1, verbose=1)
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.537313            469  0.015641
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.030876
# 2  (2018, -, 2019)            0.53  0.525547            411 -0.009933
# 3  (2019, -, 2020)            0.53  0.533898            354  0.005371
# 4  (2021, -, 2021)            0.53  0.569507            223  0.063053
#
#      profits
# 0  18.652648
# 1 -41.704678
# 2 -11.973795
# 3   6.155983
# 4  63.748676
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.537313            469  0.015641
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.030876
# 2  (2018, -, 2019)            0.53  0.525547            411 -0.009933
# 3  (2019, -, 2020)            0.53  0.533898            354  0.005371
# 4  (2021, -, 2021)            0.53  0.569507            223  0.063053
#
#      profits
# 0  18.652648
# 1 -41.704678
# 2 -11.973795
# 3   6.155983
# 4  63.748676

# %%
cutoffs = [cutoff_16, cutoff_17, cutoff_18, cutoff_19, cutoff_20, cutoff_21]

threshold = 0.53

for estimator in [stacked_clf2]:
    season = []
    win_pcts = []
    rois = []
    profits = []
    num_games_bet = []
    best_thresholds = []
    for i in range(len(cutoffs)-1):
        X_train1, X_test1, y_train1, y_test1, train_idx1, test_idx1 = split_prep_data(df_ewm_19_diffs, cutoffs[i])

        X_test1, y_test1, test_idx1 = (X_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       y_test1.loc[cutoffs[i]+1:cutoffs[i+1]], 
                                       X_test1.loc[cutoffs[i]+1:cutoffs[i+1]].index)

        print(i)
        print("test set 1:", np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='D'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='D'))

        year = (np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[0], unit='Y'), "-",
             np.datetime_as_string(df_ewm_19_diffs.loc[test_idx1, 'GAME_DATE'].values[-1], unit='Y'))


        estimator.fit(X_train1, y_train1)
        try:
            y_probs = estimator.predict_proba(X_test1)
        except:
            decisions = estimator.decision_function(X_test1)
            y_probs = 1 / (1 + np.exp(-decisions))
            y_probs = np.concatenate([np.zeros_like(y_probs).reshape(-1,1), y_probs.reshape(-1,1)], axis=1)
        
        betting_df = create_betting_df(df_ewm_19_diffs, y_probs, test_idx1)

        
        select_bets = betting_df.loc[~betting_df['prob_avg'].between(1-threshold, threshold)]
        
        selected_bets, roi, profit, win_pct = simulate_bets_1(select_bets, unit_size=3)

        season.append(year)
        best_thresholds.append(threshold)
        win_pcts.append(win_pct)
        profits.append(profit)
        rois.append(roi)
        num_games_bet.append(selected_bets.shape[0])

    results_by_season = pd.DataFrame({
                                    'season':season,
                                    'best_threshold':best_thresholds,
                                     'win_pcts':win_pcts,
                                     'num_games_bet':num_games_bet,
                                     'rois':rois,
                                      'profits':profits
                                     })
    
    print('\n', estimator)
    print(results_by_season)

results_by_season
# Out:
# 0
# test set 1: 2016-11-04 - 2017-06-12
# min balance: 42.45454545454595
# max balance: 146.3636363636373
# final balance: 133.27272727272813
# win percentage 53.620000000000005
# profit: 33.27272727272725 risk: 1410.0
# ROI: 2.36
# 1
# test set 1: 2017-10-28 - 2018-06-08
# min balance: 44.09090909090962
# max balance: 137.63636363636468
# final balance: 67.81818181818343
# win percentage 51.32
# profit: -32.181818181818244 risk: 1590.0
# ROI: -2.02
# 2
# test set 1: 2018-10-26 - 2019-06-13
# min balance: 49.54545454545478
# max balance: 143.9090909090913
# final balance: 104.0909090909096
# win percentage 52.55
# profit: 4.090909090909008 risk: 1233.0
# ROI: 0.33
# 3
# test set 1: 2019-11-01 - 2020-10-11
# min balance: 93.45454545454547
# max balance: 146.90909090909133
# final balance: 120.45454545454633
# win percentage 53.39
# profit: 20.454545454545382 risk: 1062.0
# ROI: 1.9300000000000002
# 4
# test set 1: 2021-01-01 - 2021-07-20
# min balance: 99.72727272727273
# max balance: 180.1818181818177
# final balance: 158.3636363636356
# win percentage 56.95
# profit: 58.36363636363632 risk: 669.0
# ROI: 8.72
#
#  StackingClassifier(estimators=[('log',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('logreg',
#                                                  LogisticRegression(C=0.001258237256125393,
#                                                                     max_iter=10000,
#                                                                     random_state=22,
#                                                                     solver='saga',
#                                                                     verbose=1))])),
#                                ('sgd',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('sgd',
#                                                  SGDClassifier(alpha=0.1572381278512917,
#                                                                loss='modified_huber',
#                                                                max_iter=10000,
#                                                                random_state=23))])),
#                                (...
#                                                reg_alpha=3.571940784753475,
#                                                reg_lambda=17.76958546447963)),
#                                ('rf',
#                                 RandomForestClassifier(max_depth=25,
#                                                        min_samples_leaf=0.01976415081790832,
#                                                        min_samples_split=0.10607525263857515,
#                                                        random_state=22)),
#                                ('knn',
#                                 Pipeline(steps=[('scaler', StandardScaler()),
#                                                 ('knn',
#                                                  KNeighborsClassifier(n_neighbors=24))]))],
#                    final_estimator=LogisticRegression(), n_jobs=-1, verbose=1)
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.536170            470  0.023598
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.020240
# 2  (2018, -, 2019)            0.53  0.525547            411  0.003318
# 3  (2019, -, 2020)            0.53  0.533898            354  0.019260
# 4  (2021, -, 2021)            0.53  0.569507            223  0.087240
#
#      profits
# 0  33.272727
# 1 -32.181818
# 2   4.090909
# 3  20.454545
# 4  58.363636
#             season  best_threshold  win_pcts  num_games_bet      rois  \
# 0  (2016, -, 2017)            0.53  0.536170            470  0.023598
# 1  (2017, -, 2018)            0.53  0.513208            530 -0.020240
# 2  (2018, -, 2019)            0.53  0.525547            411  0.003318
# 3  (2019, -, 2020)            0.53  0.533898            354  0.019260
# 4  (2021, -, 2021)            0.53  0.569507            223  0.087240
#
#      profits
# 0  33.272727
# 1 -32.181818
# 2   4.090909
# 3  20.454545
# 4  58.363636

# %%
def add_elo_ratings(df, prev_season_final_elo):
    """This function will generate elo_ratings in the elo_df
    """
    df = df.copy()
    df = df.loc[df['HOME_GAME'] == 1]
    # Initialize the following columns

    df['home_elo_pred'] = np.nan

    df['home_rating_i'] = np.nan
    df['home_rating_n'] = np.nan

    df['away_rating_i'] = np.nan
    df['away_rating_n'] = np.nan

    elo_dic = prev_season_final_elo
    for team in elo_dic:
        elo_dic[team] = season_reset(elo_dic[team])
        
    for idx, row in tqdm(df.iterrows(), desc="progress:"):
        home_team_abbr = row['MATCHUP'][:3]
        away_team_abbr = row['MATCHUP'][-3:]
        
        df.loc[idx, 'home_rating_i'] = elo_dic[home_team_abbr]
        df.loc[idx, 'away_rating_i'] = elo_dic[away_team_abbr]

        home_score = row['SCORE_team']
        away_score = home_score - row['point_diff_team']
        home_rating = elo_dic[home_team_abbr]
        away_rating = elo_dic[away_team_abbr]

        home_update, away_update = elo_update(home_score, away_score, home_rating, away_rating)

        df.loc[idx, 'home_rating_n'] = home_rating + home_update
        df.loc[idx, 'away_rating_n'] = away_rating + away_update
        df.loc[idx, 'home_elo_pred'] = elo_prediction(home_rating+100, away_rating)

    df['elo_MOV_pred'] = round((df['home_rating_i']+100 - df['away_rating_i'])/28, 2)

    return df

df_2020 = add_elo_ratings(df_2020, final_elo_2020)
# Out:
# progress:: 603it [00:00, 716.17it/s]

# %% [markdown]
# ## Make Predictions
#
# ETL Pipeline

# %% [markdown]
# ### Update Date

# %%
from src.data.update_data import update_all_data
from src.data.update_data import update_moneyline_data
from src.data.update_data import update_spread_data

update_all_data(season='2020-21')
update_spread_data(season='2020-21')
update_moneyline_data(season='2020-21')
# Out:
# updating basic team boxscores
# updating basic player boxscores
# updating advanced boxscores
# progress:   0%|                                                                                 | 0/10 [00:00<?, ?it/s]
# Updating 10 Games
# progress: 100%|████████████████████████████████████████████████████████████████████████| 10/10 [00:22<00:00,  2.26s/it]
# updating scoring boxscores
# progress:   0%|                                                                                 | 0/10 [00:00<?, ?it/s]
# Updating 10 Games
# progress: 100%|████████████████████████████████████████████████████████████████████████| 10/10 [00:24<00:00,  2.50s/it]
# updating tracking boxscores
# Updating 10 Games
# progress: 100%|████████████████████████████████████████████████████████████████████████| 10/10 [00:23<00:00,  2.31s/it]
# progress:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
# Updating lines for 1 days
# progress: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:11<00:00, 11.70s/it]
# progress:   0%|                                                                                  | 0/1 [00:00<?, ?it/s]
# Updating lines for 1 days
# progress: 100%|██████████████████████████████████████████████████████████████████████████| 1/1 [00:12<00:00, 12.00s/it]

# %% [markdown]
# ### Get Todays Betting Data

# %%
from src.models.model_preparation import get_days_spreads
from datetime import datetime
todays_date = datetime.today().strftime('%Y-%m-%d')

todays_spreads = get_days_spreads(todays_date)
todays_spreads = clean_spread_data(todays_spreads)
todays_spreads
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   warn(f"Unable to sort modes: {err}")
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   warn(f"Unable to sort modes: {err}")
#   away_team home_team   game_date away_spread1 away_spread2  away_spread3  \
# 0       DAL       WAS  2021-04-03     -4.5-110     -4.5-112          -4.5
# 1       CLE       MIA  2021-04-03       12-110       12-108          12.5
# 2       MIN       PHI  2021-04-03       13-110       12-110          13.5
# 3       NYK       DET  2021-04-03     -1.5-110     -1.5-113          -1.5
# 4       IND       SAS  2021-04-03        6-110      4.5-113           5.5
# 5       ORL       UTA  2021-04-03       15-110       15-110          15.0
# 6       MIL       SAC  2021-04-03       -6-105     -6.5-110          -5.5
# 7       OKC       POR  2021-04-03     11.5-110     11.5-105          11.5
#
#    away_spread4  home_spread1  home_spread2  home_spread3  home_spread4  \
# 0          -4.5           4.5           4.5           4.5           4.5
# 1          12.0         -12.0         -12.0         -12.5         -12.0
# 2          13.0         -13.0         -12.0         -13.5         -13.0
# 3          -1.5           1.5           1.5           1.5           1.5
# 4           6.0          -6.0          -4.5          -5.5          -6.0
# 5          14.5         -15.0         -15.0         -15.0         -14.5
# 6          -5.5           6.0           6.5           5.5           5.5
# 7          11.5         -11.5         -11.5         -11.5         -11.5
#
#   away_spread_mode  home_spread_mode
# 0             -4.5               4.5
# 1             12.5             -12.0
# 2           13-110             -13.0
# 3             -1.5               1.5
# 4            6-110              -6.0
# 5           15-110             -15.0
# 6             -5.5               5.5
# 7             11.5             -11.5

# %%
def load_current_season_team_data(season):
    """Loads basic, advanced, and scoring boxscores from
    current season and merges them into one dataframe
    """
    basic_gls = pd.read_csv('../data/current_season_data/team_gamelogs_{}.csv'.format(season))

    adv_gls = pd.read_csv('../data/current_season_data/team_advanced_boxscores_{}.csv'.format(season))

    scoring_gls = pd.read_csv('../data/current_season_data/team_scoring_boxscores_{}.csv'.format(season))

    temp = pd.merge(basic_gls, adv_gls, how='left', on=['GAME_ID', 'TEAM_ABBREVIATION'], suffixes=['', '_y'])
    full_df = pd.merge(temp, scoring_gls, how='left', on=['GAME_ID', 'TEAM_ABBREVIATION'], suffixes=['', '_y'])

    full_df = full_df.drop(columns = ['VIDEO_AVAILABLE', 'TEAM_ID_y', 
                                      'TEAM_NAME_y', 'TEAM_CITY', 
                                      'MIN_y', 'TEAM_ID_y',
                                      'TEAM_NAME_y', 'TEAM_CITY_y',
                                      'MIN_y'], errors='ignore')
    
    full_df['SEASON_YEAR'] = season
    
    full_df = full_df[['SEASON_YEAR', 'SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
       'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
       'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
       'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'E_OFF_RATING',
       'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING',
       'NET_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT',
       'REB_PCT', 'E_TM_TOV_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT',
       'E_USG_PCT', 'E_PACE', 'PACE', 'PACE_PER40', 'POSS', 'PIE',
       'PCT_FGA_2PT', 'PCT_FGA_3PT', 'PCT_PTS_2PT', 'PCT_PTS_2PT_MR',
       'PCT_PTS_3PT', 'PCT_PTS_FB', 'PCT_PTS_FT', 'PCT_PTS_OFF_TOV',
       'PCT_PTS_PAINT', 'PCT_AST_2PM', 'PCT_UAST_2PM', 'PCT_AST_3PM',
       'PCT_UAST_3PM', 'PCT_AST_FGM', 'PCT_UAST_FGM']]
    return full_df

df = load_current_season_team_data('2020-21')

# %%
def get_team_and_opp_ewm_for_model(df, min_periods=5, span=19, adjust=True):
    df = df.copy()
    df = df[['SEASON_YEAR_team', 'SEASON_ID_team', 'TEAM_ID_team',
       'TEAM_ABBREVIATION_team', 'TEAM_NAME_team', 'GAME_ID', 'GAME_DATE_team',
       'MATCHUP_team', 'HOME_GAME_team', 'TEAM_SCORE_team', 'point_diff_team',
       'WL_team', 'MIN_team', 'home_spread_mode', 'RECORD_team', 'team_covered', 'FG2M_team', 'FG2A_team',
       'FG3M_team', 'FG3A_team', 'FTM_team', 'FTA_team', 'OREB_team',
       'DREB_team', 'REB_team', 'AST_team', 'STL_team', 'BLK_team', 'TOV_team',
       'PF_team', 'PTS_team', 'PLUS_MINUS_team', 'E_OFF_RATING_team',
       'OFF_RATING_team', 'E_DEF_RATING_team', 'DEF_RATING_team',
       'E_NET_RATING_team', 'NET_RATING_team', 'POSS_team', 'PIE_team',
       'PTS_2PT_MR_team', 'PTS_FB_team', 'PTS_OFF_TOV_team', 'PTS_PAINT_team',
       'AST_2PM_team', 'UAST_2PM_team', 'AST_3PM_team', 'UAST_3PM_team',
       'SEASON_YEAR_opp', 'SEASON_ID_opp', 'TEAM_ID_opp',
       'TEAM_ABBREVIATION_opp', 'TEAM_NAME_opp', 'GAME_DATE_opp',
       'MATCHUP_opp', 'HOME_GAME_opp', 'TEAM_SCORE_opp', 'point_diff_opp',
       'WL_opp', 'MIN_opp', 'RECORD_opp', 'FG2M_opp', 'FG2A_opp', 'FG3M_opp',
       'FG3A_opp', 'FTM_opp', 'FTA_opp', 'OREB_opp', 'DREB_opp', 'REB_opp',
       'AST_opp', 'STL_opp', 'BLK_opp', 'TOV_opp', 'PF_opp', 'PTS_opp',
       'PLUS_MINUS_opp', 'E_OFF_RATING_opp', 'OFF_RATING_opp',
       'E_DEF_RATING_opp', 'DEF_RATING_opp', 'E_NET_RATING_opp',
       'NET_RATING_opp', 'POSS_opp', 'PIE_opp', 'PTS_2PT_MR_opp', 'PTS_FB_opp',
       'PTS_OFF_TOV_opp', 'PTS_PAINT_opp', 'AST_2PM_opp', 'UAST_2PM_opp',
       'AST_3PM_opp', 'UAST_3PM_opp', 'home_team', 'away_team', 'game_date',
       'away_spread_mode']]
    
    df = df.drop(columns = ['SEASON_YEAR_opp', 'SEASON_ID_opp', 
                            'TEAM_ID_opp', 'TEAM_ABBREVIATION_opp',
                            'TEAM_NAME_opp', 'GAME_DATE_opp', 
                            'MATCHUP_opp', 'WL_opp', 'HOME_GAME_opp',
                           'point_diff_opp', 'home_team', 'away_team', 'game_date',
                           'away_spread_mode'])
    team_dfs = []

    for team in df['TEAM_ABBREVIATION_team'].unique():
        team_df = df.loc[df['TEAM_ABBREVIATION_team'] == team].sort_values('GAME_DATE_team')
        team_record = team_df['RECORD_team'].shift(1).expanding().mean()
        ATS_rec = team_df['team_covered'].shift(1).expanding().mean()
        records_df = pd.DataFrame({'WL_record':team_record, 
                                  'ATS_record':ATS_rec})

        team_df.iloc[:, 14:] = team_df.iloc[:, 14:].shift(1).ewm(span = span, min_periods=min_periods).mean()

        team_df = pd.concat([team_df, records_df], axis=1)

        team_dfs.append(team_df)

    new_df = pd.concat(team_dfs)
    new_df = new_df.reset_index(drop=True)
        
    return new_df

# %%
def add_rest_days_for_model(df):
    df['rest'] = np.nan
    for season in df['SEASON_YEAR_team'].unique():
        season_df = df.loc[df['SEASON_YEAR_team'] == season]
        for team in season_df['TEAM_ABBREVIATION_team'].unique():
            team_df = season_df.loc[season_df['TEAM_ABBREVIATION_team'] == team].sort_values('GAME_DATE_team')
            idx = team_df.index
            team_df['rest'] = (team_df['GAME_DATE_team'] - team_df['GAME_DATE_team'].shift(1)) / np.timedelta64(1, 'D')
            df.loc[idx, 'rest'] = team_df['rest']
            
    return df

# %%
df = load_current_season_team_data(season='2020-21')
df1 = clean_team_data(df)
df1 = prep_for_aggregation(df1)
df1 = create_matchups(df1) 
df1 = add_spread_data(df1)
df1 = get_team_and_opp_ewm_for_model(df1)
df1 = add_rest_days_for_model(df1)
df1 = add_percentage_features(df1)
df1
# Out:
#      SEASON_YEAR_team  SEASON_ID_team  TEAM_ID_team TEAM_ABBREVIATION_team  \
# 0             2020-21           22020    1610612746                    LAC
# 1             2020-21           22020    1610612746                    LAC
# 2             2020-21           22020    1610612746                    LAC
# 3             2020-21           22020    1610612746                    LAC
# 4             2020-21           22020    1610612746                    LAC
# ...               ...             ...           ...                    ...
# 1421          2020-21           22020    1610612760                    OKC
# 1422          2020-21           22020    1610612760                    OKC
# 1423          2020-21           22020    1610612760                    OKC
# 1424          2020-21           22020    1610612760                    OKC
# 1425          2020-21           22020    1610612760                    OKC
#
#              TEAM_NAME_team   GAME_ID GAME_DATE_team MATCHUP_team  \
# 0               LA Clippers  22000002     2020-12-22    LAC @ LAL
# 1               LA Clippers  22000009     2020-12-25    LAC @ DEN
# 2               LA Clippers  22000031     2020-12-27  LAC vs. DAL
# 3               LA Clippers  22000054     2020-12-29  LAC vs. MIN
# 4               LA Clippers  22000061     2020-12-30  LAC vs. POR
# ...                     ...       ...            ...          ...
# 1421  Oklahoma City Thunder  22000654     2021-03-22    OKC @ MIN
# 1422  Oklahoma City Thunder  22000674     2021-03-24  OKC vs. MEM
# 1423  Oklahoma City Thunder  22000713     2021-03-29  OKC vs. DAL
# 1424  Oklahoma City Thunder  22000727     2021-03-31  OKC vs. TOR
# 1425  Oklahoma City Thunder  22000744     2021-04-02    OKC @ PHX
#
#       HOME_GAME_team  TEAM_SCORE_team  point_diff_team  WL_team  MIN_team  \
# 0                  0              116                7        1       240
# 1                  0              121               13        1       240
# 2                  1               73              -51        0       240
# 3                  1              124               23        1       240
# 4                  1              128               23        1       240
# ...              ...              ...              ...      ...       ...
# 1421               0              112                9        1       240
# 1422               1              107               -9        0       240
# 1423               1              106              -21        0       240
# 1424               1              113               10        1       240
# 1425               0              103              -37        0       240
#
#       home_spread_mode  WL_record  ATS_record  RECORD_team  team_covered  \
# 0                 -2.0        NaN         NaN          NaN           NaN
# 1                  4.0   1.000000    1.000000          NaN           NaN
# 2                 -3.0   1.000000    1.000000          NaN           NaN
# 3                -11.0   0.666667    0.666667          NaN           NaN
# 4                 -6.0   0.750000    0.750000          NaN           NaN
# ...                ...        ...         ...          ...           ...
# 1421              -5.0   0.428571    0.523810     0.462632      0.503451
# 1422               7.0   0.441860    0.534884     0.516954      0.553647
# 1423              11.5   0.431818    0.522727     0.464753      0.497740
# 1424               NaN   0.422222    0.511111     0.417868      0.447528
# 1425               NaN   0.434783    0.500000     0.476542      0.402421
#
#       FG2M_team  FG2A_team  FG3M_team  FG3A_team   FTM_team   FTA_team  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 1421  26.230628  51.219857  12.503302  35.296836  15.565898  20.527251
# 1422  25.600778  51.096543  13.362227  35.469008  14.902156  19.463059
# 1423  26.347946  51.995607  13.022712  35.421648  14.508119  19.214341
# 1424  26.615487  52.298692  12.616898  34.471187  15.163023  20.605045
# 1425  26.452659  52.369378  12.756304  34.322904  15.751342  21.350395
#
#       OREB_team  DREB_team   REB_team   AST_team  STL_team  BLK_team  \
# 0           NaN        NaN        NaN        NaN       NaN       NaN
# 1           NaN        NaN        NaN        NaN       NaN       NaN
# 2           NaN        NaN        NaN        NaN       NaN       NaN
# 3           NaN        NaN        NaN        NaN       NaN       NaN
# 4           NaN        NaN        NaN        NaN       NaN       NaN
# ...         ...        ...        ...        ...       ...       ...
# 1421   9.930686  34.635260  44.565946  21.981191  6.544424  4.110318
# 1422   9.836604  34.975399  44.812003  22.488539  6.691567  4.705702
# 1423   9.752124  34.977883  44.730007  22.843124  7.328588  5.038358
# 1424   9.777130  35.181875  44.959005  22.253667  7.396320  4.933608
# 1425  10.706719  36.171461  46.878180  21.925724  6.852416  5.041091
#
#        TOV_team    PF_team    PTS_team  PLUS_MINUS_team  E_OFF_RATING_team  \
# 0           NaN        NaN         NaN              NaN                NaN
# 1           NaN        NaN         NaN              NaN                NaN
# 2           NaN        NaN         NaN              NaN                NaN
# 3           NaN        NaN         NaN              NaN                NaN
# 4           NaN        NaN         NaN              NaN                NaN
# ...         ...        ...         ...              ...                ...
# 1421  15.351618  18.185672  105.537059        -6.601207         104.546955
# 1422  15.518251  17.762546  106.190393        -5.024093         105.371140
# 1423  15.465919  16.978690  106.272147        -5.425577         104.687395
# 1424  15.519797  16.678198  106.244692        -6.996732         104.658403
# 1425  15.971365  16.609841  106.925572        -5.283602         105.579800
#
#       OFF_RATING_team  E_DEF_RATING_team  DEF_RATING_team  E_NET_RATING_team  \
# 0                 NaN                NaN              NaN                NaN
# 1                 NaN                NaN              NaN                NaN
# 2                 NaN                NaN              NaN                NaN
# 3                 NaN                NaN              NaN                NaN
# 4                 NaN                NaN              NaN                NaN
# ...               ...                ...              ...                ...
# 1421       105.784976         111.313301       112.754732          -6.760746
# 1422       106.645753         110.381935       111.980920          -5.005761
# 1423       105.883788         110.010136       111.619322          -5.318215
# 1424       105.582782         111.381088       112.797674          -6.718616
# 1425       106.330377         110.667373       112.021812          -5.083914
#
#       NET_RATING_team   POSS_team  PIE_team  PTS_2PT_MR_team  PTS_FB_team  \
# 0                 NaN         NaN       NaN              NaN          NaN
# 1                 NaN         NaN       NaN              NaN          NaN
# 2                 NaN         NaN       NaN              NaN          NaN
# 3                 NaN         NaN       NaN              NaN          NaN
# 4                 NaN         NaN       NaN              NaN          NaN
# ...               ...         ...       ...              ...          ...
# 1421        -6.973996   99.728258  0.457005         6.242416     6.238734
# 1422        -5.338978   99.553549  0.468226         6.319000     6.315690
# 1423        -5.738960  100.406466  0.468708         6.488746     7.293604
# 1424        -7.217972  100.668103  0.462785         6.540321     7.869268
# 1425        -5.694206  100.600764  0.471878         6.385070     7.882445
#
#       PTS_OFF_TOV_team  PTS_PAINT_team  AST_2PM_team  UAST_2PM_team  \
# 0                  NaN             NaN           NaN            NaN
# 1                  NaN             NaN           NaN            NaN
# 2                  NaN             NaN           NaN            NaN
# 3                  NaN             NaN           NaN            NaN
# 4                  NaN             NaN           NaN            NaN
# ...                ...             ...           ...            ...
# 1421         13.694338       45.493230     11.329517      14.120216
# 1422         13.421969       44.129209     11.296206      13.602617
# 1423         14.389152       45.428892     11.771192      13.844703
# 1424         13.845492       45.890028     11.592513      14.263891
# 1425         13.256315       45.598737     11.532793      14.237293
#
#       AST_3PM_team  UAST_3PM_team  TEAM_SCORE_opp     MIN_opp  RECORD_opp  \
# 0              NaN            NaN             NaN         NaN         NaN
# 1              NaN            NaN             NaN         NaN         NaN
# 2              NaN            NaN             NaN         NaN         NaN
# 3              NaN            NaN             NaN         NaN         NaN
# 4              NaN            NaN             NaN         NaN         NaN
# ...            ...            ...             ...         ...         ...
# 1421      9.956811       2.068146      112.138267  240.828851    0.537368
# 1422     10.567713       2.263436      111.214486  240.745063    0.483046
# 1423     10.409406       2.135855      111.697724  240.669827    0.535247
# 1424      9.964583       2.122150      113.241425  240.602255    0.582132
# 1425      9.665778       2.513005      112.209174  240.541552    0.523458
#
#        FG2M_opp   FG2A_opp   FG3M_opp   FG3A_opp    FTM_opp    FTA_opp  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 1421  30.048066  53.255042  12.120984  34.810027  15.679182  20.544949
# 1422  29.436671  53.229260  12.310933  35.233588  15.408346  20.287682
# 1423  30.099431  54.821778  12.178556  34.705104  14.963194  19.551777
# 1424  30.593803  54.537115  12.564065  35.642778  14.361624  18.890831
# 1425  29.425244  53.475061  12.910379  36.686700  14.627551  19.002626
#
#       OREB_opp   DREB_opp    REB_opp    AST_opp   STL_opp   BLK_opp  \
# 0          NaN        NaN        NaN        NaN       NaN       NaN
# 1          NaN        NaN        NaN        NaN       NaN       NaN
# 2          NaN        NaN        NaN        NaN       NaN       NaN
# 3          NaN        NaN        NaN        NaN       NaN       NaN
# 4          NaN        NaN        NaN        NaN       NaN       NaN
# ...        ...        ...        ...        ...       ...       ...
# 1421  9.298997  35.502915  44.801913  24.029114  8.073405  4.758502
# 1422  9.470951  35.047719  44.518669  24.026171  8.369252  4.681825
# 1423  9.928291  35.749755  45.678046  23.518632  8.735883  5.218851
# 1424  9.733764  35.674119  45.407883  24.172476  8.964288  4.995012
# 1425  9.458223  34.900632  44.358855  23.852716  9.371054  5.197098
#
#         TOV_opp     PF_opp     PTS_opp  PLUS_MINUS_opp  E_OFF_RATING_opp  \
# 0           NaN        NaN         NaN             NaN               NaN
# 1           NaN        NaN         NaN             NaN               NaN
# 2           NaN        NaN         NaN             NaN               NaN
# 3           NaN        NaN         NaN             NaN               NaN
# 4           NaN        NaN         NaN             NaN               NaN
# ...         ...        ...         ...             ...               ...
# 1421  12.961008  18.202615  112.138267        6.601207        111.313301
# 1422  12.863860  18.081044  111.214486        5.024093        110.381935
# 1423  13.382504  17.265026  111.697724        5.425577        110.010136
# 1424  12.940395  17.641812  113.241425        6.996732        111.381088
# 1425  12.341652  18.383456  112.209174        5.283602        110.667373
#
#       OFF_RATING_opp  E_DEF_RATING_opp  DEF_RATING_opp  E_NET_RATING_opp  \
# 0                NaN               NaN             NaN               NaN
# 1                NaN               NaN             NaN               NaN
# 2                NaN               NaN             NaN               NaN
# 3                NaN               NaN             NaN               NaN
# 4                NaN               NaN             NaN               NaN
# ...              ...               ...             ...               ...
# 1421      112.754732        104.546955      105.784976          6.760746
# 1422      111.980920        105.371140      106.645753          5.005761
# 1423      111.619322        104.687395      105.883788          5.318215
# 1424      112.797674        104.658403      105.582782          6.718616
# 1425      112.021812        105.579800      106.330377          5.083914
#
#       NET_RATING_opp    POSS_opp   PIE_opp  PTS_2PT_MR_opp  PTS_FB_opp  \
# 0                NaN         NaN       NaN             NaN         NaN
# 1                NaN         NaN       NaN             NaN         NaN
# 2                NaN         NaN       NaN             NaN         NaN
# 3                NaN         NaN       NaN             NaN         NaN
# 4                NaN         NaN       NaN             NaN         NaN
# ...              ...         ...       ...             ...         ...
# 1421        6.973996   99.495615  0.542995       11.162046    9.206507
# 1422        5.338978   99.344425  0.531774       10.438040    9.084542
# 1423        5.738960  100.117479  0.531292        9.686952   10.085798
# 1424        7.217972  100.408269  0.537215        9.819413   10.178023
# 1425        5.694206  100.165536  0.528122        9.232864   10.764830
#
#       PTS_OFF_TOV_opp  PTS_PAINT_opp  AST_2PM_opp  UAST_2PM_opp  AST_3PM_opp  \
# 0                 NaN            NaN          NaN           NaN          NaN
# 1                 NaN            NaN          NaN           NaN          NaN
# 2                 NaN            NaN          NaN           NaN          NaN
# 3                 NaN            NaN          NaN           NaN          NaN
# 4                 NaN            NaN          NaN           NaN          NaN
# ...               ...            ...          ...           ...          ...
# 1421        18.448466      48.025290    13.488060     15.918299     9.853507
# 1422        18.908577      47.517287    13.135454     15.623291    10.171584
# 1423        19.018788      49.484637    12.919818     16.469165     9.750340
# 1424        19.521295      50.343671    13.331428     16.522716     9.977287
# 1425        19.367961      48.595573    12.693273     15.966072    10.281951
#
#       UAST_3PM_opp  OREB_PCT_team  OREB_PCT_opp  DREB_PCT_team  DREB_PCT_opp  \
# 0              NaN            NaN           NaN            NaN           NaN
# 1              NaN            NaN           NaN            NaN           NaN
# 2              NaN            NaN           NaN            NaN           NaN
# 3              NaN            NaN           NaN            NaN           NaN
# 4              NaN            NaN           NaN            NaN           NaN
# ...            ...            ...           ...            ...           ...
# 1421      1.702402       0.218576      0.211657       0.788343      0.781424
# 1422      1.530308       0.219155      0.213087       0.786913      0.780845
# 1423      1.779695       0.214324      0.221090       0.778910      0.785676
# 1424      2.003681       0.215112      0.216712       0.783288      0.784888
# 1425      2.104102       0.234759      0.207282       0.792718      0.765241
#
#       REB_PCT_team  REB_PCT_opp  TS_PCT_team  TS_PCT_opp  EFG_PCT_team  \
# 0              NaN          NaN          NaN         NaN           NaN
# 1              NaN          NaN          NaN         NaN           NaN
# 2              NaN          NaN          NaN         NaN           NaN
# 3              NaN          NaN          NaN         NaN           NaN
# 4              NaN          NaN          NaN         NaN           NaN
# ...            ...          ...          ...         ...           ...
# 1421      0.498680     0.501320     0.579666    0.605597      0.519964
# 1422      0.501642     0.498358     0.584444    0.598403      0.527278
# 1423      0.494757     0.505243     0.579807    0.595224      0.524862
# 1424      0.497516     0.502484     0.581825    0.600203      0.524846
# 1425      0.513806     0.486194     0.585000    0.594691      0.525850
#
#       EFG_PCT_opp  AST_RATIO_team  AST_RATIO_opp  TOV_PCT_team  TOV_PCT_opp  \
# 0             NaN             NaN            NaN           NaN          NaN
# 1             NaN             NaN            NaN           NaN          NaN
# 2             NaN             NaN            NaN           NaN          NaN
# 3             NaN             NaN            NaN           NaN          NaN
# 4             NaN             NaN            NaN           NaN          NaN
# ...           ...             ...            ...           ...          ...
# 1421     0.547658       22.041086      24.150928     13.842720    11.775684
# 1422     0.541505       22.589390      24.184720     14.024939    11.667552
# 1423     0.540254       22.750650      23.491035     13.891026    12.000936
# 1424     0.548236       22.105976      24.074188     13.937113    11.612791
# 1425     0.541147       21.794789      23.813297     14.252789    11.132188
#
#       rest
# 0      NaN
# 1      3.0
# 2      2.0
# 3      2.0
# 4      1.0
# ...    ...
# 1421   1.0
# 1422   2.0
# 1423   5.0
# 1424   2.0
# 1425   2.0
#
# [1426 rows x 100 columns]

# %%
df1
# Out:
#      SEASON_YEAR_team  SEASON_ID_team  TEAM_ID_team TEAM_ABBREVIATION_team  \
# 0             2020-21           22020    1610612746                    LAC
# 1             2020-21           22020    1610612746                    LAC
# 2             2020-21           22020    1610612746                    LAC
# 3             2020-21           22020    1610612746                    LAC
# 4             2020-21           22020    1610612746                    LAC
# ...               ...             ...           ...                    ...
# 1421          2020-21           22020    1610612760                    OKC
# 1422          2020-21           22020    1610612760                    OKC
# 1423          2020-21           22020    1610612760                    OKC
# 1424          2020-21           22020    1610612760                    OKC
# 1425          2020-21           22020    1610612760                    OKC
#
#              TEAM_NAME_team   GAME_ID GAME_DATE_team MATCHUP_team  \
# 0               LA Clippers  22000002     2020-12-22    LAC @ LAL
# 1               LA Clippers  22000009     2020-12-25    LAC @ DEN
# 2               LA Clippers  22000031     2020-12-27  LAC vs. DAL
# 3               LA Clippers  22000054     2020-12-29  LAC vs. MIN
# 4               LA Clippers  22000061     2020-12-30  LAC vs. POR
# ...                     ...       ...            ...          ...
# 1421  Oklahoma City Thunder  22000654     2021-03-22    OKC @ MIN
# 1422  Oklahoma City Thunder  22000674     2021-03-24  OKC vs. MEM
# 1423  Oklahoma City Thunder  22000713     2021-03-29  OKC vs. DAL
# 1424  Oklahoma City Thunder  22000727     2021-03-31  OKC vs. TOR
# 1425  Oklahoma City Thunder  22000744     2021-04-02    OKC @ PHX
#
#       HOME_GAME_team  TEAM_SCORE_team  point_diff_team  WL_team  MIN_team  \
# 0                  0              116                7        1       240
# 1                  0              121               13        1       240
# 2                  1               73              -51        0       240
# 3                  1              124               23        1       240
# 4                  1              128               23        1       240
# ...              ...              ...              ...      ...       ...
# 1421               0              112                9        1       240
# 1422               1              107               -9        0       240
# 1423               1              106              -21        0       240
# 1424               1              113               10        1       240
# 1425               0              103              -37        0       240
#
#       home_spread_mode  WL_record  ATS_record  RECORD_team  team_covered  \
# 0                 -2.0        NaN         NaN          NaN           NaN
# 1                  4.0   1.000000    1.000000          NaN           NaN
# 2                 -3.0   1.000000    1.000000          NaN           NaN
# 3                -11.0   0.666667    0.666667          NaN           NaN
# 4                 -6.0   0.750000    0.750000          NaN           NaN
# ...                ...        ...         ...          ...           ...
# 1421              -5.0   0.428571    0.523810     0.462632      0.503451
# 1422               7.0   0.441860    0.534884     0.516954      0.553647
# 1423              11.5   0.431818    0.522727     0.464753      0.497740
# 1424               NaN   0.422222    0.511111     0.417868      0.447528
# 1425               NaN   0.434783    0.500000     0.476542      0.402421
#
#       FG2M_team  FG2A_team  FG3M_team  FG3A_team   FTM_team   FTA_team  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 1421  26.230628  51.219857  12.503302  35.296836  15.565898  20.527251
# 1422  25.600778  51.096543  13.362227  35.469008  14.902156  19.463059
# 1423  26.347946  51.995607  13.022712  35.421648  14.508119  19.214341
# 1424  26.615487  52.298692  12.616898  34.471187  15.163023  20.605045
# 1425  26.452659  52.369378  12.756304  34.322904  15.751342  21.350395
#
#       OREB_team  DREB_team   REB_team   AST_team  STL_team  BLK_team  \
# 0           NaN        NaN        NaN        NaN       NaN       NaN
# 1           NaN        NaN        NaN        NaN       NaN       NaN
# 2           NaN        NaN        NaN        NaN       NaN       NaN
# 3           NaN        NaN        NaN        NaN       NaN       NaN
# 4           NaN        NaN        NaN        NaN       NaN       NaN
# ...         ...        ...        ...        ...       ...       ...
# 1421   9.930686  34.635260  44.565946  21.981191  6.544424  4.110318
# 1422   9.836604  34.975399  44.812003  22.488539  6.691567  4.705702
# 1423   9.752124  34.977883  44.730007  22.843124  7.328588  5.038358
# 1424   9.777130  35.181875  44.959005  22.253667  7.396320  4.933608
# 1425  10.706719  36.171461  46.878180  21.925724  6.852416  5.041091
#
#        TOV_team    PF_team    PTS_team  PLUS_MINUS_team  E_OFF_RATING_team  \
# 0           NaN        NaN         NaN              NaN                NaN
# 1           NaN        NaN         NaN              NaN                NaN
# 2           NaN        NaN         NaN              NaN                NaN
# 3           NaN        NaN         NaN              NaN                NaN
# 4           NaN        NaN         NaN              NaN                NaN
# ...         ...        ...         ...              ...                ...
# 1421  15.351618  18.185672  105.537059        -6.601207         104.546955
# 1422  15.518251  17.762546  106.190393        -5.024093         105.371140
# 1423  15.465919  16.978690  106.272147        -5.425577         104.687395
# 1424  15.519797  16.678198  106.244692        -6.996732         104.658403
# 1425  15.971365  16.609841  106.925572        -5.283602         105.579800
#
#       OFF_RATING_team  E_DEF_RATING_team  DEF_RATING_team  E_NET_RATING_team  \
# 0                 NaN                NaN              NaN                NaN
# 1                 NaN                NaN              NaN                NaN
# 2                 NaN                NaN              NaN                NaN
# 3                 NaN                NaN              NaN                NaN
# 4                 NaN                NaN              NaN                NaN
# ...               ...                ...              ...                ...
# 1421       105.784976         111.313301       112.754732          -6.760746
# 1422       106.645753         110.381935       111.980920          -5.005761
# 1423       105.883788         110.010136       111.619322          -5.318215
# 1424       105.582782         111.381088       112.797674          -6.718616
# 1425       106.330377         110.667373       112.021812          -5.083914
#
#       NET_RATING_team   POSS_team  PIE_team  PTS_2PT_MR_team  PTS_FB_team  \
# 0                 NaN         NaN       NaN              NaN          NaN
# 1                 NaN         NaN       NaN              NaN          NaN
# 2                 NaN         NaN       NaN              NaN          NaN
# 3                 NaN         NaN       NaN              NaN          NaN
# 4                 NaN         NaN       NaN              NaN          NaN
# ...               ...         ...       ...              ...          ...
# 1421        -6.973996   99.728258  0.457005         6.242416     6.238734
# 1422        -5.338978   99.553549  0.468226         6.319000     6.315690
# 1423        -5.738960  100.406466  0.468708         6.488746     7.293604
# 1424        -7.217972  100.668103  0.462785         6.540321     7.869268
# 1425        -5.694206  100.600764  0.471878         6.385070     7.882445
#
#       PTS_OFF_TOV_team  PTS_PAINT_team  AST_2PM_team  UAST_2PM_team  \
# 0                  NaN             NaN           NaN            NaN
# 1                  NaN             NaN           NaN            NaN
# 2                  NaN             NaN           NaN            NaN
# 3                  NaN             NaN           NaN            NaN
# 4                  NaN             NaN           NaN            NaN
# ...                ...             ...           ...            ...
# 1421         13.694338       45.493230     11.329517      14.120216
# 1422         13.421969       44.129209     11.296206      13.602617
# 1423         14.389152       45.428892     11.771192      13.844703
# 1424         13.845492       45.890028     11.592513      14.263891
# 1425         13.256315       45.598737     11.532793      14.237293
#
#       AST_3PM_team  UAST_3PM_team  TEAM_SCORE_opp     MIN_opp  RECORD_opp  \
# 0              NaN            NaN             NaN         NaN         NaN
# 1              NaN            NaN             NaN         NaN         NaN
# 2              NaN            NaN             NaN         NaN         NaN
# 3              NaN            NaN             NaN         NaN         NaN
# 4              NaN            NaN             NaN         NaN         NaN
# ...            ...            ...             ...         ...         ...
# 1421      9.956811       2.068146      112.138267  240.828851    0.537368
# 1422     10.567713       2.263436      111.214486  240.745063    0.483046
# 1423     10.409406       2.135855      111.697724  240.669827    0.535247
# 1424      9.964583       2.122150      113.241425  240.602255    0.582132
# 1425      9.665778       2.513005      112.209174  240.541552    0.523458
#
#        FG2M_opp   FG2A_opp   FG3M_opp   FG3A_opp    FTM_opp    FTA_opp  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1           NaN        NaN        NaN        NaN        NaN        NaN
# 2           NaN        NaN        NaN        NaN        NaN        NaN
# 3           NaN        NaN        NaN        NaN        NaN        NaN
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ...         ...        ...        ...        ...        ...        ...
# 1421  30.048066  53.255042  12.120984  34.810027  15.679182  20.544949
# 1422  29.436671  53.229260  12.310933  35.233588  15.408346  20.287682
# 1423  30.099431  54.821778  12.178556  34.705104  14.963194  19.551777
# 1424  30.593803  54.537115  12.564065  35.642778  14.361624  18.890831
# 1425  29.425244  53.475061  12.910379  36.686700  14.627551  19.002626
#
#       OREB_opp   DREB_opp    REB_opp    AST_opp   STL_opp   BLK_opp  \
# 0          NaN        NaN        NaN        NaN       NaN       NaN
# 1          NaN        NaN        NaN        NaN       NaN       NaN
# 2          NaN        NaN        NaN        NaN       NaN       NaN
# 3          NaN        NaN        NaN        NaN       NaN       NaN
# 4          NaN        NaN        NaN        NaN       NaN       NaN
# ...        ...        ...        ...        ...       ...       ...
# 1421  9.298997  35.502915  44.801913  24.029114  8.073405  4.758502
# 1422  9.470951  35.047719  44.518669  24.026171  8.369252  4.681825
# 1423  9.928291  35.749755  45.678046  23.518632  8.735883  5.218851
# 1424  9.733764  35.674119  45.407883  24.172476  8.964288  4.995012
# 1425  9.458223  34.900632  44.358855  23.852716  9.371054  5.197098
#
#         TOV_opp     PF_opp     PTS_opp  PLUS_MINUS_opp  E_OFF_RATING_opp  \
# 0           NaN        NaN         NaN             NaN               NaN
# 1           NaN        NaN         NaN             NaN               NaN
# 2           NaN        NaN         NaN             NaN               NaN
# 3           NaN        NaN         NaN             NaN               NaN
# 4           NaN        NaN         NaN             NaN               NaN
# ...         ...        ...         ...             ...               ...
# 1421  12.961008  18.202615  112.138267        6.601207        111.313301
# 1422  12.863860  18.081044  111.214486        5.024093        110.381935
# 1423  13.382504  17.265026  111.697724        5.425577        110.010136
# 1424  12.940395  17.641812  113.241425        6.996732        111.381088
# 1425  12.341652  18.383456  112.209174        5.283602        110.667373
#
#       OFF_RATING_opp  E_DEF_RATING_opp  DEF_RATING_opp  E_NET_RATING_opp  \
# 0                NaN               NaN             NaN               NaN
# 1                NaN               NaN             NaN               NaN
# 2                NaN               NaN             NaN               NaN
# 3                NaN               NaN             NaN               NaN
# 4                NaN               NaN             NaN               NaN
# ...              ...               ...             ...               ...
# 1421      112.754732        104.546955      105.784976          6.760746
# 1422      111.980920        105.371140      106.645753          5.005761
# 1423      111.619322        104.687395      105.883788          5.318215
# 1424      112.797674        104.658403      105.582782          6.718616
# 1425      112.021812        105.579800      106.330377          5.083914
#
#       NET_RATING_opp    POSS_opp   PIE_opp  PTS_2PT_MR_opp  PTS_FB_opp  \
# 0                NaN         NaN       NaN             NaN         NaN
# 1                NaN         NaN       NaN             NaN         NaN
# 2                NaN         NaN       NaN             NaN         NaN
# 3                NaN         NaN       NaN             NaN         NaN
# 4                NaN         NaN       NaN             NaN         NaN
# ...              ...         ...       ...             ...         ...
# 1421        6.973996   99.495615  0.542995       11.162046    9.206507
# 1422        5.338978   99.344425  0.531774       10.438040    9.084542
# 1423        5.738960  100.117479  0.531292        9.686952   10.085798
# 1424        7.217972  100.408269  0.537215        9.819413   10.178023
# 1425        5.694206  100.165536  0.528122        9.232864   10.764830
#
#       PTS_OFF_TOV_opp  PTS_PAINT_opp  AST_2PM_opp  UAST_2PM_opp  AST_3PM_opp  \
# 0                 NaN            NaN          NaN           NaN          NaN
# 1                 NaN            NaN          NaN           NaN          NaN
# 2                 NaN            NaN          NaN           NaN          NaN
# 3                 NaN            NaN          NaN           NaN          NaN
# 4                 NaN            NaN          NaN           NaN          NaN
# ...               ...            ...          ...           ...          ...
# 1421        18.448466      48.025290    13.488060     15.918299     9.853507
# 1422        18.908577      47.517287    13.135454     15.623291    10.171584
# 1423        19.018788      49.484637    12.919818     16.469165     9.750340
# 1424        19.521295      50.343671    13.331428     16.522716     9.977287
# 1425        19.367961      48.595573    12.693273     15.966072    10.281951
#
#       UAST_3PM_opp  OREB_PCT_team  OREB_PCT_opp  DREB_PCT_team  DREB_PCT_opp  \
# 0              NaN            NaN           NaN            NaN           NaN
# 1              NaN            NaN           NaN            NaN           NaN
# 2              NaN            NaN           NaN            NaN           NaN
# 3              NaN            NaN           NaN            NaN           NaN
# 4              NaN            NaN           NaN            NaN           NaN
# ...            ...            ...           ...            ...           ...
# 1421      1.702402       0.218576      0.211657       0.788343      0.781424
# 1422      1.530308       0.219155      0.213087       0.786913      0.780845
# 1423      1.779695       0.214324      0.221090       0.778910      0.785676
# 1424      2.003681       0.215112      0.216712       0.783288      0.784888
# 1425      2.104102       0.234759      0.207282       0.792718      0.765241
#
#       REB_PCT_team  REB_PCT_opp  TS_PCT_team  TS_PCT_opp  EFG_PCT_team  \
# 0              NaN          NaN          NaN         NaN           NaN
# 1              NaN          NaN          NaN         NaN           NaN
# 2              NaN          NaN          NaN         NaN           NaN
# 3              NaN          NaN          NaN         NaN           NaN
# 4              NaN          NaN          NaN         NaN           NaN
# ...            ...          ...          ...         ...           ...
# 1421      0.498680     0.501320     0.579666    0.605597      0.519964
# 1422      0.501642     0.498358     0.584444    0.598403      0.527278
# 1423      0.494757     0.505243     0.579807    0.595224      0.524862
# 1424      0.497516     0.502484     0.581825    0.600203      0.524846
# 1425      0.513806     0.486194     0.585000    0.594691      0.525850
#
#       EFG_PCT_opp  AST_RATIO_team  AST_RATIO_opp  TOV_PCT_team  TOV_PCT_opp  \
# 0             NaN             NaN            NaN           NaN          NaN
# 1             NaN             NaN            NaN           NaN          NaN
# 2             NaN             NaN            NaN           NaN          NaN
# 3             NaN             NaN            NaN           NaN          NaN
# 4             NaN             NaN            NaN           NaN          NaN
# ...           ...             ...            ...           ...          ...
# 1421     0.547658       22.041086      24.150928     13.842720    11.775684
# 1422     0.541505       22.589390      24.184720     14.024939    11.667552
# 1423     0.540254       22.750650      23.491035     13.891026    12.000936
# 1424     0.548236       22.105976      24.074188     13.937113    11.612791
# 1425     0.541147       21.794789      23.813297     14.252789    11.132188
#
#       rest
# 0      NaN
# 1      3.0
# 2      2.0
# 3      2.0
# 4      1.0
# ...    ...
# 1421   1.0
# 1422   2.0
# 1423   5.0
# 1424   2.0
# 1425   2.0
#
# [1426 rows x 100 columns]

# %%
prev_season_final_elo = {}
for team in full_df_ewm_19['TEAM_ABBREVIATION'].unique():
    team_df = full_df_ewm_19.loc[full_df_ewm_19['MATCHUP'].str.contains(team)].sort_values('GAME_DATE').reset_index(drop=True)
    if team_df.loc[team_df.shape[0]-1, 'MATCHUP'][:3] == team:
        final_elo = team_df.loc[team_df.shape[0]-1, 'home_rating_n']
    else:
        final_elo = team_df.loc[team_df.shape[0]-1, 'away_rating_n']
    prev_season_final_elo[team] = final_elo
    
    
prev_season_final_elo
# Out:
# {'IND': 1529.4483384275268,
#  'HOU': 1540.8964001636646,
#  'POR': 1500.1407073118096,
#  'LAL': 1684.3757506350337,
#  'CLE': 1298.0343645791245,
#  'SAS': 1522.744349117492,
#  'MIN': 1340.3072979400008,
#  'CHI': 1332.027526532048,
#  'MIL': 1629.7867944120128,
#  'GSW': 1360.7007973857746,
#  'SAC': 1516.141852484055,
#  'LAC': 1626.6462653315195,
#  'MIA': 1618.0421597762124,
#  'BOS': 1703.07997468606,
#  'NYK': 1326.2237584707232,
#  'ATL': 1337.167197222995,
#  'NOP': 1499.3615728404923,
#  'DAL': 1544.6886733768054,
#  'UTA': 1549.7536707979227,
#  'DET': 1342.6198199001185,
#  'ORL': 1490.8373868097253,
#  'BKN': 1467.7010014887078,
#  'PHX': 1536.6695679529985,
#  'MEM': 1553.2535462864591,
#  'DEN': 1584.84073526912,
#  'WAS': 1380.5107315006996,
#  'CHA': 1394.9240309027477,
#  'PHI': 1552.491927190443,
#  'TOR': 1676.213996740524,
#  'OKC': 1560.4746669932429}

# %%
with open("../data/final_elo_2020.pkl", 'wb') as file:
    pickle.dump(prev_season_final_elo, file)

# %%
# Add ELO ratings
with open("../data/final_elo_2020.pkl", "rb") as file:
    final_elo_2020 = pickle.load(file)


def get_current_elo_ratings(df, prev_season_final_elo):
    """This function will generate elo_ratings in the elo_df
    """
    df = df.copy()
    df = df.loc[df['HOME_GAME_team'] == 1]
    # Initialize the following columns
    df = df.sort_values('GAME_DATE_team')

    df['home_elo_pred'] = np.nan

    df['home_rating_i'] = np.nan
    df['home_rating_n'] = np.nan

    df['away_rating_i'] = np.nan
    df['away_rating_n'] = np.nan

    elo_dic = prev_season_final_elo
    for team in elo_dic:
        elo_dic[team] = season_reset(elo_dic[team])
        
    for idx, row in tqdm(df.iterrows(), desc="progress:"):
        home_team_abbr = row['MATCHUP_team'][:3]
        away_team_abbr = row['MATCHUP_team'][-3:]
        
        df.loc[idx, 'home_rating_i'] = elo_dic[home_team_abbr]
        df.loc[idx, 'away_rating_i'] = elo_dic[away_team_abbr]

        home_score = row['TEAM_SCORE_team']
        away_score = home_score - row['point_diff_team']
        home_rating = elo_dic[home_team_abbr]
        away_rating = elo_dic[away_team_abbr]

        home_update, away_update = elo_update(home_score, away_score, home_rating, away_rating)

        df.loc[idx, 'home_rating_n'] = home_rating + home_update
        df.loc[idx, 'away_rating_n'] = away_rating + away_update
        df.loc[idx, 'home_elo_pred'] = elo_prediction(home_rating+100, away_rating)

        elo_dic[home_team_abbr] = df.loc[idx, 'home_rating_n']
        elo_dic[away_team_abbr] = df.loc[idx, 'away_rating_n']

    df['elo_MOV_pred'] = round((df['home_rating_i']+100 - df['away_rating_i'])/28, 2)

    return elo_dic

elo_ratings_dic = get_current_elo_ratings(df1, final_elo_2020)
# Out:
# progress:: 713it [00:01, 594.18it/s]

# %%
sorted(list(elo_ratings_dic.items()), key=lambda x: x[1], reverse=True)
# Out:
# [('UTA', 1695.1116127688701),
#  ('DEN', 1643.9932061267505),
#  ('PHX', 1643.2505280213047),
#  ('PHI', 1641.91906223637),
#  ('MIL', 1636.6251277234726),
#  ('LAC', 1617.9483674908743),
#  ('BKN', 1609.0970800387167),
#  ('DAL', 1600.6323347879759),
#  ('LAL', 1594.685823621672),
#  ('ATL', 1549.0858878760444),
#  ('CHA', 1529.246188892717),
#  ('MEM', 1529.1740586616115),
#  ('MIA', 1522.2233032905194),
#  ('POR', 1509.5329643682226),
#  ('BOS', 1508.5640846888216),
#  ('IND', 1506.1032699853033),
#  ('TOR', 1484.370998943311),
#  ('NOP', 1460.0619221119289),
#  ('NYK', 1459.8277688751557),
#  ('SAC', 1454.8135939558026),
#  ('SAS', 1445.5081664753009),
#  ('GSW', 1443.6002087162024),
#  ('CHI', 1422.7871491263463),
#  ('OKC', 1406.9973753498114),
#  ('DET', 1402.306882583506),
#  ('ORL', 1388.455298586604),
#  ('WAS', 1371.5658080238677),
#  ('CLE', 1342.7394090393968),
#  ('MIN', 1326.6109047226719),
#  ('HOU', 1290.7402598053923)]

# %%
def create_matchup_rows_for_model(df, away_team, home_team, spread, current_elo_dic):
    df = df.copy(deep=True)
    df.rename(columns={'SEASON_YEAR_team':'SEASON_YEAR',
                      'SEASON_ID_team':'SEASON_ID',
                      'TEAM_ID_team':'TEAM_ID',
                      'TEAM_ABBREVIATION_team':'TEAM_ABBREVIATION',
                      'GAME_DATE_team':'GAME_DATE',
                      'MATCHUP_team':'MATCHUP',
                      'HOME_GAME_team':'HOME_GAME',
                       'TEAM_SCORE_team':'SCORE_team'}, inplace=True)
    
    df.sort_values(['GAME_DATE'], inplace=True)
    
    home_stats = df.loc[df['TEAM_ABBREVIATION'] == home_team].reset_index(drop=True)
    home_stats.at[home_stats.shape[0]-1, 'rest'] = (datetime.today() - home_stats.at[home_stats.shape[0]-1, 'GAME_DATE']) // np.timedelta64(1, 'D')
    away_stats = df.loc[df['TEAM_ABBREVIATION'] == away_team].reset_index(drop=True)
    away_stats.at[away_stats.shape[0]-1, 'rest'] = (datetime.today() - away_stats.at[away_stats.shape[0]-1, 'GAME_DATE']) // np.timedelta64(1, 'D')

    diffs = home_stats.iloc[-1, 14:] - away_stats.iloc[-1, 14:]
    diffs = diffs.values.reshape(1, -1)
    
    new_cols = [col+"_diff" for col in home_stats.columns[14:]]
    
    diffs = pd.DataFrame(diffs, columns=new_cols)
        
    diffs['home_rating_i'] = current_elo_dic[home_team]
    diffs['away_rating_i'] = current_elo_dic[away_team]
    diffs['home_elo_pred'] = 1.0/(1 + 10 ** (( diffs['away_rating_i'] - diffs['home_rating_i']) / (400.0)))

    diffs['elo_MOV_pred'] = round((diffs['home_rating_i']+100 - diffs['away_rating_i'])/28, 2)
    diffs['home_spread_mode'] = spread 
    
    diffs = diffs[X_train_ewm_19.columns]
    
    return diffs

create_matchup_rows_for_model(df1, 'OKC', 'MIN', -3, current_elo_dic=elo_ratings_dic)
# Out:
#    home_spread_mode WL_record_diff ATS_record_diff RECORD_team_diff  \
# 0                -3      -0.179463      -0.0744681        -0.130346
#
#   team_covered_diff FG2M_team_diff FG2A_team_diff FG3M_team_diff  \
# 0         0.0100565       0.771314        1.38298   -0.000764037
#
#   FG3A_team_diff FTM_team_diff FTA_team_diff OREB_team_diff DREB_team_diff  \
# 0        3.60108       1.18658      0.615254        -0.3409       -3.48034
#
#   REB_team_diff AST_team_diff STL_team_diff BLK_team_diff TOV_team_diff  \
# 0      -3.82125       3.28415       2.38366      0.670353      -2.05369
#
#   PF_team_diff PTS_team_diff PLUS_MINUS_team_diff E_OFF_RATING_team_diff  \
# 0      3.52316       2.72691            -0.580535              -0.945318
#
#   OFF_RATING_team_diff E_DEF_RATING_team_diff DEF_RATING_team_diff  \
# 0              1.11265              -0.177191               1.1315
#
#   E_NET_RATING_team_diff NET_RATING_team_diff POSS_team_diff PIE_team_diff  \
# 0              -0.786312           -0.0324955        1.48803   -0.00496232
#
#   PTS_2PT_MR_team_diff PTS_FB_team_diff PTS_OFF_TOV_team_diff  \
# 0             -1.20019          3.19163               4.46767
#
#   PTS_PAINT_team_diff AST_2PM_team_diff UAST_2PM_team_diff AST_3PM_team_diff  \
# 0             2.72338           2.67205           -1.99951          0.718132
#
#   UAST_3PM_team_diff TEAM_SCORE_opp_diff RECORD_opp_diff FG2M_opp_diff  \
# 0          -0.695025             3.30745        0.130346     -0.135756
#
#   FG2A_opp_diff FG3M_opp_diff FG3A_opp_diff FTM_opp_diff FTA_opp_diff  \
# 0       1.99365      0.416147       -3.4697      2.33052      2.30673
#
#   OREB_opp_diff DREB_opp_diff REB_opp_diff AST_opp_diff STL_opp_diff  \
# 0   -0.00117765       2.07533      2.07415      2.90665     -2.29005
#
#   BLK_opp_diff TOV_opp_diff PF_opp_diff PTS_opp_diff PLUS_MINUS_opp_diff  \
# 0     0.671452      3.54816    0.931445      3.30745            0.580535
#
#   E_OFF_RATING_opp_diff OFF_RATING_opp_diff E_DEF_RATING_opp_diff  \
# 0             -0.177191              1.1315             -0.945318
#
#   DEF_RATING_opp_diff E_NET_RATING_opp_diff NET_RATING_opp_diff POSS_opp_diff  \
# 0             1.11265              0.786312           0.0324955       1.81846
#
#   PIE_opp_diff PTS_2PT_MR_opp_diff PTS_FB_opp_diff PTS_OFF_TOV_opp_diff  \
# 0   0.00496232             1.39736         3.59304             -4.42725
#
#   PTS_PAINT_opp_diff AST_2PM_opp_diff UAST_2PM_opp_diff AST_3PM_opp_diff  \
# 0           -1.72532          2.22005          -2.37193         0.657797
#
#   UAST_3PM_opp_diff OREB_PCT_team_diff OREB_PCT_opp_diff DREB_PCT_team_diff  \
# 0         -0.346865         -0.0158015          0.017094          -0.017094
#
#   DREB_PCT_opp_diff REB_PCT_team_diff REB_PCT_opp_diff TS_PCT_team_diff  \
# 0         0.0158015        -0.0326693        0.0326693       -0.0169042
#
#   TS_PCT_opp_diff EFG_PCT_team_diff EFG_PCT_opp_diff AST_RATIO_team_diff  \
# 0       0.0238796        -0.0201873        0.0145145             2.89928
#
#   AST_RATIO_opp_diff TOV_PCT_team_diff TOV_PCT_opp_diff rest_diff  \
# 0            2.42549          -2.17765          2.81216         0
#
#    home_elo_pred  home_rating_i  away_rating_i  elo_MOV_pred
# 0       0.386336    1326.610905    1406.997375           0.7

# %% [markdown]
# ### Make Predictions

# %%
todays_spreads = get_days_spreads(todays_date)
todays_spreads = clean_spread_data(todays_spreads)
todays_spreads
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'float'
#   warn(f"Unable to sort modes: {err}")
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\algorithms.py:897: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   warn(f"Unable to sort modes: {err}")
#   away_team home_team   game_date away_spread1 away_spread2  away_spread3  \
# 0       DAL       WAS  2021-04-03     -4.5-110     -4.5-112          -4.5
# 1       CLE       MIA  2021-04-03       12-110       12-108          12.5
# 2       MIN       PHI  2021-04-03       13-110       12-110          13.5
# 3       NYK       DET  2021-04-03     -1.5-110     -1.5-113          -1.5
# 4       IND       SAS  2021-04-03        6-110      4.5-113           5.5
# 5       ORL       UTA  2021-04-03       15-110       15-110          15.0
# 6       MIL       SAC  2021-04-03       -6-105     -6.5-110          -5.5
# 7       OKC       POR  2021-04-03     11.5-110     11.5-105          11.5
#
#    away_spread4  home_spread1  home_spread2  home_spread3  home_spread4  \
# 0          -4.5           4.5           4.5           4.5           4.5
# 1          12.0         -12.0         -12.0         -12.5         -12.0
# 2          13.0         -13.0         -12.0         -13.5         -13.0
# 3          -1.5           1.5           1.5           1.5           1.5
# 4           6.0          -6.0          -4.5          -5.5          -6.0
# 5          14.5         -15.0         -15.0         -15.0         -14.5
# 6          -5.5           6.0           6.5           5.5           5.5
# 7          11.5         -11.5         -11.5         -11.5         -11.5
#
#   away_spread_mode  home_spread_mode
# 0             -4.5               4.5
# 1             12.5             -12.0
# 2           13-110             -13.0
# 3             -1.5               1.5
# 4            6-110              -6.0
# 5           15-110             -15.0
# 6             -5.5               5.5
# 7             11.5             -11.5

# %%
# Load Models

with open('../models/sgd_ewm_19.pkl', 'rb') as f:
    sgd_pipe = pickle.load(f)
    
with open('../models/lgbr_ewm_19.pkl', 'rb') as f:
    best_lgbr = pickle.load(f)
    
with open('../models/xgb_ewm_19.pkl', 'rb') as f:
    best_xgbr = pickle.load(f)
    
with open('../models/rf_ewm_19.pkl', 'rb') as f:
    best_rf = pickle.load(f)
    
with open('../models/en_ewm_19.pkl', 'rb') as f:
    en_pipe = pickle.load(f)
    
with open("../models/lasso_ewm_19.pkl", 'rb') as f:
    lasso_pipe = pickle.load(f)

# %%
df = load_current_season_team_data(season='2020-21')
df1 = clean_team_data(df)
df1 = prep_for_aggregation(df1)
df1 = create_matchups(df1) 
df1 = add_spread_data(df1)
df1 = get_team_and_opp_ewm_for_model(df1)
df1 = add_rest_days_for_model(df1)
df1 = add_percentage_features(df1)

create_matchup_rows_for_model(df1, 'OKC', 'MIN', -3, current_elo_dic=elo_ratings_dic)
# Out:
#    home_spread_mode WL_record_diff ATS_record_diff RECORD_team_diff  \
# 0                -3      -0.183092      -0.0763285        -0.144892
#
#   team_covered_diff FG2M_team_diff FG2A_team_diff FG3M_team_diff  \
# 0          0.011143        1.19352        2.20987   -0.000726966
#
#   FG3A_team_diff FTM_team_diff FTA_team_diff OREB_team_diff DREB_team_diff  \
# 0         3.2203       1.87994       1.69273       0.741648       -2.30137
#
#   REB_team_diff AST_team_diff STL_team_diff BLK_team_diff TOV_team_diff  \
# 0      -1.55972       2.97972       1.86619      0.521539      -1.49935
#
#   PF_team_diff PTS_team_diff PLUS_MINUS_team_diff E_OFF_RATING_team_diff  \
# 0      4.14165        4.2648             0.363874               0.192724
#
#   OFF_RATING_team_diff E_DEF_RATING_team_diff DEF_RATING_team_diff  \
# 0              2.11145               0.115911              1.12315
#
#   E_NET_RATING_team_diff NET_RATING_team_diff POSS_team_diff PIE_team_diff  \
# 0              0.0677887             0.984322        1.99059   -0.00237432
#
#   PTS_2PT_MR_team_diff PTS_FB_team_diff PTS_OFF_TOV_team_diff  \
# 0             -1.44673          3.10111               3.84759
#
#   PTS_PAINT_team_diff AST_2PM_team_diff UAST_2PM_team_diff AST_3PM_team_diff  \
# 0             3.58807           2.97124           -1.88749         0.0143575
#
#   UAST_3PM_team_diff TEAM_SCORE_opp_diff RECORD_opp_diff FG2M_opp_diff  \
# 0          -0.100572             3.90093        0.144892       -1.1599
#
#   FG2A_opp_diff FG3M_opp_diff FG3A_opp_diff FTM_opp_diff FTA_opp_diff  \
# 0      0.536119       1.02301      -1.28157      3.15171      2.90113
#
#   OREB_opp_diff DREB_opp_diff REB_opp_diff AST_opp_diff STL_opp_diff  \
# 0   -0.00155193       1.63512      1.63357      3.34388     -1.87421
#
#   BLK_opp_diff TOV_opp_diff PF_opp_diff PTS_opp_diff PLUS_MINUS_opp_diff  \
# 0     0.858817      2.82509     1.82035      3.90093           -0.363874
#
#   E_OFF_RATING_opp_diff OFF_RATING_opp_diff E_DEF_RATING_opp_diff  \
# 0              0.115911             1.12315              0.192724
#
#   DEF_RATING_opp_diff E_NET_RATING_opp_diff NET_RATING_opp_diff POSS_opp_diff  \
# 0             2.11145            -0.0677887           -0.984322       2.35787
#
#   PIE_opp_diff PTS_2PT_MR_opp_diff PTS_FB_opp_diff PTS_OFF_TOV_opp_diff  \
# 0   0.00237432            0.095416         3.99595              -3.6913
#
#   PTS_PAINT_opp_diff AST_2PM_opp_diff UAST_2PM_opp_diff AST_3PM_opp_diff  \
# 0           -2.36804          2.24413          -3.42199           1.1797
#
#   UAST_3PM_opp_diff OREB_PCT_team_diff OREB_PCT_opp_diff DREB_PCT_team_diff  \
# 0         -0.161641         0.00481673         0.0116754         -0.0116754
#
#   DREB_PCT_opp_diff REB_PCT_team_diff REB_PCT_opp_diff TS_PCT_team_diff  \
# 0       -0.00481673         -0.017652         0.017652       -0.0128075
#
#   TS_PCT_opp_diff EFG_PCT_team_diff EFG_PCT_opp_diff AST_RATIO_team_diff  \
# 0       0.0213821         -0.017978       0.00875831              2.4739
#
#   AST_RATIO_opp_diff TOV_PCT_team_diff TOV_PCT_opp_diff rest_diff  \
# 0            2.70151          -1.85381           2.1216         0
#
#    home_elo_pred  home_rating_i  away_rating_i  elo_MOV_pred
# 0       0.383526    1329.036655    1411.484854          0.63

# %%
matchup_row = create_matchup_rows_for_model(df1, 'DAL', 'WAS', 20, current_elo_dic=elo_ratings_dic)
print(matchup_row.shape)
net_full(torch.tensor(nn_scaler.transform(matchup_row)).float())
# Out:
# (1, 90)
# tensor([[-2.6207]], grad_fn=<AddmmBackward>)

# %%
net_full(torch.tensor(nn_scaler.transform(matchup_row)).float())
# Out:
# tensor([[0.0996]], grad_fn=<AddmmBackward>)

# %%
df = load_current_season_team_data(season='2020-21')
df1 = clean_team_data(df)
df1 = prep_for_aggregation(df1)
df1 = create_matchups(df1) 
df1 = add_spread_data(df1)
df1 = get_team_and_opp_ewm_for_model(df1)
df1 = add_rest_days_for_model(df1)
df1 = add_percentage_features(df1)

elo_ratings_dic = get_current_elo_ratings(df1, final_elo_2020)



away_teams = []
home_teams = []
spreads = []
game_dates = []
# sgd_preds = []
# lgb_preds = []
# xgb_preds = []
# rf_preds = []
# en_preds = []
# lasso_preds = []
# svm_preds = []
# custom_loss_lr_preds = []
net_preds = []

for row in todays_spreads.itertuples(index=False):
    away_team = row.away_team
    home_team = row.home_team
    spread = row.home_spread_mode
    game_date = row.game_date
    matchup_row = create_matchup_rows_for_model(df1, away_team, home_team, spread, elo_ratings_dic)
    matchup_row = matchup_row.astype(float)
#     sgd_pred = sgd_pipe.predict(matchup_row)
#     lgb_pred = best_lgbr.predict(matchup_row)
#     xgb_pred = best_xgbr.predict(matchup_row)
#     rf_pred = best_rf.predict(matchup_row)
#     en_pred = en_pipe.predict(matchup_row)
#     lasso_pred = lasso_pipe.predict(matchup_row)
#     svm_pred = linear_svm.predict(matchup_row)
#     custom_loss_lr_pred = wTx(weights, scaler.transform(matchup_row))
    net_pred = net_full(torch.tensor(nn_scaler.transform(matchup_row)).float())

    
    
    away_teams.append(away_team)
    home_teams.append(home_team)
    spreads.append(spread)
    game_dates.append(game_date)
#     lgb_preds.append(lgb_pred[0])
#     sgd_preds.append(sgd_pred[0])
#     xgb_preds.append(xgb_pred[0])
#     lasso_preds.append(lasso_pred[0])
#     rf_preds.append(rf_pred[0])
#     en_preds.append(en_pred[0])
#     svm_preds.append(svm_pred[0])
#     custom_loss_lr_preds.append(custom_loss_lr_pred[0])
    net_preds.append(net_pred.detach().numpy()[0])
       
preds_df = pd.DataFrame({'away_team':away_teams,
                        'home_team':home_teams,
                        'spread':spreads,
                        'game_date':game_dates,
#                          'sgd_pred':sgd_preds,
#                         'lgb_pred':lgb_preds,
#                          'xgb_pred':xgb_preds,
#                          'rf_pred':rf_preds,
#                          'en_pred':en_preds,
#                          'lasso_pred':lasso_preds,
                        'net_pred':net_preds})
#                         'svm_pred':svm_preds,
#                         'custom_loss_lr_pred':custom_loss_lr_preds})

preds_df
# Out:
# progress:: 713it [00:00, 768.00it/s]
#   away_team home_team  spread   game_date        net_pred
# 0       DAL       WAS     4.5  2021-04-03    [-2.0314543]
# 1       CLE       MIA   -12.0  2021-04-03    [-0.7431023]
# 2       MIN       PHI   -13.0  2021-04-03     [-2.774469]
# 3       NYK       DET     1.5  2021-04-03    [0.21155608]
# 4       IND       SAS    -6.0  2021-04-03    [-1.0953536]
# 5       ORL       UTA   -15.0  2021-04-03  [-0.026118085]
# 6       MIL       SAC     5.5  2021-04-03    [0.10418765]
# 7       OKC       POR   -11.5  2021-04-03     [-2.474314]

# %%
df = load_current_season_team_data(season='2020-21')
df1 = clean_team_data(df)
df1 = prep_for_aggregation(df1)
df1 = create_matchups(df1) 
df1 = add_spread_data(df1)
df1 = get_team_and_opp_ewm_for_model(df1)
df1 = add_rest_days_for_model(df1)
df1 = add_percentage_features(df1)

elo_ratings_dic = get_current_elo_ratings(df1, final_elo_2020)



away_teams = []
home_teams = []
spreads = []
game_dates = []
sgd_preds = []
lgb_preds = []
xgb_preds = []
rf_preds = []
en_preds = []
lasso_preds = []
# svm_preds = []
# custom_loss_lr_preds = []
net_preds = []

for row in todays_spreads.itertuples(index=False):
    away_team = row.away_team
    home_team = row.home_team
    spread = row.home_spread_mode
    game_date = row.game_date
    matchup_row = create_matchup_rows_for_model(df1, away_team, home_team, spread, elo_ratings_dic)
    matchup_row = matchup_row.astype(float)

    if spread >= 0:
        
        sgd_pred = sgd_hd.predict(matchup_row)
        en_pred = en_pipe_hd.predict(matchup_row)

        lgb_pred = best_lgbr_hd.predict(matchup_row)
        xgb_pred = best_xgbr_hd.predict(matchup_row)
        rf_pred = best_rf_hd.predict(matchup_row)
        lasso_pred = lasso_pipe.predict(matchup_row)
#     svm_pred = linear_svm.predict(matchup_row)
#     custom_loss_lr_pred = wTx(weights, scaler.transform(matchup_row))
    net_pred = net(nn_scaler.transform(matchup_row))

    
    
    away_teams.append(away_team)
    home_teams.append(home_team)
    spreads.append(spread)
    game_dates.append(game_date)
    lgb_preds.append(lgb_pred[0])
    sgd_preds.append(sgd_pred[0])
    xgb_preds.append(xgb_pred[0])
    lasso_preds.append(lasso_pred[0])
    rf_preds.append(rf_pred[0])
    en_preds.append(en_pred[0])
#     svm_preds.append(svm_pred[0])
#     custom_loss_lr_preds.append(custom_loss_lr_pred[0])
    net_preds.append(net_pred.detach().numpy()[0])
       
preds_df = pd.DataFrame({'away_team':away_teams,
                        'home_team':home_teams,
                        'spread':spreads,
                        'game_date':game_dates,
                         'sgd_pred':sgd_preds,
                        'lgb_pred':lgb_preds,
                         'xgb_pred':xgb_preds,
                         'rf_pred':rf_preds,
                         'en_pred':en_preds,
                         'lasso_pred':lasso_preds,
                        'net_pred':net_preds})
#                         'svm_pred':svm_preds,
#                         'custom_loss_lr_pred':custom_loss_lr_preds})

preds_df

# %% [markdown]
# # Team Based Model

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt


from tqdm import tqdm
from nba_api.stats.static import players, teams

import sys

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")

from src.data.make_team_dataset import load_team_data


from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression, ElasticNetCV, LassoCV, RidgeCV, LogisticRegression
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVR, SVC
import xgboost as xgb


from sklearn.preprocessing import Normalizer, StandardScaler
from sklearn.feature_selection import VarianceThreshold, RFE, RFECV
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import learning_curve, validation_curve
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.options.display.max_columns=230
pd.options.display.max_rows=100

# %% [markdown]
# ## Gather Team Level Basic, Advanced, and Scoring Data

# %%
team_data = load_team_data()

# %%
from src.data.make_team_dataset import clean_team_data

clean_team_df = clean_team_data(team_data)

# %%
clean_team_df
# Out:
#       SEASON_YEAR  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0         2000-01      22000  1610612745               HOU
# 1         2000-01      22000  1610612750               MIN
# 2         2000-01      22000  1610612751               BKN
# 3         2000-01      22000  1610612739               CLE
# 4         2000-01      22000  1610612754               IND
# ...           ...        ...         ...               ...
# 51343     2019-20      42019  1610612747               LAL
# 51344     2019-20      42019  1610612748               MIA
# 51345     2019-20      42019  1610612747               LAL
# 51346     2019-20      42019  1610612748               MIA
# 51347     2019-20      42019  1610612747               LAL
#
#                     TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  WL  MIN  FGM  \
# 0             Houston Rockets  20000008 2000-10-31  HOU vs. MIN   0  240   34
# 1      Minnesota Timberwolves  20000008 2000-10-31    MIN @ HOU   1  240   43
# 2             New Jersey Nets  20000002 2000-10-31  BKN vs. CLE   0  240   31
# 3         Cleveland Cavaliers  20000002 2000-10-31    CLE @ BKN   1  240   32
# 4              Indiana Pacers  20000009 2000-10-31    IND @ SAS   0  240   36
# ...                       ...       ...        ...          ...  ..  ...  ...
# 51343      Los Angeles Lakers  41900404 2020-10-06    LAL @ MIA   1  240   35
# 51344              Miami Heat  41900405 2020-10-09    MIA @ LAL   1  240   38
# 51345      Los Angeles Lakers  41900405 2020-10-09  LAL vs. MIA   0  240   38
# 51346              Miami Heat  41900406 2020-10-11  MIA vs. LAL   0  240   35
# 51347      Los Angeles Lakers  41900406 2020-10-11    LAL @ MIA   1  240   43
#
#        FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  \
# 0       74   0.459     2     9    0.222   28   40   0.700    11    27   38
# 1       88   0.489     6    11    0.545   14   16   0.875    13    31   44
# 2       85   0.365     3    10    0.300   17   26   0.654    12    35   47
# 3       78   0.410     2     7    0.286   20   32   0.625    11    41   52
# 4       80   0.450     4    17    0.235    9   13   0.692     9    26   35
# ...    ...     ...   ...   ...      ...  ...  ...     ...   ...   ...  ...
# 51343   79   0.443    14    39    0.359   18   21   0.857    10    32   42
# 51344   83   0.458    14    33    0.424   21   22   0.955     9    26   35
# 51345   82   0.463    14    38    0.368   18   21   0.857    12    29   41
# 51346   79   0.443    10    28    0.357   13   22   0.591     9    32   41
# 51347   89   0.483    11    35    0.314    9   14   0.643    12    34   46
#
#        AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS
CT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  \
# 0            0.061       0.102       0.286            0.204          0.490
# 1            0.170       0.085       0.132            0.208          0.302
# 2            0.110       0.110       0.207            0.256          0.512
# 3            0.070       0.163       0.233            0.140          0.419
# 4            0.141       0.106       0.106            0.259          0.306
# ...            ...         ...         ...              ...            ...
# 51343        0.412       0.069       0.176            0.186          0.333
# 51344        0.378       0.036       0.189            0.180          0.288
# 51345        0.389       0.231       0.167            0.130          0.389
# 51346        0.323       0.086       0.140            0.151          0.473
# 51347        0.311       0.151       0.085            0.189          0.491
#
#        PCT_AST_2PM  PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  \
# 0            0.563         0.438        0.000         1.000        0.529
# 1            0.622         0.378        1.000         0.000        0.674
# 2            0.750         0.250        1.000         0.000        0.774
# 3            0.467         0.533        1.000         0.000        0.500
# 4            0.469         0.531        1.000         0.000        0.528
# ...            ...           ...          ...           ...          ...
# 51343        0.619         0.381        0.857         0.143        0.714
# 51344        0.542         0.458        0.929         0.071        0.684
# 51345        0.458         0.542        0.714         0.286        0.553
# 51346        0.720         0.280        0.700         0.300        0.714
# 51347        0.406         0.594        0.909         0.091        0.535
#
#        PCT_UAST_FGM  HOME_GAME
# 0             0.471          1
# 1             0.326          0
# 2             0.226          1
# 3             0.500          0
# 4             0.472          0
# ...             ...        ...
# 51343         0.286          0
# 51344         0.316          0
# 51345         0.447          1
# 51346         0.286          1
# 51347         0.465          0
#
# [51344 rows x 68 columns]

# %%
from src.data.make_team_dataset import prep_for_aggregation
ready_for_agg_df = prep_for_aggregation(clean_team_df)
ready_for_agg_df
# Out:
#       SEASON_YEAR  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0         2000-01      22000  1610612745               HOU
# 1         2000-01      22000  1610612750               MIN
# 2         2000-01      22000  1610612751               BKN
# 3         2000-01      22000  1610612739               CLE
# 4         2000-01      22000  1610612754               IND
# ...           ...        ...         ...               ...
# 51343     2019-20      42019  1610612747               LAL
# 51344     2019-20      42019  1610612748               MIA
# 51345     2019-20      42019  1610612747               LAL
# 51346     2019-20      42019  1610612748               MIA
# 51347     2019-20      42019  1610612747               LAL
#
#                     TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  HOME_GAME  \
# 0             Houston Rockets  20000008 2000-10-31  HOU vs. MIN          1
# 1      Minnesota Timberwolves  20000008 2000-10-31    MIN @ HOU          0
# 2             New Jersey Nets  20000002 2000-10-31  BKN vs. CLE          1
# 3         Cleveland Cavaliers  20000002 2000-10-31    CLE @ BKN          0
# 4              Indiana Pacers  20000009 2000-10-31    IND @ SAS          0
# ...                       ...       ...        ...          ...        ...
# 51343      Los Angeles Lakers  41900404 2020-10-06    LAL @ MIA          0
# 51344              Miami Heat  41900405 2020-10-09    MIA @ LAL          0
# 51345      Los Angeles Lakers  41900405 2020-10-09  LAL vs. MIA          1
# 51346              Miami Heat  41900406 2020-10-11  MIA vs. LAL          1
# 51347      Los Angeles Lakers  41900406 2020-10-11    LAL @ MIA          0
#
#        TEAM_SCORE  point_diff  WL  MIN  RECORD  FG2M  FG2A  FG3M  FG3A  FTM  \
# 0              98          -8   0  240       0    32    65     2     9   28
# 1             106           8   1  240       1    37    77     6    11   14
# 2              82          -4   0  240       0    28    75     3    10   17
# 3              86           4   1  240       1    30    71     2     7   20
# 4              85         -13   0  240       0    32    63     4    17    9
# ...           ...         ...  ..  ...     ...   ...   ...   ...   ...  ...
# 51343         102           6   1  240       1    21    40    14    39   18
# 51344         111           3   1  240       1    24    50    14    33   21
# 51345         108          -3   0  240       0    24    44    14    38   18
# 51346          93         -13   0  240       0    25    51    10    28   13
# 51347         106          13   1  240       1    32    54    11    35    9
#
#        FTA  OREB  DREB  REB  AST  STL  BLK  TOV  PF  PTS  PLUS_MINUS  \
# 0       40    11    27   38   18    9    7   18  17   98          -8
# 1       16    13    31   44   29    7    1   16  25  106           8
# 2       26    12    35   47   24    9    8   15  31   82          -4
# 3       32    11    41   52   16    5    8   19  27   86           4
# 4       13     9    26   35   19    5    4   17  32   85         -13
# ...    ...   ...   ...  ...  ...  ...  ...  ...  ..  ...         ...
# 51343   21    10    32   42   25    5    4   15  14  102           6
# 51344   22     9    26   35   26    7    3   13  19  111           3
# 51345   21    12    29   41   21   10    5   15  21  108          -3
# 51346   22     9    32   41   25    4    4   15  18   93         -13
# 51347   14    12    34   46   23    5    4   14  22  106          13
#
#        E_OFF_RATING  OFF_RATING  E_DEF_RATING  DEF_RATING  E_NET_RATING  \
# 0              99.4       103.2         108.1       110.4          -8.7
# 1             108.1       110.4          99.4       103.2           8.7
# 2              82.5        83.7          85.9        87.8          -3.5
# 3              85.9        87.8          82.5        83.7           3.5
# 4              90.7        90.4         106.1       104.3         -15.4
# ...             ...         ...           ...         ...           ...
# 51343         109.4       110.9         101.7       104.3           7.7
# 51344         114.8       119.4         114.6       114.9           0.2
# 51345         114.6       114.9         114.8       119.4          -0.2
# 51346          98.2       100.0         109.1       112.8         -10.9
# 51347         109.1       112.8          98.2       100.0          10.9
#
#        NET_RATING  POSS    PIE  PTS_2PT_MR  PTS_FB  PTS_OFF_TOV  PTS_PAINT  \
# 0            -7.3  95.0  0.446          15       9           19         48
# 1             7.3  96.0  0.554          41       9           22         32
# 2            -4.1  98.0  0.488          14       9           20         41
# 3             4.1  98.0  0.512          23      14           12         36
# 4           -13.8  94.0  0.359          37       9           22         26
# ...           ...   ...    ...         ...     ...          ...        ...
# 51343         6.5  92.0  0.559           7       7           18         33
# 51344         4.5  93.0  0.512          15       3           19         31
# 51345        -4.5  94.0  0.488           6      24           14         42
# 51346       -12.8  93.0  0.456           6       7           14         43
# 51347        12.8  94.0  0.544          11      16           20         52
#
#        AST_2PM  UAST_2PM  AST_3PM  UAST_3PM
# 0           18        14        0         2
# 1           23        13        6         0
# 2           21         7        3         0
# 3           14        15        2         0
# 4           15        16        4         0
# ...        ...       ...      ...       ...
# 51343       12         8       11         2
# 51344       13        10       13         0
# 51345       10        13        9         4
# 51346       18         7        7         3
# 51347       12        19        9         1
#
# [51344 rows x 46 columns]

# %%
from src.data import make_team_dataset

matchups = make_team_dataset.create_matchups(ready_for_agg_df)

matchups
# Out:
#        SEASON_YEAR_team  SEASON_ID_team  TEAM_ID_team TEAM_ABBREVIATION_team  \
# 1               2000-01           22000    1610612745                    HOU
# 2               2000-01           22000    1610612750                    MIN
# 5               2000-01           22000    1610612751                    BKN
# 6               2000-01           22000    1610612739                    CLE
# 9               2000-01           22000    1610612754                    IND
# ...                 ...             ...           ...                    ...
# 102678          2019-20           42019    1610612747                    LAL
# 102681          2019-20           42019    1610612748                    MIA
# 102682          2019-20           42019    1610612747                    LAL
# 102685          2019-20           42019    1610612748                    MIA
# 102686          2019-20           42019    1610612747                    LAL
#
#                 TEAM_NAME_team   GAME_ID GAME_DATE_team MATCHUP_team  \
# 1              Houston Rockets  20000008     2000-10-31  HOU vs. MIN
# 2       Minnesota Timberwolves  20000008     2000-10-31    MIN @ HOU
# 5              New Jersey Nets  20000002     2000-10-31  BKN vs. CLE
# 6          Cleveland Cavaliers  20000002     2000-10-31    CLE @ BKN
# 9               Indiana Pacers  20000009     2000-10-31    IND @ SAS
# ...                        ...       ...            ...          ...
# 102678      Los Angeles Lakers  41900404     2020-10-06    LAL @ MIA
# 102681              Miami Heat  41900405     2020-10-09    MIA @ LAL
# 102682      Los Angeles Lakers  41900405     2020-10-09  LAL vs. MIA
# 102685              Miami Heat  41900406     2020-10-11  MIA vs. LAL
# 102686      Los Angeles Lakers  41900406     2020-10-11    LAL @ MIA
#
#         HOME_GAME_team  TEAM_SCORE_team  point_diff_team  WL_team  MIN_team  \
# 1                    1               98               -8        0       240
# 2                    0              106                8        1       240
# 5                    1               82               -4        0       240
# 6                    0               86                4        1       240
# 9                    0               85              -13        0       240
# ...                ...              ...              ...      ...       ...
# 102678               0              102                6        1       240
# 102681               0              111                3        1       240
# 102682               1              108               -3        0       240
# 102685               1               93              -13        0       240
# 102686               0              106               13        1       240
#
#         RECORD_team  FG2M_team  FG2A_team  FG3M_team  FG3A_team  FTM_team  \
# 1                 0         32         65          2          9        28
# 2                 1         37         77          6         11        14
# 5                 0         28         75          3         10        17
# 6                 1         30         71          2          7        20
# 9                 0         32         63          4         17         9
# ...             ...        ...        ...        ...        ...       ...
# 102678            1         21         40         14         39        18
# 102681            1         24         50         14         33        21
# 102682            0         24         44         14         38        18
# 102685            0         25         51         10         28        13
# 102686            1         32         54         11         35         9
#
#         FTA_team  OREB_team  DREB_team  REB_team  AST_team  STL_team  \
# 1             40         11         27        38        18         9
# 2             16         13         31        44        29         7
# 5             26         12         35        47        24         9
# 6             32         11         41        52        16         5
# 9             13          9         26        35        19         5
# ...          ...        ...        ...       ...       ...       ...
# 102678        21         10         32        42        25         5
# 102681        22          9         26        35        26         7
# 102682        21         12         29        41        21        10
# 102685        22          9         32        41        25         4
# 102686        14         12         34        46        23         5
#
#         BLK_team  TOV_team  PF_team  PTS_team  PLUS_MINUS_team  \
# 1              7        18       17        98               -8
# 2              1        16       25       106                8
# 5              8        15       31        82               -4
# 6              8        19       27        86                4
# 9              4        17       32        85              -13
# ...          ...       ...      ...       ...              ...
# 102678         4        15       14       102                6
# 102681         3        13       19       111                3
# 102682         5        15       21       108               -3
# 102685         4        15       18        93              -13
# 102686         4        14       22       106               13
#
#         E_OFF_RATING_team  OFF_RATING_team  E_DEF_RATING_team  \
# 1                    99.4            103.2              108.1
# 2                   108.1            110.4               99.4
# 5                    82.5             83.7               85.9
# 6                    85.9             87.8               82.5
# 9                    90.7             90.4              106.1
# ...                   ...              ...                ...
# 102678              109.4            110.9              101.7
# 102681              114.8            119.4              114.6
# 102682              114.6            114.9              114.8
# 102685               98.2            100.0              109.1
# 102686              109.1            112.8               98.2
#
#         DEF_RATING_team  E_NET_RATING_team  NET_RATING_team  POSS_team  \
# 1                 110.4               -8.7             -7.3       95.0
# 2                 103.2                8.7              7.3       96.0
# 5                  87.8               -3.5             -4.1       98.0
# 6                  83.7                3.5              4.1       98.0
# 9                 104.3              -15.4            -13.8       94.0
# ...                 ...                ...              ...        ...
# 102678            104.3                7.7              6.5       92.0
# 102681            114.9                0.2              4.5       93.0
# 102682            119.4               -0.2             -4.5       94.0
# 102685            112.8              -10.9            -12.8       93.0
# 102686            100.0               10.9             12.8       94.0
#
#         PIE_team  PTS_2PT_MR_team  PTS_FB_team  PTS_OFF_TOV_team  \
# 1          0.446               15            9                19
# 2          0.554               41            9                22
# 5          0.488               14            9                20
# 6          0.512               23           14                12
# 9          0.359               37            9                22
# ...          ...              ...          ...               ...
# 102678     0.559                7            7                18
# 102681     0.512               15            3                19
# 102682     0.488                6           24                14
# 102685     0.456                6            7                14
# 102686     0.544               11           16                20
#
#         PTS_PAINT_team  AST_2PM_team  UAST_2PM_team  AST_3PM_team  \
# 1                   48            18             14             0
# 2                   32            23             13             6
# 5                   41            21              7             3
# 6                   36            14             15             2
# 9                   26            15             16             4
# ...                ...           ...            ...           ...
# 102678              33            12              8            11
# 102681              31            13             10            13
# 102682              42            10             13             9
# 102685              43            18              7             7
# 102686              52            12             19             9
#
#         UAST_3PM_team SEASON_YEAR_opp  SEASON_ID_opp  TEAM_ID_opp  \
# 1                   2         2000-01          22000   1610612750
# 2                   0         2000-01          22000   1610612745
# 5                   0         2000-01          22000   1610612739
# 6                   0         2000-01          22000   1610612751
# 9                   0         2000-01          22000   1610612759
# ...               ...             ...            ...          ...
# 102678              2         2019-20          42019   1610612748
# 102681              0         2019-20          42019   1610612747
# 102682              4         2019-20          42019   1610612748
# 102685              3         2019-20          42019   1610612747
# 102686              1         2019-20          42019   1610612748
#
#        TEAM_ABBREVIATION_opp           TEAM_NAME_opp GAME_DATE_opp  \
# 1                        MIN  Minnesota Timberwolves    2000-10-31
# 2                        HOU         Houston Rockets    2000-10-31
# 5                        CLE     Cleveland Cavaliers    2000-10-31
# 6                        BKN         New Jersey Nets    2000-10-31
# 9                        SAS       San Antonio Spurs    2000-10-31
# ...                      ...                     ...           ...
# 102678                   MIA              Miami Heat    2020-10-06
# 102681                   LAL      Los Angeles Lakers    2020-10-09
# 102682                   MIA              Miami Heat    2020-10-09
# 102685                   LAL      Los Angeles Lakers    2020-10-11
# 102686                   MIA              Miami Heat    2020-10-11
#
#         MATCHUP_opp  HOME_GAME_opp  TEAM_SCORE_opp  point_diff_opp  WL_opp  \
# 1         MIN @ HOU              0             106               8       1
# 2       HOU vs. MIN              1              98              -8       0
# 5         CLE @ BKN              0              86               4       1
# 6       BKN vs. CLE              1              82              -4       0
# 9       SAS vs. IND              1              98              13       1
# ...             ...            ...             ...             ...     ...
# 102678  MIA vs. LAL              1              96              -6       0
# 102681  LAL vs. MIA              1             108              -3       0
# 102682    MIA @ LAL              0             111               3       1
# 102685    LAL @ MIA              0             106              13       1
# 102686  MIA vs. LAL              1              93             -13       0
#
#         MIN_opp  RECORD_opp  FG2M_opp  FG2A_opp  FG3M_opp  FG3A_opp  FTM_opp  \
# 1           240           1        37        77         6        11       14
# 2           240           0        32        65         2         9       28
# 5           240           1        30        71         2         7       20
# 6           240           0        28        75         3        10       17
# 9           240           1        29        56         4         8       28
# ...         ...         ...       ...       ...       ...       ...      ...
# 102678      240           0        21        43        11        32       21
# 102681      240           0        24        44        14        38       18
# 102682      240           1        24        50        14        33       21
# 102685      240           1        32        54        11        35        9
# 102686      240           0        25        51        10        28       13
#
#         FTA_opp  OREB_opp  DREB_opp  REB_opp  AST_opp  STL_opp  BLK_opp  \
# 1            16        13        31       44       29        7        1
# 2            40        11        27       38       18        9        7
# 5            32        11        41       52       16        5        8
# 6            26        12        35       47       24        9        8
# 9            35         5        32       37       17        6        4
# ...         ...       ...       ...      ...      ...      ...      ...
# 102678       26         7        32       39       18        8        3
# 102681       21        12        29       41       21       10        5
# 102682       22         9        26       35       26        7        3
# 102685       14        12        34       46       23        5        4
# 102686       22         9        32       41       25        4        4
#
#         TOV_opp  PF_opp  PTS_opp  PLUS_MINUS_opp  E_OFF_RATING_opp  \
# 1            16      25      106               8             108.1
# 2            18      17       98              -8              99.4
# 5            19      27       86               4              85.9
# 6            15      31       82              -4              82.5
# 9            18      22       98              13             106.1
# ...         ...     ...      ...             ...               ...
# 102678       15      21       96              -6             101.7
# 102681       15      21      108              -3             114.6
# 102682       13      19      111               3             114.8
# 102685       14      22      106              13             109.1
# 102686       15      18       93             -13              98.2
#
#         OFF_RATING_opp  E_DEF_RATING_opp  DEF_RATING_opp  E_NET_RATING_opp  \
# 1                110.4              99.4           103.2               8.7
# 2                103.2             108.1           110.4              -8.7
# 5                 87.8              82.5            83.7               3.5
# 6                 83.7              85.9            87.8              -3.5
# 9                104.3              90.7            90.4              15.4
# ...                ...               ...             ...               ...
# 102678           104.3             109.4           110.9              -7.7
# 102681           114.9             114.8           119.4              -0.2
# 102682           119.4             114.6           114.9               0.2
# 102685           112.8              98.2           100.0              10.9
# 102686           100.0             109.1           112.8             -10.9
#
#         NET_RATING_opp  POSS_opp  PIE_opp  PTS_2PT_MR_opp  PTS_FB_opp  \
# 1                  7.3      96.0    0.554              41           9
# 2                 -7.3      95.0    0.446              15           9
# 5                  4.1      98.0    0.512              23          14
# 6                 -4.1      98.0    0.488              14           9
# 9                 13.8      94.0    0.641              42           5
# ...                ...       ...      ...             ...         ...
# 102678            -6.5      92.0    0.441               9           4
# 102681            -4.5      94.0    0.488               6          24
# 102682             4.5      93.0    0.512              15           3
# 102685            12.8      94.0    0.544              11          16
# 102686           -12.8      93.0    0.456               6           7
#
#         PTS_OFF_TOV_opp  PTS_PAINT_opp  AST_2PM_opp  UAST_2PM_opp  \
# 1                    22             32           23            13
# 2                    19             48           18            14
# 5                    12             36           14            15
# 6                    20             41           21             7
# 9                    14             15           12            16
# ...                 ...            ...          ...           ...
# 102678               12             31            6            14
# 102681               14             42           10            13
# 102682               19             31           13            10
# 102685               20             52           12            19
# 102686               14             43           18             7
#
#         AST_3PM_opp  UAST_3PM_opp
# 1                 6             0
# 2                 0             2
# 5                 2             0
# 6                 3             0
# 9                 4             0
# ...             ...           ...
# 102678           11             0
# 102681            9             4
# 102682           13             0
# 102685            9             1
# 102686            7             3
#
# [51344 rows x 91 columns]

# %%
from src.data.make_team_dataset import get_team_and_opp_avg
avg_data = get_team_and_opp_avg(matchups)
# Out:
# Progress: 100%|████████████████████████████████████████████████████████████████████████| 20/20 [00:16<00:00,  1.24it/s]

# %%
avg_data
# Out:
#       SEASON_YEAR_team  SEASON_ID_team  TEAM_ID_team TEAM_ABBREVIATION_team  \
# 0              2000-01           22000    1610612745                    HOU
# 1              2000-01           22000    1610612745                    HOU
# 2              2000-01           22000    1610612745                    HOU
# 3              2000-01           22000    1610612745                    HOU
# 4              2000-01           22000    1610612745                    HOU
# ...                ...             ...           ...                    ...
# 51339          2019-20           22019    1610612740                    NOP
# 51340          2019-20           22019    1610612740                    NOP
# 51341          2019-20           22019    1610612740                    NOP
# 51342          2019-20           22019    1610612740                    NOP
# 51343          2019-20           22019    1610612740                    NOP
#
#              TEAM_NAME_team   GAME_ID GAME_DATE_team MATCHUP_team  \
# 0           Houston Rockets  20000008     2000-10-31  HOU vs. MIN
# 1           Houston Rockets  20000023     2000-11-02  HOU vs. MIL
# 2           Houston Rockets  20000044     2000-11-04    HOU @ LAC
# 3           Houston Rockets  20000048     2000-11-05    HOU @ PHX
# 4           Houston Rockets  20000058     2000-11-07  HOU vs. LAL
# ...                     ...       ...            ...          ...
# 51339  New Orleans Pelicans  21901268     2020-08-06    NOP @ SAC
# 51340  New Orleans Pelicans  21901278     2020-08-07  NOP vs. WAS
# 51341  New Orleans Pelicans  21901287     2020-08-09  NOP vs. SAS
# 51342  New Orleans Pelicans  21901302     2020-08-11    NOP @ SAC
# 51343  New Orleans Pelicans  21901312     2020-08-13    NOP @ ORL
#
#        HOME_GAME_team  TEAM_SCORE_team  point_diff_team  WL_team  MIN_team  \
# 0                   1               98               -8        0       NaN
# 1                   1              115               22        1       NaN
# 2                   0               74               -3        0       NaN
# 3                   0               99               -5        0       NaN
# 4                   1               84               10        1       NaN
# ...               ...              ...              ...      ...       ...
# 51339               0              125              -15        0     242.5
# 51340               1              118               11        1     242.5
# 51341               1              113               -9        0     242.5
# 51342               0              106               -6        0     242.5
# 51343               0              127               -6        0     242.5
#
#        RECORD_team  FG2M_team  FG2A_team  FG3M_team  FG3A_team  FTM_team  \
# 0              NaN        NaN        NaN        NaN        NaN       NaN
# 1              NaN        NaN        NaN        NaN        NaN       NaN
# 2              NaN        NaN        NaN        NaN        NaN       NaN
# 3              NaN        NaN        NaN        NaN        NaN       NaN
# 4              NaN        NaN        NaN        NaN        NaN       NaN
# ...            ...        ...        ...        ...        ...       ...
# 51339          0.4       31.5       59.5       11.1       33.0      17.9
# 51340          0.4       31.7       58.4       11.7       33.7      17.3
# 51341          0.4       30.8       57.2       12.0       34.9      18.4
# 51342          0.4       30.5       57.5       12.5       34.7      17.4
# 51343          0.4       30.2       57.2       11.8       33.2      17.3
#
#        FTA_team  OREB_team  DREB_team  REB_team  AST_team  STL_team  BLK_team  \
# 0           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# ...         ...        ...        ...       ...       ...       ...       ...
# 51339      26.0       11.8       37.3      49.1      28.3       8.7       3.4
# 51340      25.3       11.7       35.9      47.6      28.3       8.1       3.5
# 51341      26.4       11.6       35.6      47.2      27.2       7.6       3.5
# 51342      25.3       11.7       35.1      46.8      27.8       7.4       3.7
# 51343      24.5       10.9       34.9      45.8      26.6       6.9       4.1
#
#        TOV_team  PF_team  PTS_team  PLUS_MINUS_team  E_OFF_RATING_team  \
# 0           NaN      NaN       NaN              NaN                NaN
# 1           NaN      NaN       NaN              NaN                NaN
# 2           NaN      NaN       NaN              NaN                NaN
# 3           NaN      NaN       NaN              NaN                NaN
# 4           NaN      NaN       NaN              NaN                NaN
# ...         ...      ...       ...              ...                ...
# 51339      17.8     20.9     114.2             -1.0             103.95
# 51340      17.5     21.1     115.8             -1.6             106.33
# 51341      17.8     21.3     116.0             -1.7             105.56
# 51342      18.2     22.8     115.9             -1.8             105.55
# 51343      18.6     22.8     113.1             -1.9             103.94
#
#        OFF_RATING_team  E_DEF_RATING_team  DEF_RATING_team  E_NET_RATING_team  \
# 0                  NaN                NaN              NaN                NaN
# 1                  NaN                NaN              NaN                NaN
# 2                  NaN                NaN              NaN                NaN
# 3                  NaN                NaN              NaN                NaN
# 4                  NaN                NaN              NaN                NaN
# ...                ...                ...              ...                ...
# 51339           107.11             105.67           107.63              -1.74
# 51340           109.58             108.91           110.73              -2.60
# 51341           109.44             109.02           110.61              -3.47
# 51342           109.35             109.38           110.29              -3.84
# 51343           107.56             107.93           108.75              -3.99
#
#        NET_RATING_team  POSS_team  PIE_team  PTS_2PT_MR_team  PTS_FB_team  \
# 0                  NaN        NaN       NaN              NaN          NaN
# 1                  NaN        NaN       NaN              NaN          NaN
# 2                  NaN        NaN       NaN              NaN          NaN
# 3                  NaN        NaN       NaN              NaN          NaN
# 4                  NaN        NaN       NaN              NaN          NaN
# ...                ...        ...       ...              ...          ...
# 51339            -0.51      106.6    0.5058              7.8         17.2
# 51340            -1.14      105.7    0.5030              8.5         14.6
# 51341            -1.16      106.0    0.4990              8.7         14.2
# 51342            -0.93      106.0    0.4936              9.0         12.9
# 51343            -1.18      105.2    0.4937              8.9         11.2
#
#        PTS_OFF_TOV_team  PTS_PAINT_team  AST_2PM_team  UAST_2PM_team  \
# 0                   NaN             NaN           NaN            NaN
# 1                   NaN             NaN           NaN            NaN
# 2                   NaN             NaN           NaN            NaN
# 3                   NaN             NaN           NaN            NaN
# 4                   NaN             NaN           NaN            NaN
# ...                 ...             ...           ...            ...
# 51339              15.6            54.5          17.8           12.8
# 51340              14.7            54.4          17.2           13.6
# 51341              15.7            52.4          16.0           13.9
# 51342              16.7            51.5          16.3           13.3
# 51343              16.9            51.0          15.6           13.7
#
#        AST_3PM_team  UAST_3PM_team  TEAM_SCORE_opp  MIN_opp  RECORD_opp  \
# 0               NaN            NaN             NaN      NaN         NaN
# 1               NaN            NaN             NaN      NaN         NaN
# 2               NaN            NaN             NaN      NaN         NaN
# 3               NaN            NaN             NaN      NaN         NaN
# 4               NaN            NaN             NaN      NaN         NaN
# ...             ...            ...             ...      ...         ...
# 51339           9.5            0.9           115.2    242.5         0.6
# 51340          10.1            0.8           117.4    242.5         0.6
# 51341          10.3            0.8           117.7    242.5         0.6
# 51342          10.7            0.9           117.7    242.5         0.6
# 51343          10.1            0.9           115.0    242.5         0.6
#
#        FG2M_opp  FG2A_opp  FG3M_opp  FG3A_opp  FTM_opp  FTA_opp  OREB_opp  \
# 0           NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 1           NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 2           NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 3           NaN       NaN       NaN       NaN      NaN      NaN       NaN
# 4           NaN       NaN       NaN       NaN      NaN      NaN       NaN
# ...         ...       ...       ...       ...      ...      ...       ...
# 51339      28.6      54.6      13.5      38.4     17.5     22.7       9.3
# 51340      28.8      54.8      13.8      37.3     18.4     23.9       9.2
# 51341      28.4      54.7      13.7      36.9     19.8     25.0       9.2
# 51342      27.6      54.6      13.5      36.2     22.0     27.2      10.1
# 51343      26.8      54.5      13.2      35.4     21.8     26.8      10.5
#
#        DREB_opp  REB_opp  AST_opp  STL_opp  BLK_opp  TOV_opp  PF_opp  PTS_opp  \
# 0           NaN      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 1           NaN      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 2           NaN      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 3           NaN      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# 4           NaN      NaN      NaN      NaN      NaN      NaN     NaN      NaN
# ...         ...      ...      ...      ...      ...      ...     ...      ...
# 51339      34.0     43.3     25.0      9.3      6.9     15.3    22.7    115.2
# 51340      32.9     42.1     24.9      9.4      6.0     14.5    22.7    117.4
# 51341      33.5     42.7     24.4      9.6      6.2     14.7    24.1    117.7
# 51342      34.1     44.2     24.3      9.9      5.8     15.1    24.2    117.7
# 51343      34.0     44.5     23.9      9.2      6.2     15.6    24.2    115.0
#
#        PLUS_MINUS_opp  E_OFF_RATING_opp  OFF_RATING_opp  E_DEF_RATING_opp  \
# 0                 NaN               NaN             NaN               NaN
# 1                 NaN               NaN             NaN               NaN
# 2                 NaN               NaN             NaN               NaN
# 3                 NaN               NaN             NaN               NaN
# 4                 NaN               NaN             NaN               NaN
# ...               ...               ...             ...               ...
# 51339             1.0            105.67          107.63            103.95
# 51340             1.6            108.91          110.73            106.33
# 51341             1.7            109.02          110.61            105.56
# 51342             1.8            109.38          110.29            105.55
# 51343             1.9            107.93          108.75            103.94
#
#        DEF_RATING_opp  E_NET_RATING_opp  NET_RATING_opp  POSS_opp  PIE_opp  \
# 0                 NaN               NaN             NaN       NaN      NaN
# 1                 NaN               NaN             NaN       NaN      NaN
# 2                 NaN               NaN             NaN       NaN      NaN
# 3                 NaN               NaN             NaN       NaN      NaN
# 4                 NaN               NaN             NaN       NaN      NaN
# ...               ...               ...             ...       ...      ...
# 51339          107.11              1.74            0.51     107.0   0.4942
# 51340          109.58              2.60            1.14     106.1   0.4970
# 51341          109.44              3.47            1.16     106.5   0.5010
# 51342          109.35              3.84            0.93     106.8   0.5064
# 51343          107.56              3.99            1.18     105.9   0.5063
#
#        PTS_2PT_MR_opp  PTS_FB_opp  PTS_OFF_TOV_opp  PTS_PAINT_opp  \
# 0                 NaN         NaN              NaN            NaN
# 1                 NaN         NaN              NaN            NaN
# 2                 NaN         NaN              NaN            NaN
# 3                 NaN         NaN              NaN            NaN
# 4                 NaN         NaN              NaN            NaN
# ...               ...         ...              ...            ...
# 51339             6.1        17.0             21.0           50.7
# 51340             6.2        13.9             20.8           50.8
# 51341             7.0        14.8             20.6           49.3
# 51342             7.7        13.2             22.2           46.8
# 51343             7.8        12.0             21.6           44.9
#
#        AST_2PM_opp  UAST_2PM_opp  AST_3PM_opp  UAST_3PM_opp
# 0              NaN           NaN          NaN           NaN
# 1              NaN           NaN          NaN           NaN
# 2              NaN           NaN          NaN           NaN
# 3              NaN           NaN          NaN           NaN
# 4              NaN           NaN          NaN           NaN
# ...            ...           ...          ...           ...
# 51339         14.4          13.5          9.8           3.1
# 51340         14.0          14.1         10.3           3.0
# 51341         13.4          14.2         10.4           2.9
# 51342         13.4          13.4         10.4           2.7
# 51343         12.9          13.0         10.4           2.4
#
# [51344 rows x 81 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We will calculate OREB_PCT, DREB_PCT, TS_PCT,
# <br>EFG_PCT, AST_RATIO, TOV_PCT for both team and opp
# <br>which we removed earlier, from the averaged raw numbers.

# %%
from src.features.build_team_features import add_rest_days
from src.features.build_team_features import add_percentage_features

# %%
avg_data_2 = add_percentage_features(avg_data)

# %%
avg_data_3 = add_rest_days(avg_data_2)
avg_data_3
# Out:
# ..\src\features\build_team_features.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df['rest'] = (team_df['GAME_DATE_team'] - team_df['GAME_DATE_team'].shift(1)) / np.timedelta64(1, 'D')
#       SEASON_YEAR_team  SEASON_ID_team  TEAM_ID_team TEAM_ABBREVIATION_team  \
# 0              2000-01           22000    1610612745                    HOU
# 1              2000-01           22000    1610612745                    HOU
# 2              2000-01           22000    1610612745                    HOU
# 3              2000-01           22000    1610612745                    HOU
# 4              2000-01           22000    1610612745                    HOU
# ...                ...             ...           ...                    ...
# 51339          2019-20           22019    1610612740                    NOP
# 51340          2019-20           22019    1610612740                    NOP
# 51341          2019-20           22019    1610612740                    NOP
# 51342          2019-20           22019    1610612740                    NOP
# 51343          2019-20           22019    1610612740                    NOP
#
#              TEAM_NAME_team   GAME_ID GAME_DATE_team MATCHUP_team  \
# 0           Houston Rockets  20000008     2000-10-31  HOU vs. MIN
# 1           Houston Rockets  20000023     2000-11-02  HOU vs. MIL
# 2           Houston Rockets  20000044     2000-11-04    HOU @ LAC
# 3           Houston Rockets  20000048     2000-11-05    HOU @ PHX
# 4           Houston Rockets  20000058     2000-11-07  HOU vs. LAL
# ...                     ...       ...            ...          ...
# 51339  New Orleans Pelicans  21901268     2020-08-06    NOP @ SAC
# 51340  New Orleans Pelicans  21901278     2020-08-07  NOP vs. WAS
# 51341  New Orleans Pelicans  21901287     2020-08-09  NOP vs. SAS
# 51342  New Orleans Pelicans  21901302     2020-08-11    NOP @ SAC
# 51343  New Orleans Pelicans  21901312     2020-08-13    NOP @ ORL
#
#        HOME_GAME_team  TEAM_SCORE_team  point_diff_team  WL_team  MIN_team  \
# 0                   1               98               -8        0       NaN
# 1                   1              115               22        1       NaN
# 2                   0               74               -3        0       NaN
# 3                   0               99               -5        0       NaN
# 4                   1               84               10        1       NaN
# ...               ...              ...              ...      ...       ...
# 51339               0              125              -15        0     242.5
# 51340               1              118               11        1     242.5
# 51341               1              113               -9        0     242.5
# 51342               0              106               -6        0     242.5
# 51343               0              127               -6        0     242.5
#
#        RECORD_team  FG2M_team  FG2A_team  FG3M_team  FG3A_team  FTM_team  \
# 0              NaN        NaN        NaN        NaN        NaN       NaN
# 1              NaN        NaN        NaN        NaN        NaN       NaN
# 2              NaN        NaN        NaN        NaN        NaN       NaN
# 3              NaN        NaN        NaN        NaN        NaN       NaN
# 4              NaN        NaN        NaN        NaN        NaN       NaN
# ...            ...        ...        ...        ...        ...       ...
# 51339          0.4       31.5       59.5       11.1       33.0      17.9
# 51340          0.4       31.7       58.4       11.7       33.7      17.3
# 51341          0.4       30.8       57.2       12.0       34.9      18.4
# 51342          0.4       30.5       57.5       12.5       34.7      17.4
# 51343          0.4       30.2       57.2       11.8       33.2      17.3
#
#        FTA_team  OREB_team  DREB_team  REB_team  AST_team  STL_team  BLK_team  \
# 0           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 1           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 2           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 3           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# 4           NaN        NaN        NaN       NaN       NaN       NaN       NaN
# ...         ...        ...        ...       ...       ...       ...       ...
# 51339      26.0       11.8       37.3      49.1      28.3       8.7       3.4
# 51340      25.3       11.7       35.9      47.6      28.3       8.1       3.5
# 51341      26.4       11.6       35.6      47.2      27.2       7.6       3.5
# 51342      25.3       11.7       35.1      46.8      27.8       7.4       3.7
# 51343      24.5       10.9       34.9      45.8      26.6       6.9       4.1
#
#        TOV_team  PF_team  PTS_team  PLUS_MINUS_team  E_OFF_RATING_team  \
# 0           NaN      NaN       NaN              NaN                NaN
# 1           NaN      NaN       NaN              NaN                NaN
# 2           NaN      NaN       NaN              NaN                NaN
# 3           NaN      NaN       NaN              NaN                NaN
# 4           NaN      NaN       NaN              NaN                NaN
# ...         ...      ...       ...              ...                ...
# 51339      17.8     20.9     114.2             -1.0             103.95
# 51340      17.5     21.1     115.8             -1.6             106.33
# 51341      17.8     21.3     116.0             -1.7             105.56
# 51342      18.2     22.8     115.9             -1.8             105.55
# 51343      18.6     22.8     113.1             -1.9             103.94
#
#        OFF_RATING_team  E_DEF_RATING_team  DEF_RATING_team  E_NET_RATING_team  \
# 0                  NaN                NaN              NaN                NaN
# 1                  NaN                NaN              NaN                NaN
# 2                  NaN                NaN              NaN                NaN
# 3                  NaN                NaN              NaN                NaN
# 4                  NaN                NaN              NaN                NaN
# ...                ...                ...              ...                ...
# 51339           107.11             105.67           107.63              -1.74
# 51340           109.58             108.91           110.73              -2.60
# 51341           109.44             109.02           110.61              -3.47
# 51342           109.35             109.38           110.29              -3.84
# 51343           107.56             107.93           108.75              -3.99
#
#        NET_RATING_team  POSS_team  PIE_team  PTS_2PT_MR_team  PTS_FB_team  \
# 0                  NaN        NaN       NaN              NaN          NaN
# 1                  NaN        NaN       NaN              NaN          NaN
# 2                  NaN        NaN       NaN              NaN          NaN
# 3                  NaN        NaN       NaN              NaN          NaN
# 4                  NaN        NaN       NaN              NaN          NaN
# ...                ...        ...       ...              ...          ...
# 51339            -0.51      106.6    0.5058              7.8         17.2
# 51340            -1.14      105.7    0.5030              8.5         14.6
# 51341            -1.16      106.0    0.4990              8.7         14.2
# 51342            -0.93      106.0    0.4936              9.0         12.9
# 51343            -1.18      105.2    0.4937              8.9         11.2
#
#        PTS_OFF_TOV_team  PTS_PAINT_team  AST_2PM_team  UAST_2PM_team  \
# 0                   NaN             NaN           NaN            NaN
# 1                   NaN             NaN           NaN            NaN
# 2                   NaN             NaN           NaN            NaN
# 3                   NaN             NaN           NaN            NaN
# 4                   NaN             NaN           NaN            NaN
# ...                 ...             ...           ...            ...
# 51339              15.6            54.5          17.8           12.8
# 51340              14.7            54.4          17.2           13.6
# 51341              15.7            52.4          16.0           13.9
# 51342              16.7            51.5          16.3           13.3
# 51343              16.9            51.0          15.6           13.7
#
#        AST_3PM_team  UAST_3PM_team  OREB_PCT_team  DREB_PCT_team  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 51339           9.5            0.9       0.257642       0.800429
# 51340          10.1            0.8       0.262332       0.796009
# 51341          10.3            0.8       0.257206       0.794643
# 51342          10.7            0.9       0.255459       0.776549
# 51343          10.1            0.9       0.242762       0.768722
#
#        REB_PCT_team  TS_PCT_team  EFG_PCT_team  AST_RATIO_team  TOV_PCT_team  \
# 0               NaN          NaN           NaN             NaN           NaN
# 1               NaN          NaN           NaN             NaN           NaN
# 2               NaN          NaN           NaN             NaN           NaN
# 3               NaN          NaN           NaN             NaN           NaN
# 4               NaN          NaN           NaN             NaN           NaN
# ...             ...          ...           ...             ...           ...
# 51339      0.531385     0.581348      0.520541       26.547842     14.621324
# 51340      0.530658     0.592837      0.534745       26.773888     14.494914
# 51341      0.525028     0.592393      0.529859       25.660377     14.648277
# 51342      0.514286     0.592742      0.534165       26.226415     14.975480
# 51343      0.507198     0.590354      0.529867       25.285171     15.528469
#
#        MIN_opp  RECORD_opp  FG2M_opp  FG2A_opp  FG3M_opp  FG3A_opp  FTM_opp  \
# 0          NaN         NaN       NaN       NaN       NaN       NaN      NaN
# 1          NaN         NaN       NaN       NaN       NaN       NaN      NaN
# 2          NaN         NaN       NaN       NaN       NaN       NaN      NaN
# 3          NaN         NaN       NaN       NaN       NaN       NaN      NaN
# 4          NaN         NaN       NaN       NaN       NaN       NaN      NaN
# ...        ...         ...       ...       ...       ...       ...      ...
# 51339    242.5         0.6      28.6      54.6      13.5      38.4     17.5
# 51340    242.5         0.6      28.8      54.8      13.8      37.3     18.4
# 51341    242.5         0.6      28.4      54.7      13.7      36.9     19.8
# 51342    242.5         0.6      27.6      54.6      13.5      36.2     22.0
# 51343    242.5         0.6      26.8      54.5      13.2      35.4     21.8
#
#        FTA_opp  OREB_opp  DREB_opp  REB_opp  AST_opp  STL_opp  BLK_opp  \
# 0          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 1          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 2          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 3          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# 4          NaN       NaN       NaN      NaN      NaN      NaN      NaN
# ...        ...       ...       ...      ...      ...      ...      ...
# 51339     22.7       9.3      34.0     43.3     25.0      9.3      6.9
# 51340     23.9       9.2      32.9     42.1     24.9      9.4      6.0
# 51341     25.0       9.2      33.5     42.7     24.4      9.6      6.2
# 51342     27.2      10.1      34.1     44.2     24.3      9.9      5.8
# 51343     26.8      10.5      34.0     44.5     23.9      9.2      6.2
#
#        TOV_opp  PF_opp  PTS_opp  PLUS_MINUS_opp  E_OFF_RATING_opp  \
# 0          NaN     NaN      NaN             NaN               NaN
# 1          NaN     NaN      NaN             NaN               NaN
# 2          NaN     NaN      NaN             NaN               NaN
# 3          NaN     NaN      NaN             NaN               NaN
# 4          NaN     NaN      NaN             NaN               NaN
# ...        ...     ...      ...             ...               ...
# 51339     15.3    22.7    115.2             1.0            105.67
# 51340     14.5    22.7    117.4             1.6            108.91
# 51341     14.7    24.1    117.7             1.7            109.02
# 51342     15.1    24.2    117.7             1.8            109.38
# 51343     15.6    24.2    115.0             1.9            107.93
#
#        OFF_RATING_opp  E_DEF_RATING_opp  DEF_RATING_opp  E_NET_RATING_opp  \
# 0                 NaN               NaN             NaN               NaN
# 1                 NaN               NaN             NaN               NaN
# 2                 NaN               NaN             NaN               NaN
# 3                 NaN               NaN             NaN               NaN
# 4                 NaN               NaN             NaN               NaN
# ...               ...               ...             ...               ...
# 51339          107.63            103.95          107.11              1.74
# 51340          110.73            106.33          109.58              2.60
# 51341          110.61            105.56          109.44              3.47
# 51342          110.29            105.55          109.35              3.84
# 51343          108.75            103.94          107.56              3.99
#
#        NET_RATING_opp  POSS_opp  PIE_opp  PTS_2PT_MR_opp  PTS_FB_opp  \
# 0                 NaN       NaN      NaN             NaN         NaN
# 1                 NaN       NaN      NaN             NaN         NaN
# 2                 NaN       NaN      NaN             NaN         NaN
# 3                 NaN       NaN      NaN             NaN         NaN
# 4                 NaN       NaN      NaN             NaN         NaN
# ...               ...       ...      ...             ...         ...
# 51339            0.51     107.0   0.4942             6.1        17.0
# 51340            1.14     106.1   0.4970             6.2        13.9
# 51341            1.16     106.5   0.5010             7.0        14.8
# 51342            0.93     106.8   0.5064             7.7        13.2
# 51343            1.18     105.9   0.5063             7.8        12.0
#
#        PTS_OFF_TOV_opp  PTS_PAINT_opp  AST_2PM_opp  UAST_2PM_opp  AST_3PM_opp  \
# 0                  NaN            NaN          NaN           NaN          NaN
# 1                  NaN            NaN          NaN           NaN          NaN
# 2                  NaN            NaN          NaN           NaN          NaN
# 3                  NaN            NaN          NaN           NaN          NaN
# 4                  NaN            NaN          NaN           NaN          NaN
# ...                ...            ...          ...           ...          ...
# 51339             21.0           50.7         14.4          13.5          9.8
# 51340             20.8           50.8         14.0          14.1         10.3
# 51341             20.6           49.3         13.4          14.2         10.4
# 51342             22.2           46.8         13.4          13.4         10.4
# 51343             21.6           44.9         12.9          13.0         10.4
#
#        UAST_3PM_opp  OREB_PCT_opp  DREB_PCT_opp  REB_PCT_opp  TS_PCT_opp  \
# 0               NaN           NaN           NaN          NaN         NaN
# 1               NaN           NaN           NaN          NaN         NaN
# 2               NaN           NaN           NaN          NaN         NaN
# 3               NaN           NaN           NaN          NaN         NaN
# 4               NaN           NaN           NaN          NaN         NaN
# ...             ...           ...           ...          ...         ...
# 51339           3.1      0.199571      0.742358     0.468615    0.587791
# 51340           3.0      0.203991      0.737668     0.469342    0.602929
# 51341           2.9      0.205357      0.742794     0.474972    0.606076
# 51342           2.7      0.223451      0.744541     0.485714    0.608055
# 51343           2.4      0.231278      0.757238     0.492802    0.600234
#
#        EFG_PCT_opp  AST_RATIO_opp  TOV_PCT_opp  rest
# 0              NaN            NaN          NaN   NaN
# 1              NaN            NaN          NaN   2.0
# 2              NaN            NaN          NaN   2.0
# 3              NaN            NaN          NaN   1.0
# 4              NaN            NaN          NaN   2.0
# ...            ...            ...          ...   ...
# 51339     0.525269      23.364486    12.934533   3.0
# 51340     0.537459      23.468426    12.380887   1.0
# 51341     0.534389      22.910798    12.531969   2.0
# 51342     0.526982      22.752809    12.810941   2.0
# 51343     0.518354      22.568461    13.300140   2.0
#
# [51344 rows x 95 columns]

# %%
avg_data_3 = avg_data_3.dropna()

# %%
home_teams = avg_data_3.loc[avg_data_3['HOME_GAME_team'] == 1]
away_teams = avg_data_3.loc[avg_data_3['HOME_GAME_team'] == 0]
away_teams = away_teams.drop(columns = ['GAME_DATE_team',
                                        'SEASON_YEAR_team',
                                        'SEASON_ID_team',
                                        'TEAM_ID_team',
                                        'TEAM_ABBREVIATION_team',
                                        'TEAM_NAME_team',
                                        'GAME_DATE_team',
                                        'MATCHUP_team',
                                        'HOME_GAME_team',
                                        'point_diff_team',
                                        'WL_team'])

full_df = pd.merge(home_teams, away_teams, on='GAME_ID')
full_df = full_df.dropna()

new_cols = []
for col in full_df.columns:
    if col.endswith('_x'):
        col = 'HOME_' + col[:-2]
    if col.endswith('_y'):
        col = 'AWAY_' + col[:-2]
    if col.endswith('_team'):
        col = col[:-5]
        
    new_cols.append(col)
    
full_df.columns = new_cols


columns = full_df.columns.tolist()
columns.remove('AWAY_TEAM_SCORE')
columns.insert(10, 'AWAY_TEAM_SCORE')

full_df = full_df[columns]

# %%
full_df
# Out:
#       SEASON_YEAR  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 3         2000-01      22000  1610612745               HOU
# 4         2000-01      22000  1610612745               HOU
# 5         2000-01      22000  1610612745               HOU
# 6         2000-01      22000  1610612745               HOU
# 7         2000-01      22000  1610612745               HOU
# ...           ...        ...         ...               ...
# 25667     2019-20      22019  1610612740               NOP
# 25668     2019-20      22019  1610612740               NOP
# 25669     2019-20      22019  1610612740               NOP
# 25670     2019-20      22019  1610612740               NOP
# 25671     2019-20      22019  1610612740               NOP
#
#                   TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  HOME_GAME  \
# 3           Houston Rockets  20000076 2000-11-09  HOU vs. MEM          1
# 4           Houston Rockets  20000106 2000-11-14  HOU vs. CHI          1
# 5           Houston Rockets  20000121 2000-11-16  HOU vs. CHA          1
# 6           Houston Rockets  20000139 2000-11-18  HOU vs. PHX          1
# 7           Houston Rockets  20000205 2000-11-28  HOU vs. SAC          1
# ...                     ...       ...        ...          ...        ...
# 25667  New Orleans Pelicans  21900936 2020-03-06  NOP vs. MIA          1
# 25668  New Orleans Pelicans  21901231 2020-07-30  NOP vs. UTA          1
# 25669  New Orleans Pelicans  21901253 2020-08-03  NOP vs. MEM          1
#        HOME_E_OFF_RATING  HOME_OFF_RATING  HOME_E_DEF_RATING  HOME_DEF_RATING  \
# 3             100.720000          103.160          98.420000        99.200000
# 4              99.787500          101.275         100.662500       101.637500
# 5             102.122222          103.600          99.422222       100.477778
# 6             101.890000          103.360          99.070000       100.190000
# 7             101.760000          102.140          97.890000        98.100000
# ...                  ...              ...                ...              ...
# 25667         112.660000          115.420         109.050000       111.790000
# 25668         108.390000          111.810         106.390000       109.120000
# 25669         104.880000          108.130         106.130000       108.400000
# 25670         106.330000          109.580         108.910000       110.730000
# 25671         105.560000          109.440         109.020000       110.610000
#
#        HOME_E_NET_RATING  HOME_NET_RATING   HOME_POSS  HOME_PIE  \
# 3               2.280000         3.940000   91.000000  0.511000
# 4              -0.900000        -0.375000   91.500000  0.496250
# 5               2.677778         3.111111   91.333333  0.523667
# 6               2.800000         3.160000   90.500000  0.526900
# 7               3.870000         4.060000   90.100000  0.537800
# ...                  ...              ...         ...       ...
# 25667           3.580000         3.630000  105.700000  0.526600
# 25668           1.970000         2.710000  106.300000  0.517900
# 25669          -1.280000        -0.260000  106.200000  0.502900
# 25670          -2.600000        -1.140000  105.700000  0.503000
# 25671          -3.470000        -1.160000  106.000000  0.499000
#
#        HOME_PTS_2PT_MR  HOME_PTS_FB  HOME_PTS_OFF_TOV  HOME_PTS_PAINT  \
# 3            18.000000     7.000000         18.200000       34.600000
# 4            18.250000     6.250000         17.500000       36.500000
# 5            17.666667     7.444444         17.111111       37.666667
# 6            17.800000     7.100000         16.500000       38.500000
# 7            21.300000     6.900000         15.500000       35.500000
# ...                ...          ...               ...             ...
# 25667         7.800000    21.100000         14.600000       55.900000
# 25668         7.200000    19.500000         15.500000       55.100000
# 25669         7.300000    17.700000         15.800000       55.500000
# 25670         8.500000    14.600000         14.700000       54.400000
# 25671         8.700000    14.200000         15.700000       52.400000
#
#        HOME_AST_2PM  HOME_UAST_2PM  HOME_AST_3PM  HOME_UAST_3PM  \
# 3             14.20      12.000000      4.600000       1.000000
# 4             13.75      13.250000      4.250000       0.625000
# 5             14.00      13.333333      4.444444       0.777778
# 6             14.20      13.600000      4.200000       0.700000
# 7             13.60      14.400000      4.100000       0.700000
# ...             ...            ...           ...            ...
# 25667         20.30      10.900000     11.300000       1.300000
# 25668         19.50      11.100000     10.800000       1.300000
# 25669         18.10      12.800000     10.100000       0.900000
# 25670         17.20      13.600000     10.100000       0.800000
# 25671         16.00      13.900000     10.300000       0.800000
#
#        HOME_OREB_PCT  HOME_DREB_PCT  HOME_REB_PCT  HOME_TS_PCT  HOME_EFG_PCT  \
# 3           0.290640       0.728723      0.501279     0.572696      0.469577
# 4           0.267913       0.727915      0.483444     0.573664      0.472362
# 5           0.275568       0.714715      0.489051     0.587781      0.486527
# 6           0.270130       0.707124      0.486911     0.583658      0.486523
# 7           0.270619       0.713198      0.493606     0.574374      0.483936
# ...              ...            ...           ...          ...           ...
# 25667       0.267544       0.804825      0.536184     0.614341      0.555970
# 25668       0.256579       0.800000      0.532397     0.601585      0.545601
# 5         92.333333            -2.333333              99.422222
# 6         91.100000            -2.500000              99.070000
# 7         88.500000            -3.200000              97.890000
# ...             ...                  ...                    ...
# 25667    118.300000            -3.600000             109.050000
# 25668    116.000000            -2.700000             106.390000
# 25669    115.400000             0.600000             106.130000
# 25670    117.400000             1.600000             108.910000
# 25671    117.700000             1.700000             109.020000
#
#        HOME_OFF_RATING_opp  HOME_E_DEF_RATING_opp  HOME_DEF_RATING_opp  \
# 3                99.200000             100.720000              103.160
# 4               101.637500              99.787500              101.275
# 5               100.477778             102.122222              103.600
# 6               100.190000             101.890000              103.360
# 7                98.100000             101.760000              102.140
# ...                    ...                    ...                  ...
# 25667           111.790000             112.660000              115.420
# 25668           109.120000             108.390000              111.810
# 25669           108.400000             104.880000              108.130
# 25670           110.730000             106.330000              109.580
# 25671           110.610000             105.560000              109.440
#
#        HOME_E_NET_RATING_opp  HOME_NET_RATING_opp  HOME_POSS_opp  \
# 3                  -2.280000            -3.940000      91.400000
# 4                   0.900000             0.375000      91.750000
# 5                  -2.677778            -3.111111      91.666667
# 6                  -2.800000            -3.160000      90.700000
# 7                  -3.870000            -4.060000      90.100000
# ...                      ...                  ...            ...
# 25667              -3.580000            -3.630000     105.700000
# 25668              -1.970000            -2.710000     106.300000
# 25669               1.280000             0.260000     106.400000
# 25670               2.600000             1.140000     106.100000
# 25671               3.470000             1.160000     106.500000
#
#        HOME_PIE_opp  HOME_PTS_2PT_MR_opp  HOME_PTS_FB_opp  \
# 3          0.489000            23.200000         7.800000
# 4          0.503750            22.875000        10.000000
# 5          0.476333            22.555556        10.555556
# 6          0.473100            23.100000        10.100000
# 7          0.462200            19.500000        12.800000
# ...             ...                  ...              ...
# 25667      0.473400            12.400000        18.200000
# 25668      0.482100             9.600000        19.200000
# 25669      0.497100             7.200000        17.600000
# 25670      0.497000             6.200000        13.900000
# 25671      0.501000             7.000000        14.800000
#
#        HOME_PTS_OFF_TOV_opp  HOME_PTS_PAINT_opp  HOME_AST_2PM_opp  \
# 3                 17.600000           35.200000         15.600000
# 4                 17.625000           36.750000         15.625000
# 5                 17.222222           37.888889         15.222222
# 6                 16.500000           37.900000         15.600000
# 7                 15.400000           38.300000         14.700000
# ...                     ...                 ...               ...
# 25667             19.100000           53.100000         16.400000
# 25668             19.800000           52.900000         16.200000
# 25669             21.100000           50.400000         14.800000
# 25670             20.800000           50.800000         14.000000
# 25671             20.600000           49.300000         13.400000
#
#        HOME_UAST_2PM_opp  HOME_AST_3PM_opp  HOME_UAST_3PM_opp  \
# 3              13.400000             4.400           0.200000
# 4              14.000000             4.375           0.625000
# 5              14.777778             4.000           0.666667
# 6              14.600000             3.800           0.600000
# 7              14.000000             3.300           0.700000
# ...                  ...               ...                ...
# 25667          15.800000             8.400           3.000000
# 25668          14.500000             8.900           2.800000
# 25669          13.400000             9.500           3.300000
# 25670          14.100000            10.300           3.000000
# 25671          14.200000            10.400           2.900000
#
#        HOME_OREB_PCT_opp  HOME_DREB_PCT_opp  HOME_REB_PCT_opp  \
# 3               0.271277           0.709360          0.498721
# 25669      11.900000      32.800000     44.700000     24.000000      8.100000
# 25670       8.400000      34.600000     43.000000     24.700000      8.500000
# 25671       9.300000      35.800000     45.100000     25.900000      6.200000
#
#        AWAY_BLK_opp  AWAY_TOV_opp  AWAY_PF_opp  AWAY_PTS_opp  \
# 3          8.000000     19.400000    25.200000     87.600000
# 4          6.166667     13.166667    25.000000     93.666667
# 5          4.125000     14.875000    26.250000     88.125000
# 6          5.000000     20.111111    23.555556     87.333333
# 7          4.300000     19.400000    23.200000     90.800000
# ...             ...           ...          ...           ...
# 25667      4.300000     14.800000    22.000000    113.800000
# 25668      3.300000     11.600000    19.900000    111.400000
# 25669      5.400000     15.000000    20.900000    108.900000
# 25670      5.700000     16.600000    23.500000    115.600000
# 25671      3.600000     14.300000    21.800000    120.000000
#
#        AWAY_PLUS_MINUS_opp  AWAY_E_OFF_RATING_opp  AWAY_OFF_RATING_opp  \
# 3                -8.400000              90.120000            90.340000
# 4                10.833333             100.533333           102.633333
# 5                -0.250000              95.037500            97.162500
# 6                -8.666667              89.044444            90.611111
# 7               -13.100000              89.760000            91.780000
# ...                    ...                    ...                  ...
# 25667            -3.200000             109.910000           112.480000
# 25668             1.700000             112.870000           115.150000
# 25669            -4.400000             103.860000           105.720000
# 25670             5.300000             111.620000           113.240000
# 25671             0.500000             114.010000           116.150000
#
#        AWAY_E_DEF_RATING_opp  AWAY_DEF_RATING_opp  AWAY_E_NET_RATING_opp  \
# 3                  97.460000              99.4800              -7.360000
# 4                  88.783333              90.4000              11.783333
# 5                  95.200000              96.8375              -0.162500
# 6                  97.444444             100.2000              -8.388889
# 7                 103.540000             104.1300             -13.770000
# ...                      ...                  ...                    ...
# 25667             114.090000             116.0200              -4.190000
# 25668             111.570000             112.9100               1.300000
# 25669             107.630000             109.8500              -3.780000
# 25670             106.640000             107.6400               4.950000
# 25671             114.280000             115.9000              -0.260000
#
#        AWAY_NET_RATING_opp  AWAY_POSS_opp  AWAY_PIE_opp  AWAY_PTS_2PT_MR_opp  \
# 3                -9.120000      97.000000      0.424000            15.400000
# 4                12.233333      91.333333      0.589667            23.666667
# 5                 0.337500      90.875000      0.488875            19.750000
# 6                -9.577778      96.555556      0.429000            23.222222
# 7               -12.350000      98.800000      0.391000            22.400000
# ...                    ...            ...           ...                  ...
# 25667            -3.540000     101.100000      0.471500             4.700000
# 25668             2.250000      96.700000      0.508100            10.300000
# 25669            -4.150000     102.600000      0.455200             9.900000
# 25670             5.590000     102.000000      0.544400             9.300000
# 25671             0.270000     103.400000      0.490400             9.100000
#
#        AWAY_PTS_FB_opp  AWAY_PTS_OFF_TOV_opp  AWAY_PTS_PAINT_opp  \
# 3                 10.4                16.200           44.600000
# 4                 10.5                19.000           37.166667
# 5                  9.5                17.625           34.750000
# 6                 12.0                19.000           31.000000
# 7                 10.5                13.600           40.400000
# ...                ...                   ...                 ...
# 25667             10.9                14.700           45.400000
# 25668             12.2                16.200           47.400000
# 25669             12.8                16.300           42.100000
# 25670             13.1                18.500           51.800000
# 25671             10.6                14.000           50.300000
#
#        AWAY_AST_2PM_opp  AWAY_UAST_2PM_opp  AWAY_AST_3PM_opp  \
# 3             14.800000          15.200000             2.800
# 4             19.666667          10.500000             3.000
# 5             14.125000          12.500000             3.875
# 6             15.555556          11.222222             3.000
# 7             15.300000          16.000000             2.800
# ...                 ...                ...               ...
# 25667         13.300000          11.700000            11.100
# 25668         14.100000          14.800000             8.800
# 25669         13.300000          12.100000            10.000
# 25670         15.400000          14.400000             8.000
# 25671         13.800000          15.600000            11.500
#
#        AWAY_UAST_3PM_opp  AWAY_OREB_PCT_opp  AWAY_DREB_PCT_opp  \
# 3               0.600000           0.289474           0.707763
# 4               0.333333           0.286822           0.715415
# 5               0.625000           0.240625           0.696594
# 6               0.333333           0.256684           0.703911
# 7               0.100000           0.270925           0.723112
# ...                  ...                ...                ...
# 25667           2.600000           0.180952           0.817967
# 25668           2.900000           0.239180           0.797030
# 25669           2.000000           0.243354           0.727273
# 25670           2.000000           0.213740           0.806527
# 25671           1.200000           0.219858           0.826790
#
#        AWAY_REB_PCT_opp  AWAY_TS_PCT_opp  AWAY_EFG_PCT_opp  \
# 3              0.494407         0.508947          0.444444
# 4              0.499022         0.544046          0.455021
# 5              0.469673         0.535617          0.445528
# 6              0.475410         0.528709          0.428675
# 7              0.492705         0.510606          0.437276
# ...                 ...              ...               ...
# 25667          0.500593         0.626266          0.550351
# 25668          0.506524         0.596424          0.538159
# 25669          0.475532         0.563490          0.497824
# 25670          0.523114         0.646316          0.562201
# 25671          0.526869         0.631127          0.561315
#
#        AWAY_AST_RATIO_opp  AWAY_TOV_PCT_opp  AWAY_rest
# 3               18.556701         17.553384        1.0
# 4               25.547445         12.460568        3.0
# 5               20.220083         14.507949        2.0
# 6               19.907940         18.457334        1.0
# 7               18.724696         17.088295        3.0
# ...                   ...               ...        ...
# 25667           24.925816         13.319893        2.0
# 25668           24.301965         10.614934      143.0
# 25669           23.391813         12.891028        1.0
# 25670           24.215686         14.839979        2.0
# 25671           25.048356         12.463394        2.0
#
# [24089 rows x 179 columns]

# %%
abs(full_df['point_diff']).mean()
# Out:
# 10.969488148117398

# %% [markdown]
# ## Add ELO Rating

# %%
for idx, row in full_df.iterrows():
    print(row['MATCHUP'][-3:])
    break
# Out:
# MEM

# %%
# Helper functions go generate ELO rating

def get_K(MOV, elo_diff):
    """This K multiplier """
    K_0 = 20    
    # If the home team wins
    if MOV > 0:
        multiplier = (MOV+3)**(0.8)/(7.5+0.006*(elo_diff))
    else:
        multiplier = (-MOV+3)**(0.8)/(7.5+0.006*(-elo_diff))
        
    return K_0*multiplier, K_0*multiplier

def get_S(home_score, away_score):
    """S is the 1 if the team wins, and 0 if the team loses"""
    S_home, S_away = 0, 0
    if home_score > away_score:
        S_home = 1
    else:
        S_away = 1
    return S_home, S_away


def elo_prediction(home_rating, away_rating):
    """Generate the probability of a home victory based on the teams' elo ratings"""
    E_home = 1.0/(1 + 10 ** ((away_rating - home_rating) / (400.0)))
    return E_home


def elo_update(home_score, away_score, home_rating, away_rating):
    # Add 100 to the home_rating for home court advantage
    HOME_AD = 100
    home_rating += HOME_AD
    
    
    E_home = elo_prediction(home_rating, away_rating)
    E_away = 1.0 - E_home
    
    MOV = home_score - away_score
    
    if MOV > 0:
        elo_diff = home_rating - away_rating
    else:
        elo_diff = away_rating - home_rating
        
    
    S_home, S_away = get_S(home_score, away_score)
    
    K_home, K_away = get_K(MOV, elo_diff)
        
#     print("expected_win_prob: ", E_home, E_away)
#     print("elo_diff:", elo_diff)
#     print("S_home:", S_home, "S_away:", S_away)
#     print("K_home:", K_home, "K_away:", K_away)
#     print(K_home*(S_home-E_home), K_away*(S_away-E_away))
    return K_home*(S_home-E_home), K_away*(S_away-E_away)
    



def season_reset(rating):
    new_rating = 0.75*rating + 0.25*1505
    return new_rating

# %%
def get_elo_ratings(df = full_df):
    """This function will generate elo_ratings in the elo_df
    """
    
    # Initialize the following columns

    df['home_elo_pred'] = np.nan

    df['home_rating_i'] = np.nan
    df['home_rating_n'] = np.nan

    df['away_rating_i'] = np.nan
    df['away_rating_n'] = np.nan

    elo_dic = {}
    for idx, row in tqdm(df.iterrows(), desc="progress:"):
        if (idx > 2) and (row['SEASON_YEAR'] != df.loc[idx-1, 'SEASON_YEAR']):
            for team in elo_dic:
                elo_dic[team] = season_reset(elo_dic[team])

        if row['TEAM_ABBREVIATION'] not in elo_dic:
            elo_dic[row['TEAM_ABBREVIATION']] = 1300
            df.loc[idx, 'home_rating_i'] = 1300
        else:
            df.loc[idx, 'home_rating_i'] = elo_dic[row['TEAM_ABBREVIATION']]

        away_team_abbr = row['MATCHUP'][-3:]
        if away_team_abbr not in elo_dic:
            elo_dic[away_team_abbr] = 1300
            df.loc[idx, 'away_rating_i'] = 1300
        else:
            df.loc[idx, 'away_rating_i'] = elo_dic[away_team_abbr]

        home_score = row['HOME_TEAM_SCORE']
        away_score = row['AWAY_TEAM_SCORE']
        home_rating = elo_dic[row['TEAM_ABBREVIATION']]
        away_rating = elo_dic[away_team_abbr]

        home_update, away_update = elo_update(home_score, away_score, home_rating, away_rating)

        df.loc[idx, 'home_rating_n'] = home_rating + home_update
        df.loc[idx, 'away_rating_n'] = away_rating + away_update
        df.loc[idx, 'home_elo_pred'] = elo_prediction(home_rating+100, away_rating)

        elo_dic[row['TEAM_ABBREVIATION']] = df.loc[idx, 'home_rating_n']
        elo_dic[away_team_abbr] = df.loc[idx, 'away_rating_n']

    df['elo_MOV_pred'] = round((df['home_rating_i']+100 - df['away_rating_i'])/28, 2)

    return None

get_elo_ratings(df = full_df)

# %%
full_df
# Out:
#       SEASON_YEAR  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0         2000-01      22000  1610612745               HOU
# 1         2000-01      22000  1610612745               HOU
# 2         2000-01      22000  1610612745               HOU
# 3         2000-01      22000  1610612745               HOU
# 4         2000-01      22000  1610612745               HOU
# ...           ...        ...         ...               ...
# 24091     2019-20      22019  1610612740               NOP
# 24092     2019-20      22019  1610612740               NOP
# 24093     2019-20      22019  1610612740               NOP
# 24094     2019-20      22019  1610612740               NOP
# 24095     2019-20      22019  1610612740               NOP
#
# 2         19.888889      6.666667      4.333333     16.888889    24.222222
# 3         20.000000      6.500000      4.300000     16.500000    23.000000
# 4         18.600000      6.800000      4.600000     16.300000    22.700000
# ...             ...           ...           ...           ...          ...
# 24091     26.000000      8.000000      7.200000     14.300000    20.800000
# 24092     26.100000      9.600000      7.200000     14.700000    20.300000
# 24093     25.300000      9.900000      6.600000     15.400000    21.100000
# 24094     24.900000      9.400000      6.000000     14.500000    22.700000
# 24095     24.400000      9.600000      6.200000     14.700000    24.100000
#
#        HOME_PTS_opp  HOME_PLUS_MINUS_opp  HOME_E_OFF_RATING_opp  \
# 0         90.800000            -3.200000              98.420000
# 1         93.500000             0.750000             100.662500
# 2         92.333333            -2.333333              99.422222
# 3         91.100000            -2.500000              99.070000
# 4         88.500000            -3.200000              97.890000
# ...             ...                  ...                    ...
# 24091    118.300000            -3.600000             109.050000
# 24092    116.000000            -2.700000             106.390000
# 24093    115.400000             0.600000             106.130000
# 24094    117.400000             1.600000             108.910000
# 24095    117.700000             1.700000             109.020000
#
#        HOME_OFF_RATING_opp  HOME_E_DEF_RATING_opp  HOME_DEF_RATING_opp  \
# 0                99.200000             100.720000              103.160
# 1               101.637500              99.787500              101.275
# 2               100.477778             102.122222              103.600
# 3               100.190000             101.890000              103.360
# 4                98.100000             101.760000              102.140
# ...                    ...                    ...                  ...
# 24091           111.790000             112.660000              115.420
# 24092           109.120000             108.390000              111.810
# 24093           108.400000             104.880000              108.130
# 24094           110.730000             106.330000              109.580
# 24095           110.610000             105.560000              109.440
#
#        HOME_E_NET_RATING_opp  HOME_NET_RATING_opp  HOME_POSS_opp  \
# 0                  -2.280000            -3.940000      91.400000
# 1                   0.900000             0.375000      91.750000
# 2                  -2.677778            -3.111111      91.666667
# 3                  -2.800000            -3.160000      90.700000
# 4                  -3.870000            -4.060000      90.100000
# ...                      ...                  ...            ...
# 24091              -3.580000            -3.630000     105.700000
# 24092              -1.970000            -2.710000     106.300000
# 24093               1.280000             0.260000     106.400000
# 24094               2.600000             1.140000     106.100000
# 24095               3.470000             1.160000     106.500000
#
#        HOME_PIE_opp  HOME_PTS_2PT_MR_opp  HOME_PTS_FB_opp  \
# 0          0.489000            23.200000         7.800000
# 1          0.503750            22.875000        10.000000
# 2          0.476333            22.555556        10.555556
# 3          0.473100            23.100000        10.100000
# 4          0.462200            19.500000        12.800000
# ...             ...                  ...              ...
# 24091      0.473400            12.400000        18.200000
# 24092      0.482100             9.600000        19.200000
# 24093      0.497100             7.200000        17.600000
# 24094      0.497000             6.200000        13.900000
# 24095      0.501000             7.000000        14.800000
#
#        HOME_PTS_OFF_TOV_opp  HOME_PTS_PAINT_opp  HOME_AST_2PM_opp  \
# 0                 17.600000           35.200000         15.600000
# 1                 17.625000           36.750000         15.625000
# 2                 17.222222           37.888889         15.222222
# 3                 16.500000           37.900000         15.600000
# 4                 15.400000           38.300000         14.700000
# ...                     ...                 ...               ...
# 24091             19.100000           53.100000         16.400000
# 24092             19.800000           52.900000         16.200000
# 24093             21.100000           50.400000         14.800000
# 24094             20.800000           50.800000         14.000000
# 24092             2.250000      96.700000      0.508100            10.300000
# 24093            -4.150000     102.600000      0.455200             9.900000
# 24094             5.590000     102.000000      0.544400             9.300000
# 24095             0.270000     103.400000      0.490400             9.100000
#
#        AWAY_PTS_FB_opp  AWAY_PTS_OFF_TOV_opp  AWAY_PTS_PAINT_opp  \
# 0                 10.4                16.200           44.600000
# 1                 10.5                19.000           37.166667
# 2                  9.5                17.625           34.750000
# 3                 12.0                19.000           31.000000
# 4                 10.5                13.600           40.400000
# ...                ...                   ...                 ...
# 24091             10.9                14.700           45.400000
# 24092             12.2                16.200           47.400000
# 24093             12.8                16.300           42.100000
# 24094             13.1                18.500           51.800000
# 24095             10.6                14.000           50.300000
#
#        AWAY_AST_2PM_opp  AWAY_UAST_2PM_opp  AWAY_AST_3PM_opp  \
# 0             14.800000          15.200000             2.800
# 1             19.666667          10.500000             3.000
# 2             14.125000          12.500000             3.875
# 3             15.555556          11.222222             3.000
# 4             15.300000          16.000000             2.800
# ...                 ...                ...               ...
# 24091         13.300000          11.700000            11.100
# 24092         14.100000          14.800000             8.800
# 24093         13.300000          12.100000            10.000
# 24094         15.400000          14.400000             8.000
# 24095         13.800000          15.600000            11.500
#
#        AWAY_UAST_3PM_opp  AWAY_OREB_PCT_opp  AWAY_DREB_PCT_opp  \
# 0               0.600000           0.289474           0.707763
# 1               0.333333           0.286822           0.715415
# 2               0.625000           0.240625           0.696594
# 3               0.333333           0.256684           0.703911
# 4               0.100000           0.270925           0.723112
# ...                  ...                ...                ...
# 24091           2.600000           0.180952           0.817967
# 24092           2.900000           0.239180           0.797030
# 24093           2.000000           0.243354           0.727273
# 24094           2.000000           0.213740           0.806527
# 24095           1.200000           0.219858           0.826790
#
#        AWAY_REB_PCT_opp  AWAY_TS_PCT_opp  AWAY_EFG_PCT_opp  \
# 0              0.494407         0.508947          0.444444
# 1              0.499022         0.544046          0.455021
# 2              0.469673         0.535617          0.445528
# 3              0.475410         0.528709          0.428675
# 4              0.492705         0.510606          0.437276
# ...                 ...              ...               ...
# 24091          0.500593         0.626266          0.550351
# 24092          0.506524         0.596424          0.538159
# 24093          0.475532         0.563490          0.497824
# 24094          0.523114         0.646316          0.562201
# 24095          0.526869         0.631127          0.561315
#
#        AWAY_AST_RATIO_opp  AWAY_TOV_PCT_opp  AWAY_rest  home_score  \
# 0               18.556701         17.553384        1.0         NaN
# 1               25.547445         12.460568        3.0         NaN
# 2               20.220083         14.507949        2.0         NaN
# 3               19.907940         18.457334        1.0         NaN
# 4               18.724696         17.088295        3.0         NaN
# ...                   ...               ...        ...         ...
# 24091           24.925816         13.319893        2.0       110.0
# 24092           24.301965         10.614934      143.0       104.0
# 24093           23.391813         12.891028        1.0       109.0
# 24094           24.215686         14.839979        2.0       118.0
# 24095           25.048356         12.463394        2.0       113.0
#
#        away_score  spread  total  home_elo_pred  home_rating_i  home_rating_n  \
# 0             NaN     NaN    NaN       0.640065    1300.000000    1305.607497
# 1             NaN     NaN    NaN       0.647467    1305.607497    1318.779172
# 2             NaN     NaN    NaN       0.664575    1318.779172    1322.653707
# 3             NaN     NaN    NaN       0.669528    1322.653707    1326.889398
# 4             NaN     NaN    NaN       0.674901    1326.889398    1316.580329
# ...           ...     ...    ...            ...            ...            ...
# 24091       104.0    -1.5  232.0       0.396425    1472.353686    1482.267438
# 24092       106.0    -2.5  229.0       0.460878    1482.267438    1477.714418
# 24093        99.0    -5.0  236.5       0.597433    1477.714418    1485.635138
# 24094       107.0    -8.0  236.0       0.781514    1485.635138    1489.722769
# 24095       122.0    -3.5  239.5       0.622171    1489.722769    1478.395712
#
#        away_rating_i  away_rating_n  elo_MOV_pred
# 0        1300.000000    1294.392503          3.57
# 1        1300.000000    1286.828325          3.77
# 2        1300.000000    1296.125464          4.24
# 3        1300.000000    1295.764309          4.38
# 4        1300.000000    1310.309069          4.53
# ...              ...            ...           ...
# 24091    1645.381869    1635.468118         -2.61
# 24092    1609.507937    1614.060957         -0.97
# 24093    1509.133830    1501.213110          2.45
# 24094    1364.229538    1360.141907          7.91
# 24095    1503.077130    1514.404187          3.09
#
# [24096 rows x 189 columns]

# %% [markdown]
# ## Add Betting Data

# %%
from src.data.make_betting_dataset import clean_bet_data
betting_data = pd.read_csv("../data/nba_betting_data_2010_present.csv")

bet_data_clean = clean_bet_data(betting_data)

# %%
full_df = pd.merge(full_df, bet_data_clean, how='left', left_on = ['TEAM_ABBREVIATION', 'GAME_DATE'], right_on=['home_team_abbr', 'date'])

# %%
full_df = full_df.drop(columns = ['date', 'home_team_abbr', 'away_team_abbr'])

# %%
full_df['spread'].isnull().sum()
# Out:
# 13847

# %%
full_df
# Out:
#       SEASON_YEAR  SEASON_ID     TEAM_ID TEAM_ABBREVIATION  \
# 0         2000-01      22000  1610612745               HOU
# 1         2000-01      22000  1610612745               HOU
# 2         2000-01      22000  1610612745               HOU
# 3         2000-01      22000  1610612745               HOU
# 4         2000-01      22000  1610612745               HOU
# ...           ...        ...         ...               ...
# 24091     2019-20      22019  1610612740               NOP
# 24092     2019-20      22019  1610612740               NOP
# 24093     2019-20      22019  1610612740               NOP
# 24094     2019-20      22019  1610612740               NOP
# 24095     2019-20      22019  1610612740               NOP
#
#                   TEAM_NAME   GAME_ID  GAME_DATE      MATCHUP  HOME_GAME  \
# 0           Houston Rockets  20000076 2000-11-09  HOU vs. MEM          1
# 1           Houston Rockets  20000106 2000-11-14  HOU vs. CHI          1
# 2           Houston Rockets  20000121 2000-11-16  HOU vs. CHA          1
# 3           Houston Rockets  20000139 2000-11-18  HOU vs. PHX          1
# 4           Houston Rockets  20000205 2000-11-28  HOU vs. SAC          1
# ...                     ...       ...        ...          ...        ...
# 24091  New Orleans Pelicans  21900936 2020-03-06  NOP vs. MIA          1
# 24092  New Orleans Pelicans  21901231 2020-07-30  NOP vs. UTA          1
# 24093  New Orleans Pelicans  21901253 2020-08-03  NOP vs. MEM          1
# 24094  New Orleans Pelicans  21901278 2020-08-07  NOP vs. WAS          1
# 24095  New Orleans Pelicans  21901287 2020-08-09  NOP vs. SAS          1
#
#        HOME_TEAM_SCORE  AWAY_TEAM_SCORE  point_diff  WL  HOME_MIN  \
# 24095    117.700000             1.700000             109.020000
#
#        HOME_OFF_RATING_opp  HOME_E_DEF_RATING_opp  HOME_DEF_RATING_opp  \
# 0                99.200000             100.720000              103.160
# 1               101.637500              99.787500              101.275
# 2               100.477778             102.122222              103.600
# 3               100.190000             101.890000              103.360
# 4                98.100000             101.760000              102.140
# ...                    ...                    ...                  ...
# 24091           111.790000             112.660000              115.420
# 24092           109.120000             108.390000              111.810
# 24093           108.400000             104.880000              108.130
# 24094           110.730000             106.330000              109.580
# 24095           110.610000             105.560000              109.440
#
#        HOME_E_NET_RATING_opp  HOME_NET_RATING_opp  HOME_POSS_opp  \
# 0                  -2.280000            -3.940000      91.400000
# 1                   0.900000             0.375000      91.750000
# 2                  -2.677778            -3.111111      91.666667
# 3                  -2.800000            -3.160000      90.700000
# 4                  -3.870000            -4.060000      90.100000
# ...                      ...                  ...            ...
# 24091              -3.580000            -3.630000     105.700000
# 24092              -1.970000            -2.710000     106.300000
# 24093               1.280000             0.260000     106.400000
# 24094               2.600000             1.140000     106.100000
# 24095               3.470000             1.160000     106.500000
#
#        HOME_PIE_opp  HOME_PTS_2PT_MR_opp  HOME_PTS_FB_opp  \
# 0          0.489000            23.200000         7.800000
# 1          0.503750            22.875000        10.000000
# 2          0.476333            22.555556        10.555556
# 3          0.473100            23.100000        10.100000
# 4          0.462200            19.500000        12.800000
# ...             ...                  ...              ...
# 24091      0.473400            12.400000        18.200000
# 24092      0.482100             9.600000        19.200000
# 24093      0.497100             7.200000        17.600000
# 24094      0.497000             6.200000        13.900000
# 24095      0.501000             7.000000        14.800000
#
#        HOME_PTS_OFF_TOV_opp  HOME_PTS_PAINT_opp  HOME_AST_2PM_opp  \
# 0                 17.600000           35.200000         15.600000
# 1                 17.625000           36.750000         15.625000
# 2                 17.222222           37.888889         15.222222
# 3                 16.500000           37.900000         15.600000
# 4                 15.400000           38.300000         14.700000
# ...                     ...                 ...               ...
# 24091             19.100000           53.100000         16.400000
# 24092             19.800000           52.900000         16.200000
# 24093             21.100000           50.400000         14.800000
# 24094             20.800000           50.800000         14.000000
# 24095             20.600000           49.300000         13.400000
#
#        HOME_UAST_2PM_opp  HOME_AST_3PM_opp  HOME_UAST_3PM_opp  \
# 0              13.400000             4.400           0.200000
# 1              14.000000             4.375           0.625000
# 2              14.777778             4.000           0.666667
# 3              14.600000             3.800           0.600000
# 4              14.000000             3.300           0.700000
# ...                  ...               ...                ...
# 24091          15.800000             8.400           3.000000
# 24092          14.500000             8.900           2.800000
# 24093          13.400000             9.500           3.300000
# 24094          14.100000            10.300           3.000000
# 24095          14.200000            10.400           2.900000
#
#        HOME_OREB_PCT_opp  HOME_DREB_PCT_opp  HOME_REB_PCT_opp  \
# 0               0.271277           0.709360          0.498721
# 1               0.272085           0.732087          0.516556
# 2               0.285285           0.724432          0.510949
# 3               0.292876           0.729870          0.513089
# 4               0.286802           0.729381          0.506394
# ...                  ...                ...               ...
# 24091           0.195175           0.732456          0.463816
# 24092           0.200000           0.743421          0.467603
# 24093           0.206009           0.733906          0.469957
# 0          8.000000     19.400000    25.200000     87.600000
# 1          6.166667     13.166667    25.000000     93.666667
# 2          4.125000     14.875000    26.250000     88.125000
# 3          5.000000     20.111111    23.555556     87.333333
# 4          4.300000     19.400000    23.200000     90.800000
# ...             ...           ...          ...           ...
# 24091      4.300000     14.800000    22.000000    113.800000
# 24092      3.300000     11.600000    19.900000    111.400000
# 24093      5.400000     15.000000    20.900000    108.900000
# 24094      5.700000     16.600000    23.500000    115.600000
# 24095      3.600000     14.300000    21.800000    120.000000
#
#        AWAY_PLUS_MINUS_opp  AWAY_E_OFF_RATING_opp  AWAY_OFF_RATING_opp  \
# 0                -8.400000              90.120000            90.340000
# 1                10.833333             100.533333           102.633333
# 2                -0.250000              95.037500            97.162500
# 3                -8.666667              89.044444            90.611111
# 4               -13.100000              89.760000            91.780000
# ...                    ...                    ...                  ...
# 24091            -3.200000             109.910000           112.480000
# 24092             1.700000             112.870000           115.150000
# 24093            -4.400000             103.860000           105.720000
# 24094             5.300000             111.620000           113.240000
# 24095             0.500000             114.010000           116.150000
#
#        AWAY_E_DEF_RATING_opp  AWAY_DEF_RATING_opp  AWAY_E_NET_RATING_opp  \
# 0                  97.460000              99.4800              -7.360000
# 1                  88.783333              90.4000              11.783333
# 2                  95.200000              96.8375              -0.162500
# 3                  97.444444             100.2000              -8.388889
# 4                 103.540000             104.1300             -13.770000
# ...                      ...                  ...                    ...
# 24091             114.090000             116.0200              -4.190000
# 24092             111.570000             112.9100               1.300000
# 24093             107.630000             109.8500              -3.780000
# 24094             106.640000             107.6400               4.950000
# 24095             114.280000             115.9000              -0.260000
#
#        AWAY_NET_RATING_opp  AWAY_POSS_opp  AWAY_PIE_opp  AWAY_PTS_2PT_MR_opp  \
# 0                -9.120000      97.000000      0.424000            15.400000
# 1                12.233333      91.333333      0.589667            23.666667
# 2                 0.337500      90.875000      0.488875            19.750000
# 3                -9.577778      96.555556      0.429000            23.222222
# 4               -12.350000      98.800000      0.391000            22.400000
# ...                    ...            ...           ...                  ...
# 24091            -3.540000     101.100000      0.471500             4.700000
# 24092             2.250000      96.700000      0.508100            10.300000
# 24093            -4.150000     102.600000      0.455200             9.900000
# 24094             5.590000     102.000000      0.544400             9.300000
# 24095             0.270000     103.400000      0.490400             9.100000
#
#        AWAY_PTS_FB_opp  AWAY_PTS_OFF_TOV_opp  AWAY_PTS_PAINT_opp  \
# 0                 10.4                16.200           44.600000
# 1                 10.5                19.000           37.166667
# 2                  9.5                17.625           34.750000
# 3                 12.0                19.000           31.000000
# 4                 10.5                13.600           40.400000
# ...                ...                   ...                 ...
# 24091             10.9                14.700           45.400000
# 24092             12.2                16.200           47.400000
# 24093             12.8                16.300           42.100000
# 24094             13.1                18.500           51.800000
# 24095             10.6                14.000           50.300000
#
#        AWAY_AST_2PM_opp  AWAY_UAST_2PM_opp  AWAY_AST_3PM_opp  \
# 0             14.800000          15.200000             2.800
# 1             19.666667          10.500000             3.000
# 2             14.125000          12.500000             3.875
# 3             15.555556          11.222222             3.000
# 4             15.300000          16.000000             2.800


# %% [markdown]
# ## Feature Selection

# %% [markdown]
# We have quite a lot of features. First let's see how well ELO does at predicting the spread.

# %%
features = full_df[['home_rating_i', 'away_rating_i', 'home_elo_pred', 'elo_MOV_pred']]
point_diff = full_df['point_diff']
win = full_df['WL']

cutoff = int(features.shape[0] * 0.8)
X_train = features.iloc[:cutoff, :]
X_test = features.iloc[cutoff:, :]
point_diff_train = point_diff.iloc[:cutoff]
point_diff_test = point_diff.iloc[cutoff:]
win_train = win.iloc[:cutoff]
win_test = win.iloc[cutoff:]

# %%
pipeline = Pipeline([('scaler', StandardScaler()),
                    ('linreg', LinearRegression())])

pipeline.fit(X_train, point_diff_train)
lr_preds = pipeline.predict(X_test)

mse = mean_squared_error(point_diff_test, lr_preds)
mae = mean_absolute_error(point_diff_test, lr_preds)
print("mse:", mse, "mae:", mae)
# Out:
# mse: 169.56679019296 mae: 10.157444151073072

# %%
pipeline = Pipeline([('scaler', StandardScaler()),
                    ('logreg', LogisticRegression())])

pipeline.fit(X_train, win_train)
log_r_preds = pipeline.predict(X_test)

accuracy = log_r_preds = pipeline.score(X_test, win_test)
print(accuracy)
# Out:
# 0.654149377593361

# %%
home_team_wins_baseline = (win_test == 1).mean()
print("baseline predicting home team every time:", home_team_wins_baseline)
# Out:
# baseline predicting home team every time: 0.5773858921161825

# %%
features = full_df.iloc[:, 13:-4]

features
point_diff = full_df['point_diff']
win = full_df['WL']
total = full_df['HOME_TEAM_SCORE'] + full_df['AWAY_TEAM_SCORE']

# %%
cutoff = int(features.shape[0] * 0.8)
X_train = features.iloc[:cutoff, :]
X_test = features.iloc[cutoff:, :]
point_diff_train = point_diff.iloc[:cutoff]
point_diff_test = point_diff.iloc[cutoff:]
win_train = win.iloc[:cutoff]
win_test = win.iloc[cutoff:]
total_train = total.iloc[:cutoff]
total_test = total.iloc[cutoff:]

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Linear Regression Predicting Spread

# %%
lr = LinearRegression()

lr.fit(X_train, point_diff_train)

y_preds = lr.predict(X_test)

linreg_mse = mean_squared_error(point_diff_test, y_preds)
linreg_mae = mean_absolute_error(point_diff_test, y_preds)

print("mean squared error:", linreg_mse, "mean absolute error:", linreg_mae)
# Out:
# mean squared error: 176.67169466211152 mean absolute error: 10.441528574290318

# %%
# sorted(list(zip(features.columns, lr.coef_)), key = lambda x: x[1])

# %%
betting_results = full_df[['spread', 'point_diff']].iloc[cutoff:, :]
betting_results['model_preds'] = y_preds


betting_results['bet_home'] = (betting_results['model_preds'] + betting_results['spread'] > 0).astype(int)
betting_results['home_cover'] = (betting_results['point_diff'] + betting_results['spread'] > 0).astype(int)
betting_results.loc[betting_results['spread'] + betting_results['point_diff'] == 0, 'home_cover'] = 0.5
betting_results['bet_won'] = (betting_results['bet_home'] == betting_results['home_cover']).astype(int)
betting_results.loc[betting_results['home_cover'] == 0.5, 'bet_won'] = 0.5

betting_results['bankroll_i'] = np.nan
betting_results['bankroll_n'] = np.nan
betting_results['bankroll_i'].iloc[0] = 10000
betting_results['bet_size'] = np.nan

# betting_results['bet_size'] = 
betting_results

simulate_bets(betting_results)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#        spread  point_diff  model_preds  bet_home  home_cover  bet_won  \
# 19276    -4.5           5     5.786142         1         1.0      1.0
# 19277    -6.0          23     2.563208         0         1.0      0.0
# 19278   -10.0           1     8.959846         0         0.0      1.0
# 19279   -11.5          20     5.885853         0         1.0      0.0
# 19280    -4.5          -4     5.319006         1         0.0      0.0
# ...       ...         ...          ...       ...         ...      ...
# 24091    -1.5           6     1.745681         1         1.0      1.0
# 24092    -2.5          -2   -23.505078         0         0.0      1.0
# 24093    -5.0          10     2.028545         0         1.0      0.0
# 24094    -8.0          11     4.722825         0         1.0      0.0
# 24095    -3.5          -9     1.600348         0         0.0      1.0
#
#          bankroll_i    bankroll_n    bet_size
# 19276  10000.000000  10090.909091  100.000000
# 19277  10090.909091   9990.000000  100.909091
# 19278   9990.000000  10080.818182   99.900000
# 19279  10080.818182   9980.010000  100.808182
# 19280   9980.010000   9880.209900   99.800100
# ...             ...           ...         ...
# 24091   3082.111552   3110.130748   30.821116
# 24092   3110.130748   3138.404664   31.101307
# 24093   3138.404664   3107.020617   31.384047
# 24094   3107.020617   3075.950411   31.070206
# 24095   3075.950411   3103.913596   30.759504
#
# [4820 rows x 9 columns]

# %%
def simulate_bets(df):
    for idx in df.index:
        if np.isnan(df.loc[idx, 'bankroll_i']):
            df.loc[idx, 'bankroll_i'] = df.loc[idx-1, 'bankroll_n']

        df.loc[idx, 'bet_size'] = df.loc[idx, 'bankroll_i'] * 0.01
        if df.loc[idx, 'bet_won'] == 1:
            df.loc[idx, 'bankroll_n'] = df.loc[idx, 'bankroll_i'] + (1/1.1)*df.loc[idx, 'bet_size']
        elif df.loc[idx, 'bet_won'] == 0:
            df.loc[idx, 'bankroll_n'] = df.loc[idx, 'bankroll_i'] - df.loc[idx, 'bet_size']
        else:
            df.loc[idx, 'bankroll_n'] = df.loc[idx, 'bankroll_i']
            
    plt.style.use('fivethirtyeight')

    fig, ax = plt.subplots(figsize=(12, 8))

    ax.plot(range(betting_results.shape[0]), betting_results['bankroll_i'], linewidth=1.5)            
    plt.show()
    
    return df

# %%
simulate_bets(betting_results)
# Out:
#        spread  point_diff  model_preds  bet_home  home_cover  bet_won  \
# 19276    -4.5           5     5.786142         1         1.0      1.0
# 19277    -6.0          23     2.563208         0         1.0      0.0
# 19278   -10.0           1     8.959846         0         0.0      1.0
# 19279   -11.5          20     5.885853         0         1.0      0.0
# 19280    -4.5          -4     5.319006         1         0.0      0.0
# ...       ...         ...          ...       ...         ...      ...
# 24091    -1.5           6     1.745681         1         1.0      1.0
# 24092    -2.5          -2   -23.505078         0         0.0      1.0
# 24093    -5.0          10     2.028545         0         1.0      0.0
# 24094    -8.0          11     4.722825         0         1.0      0.0
# 24095    -3.5          -9     1.600348         0         0.0      1.0
#
#          bankroll_i    bankroll_n    bet_size
# 19276  10000.000000  10090.909091  100.000000
# 19277  10090.909091   9990.000000  100.909091
# 19278   9990.000000  10080.818182   99.900000
# 19279  10080.818182   9980.010000  100.808182
# 19280   9980.010000   9880.209900   99.800100
# ...             ...           ...         ...
# 24091   3082.111552   3110.130748   30.821116
# 24092   3110.130748   3138.404664   31.101307
# 24093   3138.404664   3107.020617   31.384047
# 24094   3107.020617   3075.950411   31.070206
# 24095   3075.950411   3103.913596   30.759504
#
# [4820 rows x 9 columns]

# %%
betting_results['bet_won'].value_counts()
# Out:
# 1.0    2425
# 0.0    2300
# 0.5      95
# Name: bet_won, dtype: int64

# %%
betting_results['spread'].plot(kind='hist', bins=20, range=(-20, 20))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Linear Regression Predicting Total

# %%
lr = LinearRegression()

lr.fit(X_train, total_train)

y_preds = lr.predict(X_test)

lr_mse_total = mean_squared_error(total_test, y_preds)
lr_mae_total = mean_absolute_error(total_test, y_preds)

print("mse:", lr_mse_total, "mae:", lr_mae_total)
# Out:
# mse: 365.7964958040015 mae: 15.030883673884738

# %%
rfecv = select_features(LinearRegression(), X_train, total_train, min_features_to_select=1, cv_splits=5)
# Out:
# Optimal Number of Features: 58

# %%
X_train_select = X_train[:, rfecv.support_]
X_test_select = X_test[:, rfecv.support_]

lr = LinearRegression()
lr.fit(X_train_select, total_train)

y_preds = lr.predict(X_test_select)

lr_mse_total = mean_squared_error(total_test, y_preds)
lr_mae_total = mean_absolute_error(total_test, y_preds)

print("mse:", lr_mse_total, "mae:", lr_mae_total)
# Out:
# mse: 367.3602661965781 mae: 15.106553557788002

# %%
y_preds
# Out:
# array([212.72337146, 223.91530543, 214.0758076 , ..., 233.16270004,
#        233.09839153, 239.84808115])

# %%
betting_results = full_df[['total', 'AWAY_TEAM_SCORE', 'HOME_TEAM_SCORE']].iloc[cutoff:, :]
betting_results['actual_total'] = betting_results['AWAY_TEAM_SCORE'] + betting_results['HOME_TEAM_SCORE']
betting_results['model_preds'] = y_preds


betting_results['bet_over'] = (betting_results['model_preds'] > betting_results['total']).astype(int)
betting_results['over_correct'] = (betting_results['actual_total'] > betting_results['total']).astype(int)
betting_results.loc[betting_results['total'] == betting_results['actual_total'], 'over_correct'] = 0.5
betting_results['bet_won'] = (betting_results['bet_over'] == betting_results['over_correct']).astype(int)
betting_results.loc[betting_results['over_correct'] == 0.5, 'bet_won'] = 0.5

betting_results['bankroll_i'] = np.nan
betting_results['bankroll_n'] = np.nan
betting_results['bankroll_i'].iloc[0] = 10000
betting_results['bet_size'] = np.nan

betting_results

simulate_bets(betting_results)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#        total  AWAY_TEAM_SCORE  HOME_TEAM_SCORE  actual_total  model_preds  \
# 19276  205.0               95              100           195   212.723371
# 19277  220.0               93              116           209   223.915305
# 19278  210.0              104              105           209   214.075808
# 19279  210.5               96              116           212   218.126932
# 19280  224.5              102               98           200   223.905776
# ...      ...              ...              ...           ...          ...
# 24091  232.0              104              110           214   236.554067
# 24092  229.0              106              104           210   229.642483
# 24093  236.5               99              109           208   233.162700
# 24094  236.0              107              118           225   233.098392
# 24095  239.5              122              113           235   239.848081
#
#        bet_over  over_correct  bet_won    bankroll_i   bankroll_n    bet_size
# 19276         1           0.0      0.0  10000.000000  9900.000000  100.000000
# 19277         1           0.0      0.0   9900.000000  9801.000000   99.000000
# 19278         1           0.0      0.0   9801.000000  9702.990000   98.010000
# 19279         1           1.0      1.0   9702.990000  9791.199000   97.029900
# 19280         0           0.0      1.0   9791.199000  9880.209900   97.911990
# ...         ...           ...      ...           ...          ...         ...
# 24091         1           0.0      0.0    854.697745   846.150768    8.546977
# 24092         1           0.0      0.0    846.150768   837.689260    8.461508
# 24093         0           0.0      1.0    837.689260   845.304617    8.376893
# 24094         0           0.0      1.0    845.304617   852.989204    8.453046
# 24095         1           0.0      0.0    852.989204   844.459312    8.529892
#
# [4820 rows x 11 columns]

# %%
betting_results['bet_won'].value_counts()
# Out:
# 0.0    2389
# 1.0    2380
# 0.5      51
# Name: bet_won, dtype: int64

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
train_sizes, train_scores, valid_scores = learning_curve(LinearRegression(normalize=True), X_train, point_diff_train,
                                                        train_sizes = np.linspace(0.1, 1, 19), cv = tscv,
                                                        scoring='neg_mean_absolute_error')

mean_train_scores = train_scores.mean(axis=1)
mean_val_scores = valid_scores.mean(axis=1)

fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(train_sizes, mean_train_scores, label='train_scores')
ax.plot(train_sizes, mean_val_scores, label='validation_scores')
plt.legend()
plt.show()

# %%
def select_features(estimator, X, y, min_features_to_select, cv_splits):
    tscv = TimeSeriesSplit(n_splits = cv_splits)
    min_features_to_select = min_features_to_select

    rfecv = RFECV(estimator = LinearRegression(),
          step=2, cv = tscv,
         scoring='neg_mean_absolute_error', 
                  min_features_to_select= min_features_to_select,
         n_jobs = -1)

    rfecv.fit(X, y)

    print("Optimal Number of Features:", rfecv.n_features_)

    plt.figure()
    plt.xlabel("num_features")
    plt.ylabel("Cross validation MSE")
    plt.plot(range(min_features_to_select, len(rfecv.grid_scores_) + min_features_to_select), rfecv.grid_scores_)
    plt.show()
    
    mask = rfecv.support_
        
    return rfecv, rfecv.support_

# %%
rfecv = select_features(LinearRegression(), X_train, point_diff_train, min_features_to_select=1, cv_splits=5)
# Out:
# Optimal Number of Features: 138

# %%
selected_cols = features.iloc[:, rfecv.support_].columns

X_train_select = X_train[:, rfecv.support_]
X_test_select = X_test[:, rfecv.support_]

pd.DataFrame(X_train_select, columns=selected_cols)
# Out:
#        HOME_MIN  HOME_RECORD  HOME_FG2M  HOME_FG2A  HOME_FG3M  HOME_FG3A  \
# 0     -0.748977    -0.505279  -1.396412  -0.761323  -0.281057  -0.341124
# 1     -0.748977    -0.623864  -1.013147  -0.692433  -0.672556  -0.606310
# 2     -0.748977    -0.294462  -0.867461  -0.861923  -0.509432  -0.514579
# 3     -0.748977    -0.030940  -0.670225  -0.800688  -0.672556  -0.581292
# 4     -0.748977     0.917737  -0.589537  -0.564496  -0.721494  -0.721391
# ...         ...          ...        ...        ...        ...        ...
# 19271  0.248559     0.917737   0.540087   0.203129   1.725376   1.860423
# 19272 -0.748977     1.392076   0.862837   0.596782   1.382814   1.500170
# 19273 -0.748977     1.392076   0.903181   0.399956   1.529626   1.580226
# 19274  0.248559     0.443398   0.943525   0.124398   1.578563   1.960494
# 19275  0.248559     0.917737   1.467993   0.399956   1.040252   1.500170
# 1              -1.719945         -1.662787          -1.241350   1.063499
# 2              -0.687054         -1.002552          -0.512187   0.029086
# 3              -1.346956         -1.662787          -1.241350  -1.005328
# 4               1.120506         -1.813698          -1.824680   1.063499
# ...                  ...               ...                ...        ...
# 19271           1.017216          0.902697           1.175304   0.029086
# 19272           0.500771          2.789083           0.425308   0.029086
# 19273           0.397482          0.299054          -0.074689   0.029086
# 19274          -0.996921          1.808162           0.675307   1.063499
# 19275           0.758994          1.279974           2.425298   1.063499
#
# [19276 rows x 138 columns]

# %%
lr.fit(X_train_select, point_diff_train)

y_preds = lr.predict(X_test_select)

r2_score = lr.score(X_test_select, point_diff_test)

linreg_mse_select = mean_squared_error(point_diff_test, y_preds)
linreg_mae_select = mean_absolute_error(point_diff_test, y_preds)

print("mean squared error:", linreg_mse_select, "mean absolute error:", linreg_mae_select, "r2_score:", r2_score)
# Out:
# mean squared error: 176.67169466211152 mean absolute error: 10.441528574290318 r2_score: 0.10136011136483936

# %%
X_test
# bet_data_clean
# Out:
# array([[ 0.24855923,  0.91773698,  1.34696214, ...,  1.50634075,
#          0.92530547,  0.0290855 ],
#        [ 0.24855923,  0.91773698,  1.18558717, ...,  0.44996478,
#          0.92530547, -1.00532809],
#        [ 0.24855923,  0.91773698,  1.38730588, ...,  0.29905392,
#          0.67530678,  1.06349909],
#        ...,
#        [ 0.24855923, -0.50527897,  0.62077479, ...,  3.6190927 ,
#          2.92529498, -1.00532809],
#        [ 0.24855923, -0.50527897,  0.58043105, ...,  2.10998417,
#          2.92529498,  0.0290855 ],
#        [ 0.24855923, -0.50527897,  0.21733738, ...,  4.75092411,
#          0.92530547,  0.0290855 ]])

# %%
X_train.shape
# Out:
# (19271, 164)

# %%
ridge = RidgeCV(alphas = [0.1, 0.3, 0.5, 0.7, 1, 3, 10], cv=tscv, 
                scoring='neg_mean_squared_error')

ridge.fit(X_train, point_diff_train)

print("best_alpha: ", ridge.alpha_)
print("best_score: ", ridge.best_score_)
y_preds = ridge.predict(X_test)

ridge_mse = mean_squared_error(point_diff_test, y_preds)
ridge_mae = mean_absolute_error(point_diff_test, y_preds)

print("mean squared error:", ridge_mse, "mean absolute error:", ridge_mae)
# Out:
# best_alpha:  10.0
# best_score:  -147.48338088482112
# mean squared error: 173.7289463547496 mean absolute error: 10.371806547688983

# %%
lasso_cv = LassoCV(cv=tscv)

lasso_cv.fit(X_train, point_diff_train)

print("best_alpha: ", lasso_cv.alpha_)

lasso = Lasso(alpha = lasso_cv.alpha_)

lasso.fit(X_train, point_diff_train)

y_preds = lasso.predict(X_test)

lasso_mse = mean_squared_error(point_diff_test, y_preds)
lasso_mae = mean_absolute_error(point_diff_test, y_preds)

print("mean squared error:", lasso_mse, "mean absolute error:", lasso_mae)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.03315748774912, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 184.73371798050357, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167.49391876423033, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 462.45719806215493, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1015.2575883172103, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 535.4538364016335, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 975.4871772069018, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1391.5487317987718, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1730.908052165527, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1996.9140040177736, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2246.0199765592115, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2436.7482782110455, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2545.4178678497556, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127.45334289770108, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145.62811308400705, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222.78686075820588, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 887.4502466543345, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1250.5539820438717, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1535.54358162696, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1614.8164473189972, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1651.7776621613884, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2029.319688522839, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4692.899108660407, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 267.44367989874445, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 195.79073051642627, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 385.9423408531584, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 658.6840392383747, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1048.20937924413, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1126.9324920033105, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1519.2017093249597, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1993.9910136742983, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2758.07061939314, tolerance: 153.85233929238433
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 465.0608641812578, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 701.9193843035027, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 448.10278716590255, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1503.6841000868008, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3054.031967552146, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3955.0528127981815, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4078.771516871173, tolerance: 209.3962162969881
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 616.7811605380848, tolerance: 265.0093617932752
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 315.42338082101196, tolerance: 265.0093617932752
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 858.9114115033299, tolerance: 265.0093617932752
#   tol, rng, random, positive)
# best_alpha:  0.060299990012402174
# mean squared error: 173.1295015658412 mean absolute error: 10.366415142142827

# %%
en = ElasticNetCV(l1_ratio = [.1, .5, .7, .9, .95, .99, 1], max_iter=10000, cv=tscv)
en.fit(X_train, point_diff_train)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54.781081585912034, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 55.86134070303524, tolerance: 52.38037434701493
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 118.73763998353388, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145.57672156696208, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:527: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 150.38118944573216, tolerance: 99.96807456044813
#   tol, rng, random, positive)
# ElasticNetCV(cv=TimeSeriesSplit(max_train_size=None, n_splits=5),
#              l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1], max_iter=10000)

# %%
en.alpha_
# Out:
# 0.32180291034093467

# %%
en.l1_ratio_
# Out:
# 0.1

# %%
logr = LogisticRegression(solver='liblinear')

logr.fit(X_train, win_train)

score = logr.score(X_test, win_test)

print(score)
# Out:
# 0.6360995850622406

# %%
win_pred = logr.predict(X_test)

# %%
train_sizes, train_scores, valid_scores = learning_curve(LogisticRegression(solver='liblinear'), X_train, win_train,
                                                        train_sizes = np.linspace(0.1, 1, 19), cv = tscv)

mean_train_scores = train_scores.mean(axis=1)
mean_val_scores = valid_scores.mean(axis=1)

fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(train_sizes, mean_train_scores, label='train_scores')
ax.plot(train_sizes, mean_val_scores, label='validation_scores')
plt.legend()
plt.show()

# %%
test = pd.DataFrame({'model_predictions':y_preds, 'actual_point_diff':point_diff_test, "model_win_prediction": win_pred, "actual_win_result": win_test})

test
# Out:
#        model_predictions  actual_point_diff  model_win_prediction  \
# 19271           5.351108                  7                     1
# 19272           6.533092                  9                     1
# 19273           3.439585                  5                     1
# 19274           9.226603                  5                     1
# 19275           3.850905                 12                     1
# ...                  ...                ...                   ...
# 24084           4.072028                  6                     1
# 24085           2.799928                 -2                     1
# 24086           2.218355                 10                     1
# 24087           6.796124                 11                     1
# 24088           3.359418                 -9                     1
#
#        actual_win_result
# 19271                  1
# 19272                  1
# 19273                  1
# 19274                  1
# 19275                  1
# ...                  ...
# 24084                  1
# 24085                  0
# 24086                  1
# 24087                  1
# 24088                  0
#
# [4818 rows x 4 columns]

# %%
test['predict_home_winner'] = (test['model_predictions'] > 0).astype(int)

# %%
test['predict_home_winner'] == test['model_win_prediction']
# Out:
# 19271    True
# 19272    True
# 19273    True
# 19274    True
# 19275    True
#          ...
# 24084    True
# 24085    True
# 24086    True
# 24087    True
# 24088    True
# Length: 4818, dtype: bool

# %%
test['models_match'] = (test['predict_home_winner'] == test['model_win_prediction']).astype(int)
test.loc[test['models_match'] == 0]
# Out:
#        model_predictions  actual_point_diff  model_win_prediction  \
# 19283           0.171256                 12                     0
# 19320          -0.710795                 -5                     1
# 19332           1.783913                  9                     0
# 19366           0.427932                  6                     0
# 19369          -0.884417                 31                     1
# ...                  ...                ...                   ...
# 24019          -0.321605                 19                     1
# 24042           0.095976                 -5                     0
# 24069          -1.460965                 15                     1
# 24077           1.314890                 28                     0
# 24078          -1.192539                -12                     1
#
#        actual_win_result  predict_home_winner  models_match
# 19283                  1                    1             0
# 19320                  0                    0             0
# 19332                  1                    1             0
# 19366                  1                    1             0
# 19369                  1                    0             0
# ...                  ...                  ...           ...
# 24019                  1                    0             0
# 24042                  0                    1             0
# 24069                  1                    0             0
# 24077                  1                    1             0
# 24078                  0                    0             0
#
# [241 rows x 6 columns]

# %% [markdown]
# ### Random Forest Predict Point Spread

# %%
X_train.shape, total_train.shape
# Out:
# ((19276, 166), (19276,))

# %%
from sklearn.ensemble import RandomForestRegressor
max_features = list(np.linspace(0.2, 1, 10))
max_depth = np.arange(2, 32, 4)
max_features.append('auto')
params = {'max_depth':max_depth, 
         'max_features': max_features}

gs_rf = GridSearchCV(RandomForestRegressor(), param_grid=params, scoring='neg_mean_squared_error', verbose=2, cv=tscv)

gs_rf.fit(X_train, total_train)
# Out:
# Fitting 5 folds for each of 88 candidates, totalling 440 fits
# [CV] max_depth=2, max_features=0.2 ...................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .................... max_depth=2, max_features=0.2, total=   3.9s
# [CV] max_depth=2, max_features=0.2 ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [CV] .................... max_depth=2, max_features=0.2, total=   3.6s
# [CV] max_depth=2, max_features=0.2 ...................................
# [CV] .................... max_depth=2, max_features=0.2, total=   3.6s
# [CV] max_depth=2, max_features=0.2 ...................................
# [CV] .................... max_depth=2, max_features=0.2, total=   3.7s
# [CV] max_depth=2, max_features=0.2 ...................................
# [CV] .................... max_depth=2, max_features=0.2, total=   3.7s
# [CV] max_depth=2, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=2, max_features=0.2888888888888889, total=   5.1s
# [CV] max_depth=2, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=2, max_features=0.2888888888888889, total=   5.1s
# [CV] max_depth=2, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=2, max_features=0.2888888888888889, total=   5.1s
# [CV] max_depth=2, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=2, max_features=0.2888888888888889, total=   5.1s
# [CV] max_depth=2, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=2, max_features=0.2888888888888889, total=   5.1s
# [CV] max_depth=2, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=2, max_features=0.37777777777777777, total=   6.7s
# [CV] max_depth=2, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=2, max_features=0.37777777777777777, total=   6.6s
# [CV] max_depth=2, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=2, max_features=0.37777777777777777, total=   6.6s
# [CV] max_depth=2, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=2, max_features=0.37777777777777777, total=   6.6s
# [CV] max_depth=2, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=2, max_features=0.37777777777777777, total=   6.6s
# [CV] max_depth=2, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=2, max_features=0.4666666666666667, total=   8.2s
# [CV] max_depth=2, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=2, max_features=0.4666666666666667, total=   8.1s
# [CV] max_depth=2, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=2, max_features=0.4666666666666667, total=   8.2s
# [CV] max_depth=2, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=2, max_features=0.4666666666666667, total=   8.2s
# [CV] max_depth=2, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=2, max_features=0.4666666666666667, total=   8.1s
# [CV] max_depth=2, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=2, max_features=0.5555555555555556, total=   9.7s
# [CV] max_depth=2, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=2, max_features=0.5555555555555556, total=   9.7s
# [CV] max_depth=2, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=2, max_features=0.5555555555555556, total=   9.8s
# [CV] max_depth=2, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=2, max_features=0.5555555555555556, total=   9.7s
# [CV] max_depth=2, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=2, max_features=0.5555555555555556, total=   9.6s
# [CV] max_depth=2, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=2, max_features=0.6444444444444445, total=  11.1s
# [CV] max_depth=2, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=2, max_features=0.6444444444444445, total=  11.1s
# [CV] max_depth=2, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=2, max_features=0.6444444444444445, total=  11.2s
# [CV] max_depth=2, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=2, max_features=0.6444444444444445, total=  11.1s
# [CV] max_depth=2, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=2, max_features=0.6444444444444445, total=  11.2s
# [CV] max_depth=2, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=2, max_features=0.7333333333333334, total=  12.7s
# [CV] max_depth=2, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=2, max_features=0.7333333333333334, total=  12.6s
# [CV] max_depth=2, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=2, max_features=0.7333333333333334, total=  12.6s
# [CV] max_depth=2, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=2, max_features=0.7333333333333334, total=  12.7s
# [CV] max_depth=2, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=2, max_features=0.7333333333333334, total=  12.6s
# [CV] max_depth=2, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=2, max_features=0.8222222222222222, total=  14.2s
# [CV] max_depth=2, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=2, max_features=0.8222222222222222, total=  14.6s
# [CV] max_depth=2, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=2, max_features=0.8222222222222222, total=  15.1s
# [CV] max_depth=2, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=2, max_features=0.8222222222222222, total=  15.3s
# [CV] max_depth=2, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=2, max_features=0.8222222222222222, total=  15.7s
# [CV] max_depth=2, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=2, max_features=0.9111111111111112, total=  16.5s
# [CV] max_depth=2, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=2, max_features=0.9111111111111112, total=  15.8s
# [CV] max_depth=2, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=2, max_features=0.9111111111111112, total=  16.8s
# [CV] max_depth=2, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=2, max_features=0.9111111111111112, total=  17.5s
# [CV] max_depth=2, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=2, max_features=0.9111111111111112, total=  16.8s
# [CV] max_depth=2, max_features=1.0 ...................................
# [CV] .................... max_depth=2, max_features=1.0, total=  19.9s
# [CV] max_depth=2, max_features=1.0 ...................................
# [CV] .................... max_depth=2, max_features=1.0, total=  19.0s
# [CV] max_depth=2, max_features=1.0 ...................................
# [CV] .................... max_depth=2, max_features=1.0, total=  18.8s
# [CV] max_depth=2, max_features=1.0 ...................................
# [CV] .................... max_depth=2, max_features=1.0, total=  19.1s
# [CV] max_depth=2, max_features=1.0 ...................................
# [CV] .................... max_depth=2, max_features=1.0, total=  20.2s
# [CV] max_depth=2, max_features=auto ..................................
# [CV] ................... max_depth=2, max_features=auto, total=  20.9s
# [CV] max_depth=2, max_features=auto ..................................
# [CV] ................... max_depth=2, max_features=auto, total=  18.6s
# [CV] max_depth=2, max_features=auto ..................................
# [CV] ................... max_depth=2, max_features=auto, total=  20.4s
# [CV] max_depth=2, max_features=auto ..................................
# [CV] ................... max_depth=2, max_features=auto, total=  19.5s
# [CV] max_depth=2, max_features=auto ..................................
# [CV] ................... max_depth=2, max_features=auto, total=  19.6s
# [CV] max_depth=6, max_features=0.2 ...................................
# [CV] .................... max_depth=6, max_features=0.2, total=  10.9s
# [CV] max_depth=6, max_features=0.2 ...................................
# [CV] .................... max_depth=6, max_features=0.2, total=  10.9s
# [CV] max_depth=6, max_features=0.2 ...................................
# [CV] .................... max_depth=6, max_features=0.2, total=  11.3s
# [CV] max_depth=6, max_features=0.2 ...................................
# [CV] .................... max_depth=6, max_features=0.2, total=  12.4s
# [CV] max_depth=6, max_features=0.2 ...................................
# [CV] .................... max_depth=6, max_features=0.2, total=  11.6s
# [CV] max_depth=6, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=6, max_features=0.2888888888888889, total=  15.8s
# [CV] max_depth=6, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=6, max_features=0.2888888888888889, total=  15.5s
# [CV] max_depth=6, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=6, max_features=0.2888888888888889, total=  14.9s
# [CV] max_depth=6, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=6, max_features=0.2888888888888889, total=  16.5s
# [CV] max_depth=6, max_features=0.2888888888888889 ....................
# [CV] ..... max_depth=6, max_features=0.2888888888888889, total=  16.1s
# [CV] max_depth=6, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=6, max_features=0.37777777777777777, total=  22.0s
# [CV] max_depth=6, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=6, max_features=0.37777777777777777, total=  20.2s
# [CV] max_depth=6, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=6, max_features=0.37777777777777777, total=  20.8s
# [CV] max_depth=6, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=6, max_features=0.37777777777777777, total=  21.5s
# [CV] max_depth=6, max_features=0.37777777777777777 ...................
# [CV] .... max_depth=6, max_features=0.37777777777777777, total=  23.1s
# [CV] max_depth=6, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=6, max_features=0.4666666666666667, total=  27.5s
# [CV] max_depth=6, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=6, max_features=0.4666666666666667, total=  26.9s
# [CV] max_depth=6, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=6, max_features=0.4666666666666667, total=  27.4s
# [CV] max_depth=6, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=6, max_features=0.4666666666666667, total=  27.5s
# [CV] max_depth=6, max_features=0.4666666666666667 ....................
# [CV] ..... max_depth=6, max_features=0.4666666666666667, total=  27.2s
# [CV] max_depth=6, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=6, max_features=0.5555555555555556, total=  30.6s
# [CV] max_depth=6, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=6, max_features=0.5555555555555556, total=  29.9s
# [CV] max_depth=6, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=6, max_features=0.5555555555555556, total=  31.5s
# [CV] max_depth=6, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=6, max_features=0.5555555555555556, total=  31.0s
# [CV] max_depth=6, max_features=0.5555555555555556 ....................
# [CV] ..... max_depth=6, max_features=0.5555555555555556, total=  30.8s
# [CV] max_depth=6, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=6, max_features=0.6444444444444445, total=  34.8s
# [CV] max_depth=6, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=6, max_features=0.6444444444444445, total=  32.3s
# [CV] max_depth=6, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=6, max_features=0.6444444444444445, total=  35.8s
# [CV] max_depth=6, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=6, max_features=0.6444444444444445, total=  33.0s
# [CV] max_depth=6, max_features=0.6444444444444445 ....................
# [CV] ..... max_depth=6, max_features=0.6444444444444445, total=  34.5s
# [CV] max_depth=6, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=6, max_features=0.7333333333333334, total=  39.6s
# [CV] max_depth=6, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=6, max_features=0.7333333333333334, total=  41.7s
# [CV] max_depth=6, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=6, max_features=0.7333333333333334, total=  39.1s
# [CV] max_depth=6, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=6, max_features=0.7333333333333334, total=  38.1s
# [CV] max_depth=6, max_features=0.7333333333333334 ....................
# [CV] ..... max_depth=6, max_features=0.7333333333333334, total=  37.0s
# [CV] max_depth=6, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=6, max_features=0.8222222222222222, total=  44.0s
# [CV] max_depth=6, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=6, max_features=0.8222222222222222, total=  44.3s
# [CV] max_depth=6, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=6, max_features=0.8222222222222222, total=  43.9s
# [CV] max_depth=6, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=6, max_features=0.8222222222222222, total=  49.1s
# [CV] max_depth=6, max_features=0.8222222222222222 ....................
# [CV] ..... max_depth=6, max_features=0.8222222222222222, total=  45.3s
# [CV] max_depth=6, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=6, max_features=0.9111111111111112, total=  49.3s
# [CV] max_depth=6, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=6, max_features=0.9111111111111112, total=  48.5s
# [CV] max_depth=6, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=6, max_features=0.9111111111111112, total=  48.6s
# [CV] max_depth=6, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=6, max_features=0.9111111111111112, total=  45.9s
# [CV] max_depth=6, max_features=0.9111111111111112 ....................
# [CV] ..... max_depth=6, max_features=0.9111111111111112, total=  46.7s
# [CV] max_depth=6, max_features=1.0 ...................................
# [CV] .................... max_depth=6, max_features=1.0, total=  49.6s
# [CV] max_depth=6, max_features=1.0 ...................................
# [CV] .................... max_depth=6, max_features=1.0, total=  49.7s
# [CV] max_depth=6, max_features=1.0 ...................................
# [CV] .................... max_depth=6, max_features=1.0, total=  49.5s
# [CV] max_depth=6, max_features=1.0 ...................................
# [CV] .................... max_depth=6, max_features=1.0, total=  49.7s
# [CV] max_depth=6, max_features=1.0 ...................................
# [CV] .................... max_depth=6, max_features=1.0, total=  49.7s
# [CV] max_depth=6, max_features=auto ..................................
# [CV] ................... max_depth=6, max_features=auto, total=  50.0s
# [CV] max_depth=6, max_features=auto ..................................
# [CV] ................... max_depth=6, max_features=auto, total=  50.2s
# [CV] max_depth=6, max_features=auto ..................................
# [CV] ................... max_depth=6, max_features=auto, total=  49.6s
# [CV] max_depth=6, max_features=auto ..................................
# [CV] ................... max_depth=6, max_features=auto, total=  50.1s
# [CV] max_depth=6, max_features=auto ..................................
# [CV] ................... max_depth=6, max_features=auto, total=  50.5s
# [CV] max_depth=10, max_features=0.2 ..................................
# [CV] ................... max_depth=10, max_features=0.2, total=  17.9s
# [CV] max_depth=10, max_features=0.2 ..................................
# [CV] ................... max_depth=10, max_features=0.2, total=  17.1s
# [CV] max_depth=10, max_features=0.2 ..................................
# [CV] ................... max_depth=10, max_features=0.2, total=  16.9s
# [CV] max_depth=10, max_features=0.2 ..................................
# [CV] ................... max_depth=10, max_features=0.2, total=  16.6s
# [CV] max_depth=10, max_features=0.2 ..................................
# [CV] ................... max_depth=10, max_features=0.2, total=  17.0s
# [CV] max_depth=10, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=10, max_features=0.2888888888888889, total=  23.4s
# [CV] max_depth=10, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=10, max_features=0.2888888888888889, total=  23.6s
# [CV] max_depth=10, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=10, max_features=0.2888888888888889, total=  24.9s
# [CV] max_depth=10, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=10, max_features=0.2888888888888889, total=  27.7s
# [CV] max_depth=10, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=10, max_features=0.2888888888888889, total=  24.7s
# [CV] max_depth=10, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=10, max_features=0.37777777777777777, total=  33.3s
# [CV] max_depth=10, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=10, max_features=0.37777777777777777, total=  34.5s
# [CV] max_depth=10, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=10, max_features=0.37777777777777777, total=  32.9s
# [CV] max_depth=10, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=10, max_features=0.37777777777777777, total=  31.2s
# [CV] max_depth=10, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=10, max_features=0.37777777777777777, total=  30.9s
# [CV] max_depth=10, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=10, max_features=0.4666666666666667, total=  41.0s
# [CV] max_depth=10, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=10, max_features=0.4666666666666667, total=  44.0s
# [CV] max_depth=10, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=10, max_features=0.4666666666666667, total=  41.3s
# [CV] max_depth=10, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=10, max_features=0.4666666666666667, total=  40.1s
# [CV] max_depth=10, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=10, max_features=0.4666666666666667, total=  40.5s
# [CV] max_depth=10, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=10, max_features=0.5555555555555556, total=  49.0s
# [CV] max_depth=10, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=10, max_features=0.5555555555555556, total=  47.2s
# [CV] max_depth=10, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=10, max_features=0.5555555555555556, total=  48.5s
# [CV] max_depth=10, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=10, max_features=0.5555555555555556, total=  48.1s
# [CV] max_depth=10, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=10, max_features=0.5555555555555556, total=  48.9s
# [CV] max_depth=10, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=10, max_features=0.6444444444444445, total=  55.7s
# [CV] max_depth=10, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=10, max_features=0.6444444444444445, total=  55.8s
# [CV] max_depth=10, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=10, max_features=0.6444444444444445, total=  53.2s
# [CV] max_depth=10, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=10, max_features=0.6444444444444445, total=  55.1s
# [CV] max_depth=10, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=10, max_features=0.6444444444444445, total=  51.8s
# [CV] max_depth=10, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=10, max_features=0.7333333333333334, total=  58.6s
# [CV] max_depth=10, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=10, max_features=0.7333333333333334, total=  58.7s
# [CV] max_depth=10, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=10, max_features=0.7333333333333334, total=  58.6s
# [CV] max_depth=10, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=10, max_features=0.7333333333333334, total=  58.6s
# [CV] max_depth=10, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=10, max_features=0.7333333333333334, total=  58.7s
# [CV] max_depth=10, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=10, max_features=0.8222222222222222, total= 1.1min
# [CV] max_depth=10, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=10, max_features=0.8222222222222222, total= 1.1min
# [CV] max_depth=10, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=10, max_features=0.8222222222222222, total= 1.1min
# [CV] max_depth=10, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=10, max_features=0.8222222222222222, total= 1.1min
# [CV] max_depth=10, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=10, max_features=0.8222222222222222, total= 1.1min
# [CV] max_depth=10, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=10, max_features=0.9111111111111112, total= 1.3min
# [CV] max_depth=10, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=10, max_features=0.9111111111111112, total= 1.2min
# [CV] max_depth=10, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=10, max_features=0.9111111111111112, total= 1.3min
# [CV] max_depth=10, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=10, max_features=0.9111111111111112, total= 1.3min
# [CV] max_depth=10, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=10, max_features=0.9111111111111112, total= 1.3min
# [CV] max_depth=10, max_features=1.0 ..................................
# [CV] ................... max_depth=10, max_features=1.0, total= 1.4min
# [CV] max_depth=10, max_features=1.0 ..................................
# [CV] ................... max_depth=10, max_features=1.0, total= 1.4min
# [CV] max_depth=10, max_features=1.0 ..................................
# [CV] ................... max_depth=10, max_features=1.0, total= 1.4min
# [CV] max_depth=10, max_features=1.0 ..................................
# [CV] ................... max_depth=10, max_features=1.0, total= 1.5min
# [CV] max_depth=10, max_features=1.0 ..................................
# [CV] ................... max_depth=10, max_features=1.0, total= 1.5min
# [CV] max_depth=10, max_features=auto .................................
# [CV] .................. max_depth=10, max_features=auto, total= 1.4min
# [CV] max_depth=10, max_features=auto .................................
# [CV] .................. max_depth=10, max_features=auto, total= 1.5min
# [CV] max_depth=10, max_features=auto .................................
# [CV] .................. max_depth=10, max_features=auto, total= 1.4min
# [CV] max_depth=10, max_features=auto .................................
# [CV] .................. max_depth=10, max_features=auto, total= 1.5min
# [CV] max_depth=10, max_features=auto .................................
# [CV] .................. max_depth=10, max_features=auto, total= 1.6min
# [CV] max_depth=14, max_features=0.2 ..................................
# [CV] ................... max_depth=14, max_features=0.2, total=  25.7s
# [CV] max_depth=14, max_features=0.2 ..................................
# [CV] ................... max_depth=14, max_features=0.2, total=  26.5s
# [CV] max_depth=14, max_features=0.2 ..................................
# [CV] ................... max_depth=14, max_features=0.2, total=  27.5s
# [CV] max_depth=14, max_features=0.2 ..................................
# [CV] ................... max_depth=14, max_features=0.2, total=  25.9s
# [CV] max_depth=14, max_features=0.2 ..................................
# [CV] ................... max_depth=14, max_features=0.2, total=  25.5s
# [CV] max_depth=14, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=14, max_features=0.2888888888888889, total=  35.9s
# [CV] max_depth=14, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=14, max_features=0.2888888888888889, total=  36.1s
# [CV] max_depth=14, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=14, max_features=0.2888888888888889, total=  36.0s
# [CV] max_depth=14, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=14, max_features=0.2888888888888889, total=  36.0s
# [CV] max_depth=14, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=14, max_features=0.2888888888888889, total=  35.8s
# [CV] max_depth=14, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=14, max_features=0.37777777777777777, total=  49.4s
# [CV] max_depth=14, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=14, max_features=0.37777777777777777, total=  47.4s
# [CV] max_depth=14, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=14, max_features=0.37777777777777777, total=  47.3s
# [CV] max_depth=14, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=14, max_features=0.37777777777777777, total=  47.5s
# [CV] max_depth=14, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=14, max_features=0.37777777777777777, total=  47.2s
# [CV] max_depth=14, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=14, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=14, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=14, max_features=0.4666666666666667, total= 1.1min
# [CV] max_depth=14, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=14, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=14, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=14, max_features=0.4666666666666667, total=  58.0s
# [CV] max_depth=14, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=14, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=14, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=14, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=14, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=14, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=14, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=14, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=14, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=14, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=14, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=14, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=14, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=14, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=14, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=14, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=14, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=14, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=14, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=14, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=14, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=14, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=14, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=14, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=14, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=14, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=14, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=14, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=14, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=14, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=14, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=14, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=14, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=14, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=14, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=14, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=14, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=14, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=14, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=14, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=14, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=14, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=14, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=14, max_features=0.9111111111111112, total= 1.8min
# [CV] max_depth=14, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=14, max_features=0.9111111111111112, total= 1.8min
# [CV] max_depth=14, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=14, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=14, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=14, max_features=0.9111111111111112, total= 1.8min
# [CV] max_depth=14, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=14, max_features=0.9111111111111112, total= 1.8min
# [CV] max_depth=14, max_features=1.0 ..................................
# [CV] ................... max_depth=14, max_features=1.0, total= 2.0min
# [CV] max_depth=14, max_features=1.0 ..................................
# [CV] ................... max_depth=14, max_features=1.0, total= 2.0min
# [CV] max_depth=14, max_features=1.0 ..................................
# [CV] ................... max_depth=14, max_features=1.0, total= 2.1min
# [CV] max_depth=14, max_features=1.0 ..................................
# [CV] ................... max_depth=14, max_features=1.0, total= 2.0min
# [CV] max_depth=14, max_features=1.0 ..................................
# [CV] ................... max_depth=14, max_features=1.0, total= 2.0min
# [CV] max_depth=14, max_features=auto .................................
# [CV] .................. max_depth=14, max_features=auto, total= 1.8min
# [CV] max_depth=14, max_features=auto .................................
# [CV] .................. max_depth=14, max_features=auto, total= 1.8min
# [CV] max_depth=14, max_features=auto .................................
# [CV] .................. max_depth=14, max_features=auto, total= 1.8min
# [CV] max_depth=14, max_features=auto .................................
# [CV] .................. max_depth=14, max_features=auto, total= 1.8min
# [CV] max_depth=14, max_features=auto .................................
# [CV] .................. max_depth=14, max_features=auto, total= 1.8min
# [CV] max_depth=18, max_features=0.2 ..................................
# [CV] ................... max_depth=18, max_features=0.2, total=  25.7s
# [CV] max_depth=18, max_features=0.2 ..................................
# [CV] ................... max_depth=18, max_features=0.2, total=  25.7s
# [CV] max_depth=18, max_features=0.2 ..................................
# [CV] ................... max_depth=18, max_features=0.2, total=  25.6s
# [CV] max_depth=18, max_features=0.2 ..................................
# [CV] ................... max_depth=18, max_features=0.2, total=  25.6s
# [CV] max_depth=18, max_features=0.2 ..................................
# [CV] ................... max_depth=18, max_features=0.2, total=  25.6s
# [CV] max_depth=18, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=18, max_features=0.2888888888888889, total=  36.2s
# [CV] max_depth=18, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=18, max_features=0.2888888888888889, total=  36.0s
# [CV] max_depth=18, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=18, max_features=0.2888888888888889, total=  36.0s
# [CV] max_depth=18, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=18, max_features=0.2888888888888889, total=  36.1s
# [CV] max_depth=18, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=18, max_features=0.2888888888888889, total=  36.1s
# [CV] max_depth=18, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=18, max_features=0.37777777777777777, total=  47.8s
# [CV] max_depth=18, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=18, max_features=0.37777777777777777, total=  47.2s
# [CV] max_depth=18, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=18, max_features=0.37777777777777777, total=  47.2s
# [CV] max_depth=18, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=18, max_features=0.37777777777777777, total=  47.2s
# [CV] max_depth=18, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=18, max_features=0.37777777777777777, total=  47.2s
# [CV] max_depth=18, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=18, max_features=0.4666666666666667, total=  58.4s
# [CV] max_depth=18, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=18, max_features=0.4666666666666667, total=  58.2s
# [CV] max_depth=18, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=18, max_features=0.4666666666666667, total=  58.4s
# [CV] max_depth=18, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=18, max_features=0.4666666666666667, total=  58.5s
# [CV] max_depth=18, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=18, max_features=0.4666666666666667, total=  58.3s
# [CV] max_depth=18, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=18, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=18, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=18, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=18, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=18, max_features=0.5555555555555556, total= 1.1min
# [CV] max_depth=18, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=18, max_features=0.5555555555555556, total= 1.1min
# [CV] max_depth=18, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=18, max_features=0.5555555555555556, total= 1.1min
# [CV] max_depth=18, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=18, max_features=0.6444444444444445, total= 1.3min
# [CV] max_depth=18, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=18, max_features=0.6444444444444445, total= 1.3min
# [CV] max_depth=18, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=18, max_features=0.6444444444444445, total= 1.3min
# [CV] max_depth=18, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=18, max_features=0.6444444444444445, total= 1.3min
# [CV] max_depth=18, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=18, max_features=0.6444444444444445, total= 1.3min
# [CV] max_depth=18, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=18, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=18, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=18, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=18, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=18, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=18, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=18, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=18, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=18, max_features=0.7333333333333334, total= 1.5min
# [CV] max_depth=18, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=18, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=18, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=18, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=18, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=18, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=18, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=18, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=18, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=18, max_features=0.8222222222222222, total= 1.7min
# [CV] max_depth=18, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=18, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=18, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=18, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=18, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=18, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=18, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=18, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=18, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=18, max_features=0.9111111111111112, total= 1.9min
# [CV] max_depth=18, max_features=1.0 ..................................
# [CV] ................... max_depth=18, max_features=1.0, total= 2.1min
# [CV] max_depth=18, max_features=1.0 ..................................
# [CV] ................... max_depth=18, max_features=1.0, total= 2.1min
# [CV] max_depth=18, max_features=1.0 ..................................
# [CV] ................... max_depth=18, max_features=1.0, total= 2.1min
# [CV] max_depth=18, max_features=1.0 ..................................
# [CV] ................... max_depth=18, max_features=1.0, total= 2.1min
# [CV] max_depth=18, max_features=1.0 ..................................
# [CV] ................... max_depth=18, max_features=1.0, total= 2.1min
# [CV] max_depth=18, max_features=auto .................................
# [CV] .................. max_depth=18, max_features=auto, total= 2.1min
# [CV] max_depth=18, max_features=auto .................................
# [CV] .................. max_depth=18, max_features=auto, total= 2.1min
# [CV] max_depth=18, max_features=auto .................................
# [CV] .................. max_depth=18, max_features=auto, total= 2.1min
# [CV] max_depth=18, max_features=auto .................................
# [CV] .................. max_depth=18, max_features=auto, total= 2.1min
# [CV] max_depth=18, max_features=auto .................................
# [CV] .................. max_depth=18, max_features=auto, total= 2.1min
# [CV] max_depth=22, max_features=0.2 ..................................
# [CV] ................... max_depth=22, max_features=0.2, total=  27.2s
# [CV] max_depth=22, max_features=0.2 ..................................
# [CV] ................... max_depth=22, max_features=0.2, total=  27.1s
# [CV] max_depth=22, max_features=0.2 ..................................
# [CV] ................... max_depth=22, max_features=0.2, total=  27.2s
# [CV] max_depth=22, max_features=0.2 ..................................
# [CV] ................... max_depth=22, max_features=0.2, total=  27.2s
# [CV] max_depth=22, max_features=0.2 ..................................
# [CV] ................... max_depth=22, max_features=0.2, total=  27.5s
# [CV] max_depth=22, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=22, max_features=0.2888888888888889, total=  38.5s
# [CV] max_depth=22, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=22, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=22, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=22, max_features=0.2888888888888889, total=  38.1s
# [CV] max_depth=22, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=22, max_features=0.2888888888888889, total=  38.2s
# [CV] max_depth=22, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=22, max_features=0.2888888888888889, total=  38.3s
# [CV] max_depth=22, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=22, max_features=0.37777777777777777, total=  49.9s
# [CV] max_depth=22, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=22, max_features=0.37777777777777777, total=  50.0s
# [CV] max_depth=22, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=22, max_features=0.37777777777777777, total=  49.8s
# [CV] max_depth=22, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=22, max_features=0.37777777777777777, total=  50.2s
# [CV] max_depth=22, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=22, max_features=0.37777777777777777, total=  50.0s
# [CV] max_depth=22, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=22, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=22, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=22, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=22, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=22, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=22, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=22, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=22, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=22, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=22, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=22, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=22, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=22, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=22, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=22, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=22, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=22, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=22, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=22, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=22, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=22, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=22, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=22, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=22, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=22, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=22, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=22, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=22, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=22, max_features=0.6444444444444445, total= 1.5min
# [CV] max_depth=22, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=22, max_features=0.7333333333333334, total= 1.8min
# [CV] max_depth=22, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=22, max_features=0.7333333333333334, total= 1.7min
# [CV] max_depth=22, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=22, max_features=0.7333333333333334, total= 1.7min
# [CV] max_depth=22, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=22, max_features=0.7333333333333334, total= 1.7min
# [CV] max_depth=22, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=22, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=22, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=22, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=22, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=22, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=22, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=22, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=22, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=22, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=22, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=22, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=22, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=22, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=22, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=22, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=22, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=22, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=22, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=22, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=22, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=22, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=22, max_features=1.0 ..................................
# [CV] ................... max_depth=22, max_features=1.0, total= 2.2min
# [CV] max_depth=22, max_features=1.0 ..................................
# [CV] ................... max_depth=22, max_features=1.0, total= 2.2min
# [CV] max_depth=22, max_features=1.0 ..................................
# [CV] ................... max_depth=22, max_features=1.0, total= 2.2min
# [CV] max_depth=22, max_features=1.0 ..................................
# [CV] ................... max_depth=22, max_features=1.0, total= 2.2min
# [CV] max_depth=22, max_features=1.0 ..................................
# [CV] ................... max_depth=22, max_features=1.0, total= 2.2min
# [CV] max_depth=22, max_features=auto .................................
# [CV] .................. max_depth=22, max_features=auto, total= 2.2min
# [CV] max_depth=22, max_features=auto .................................
# [CV] .................. max_depth=22, max_features=auto, total= 2.2min
# [CV] max_depth=22, max_features=auto .................................
# [CV] .................. max_depth=22, max_features=auto, total= 2.2min
# [CV] max_depth=22, max_features=auto .................................
# [CV] .................. max_depth=22, max_features=auto, total= 2.2min
# [CV] max_depth=22, max_features=auto .................................
# [CV] .................. max_depth=22, max_features=auto, total= 2.2min
# [CV] max_depth=26, max_features=0.2 ..................................
# [CV] ................... max_depth=26, max_features=0.2, total=  27.6s
# [CV] max_depth=26, max_features=0.2 ..................................
# [CV] ................... max_depth=26, max_features=0.2, total=  27.4s
# [CV] max_depth=26, max_features=0.2 ..................................
# [CV] ................... max_depth=26, max_features=0.2, total=  27.4s
# [CV] max_depth=26, max_features=0.2 ..................................
# [CV] ................... max_depth=26, max_features=0.2, total=  27.5s
# [CV] max_depth=26, max_features=0.2 ..................................
# [CV] ................... max_depth=26, max_features=0.2, total=  27.5s
# [CV] max_depth=26, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=26, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=26, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=26, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=26, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=26, max_features=0.2888888888888889, total=  38.4s
# [CV] max_depth=26, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=26, max_features=0.2888888888888889, total=  38.5s
# [CV] max_depth=26, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=26, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=26, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=26, max_features=0.37777777777777777, total=  51.3s
# [CV] max_depth=26, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=26, max_features=0.37777777777777777, total=  50.8s
# [CV] max_depth=26, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=26, max_features=0.37777777777777777, total=  50.5s
# [CV] max_depth=26, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=26, max_features=0.37777777777777777, total=  50.4s
# [CV] max_depth=26, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=26, max_features=0.37777777777777777, total=  50.7s
# [CV] max_depth=26, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=26, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=26, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=26, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=26, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=26, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=26, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=26, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=26, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=26, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=26, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=26, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=26, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=26, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=26, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=26, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=26, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=26, max_features=0.5555555555555556, total= 1.3min
# [CV] max_depth=26, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=26, max_features=0.5555555555555556, total= 1.3min
# [CV] max_depth=26, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=26, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=26, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=26, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=26, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=26, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=26, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=26, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=26, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=26, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=26, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=26, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=26, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=26, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=26, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=26, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=26, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=26, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=26, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=26, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=26, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=26, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=26, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=26, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=26, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=26, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=26, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=26, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=26, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=26, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=26, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=26, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=26, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=26, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=26, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=26, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=26, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=26, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=26, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=26, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=26, max_features=1.0 ..................................
# [CV] ................... max_depth=26, max_features=1.0, total= 2.2min
# [CV] max_depth=26, max_features=1.0 ..................................
# [CV] ................... max_depth=26, max_features=1.0, total= 2.2min
# [CV] max_depth=26, max_features=1.0 ..................................
# [CV] ................... max_depth=26, max_features=1.0, total= 2.2min
# [CV] max_depth=26, max_features=1.0 ..................................
# [CV] ................... max_depth=26, max_features=1.0, total= 2.2min
# [CV] max_depth=26, max_features=1.0 ..................................
# [CV] ................... max_depth=26, max_features=1.0, total= 2.2min
# [CV] max_depth=26, max_features=auto .................................
# [CV] .................. max_depth=26, max_features=auto, total= 2.2min
# [CV] max_depth=26, max_features=auto .................................
# [CV] .................. max_depth=26, max_features=auto, total= 2.2min
# [CV] max_depth=26, max_features=auto .................................
# [CV] .................. max_depth=26, max_features=auto, total= 2.2min
# [CV] max_depth=26, max_features=auto .................................
# [CV] .................. max_depth=26, max_features=auto, total= 2.2min
# [CV] max_depth=26, max_features=auto .................................
# [CV] .................. max_depth=26, max_features=auto, total= 2.2min
# [CV] max_depth=30, max_features=0.2 ..................................
# [CV] ................... max_depth=30, max_features=0.2, total=  27.6s
# [CV] max_depth=30, max_features=0.2 ..................................
# [CV] ................... max_depth=30, max_features=0.2, total=  27.5s
# [CV] max_depth=30, max_features=0.2 ..................................
# [CV] ................... max_depth=30, max_features=0.2, total=  27.5s
# [CV] max_depth=30, max_features=0.2 ..................................
# [CV] ................... max_depth=30, max_features=0.2, total=  27.5s
# [CV] max_depth=30, max_features=0.2 ..................................
# [CV] ................... max_depth=30, max_features=0.2, total=  27.5s
# [CV] max_depth=30, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=30, max_features=0.2888888888888889, total=  38.9s
# [CV] max_depth=30, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=30, max_features=0.2888888888888889, total=  38.8s
# [CV] max_depth=30, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=30, max_features=0.2888888888888889, total=  38.5s
# [CV] max_depth=30, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=30, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=30, max_features=0.2888888888888889 ...................
# [CV] .... max_depth=30, max_features=0.2888888888888889, total=  38.7s
# [CV] max_depth=30, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=30, max_features=0.37777777777777777, total=  50.8s
# [CV] max_depth=30, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=30, max_features=0.37777777777777777, total=  50.7s
# [CV] max_depth=30, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=30, max_features=0.37777777777777777, total=  50.5s
# [CV] max_depth=30, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=30, max_features=0.37777777777777777, total=  50.8s
# [CV] max_depth=30, max_features=0.37777777777777777 ..................
# [CV] ... max_depth=30, max_features=0.37777777777777777, total=  50.9s
# [CV] max_depth=30, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=30, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=30, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=30, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=30, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=30, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=30, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=30, max_features=0.4666666666666667, total= 1.0min
# [CV] max_depth=30, max_features=0.4666666666666667 ...................
# [CV] .... max_depth=30, max_features=0.4666666666666667, total= 1.1min
# [CV] max_depth=30, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=30, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=30, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=30, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=30, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=30, max_features=0.5555555555555556, total= 1.3min
# [CV] max_depth=30, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=30, max_features=0.5555555555555556, total= 1.2min
# [CV] max_depth=30, max_features=0.5555555555555556 ...................
# [CV] .... max_depth=30, max_features=0.5555555555555556, total= 1.3min
# [CV] max_depth=30, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=30, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=30, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=30, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=30, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=30, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=30, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=30, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=30, max_features=0.6444444444444445 ...................
# [CV] .... max_depth=30, max_features=0.6444444444444445, total= 1.4min
# [CV] max_depth=30, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=30, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=30, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=30, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=30, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=30, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=30, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=30, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=30, max_features=0.7333333333333334 ...................
# [CV] .... max_depth=30, max_features=0.7333333333333334, total= 1.6min
# [CV] max_depth=30, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=30, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=30, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=30, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=30, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=30, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=30, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=30, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=30, max_features=0.8222222222222222 ...................
# [CV] .... max_depth=30, max_features=0.8222222222222222, total= 1.8min
# [CV] max_depth=30, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=30, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=30, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=30, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=30, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=30, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=30, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=30, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=30, max_features=0.9111111111111112 ...................
# [CV] .... max_depth=30, max_features=0.9111111111111112, total= 2.0min
# [CV] max_depth=30, max_features=1.0 ..................................
# [CV] ................... max_depth=30, max_features=1.0, total= 2.2min
# [CV] max_depth=30, max_features=1.0 ..................................
# [CV] ................... max_depth=30, max_features=1.0, total= 2.2min
# [CV] max_depth=30, max_features=1.0 ..................................
# [CV] ................... max_depth=30, max_features=1.0, total= 2.2min
# [CV] max_depth=30, max_features=1.0 ..................................
# [CV] ................... max_depth=30, max_features=1.0, total= 2.2min
# [CV] max_depth=30, max_features=1.0 ..................................
# [CV] ................... max_depth=30, max_features=1.0, total= 2.2min
# [CV] max_depth=30, max_features=auto .................................
# [CV] .................. max_depth=30, max_features=auto, total= 2.2min
# [CV] max_depth=30, max_features=auto .................................
# [CV] .................. max_depth=30, max_features=auto, total= 2.2min
# [CV] max_depth=30, max_features=auto .................................
# [CV] .................. max_depth=30, max_features=auto, total= 2.2min
# [CV] max_depth=30, max_features=auto .................................
# [CV] .................. max_depth=30, max_features=auto, total= 2.2min
# [CV] max_depth=30, max_features=auto .................................
# [CV] .................. max_depth=30, max_features=auto, total= 2.2min
# [Parallel(n_jobs=1)]: Done 440 out of 440 | elapsed: 468.5min finished
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': array([ 2,  6, 10, 14, 18, 22, 26, 30]),
#                          'max_features': [0.2, 0.2888888888888889,
#                                           0.37777777777777777,
#                                           0.4666666666666667,
#                                           0.5555555555555556,
#                                           0.6444444444444445,
#                                           0.7333333333333334,
#                                           0.8222222222222222,
#                                           0.9111111111111112, 1.0, 'auto']},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
print(gs_rf.best_params_)
best_rf = gs_rf.best_estimator_
y_preds = best_rf.predict(X_test)
mae = mean_absolute_error(total_test, y_preds)
mse = mean_squared_error(total_test, y_preds)
print('mae:', mae)
# Out:
# {'max_depth': 10, 'max_features': 0.2888888888888889}
# mae: 15.519578952157952

# %%
y_preds
# Out:
# array([205.74019359, 217.54525072, 210.78817095, ..., 219.36898161,
#        219.39432272, 220.69016304])

# %%
betting_results = full_df[['total', 'AWAY_TEAM_SCORE', 'HOME_TEAM_SCORE']].iloc[cutoff:, :]
betting_results['actual_total'] = betting_results['AWAY_TEAM_SCORE'] + betting_results['HOME_TEAM_SCORE']
betting_results['model_preds'] = y_preds


betting_results['bet_over'] = (betting_results['model_preds'] > betting_results['total']).astype(int)
betting_results['over_correct'] = (betting_results['actual_total'] > betting_results['total']).astype(int)
betting_results.loc[betting_results['total'] == betting_results['actual_total'], 'over_correct'] = 0.5
betting_results['bet_won'] = (betting_results['bet_over'] == betting_results['over_correct']).astype(int)
betting_results.loc[betting_results['over_correct'] == 0.5, 'bet_won'] = 0.5

betting_results['bankroll_i'] = np.nan
betting_results['bankroll_n'] = np.nan
betting_results['bankroll_i'].iloc[0] = 10000
betting_results['bet_size'] = np.nan

betting_results

rf_total_bet_results = simulate_bets(betting_results)
# Out:
# C:\Users\Jordan Nishimura\Anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
rf_total_bet_results.head(20)
# Out:
#        total  AWAY_TEAM_SCORE  HOME_TEAM_SCORE  actual_total  model_preds  \
# 19276  205.0               95              100           195   205.740194
# 19277  220.0               93              116           209   217.545251
# 19278  210.0              104              105           209   210.788171
# 19279  210.5               96              116           212   214.291256
# 19280  224.5              102               98           200   221.852722
# 19281  220.0              130              109           239   218.110430
# 19282  217.0               96              107           203   210.880776
# 19283  205.5               79               91           170   213.033712
# 19284  207.5               97              104           201   205.120585
# 19285  204.0              109              124           233   204.114778
# 19286  210.0              114              100           214   208.425233
# 19287  206.0               88               98           186   211.123264
# 19288    NaN              103              111           214   207.731634
# 19289    NaN               95              104           199   206.572510
# 19290    NaN              104               92           196   203.761058
# 19291  210.5              105              120           225   207.139300
# 19292  206.0              115               98           213   207.999772
# 19293  201.0               90              104           194   202.618353
# 19294  210.5              116              122           238   207.946276
# 19295  201.5              113              104           217   204.006853
#
#        bet_over  over_correct  bet_won    bankroll_i    bankroll_n    bet_size
# 19276         1           0.0      0.0  10000.000000   9900.000000  100.000000
# 19277         0           0.0      1.0   9900.000000   9990.000000   99.000000
# 19278         1           0.0      0.0   9990.000000   9890.100000   99.900000
# 19279         1           1.0      1.0   9890.100000   9980.010000   98.901000
# 19280         0           0.0      1.0   9980.010000  10070.737364   99.800100
# 19281         0           1.0      0.0  10070.737364   9970.029990  100.707374
# 19282         0           0.0      1.0   9970.029990  10060.666626   99.700300
# 19283         1           0.0      0.0  10060.666626   9960.059960  100.606666
# 19284         0           0.0      1.0   9960.059960  10050.605960   99.600600
# 19285         1           1.0      1.0  10050.605960  10141.975105  100.506060
# 19286         0           1.0      0.0  10141.975105  10040.555354  101.419751
# 19287         1           0.0      0.0  10040.555354   9940.149800  100.405554
# 19288         0           0.0      1.0   9940.149800  10030.514798   99.401498
# 19289         0           0.0      1.0  10030.514798  10121.701296  100.305148
# 19290         0           0.0      1.0  10121.701296  10213.716763  101.217013
# 19291         0           1.0      0.0  10213.716763  10111.579595  102.137168
# 19292         1           1.0      1.0  10111.579595  10203.503046  101.115796
# 19293         1           0.0      0.0  10203.503046  10101.468016  102.035030
# 19294         0           1.0      0.0  10101.468016  10000.453335  101.014680
# 19295         1           1.0      1.0  10000.453335  10091.366548  100.004533

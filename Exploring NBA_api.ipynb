# %%
from nba_api.stats.static import players, teams


from nba_api.stats.endpoints import commonplayerinfo

from nba_api.stats.endpoints import boxscoresummaryv2

from nba_api.stats.endpoints import playergamelog, playerdashboardbyclutch

from nba_api.stats.endpoints import leaguedashlineups

from nba_api.stats.endpoints import leaguegamelog

from nba_api.stats.library.parameters import SeasonAll, ActivePlayers
import pandas as pd

# %%
pd.options.display.max_columns=30

# %%
all_active_players = players.get_active_players()

active_players_df = pd.DataFrame(all_active_players)
active_players_df
# Out:
#           id                 full_name first_name         last_name  is_active
# 0     203500              Steven Adams     Steven             Adams       True
# 1    1628389               Bam Adebayo        Bam           Adebayo       True
# 2     200746         LaMarcus Aldridge   LaMarcus          Aldridge       True
# 3    1629734            Kyle Alexander       Kyle         Alexander       True
# 4    1629638  Nickeil Alexander-Walker    Nickeil  Alexander-Walker       True
# ..       ...                       ...        ...               ...        ...
# 514   201152            Thaddeus Young   Thaddeus             Young       True
# 515  1629027                Trae Young       Trae             Young       True
# 516   203469               Cody Zeller       Cody            Zeller       True
# 517  1627790                Ante Zizic       Ante             Zizic       True
# 518  1627826               Ivica Zubac      Ivica             Zubac       True
#
# [519 rows x 5 columns]

# %%
all_active_teams = teams.get_teams()

pd.DataFrame(all_active_teams)
# Out:
#             id               full_name abbreviation       nickname  \
# 0   1610612737           Atlanta Hawks          ATL          Hawks
# 1   1610612738          Boston Celtics          BOS        Celtics
# 2   1610612739     Cleveland Cavaliers          CLE      Cavaliers
# 3   1610612740    New Orleans Pelicans          NOP       Pelicans
# 4   1610612741           Chicago Bulls          CHI          Bulls
# 5   1610612742        Dallas Mavericks          DAL      Mavericks
# 6   1610612743          Denver Nuggets          DEN        Nuggets
# 7   1610612744   Golden State Warriors          GSW       Warriors
# 8   1610612745         Houston Rockets          HOU        Rockets
# 9   1610612746    Los Angeles Clippers          LAC       Clippers
# 10  1610612747      Los Angeles Lakers          LAL         Lakers
# 11  1610612748              Miami Heat          MIA           Heat
# 12  1610612749         Milwaukee Bucks          MIL          Bucks
# ...

# %%
gamelogs_2020 = leaguegamelog.LeagueGameLog()

# %%
gamelogs = gamelogs_2020.get_data_frames()[0]

# %%
gamelogs
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0       22020  1610612744               GSW  Golden State Warriors
# 1       22020  1610612751               BKN          Brooklyn Nets
# 2       22020  1610612747               LAL     Los Angeles Lakers
# 3       22020  1610612746               LAC            LA Clippers
# 4       22020  1610612766               CHA      Charlotte Hornets
# ..        ...         ...               ...                    ...
# 351     22020  1610612762               UTA              Utah Jazz
# 352     22020  1610612746               LAC            LA Clippers
# 353     22020  1610612758               SAC       Sacramento Kings
# 354     22020  1610612747               LAL     Los Angeles Lakers
# 355     22020  1610612740               NOP   New Orleans Pelicans
#
#         GAME_ID   GAME_DATE      MATCHUP WL  MIN  FGM  FGA  FG_PCT  FG3M  \
# 0    0022000001  2020-12-22    GSW @ BKN  L  240   37   99   0.374    10
# ...

# %%
from nba_api.stats.endpoints import playergamelogs

gamelogs_2020 = playergamelogs.PlayerGameLogs(season_nullable='2020-21').get_data_frames()[0]

gamelogs_2020
# Out:
#      SEASON_YEAR  PLAYER_ID       PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0        2020-21     202684  Tristan Thompson  1610612738               BOS
# 1        2020-21     202695     Kawhi Leonard  1610612746               LAC
# 2        2020-21    1630211        Karim Mane  1610612753               ORL
# 3        2020-21     202696    Nikola Vucevic  1610612753               ORL
# 4        2020-21     203114   Khris Middleton  1610612749               MIL
# ...          ...        ...               ...         ...               ...
# 3868     2020-21     202954    Brad Wanamaker  1610612744               GSW
# 3869     2020-21    1629672     Eric Paschall  1610612744               GSW
# 3870     2020-21    1628386     Jarrett Allen  1610612751               BKN
# 3871     2020-21     204020     Tyler Johnson  1610612751               BKN
# 3872     2020-21       2544      LeBron James  1610612747               LAL
#
# ...

# %%
active_players_df.loc[active_players_df['last_name'] == 'Ball']
# Out:
#          id   full_name first_name last_name  is_active
# 23  1628366  Lonzo Ball      Lonzo      Ball       True

# %%
lamelo_id = active_players_df.loc[active_players_df['full_name'] == 'Lamelo Ball', 'id']
print(lamelo_id)
gamelog_lamelo = playergamelog.PlayerGameLog(player_id = 1630163)
lamelo_games = gamelog_lamelo.get_data_frames()[0]

lamelo_games[['FGM', 'FGA', 'FG3M', 'FG3A', 'PTS']]
# Out:
# Series([], Name: id, dtype: int64)
#     FGM  FGA  FG3M  FG3A  PTS
# 0     2    8     0     4    4
# 1     3   13     2     6    8
# 2     9   13     3     5   22
# 3     4   11     1     5   12
# 4     5   11     1     4   13
# 5     5   16     0     5   12
# 6     4   12     1     4   13
# 7     6   14     2     7   15
# 8     7   10     4     5   22
# 9     2    6     2     3    6
# 10    5   10     2     4   13
# 11    0    5     0     3    0

# %%
game_ids_2020 = gamelogs['GAME_ID'].values

# %%
boxscoresummaryv2.BoxScoreSummaryV2(game_ids_2020[0]).get_data_frames()[5]
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2020-12-22T00:00:00              1  0022000001  1610612744
# 1  2020-12-22T00:00:00              1  0022000001  1610612751
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NICKNAME TEAM_WINS_LOSSES  PTS_QTR1  \
# 0               GSW   Golden State      Warriors              0-1        25
# 1               BKN       Brooklyn          Nets              1-0        40
#
#    PTS_QTR2  PTS_QTR3  PTS_QTR4  PTS_OT1  PTS_OT2  PTS_OT3  PTS_OT4  PTS_OT5  \
# 0        20        26        28        0        0        0        0        0
# 1        23        36        26        0        0        0        0        0
#
#    PTS_OT6  PTS_OT7  PTS_OT8  PTS_OT9  PTS_OT10  PTS
# 0        0        0        0        0         0   99
# 1        0        0        0        0         0  125

# %%
box_score_summaries = []
for game_id in game_ids_2020:
    game_line_score = boxscoresummaryv2.BoxScoreSummaryV2(game_id).get_data_frames()[5]
    box_score_summaries.append(game_line_score)

# %%
season_2020_linescores = pd.concat(box_score_summaries)

# %%
season_2020_linescores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-47db11093fc3> in <module>
# ----> 1 season_2020_linescores
#
# NameError: name 'season_2020_linescores' is not defined

# %%
#leaguedashlineups gives aggregated stats about groups of players (2-5)
lineups_2_man = leaguedashlineups.LeagueDashLineups(group_quantity=2).get_data_frames()[0]

lineups_2_man.sort_values(['FG_PCT'], ascending=False)
# Out:
#      GROUP_SET           GROUP_ID                  GROUP_NAME     TEAM_ID  \
# 1582   Lineups   -201568-1629631-    D. Gallinari - D. Hunter  1610612737
# 1697   Lineups   -201568-1628381-   D. Gallinari - J. Collins  1610612737
# 1799   Lineups  -1626246-1628973-  B. Marjanovic - J. Brunson  1610612742
# 1516   Lineups   -201568-1629629-   D. Gallinari - C. Reddish  1610612737
# 1855   Lineups   -201577-1629726-       R. Lopez - G. Mathews  1610612764
# ...        ...                ...                         ...         ...
# 1944   Lineups  -1628422-1629716-       D. Dotson - M. Bolden  1610612739
# 1911   Lineups  -1630197-1630221-     A. Pokusevski - J. Hall  1610612760
# 1918   Lineups  -1630219-1630233-         S. Mays - N. Knight  1610612737
# 1917   Lineups  -1629164-1630219-        B. Goodwin - S. Mays  1610612737
# 1986   Lineups  -1630177-1630221-        T. Maledon - J. Hall  1610612760
#
#      TEAM_ABBREVIATION  GP  W  L  W_PCT        MIN  FGM  FGA  FG_PCT  FG3M  \
# ...

# %%
# LeagueDashOppPtShot gives shooting statistics of teams opponents 
from nba_api.stats.endpoints import leaguedashoppptshot

league_opp_shooting = leaguedashoppptshot.LeagueDashOppPtShot(per_mode_simple='PerGame').get_data_frames()[0]

league_opp_shooting.sort_values(['FG3A_FREQUENCY'], ascending=False)
# Out:
#        TEAM_ID               TEAM_NAME TEAM_ABBREVIATION  GP   G  \
# 24  1610612740    New Orleans Pelicans               NOP   9   9
# 8   1610612748              Miami Heat               MIA   9   9
# 18  1610612766       Charlotte Hornets               CHA  11  11
# 29  1610612746             LA Clippers               LAC  11  11
# 21  1610612765         Detroit Pistons               DET  10  10
# 25  1610612761         Toronto Raptors               TOR  10  10
# 19  1610612752         New York Knicks               NYK  11  11
# 14  1610612757  Portland Trail Blazers               POR  10  10
# 13  1610612741           Chicago Bulls               CHI  11  11
# 28  1610612742        Dallas Mavericks               DAL   9   9
# 1   1610612758        Sacramento Kings               SAC  11  11
# 26  1610612739     Cleveland Cavaliers               CLE  12  12
# 11  1610612744   Golden State Warriors               GSW  11  11
# ...

# %%
# LeagueDashPlayerClutch gives you player stats from clutch time (last n mins of game)
# You can filter conditions on time or if the team was 'Ahead or Tied' or 'Behind or Tied' or both. 

pd.options.display.max_columns=70

from nba_api.stats.endpoints import leaguedashplayerclutch

player_clutch = leaguedashplayerclutch.LeagueDashPlayerClutch(ahead_behind='Behind or Tied', clutch_time='Last 30 Seconds').get_data_frames()[0]

player_clutch.sort_values(['MIN', 'FG_PCT'], ascending=[False,False])
# Out:
#     GROUP_SET  PLAYER_ID              PLAYER_NAME     TEAM_ID  \
# 105   Players    1628369             Jayson Tatum  1610612738
# 150   Players     203935             Marcus Smart  1610612738
# 104   Players    1627759             Jaylen Brown  1610612738
# 208   Players    1627789  Timothe Luwawu-Cabarrot  1610612751
# 111   Players     203925               Joe Harris  1610612751
# ..        ...        ...                      ...         ...
# 100   Players    1629020        Jarred Vanderbilt  1610612750
# 102   Players    1629633           Jarrett Culver  1610612750
# 91    Players    1627826              Ivica Zubac  1610612746
# 94    Players     203210           JaMychal Green  1610612743
# 212   Players     202684         Tristan Thompson  1610612738
#
#     TEAM_ABBREVIATION   AGE  GP  W  L  W_PCT       MIN  FGM  FGA  FG_PCT  \
# 105               BOS  22.0   5  3  2    0.6  2.311667    2    4    0.50
# ...

# %%
from nba_api.stats.library.parameters import SeasonAllTime, SeasonAll_Time

SeasonAll.all
# Out:
# 'ALL'

# %%
# Who is more clutch, Lebron or Kobe
from nba_api.stats.endpoints import leaguedashplayerclutch

player_clutch_2020 = leaguedashplayerclutch.LeagueDashPlayerClutch(clutch_time='Last 2 Minutes', season='2019-20').get_data_frames()[0]

# %%
player_clutch_2020.sort_values('FG_PCT', ascending=False)

player_clutch_2020[player_clutch_2020['FGA'] > 5].sort_values('FG_PCT', ascending=False)
# Out:
#     GROUP_SET  PLAYER_ID       PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 166   Players     202355  Hassan Whiteside  1610612757               POR
# 193   Players    1628386     Jarrett Allen  1610612751               BKN
# 28    Players    1627732       Ben Simmons  1610612755               PHI
# 376   Players     203552        Seth Curry  1610612742               DAL
# 387   Players     203500      Steven Adams  1610612760               OKC
# ..        ...        ...               ...         ...               ...
# 148   Players     202066    Garrett Temple  1610612751               BKN
# 417   Players     202684  Tristan Thompson  1610612739               CLE
# 225   Players    1629006       Josh Okogie  1610612750               MIN
# 426   Players     203506    Victor Oladipo  1610612754               IND
# 227   Players    1626196   Josh Richardson  1610612755               PHI
#
#       AGE  GP   W   L  W_PCT        MIN  FGM  FGA  FG_PCT  FG3M  ...  \
# ...

# %%
player_clutch.loc[(player_clutch['PLAYER_NAME'] == 'Kobe Bryant') | (player_clutch['PLAYER_NAME'] == 'LeBron James')]
# Out:
#     GROUP_SET  PLAYER_ID   PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 209   Players        977   Kobe Bryant  1610612747               LAL  30.0
# 221   Players       2544  LeBron James  1610612739               CLE  24.0
#
#      GP   W   L  W_PCT        MIN  FGM  FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  \
# 209  29  19  10  0.655  17.196667    7   21   0.333     2    10      0.2   21
# 221  22  16   6  0.727  12.376667    2    7   0.286     0     2      0.0   13
#
#      FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA  PF  PFD  PTS  \
# 209   24   0.875     0     5    5    1    1    0    0     0   2   14   37
# 221   17   0.765     1     6    7    1    2    1    1     0   4    9   17
#
#      PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  GP_RANK  W_RANK  L_RANK  \
# 209          32             43.5    5    1       49      21     257
# 221          20             30.9   12    2      113      40     169
#
# ...

# %%
game_ids_2020[0]
# Out:
# '0022000001'

# %%
from nba_api.stats.endpoints import boxscoremiscv2

boxscore_misc_team = []
for game_id in game_ids_2020:
    team_boxscore_misc = boxscoremiscv2.BoxScoreMiscV2(game_id).get_data_frames()[1]
    boxscore_misc_team.append(team_boxscore_misc)

# %%
boxscoremiscv2.BoxScoreMiscV2(game_id='0022000001').get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022000001  1610612744               GSW  Golden State     203952
# 1   0022000001  1610612744               GSW  Golden State    1629672
# 2   0022000001  1610612744               GSW  Golden State    1630164
# 3   0022000001  1610612744               GSW  Golden State    1626162
# 4   0022000001  1610612744               GSW  Golden State     201939
# 5   0022000001  1610612744               GSW  Golden State    1626172
# 6   0022000001  1610612744               GSW  Golden State     203145
# 7   0022000001  1610612744               GSW  Golden State    1627814
# 8   0022000001  1610612744               GSW  Golden State    1627737
# 9   0022000001  1610612744               GSW  Golden State    1629673
# 10  0022000001  1610612744               GSW  Golden State     202954
# 11  0022000001  1610612744               GSW  Golden State    1629308
# ...

# %%
boxscore_misc_team = pd.concat(boxscore_misc_team)

# %%
cols = boxscore_misc_team.columns[6:].tolist()

# %%
boxscore_misc_team.groupby(['TEAM_NAME'])[cols].mean().sort_values(['PTS_2ND_CHANCE'])
# Out:
#                PTS_OFF_TOV  PTS_2ND_CHANCE     PTS_FB  PTS_PAINT  \
# TEAM_NAME
# Thunder          13.090909        7.909091  11.090909  44.363636
# Rockets          19.333333        9.666667  12.111111  50.888889
# Mavericks        17.200000        9.700000  15.000000  41.600000
# Heat             16.444444        9.888889  12.222222  44.222222
# Cavaliers        21.666667       10.500000  12.083333  51.500000
# Nets             18.846154       10.538462  14.846154  48.769231
# Suns             14.818182       11.454545  10.636364  37.272727
# Hornets          19.333333       11.583333  16.666667  44.500000
# Bulls            16.363636       11.727273  10.545455  45.272727
# Pacers           20.181818       11.909091  16.090909  56.363636
# Spurs            18.363636       12.000000  14.181818  44.727273
# Warriors         17.818182       12.090909  13.636364  41.454545
# Clippers         18.916667       12.166667  10.666667  37.666667
# ...

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
from nba_api.stats.endpoints import boxscorefourfactorsv2
from nba_api.stats.endpoints import boxscoremiscv2
from nba_api.stats.endpoints import boxscoredefensive
from nba_api.stats.endpoints import boxscoresimilarityscore
from nba_api.stats.endpoints import boxscoreusagev2
from nba_api.stats.endpoints import boxscorescoringv2
from nba_api.stats.endpoints import boxscorematchups
from nba_api.stats.endpoints import boxscoretraditionalv2
from nba_api.stats.endpoints import boxscoresummaryv2

period = 0   # All
game_id = game_ids_2020[0]
# Player [0] or Team [1] Stats
# boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=game_id, end_period=period).get_data_frames()[0]

# Player [0] or Team [1] Stats
# boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id=game_id, end_period=period).get_data_frames()[0]

# Player [0] or Team [1] Stats
# boxscoremiscv2.BoxScoreMiscV2(game_id=game_id, end_period=period).get_data_frames()[0]

# Only Player [0] Stats
# boxscoredefensive.BoxScoreDefensive(game_id=game_id).get_data_frames()[0]

# Player Usage Stats
# boxscoreusagev2.BoxScoreUsageV2(game_id=game_id).get_data_frames()[0]

# Player [0] or Team [1] Scoring Stats
# boxscorescoringv2.BoxScoreScoringV2(game_id=game_id).get_data_frames()[1]

# All player matchup combinations stats
# boxscorematchups.BoxScoreMatchups(game_id=game_id).get_data_frames()[0]

# Traditional Player [0] or Team[1] Boxscore Stats
# boxscoretraditionalv2.BoxScoreTraditionalV2(game_id=game_id).get_data_frames()[1]

# [1]: PTS_PAINT, PTS_2ND_CHANCE, PTS_FB etc, [5]: LineScore (pts by quarter)
boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id).get_data_frames()[1]
# Out:
#   LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PTS_PAINT  \
# 0        00  1610612751               BKN      Brooklyn         46
# 1        00  1610612744               GSW  Golden State         44
#
#    PTS_2ND_CHANCE  PTS_FB  LARGEST_LEAD  LEAD_CHANGES  TIMES_TIED  \
# 0              21      28            38             1           1
# 1              21      12             2             1           1
#
#    TEAM_TURNOVERS  TOTAL_TURNOVERS  TEAM_REBOUNDS  PTS_OFF_TO
# 0               0               20              8          19
# 1               0               18             14          23

# %%
# boxscoreplayertrackingv2 

from nba_api.stats.endpoints import boxscoreplayertrackv2



player_box_scores = boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_ids_2020[0]).get_data_frames()[0]
team_box_score_track = boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_ids_2020[0]).get_data_frames()[1]

player_box_scores
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022000001  1610612744               GSW  Golden State     203952
# 1   0022000001  1610612744               GSW  Golden State    1629672
# 2   0022000001  1610612744               GSW  Golden State    1630164
# 3   0022000001  1610612744               GSW  Golden State    1626162
# 4   0022000001  1610612744               GSW  Golden State     201939
# 5   0022000001  1610612744               GSW  Golden State    1626172
# 6   0022000001  1610612744               GSW  Golden State     203145
# 7   0022000001  1610612744               GSW  Golden State    1627814
# 8   0022000001  1610612744               GSW  Golden State    1627737
# 9   0022000001  1610612744               GSW  Golden State    1629673
# 10  0022000001  1610612744               GSW  Golden State     202954
# 11  0022000001  1610612744               GSW  Golden State    1629308
# ...

# %%
player_tracking_box_scores = []
for game_id in game_ids_2020:
    player_tracking_data = boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id).get_data_frames()[0]
    player_tracking_box_scores.append(player_tracking_data)

# %%
player_tracking_2020 = pd.concat(player_tracking_box_scores)

# %%
from matplotlib import pyplot as plt
player_tracking_2020.groupby('PLAYER_NAME')['DIST'].mean().sort_values(ascending=False)[:50].plot.bar(figsize=(20,8))

plt.show()

# %%
# boxscorescoringv2 gives both player and team shooting statistics for a given game.
# Shooting Stats: MR = midrange, FB = fastbreak, UAST = unassisted 

from nba_api.stats.endpoints import boxscorescoringv2 

boxscorescoringv2.BoxScoreScoringV2(game_ids_2020[0]).get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0022000001  1610612744  Warriors               GSW  Golden State  240:00
# 1  0022000001  1610612751      Nets               BKN      Brooklyn  240:00
#
#    PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  \
# 0        0.667        0.333        0.545           0.101        0.303
# 1        0.620        0.380        0.432           0.064        0.360
#
#    PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  \
# 0       0.121       0.152            0.192          0.444        0.630
# 1       0.224       0.208            0.184          0.368        0.481
#
#    PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM
# 0         0.370        0.900         0.100        0.703         0.297
# 1         0.519        0.733         0.267        0.571         0.429

# %%
from nba_api.stats.endpoints import draftcombineplayeranthro

draftcombineplayeranthro.DraftCombinePlayerAnthro(season_year='2020').get_data_frames()[0]
# Out:
#     TEMP_PLAYER_ID  PLAYER_ID FIRST_NAME    LAST_NAME         PLAYER_NAME  \
# 0          1630173    1630173   Precious      Achiuwa    Precious Achiuwa
# 1          1630234    1630234    Ty-Shon    Alexander   Ty-Shon Alexander
# 2          1628962    1628962      Udoka     Azubuike      Udoka Azubuike
# 3          1630189    1630189      Tyler          Bey           Tyler Bey
# 4          1630213    1630213      Yoeli       Childs        Yoeli Childs
# 5          1629603    1629603     Mamadi      Diakite      Mamadi Diakite
# 6          1629653    1629653      Devon       Dotson        Devon Dotson
# 7          1630220    1630220       Paul        Eboua          Paul Eboua
# 8          1629604    1629604         CJ       Elleby           CJ Elleby
# 9          1630235    1630235      Trent      Forrest       Trent Forrest
# 10         1630182    1630182       Josh        Green          Josh Green
# 11         1630204    1630204     Ashton       Hagans       Ashton Hagans
# ...

# %%
from nba_api.stats.endpoints import leaguehustlestatsplayer

leaguehustlestatsplayer.LeagueHustleStatsPlayer(per_mode_time='PerGame').get_data_frames()[0]
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE   G   MIN  \
# 0       203932     Aaron Gordon  1610612753               ORL  25.0  10  27.2
# 1      1628988    Aaron Holiday  1610612754               IND  24.0  11  21.3
# 2      1630174    Aaron Nesmith  1610612738               BOS  21.0   3  13.0
# 3      1627846      Abdel Nader  1610612756               PHX  27.0   1   3.3
# 4      1629690      Adam Mokoka  1610612741               CHI  22.0   5   7.8
# ..         ...              ...         ...               ...   ...  ..   ...
# 457    1627812     Yogi Ferrell  1610612739               CLE  27.0   2  20.3
# 458    1629139    Yuta Watanabe  1610612761               TOR  26.0   5  11.6
# 459     203897      Zach LaVine  1610612741               CHI  25.0  11  35.2
# 460    1630192       Zeke Nnaji  1610612743               DEN  20.0   5   2.2
# 461    1629627  Zion Williamson  1610612740               NOP  20.0   9  31.8
#
# ...

# %%
from nba_api.stats.endpoints import teamgamelogs, teamgamelog
import pandas as pd

# %%
pd.options.display.max_columns=160

# %%
teamgamelog.TeamGameLog(team_id = 1610612755).get_data_frames()[0]
# Out:
#        Team_ID     Game_ID     GAME_DATE      MATCHUP WL   W  L  W_PCT  MIN  \
# 0   1610612755  0022000218  JAN 20, 2021  PHI vs. BOS  W  10  5  0.667  240
# 1   1610612755  0022000193  JAN 16, 2021    PHI @ MEM  L   9  5  0.643  240
# 2   1610612755  0022000174  JAN 14, 2021  PHI vs. MIA  W   9  4  0.692  240
# 3   1610612755  0022000157  JAN 12, 2021  PHI vs. MIA  W   8  4  0.667  265
# 4   1610612755  0022000153  JAN 11, 2021    PHI @ ATL  L   7  4  0.636  240
# 5   1610612755  0022000133  JAN 09, 2021  PHI vs. DEN  L   7  3  0.700  240
# 6   1610612755  0022000118  JAN 07, 2021    PHI @ BKN  L   7  2  0.778  240
# 7   1610612755  0022000109  JAN 06, 2021  PHI vs. WAS  W   7  1  0.875  240
# 8   1610612755  0022000094  JAN 04, 2021  PHI vs. CHA  W   6  1  0.857  240
# 9   1610612755  0022000082  JAN 02, 2021  PHI vs. CHA  W   5  1  0.833  240
# 10  1610612755  0022000064  DEC 31, 2020    PHI @ ORL  W   4  1  0.800  240
# ...

# %%
season = '2020-21'
teamgamelogs.TeamGameLogs().get_data_frames()[0]
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        2016-17  1610612755               PHI     Philadelphia 76ers
# 1        2016-17  1610612744               GSW  Golden State Warriors
# 2        2016-17  1610612737               ATL          Atlanta Hawks
# 3        2016-17  1610612745               HOU        Houston Rockets
# 4        2016-17  1610612760               OKC  Oklahoma City Thunder
# ...          ...         ...               ...                    ...
# 2455     2016-17  1610612762               UTA              Utah Jazz
# 2456     2016-17  1610612744               GSW  Golden State Warriors
# 2457     2016-17  1610612739               CLE    Cleveland Cavaliers
# 2458     2016-17  1610612752               NYK        New York Knicks
# 2459     2016-17  1610612759               SAS      San Antonio Spurs
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  FGA  FG_PCT  \
# ...

# %%
def get_cumulative_stats_matchup(homeTeam, awayTeam, season='2020-21'):
    
    gamelogs = teamgamelogs.TeamGameLogs().get_data_frames()[0]
    
    cols = ['SEASON_YEAR', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
       'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M',
       'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST',
       'TOV', 'STL', 'BLK', 'BLKA', 'PF', 'PFD', 'PTS', 'PLUS_MINUS']
    
    home_gl = gamelogs.loc[gamelogs['TEAM_ABBREVIATION'] == homeTeam, cols]

    away_gl = gamelogs.loc[gamelogs['TEAM_ABBREVIATION'] == awayTeam, cols]
    
    
get_cumulative_stats_matchup
